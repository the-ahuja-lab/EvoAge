# %% [markdown]
# # BiologicalProcess → BiologicalProcess Relation Pipeline
#
# Builds a unified, deduplicated edge table for the **BiologicalProcess–BiologicalProcess** relation
# by ingesting processed files from multiple KG sources, normalising identifiers
# if needed, and writing the final triple table to disk.
#
# **Output schema:** `head | relation | tail | head_type | relation_type | tail_type | kg_source | head_id_is | tail_id_is | head_detail_name | tail_detail_name`
#
# ---
# **Sources included:**
# - Monarch
# - Pheknowlator
# - PrimeKG
# - TAR-KG
# - Crossbar
# - GPKG
#
# **Base paths:**
# - KG data: `/storage/Arushi/090526_EvoAge/kg_formation/`
# - Processed KG files: `/storage/Arushi/090526_EvoAge/kg_formation/processed_data/`

# %% [markdown]
# ## 0 · Imports & Base Paths

# %%
import pandas as pd
import os

# ── Base directories ──────────────────────────────────────────────────────────
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/BIOLOGICALPROCESS_BIOLOGICALPROCESS/ALL_BIOLOGICALPROCESS_BIOLOGICALPROCESS.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

# %% [markdown]
# ## 1 · Load Source Files
#
# Each source DataFrame is loaded, columns lowercased, and `tail_id_is` / `head_id_is`
# set to the appropriate ID namespace (Quick_GO).

# %% [markdown]
# ### 1.1 Monarch

# %%
Monarch_BP_BP = pd.read_csv(PROC_DIR + 'Monarch/Human/Human_BiologicalProcess_BiologicalProcess_Monarch.csv')
Monarch_BP_BP.columns = Monarch_BP_BP.columns.str.lower()

Monarch_BP_BP['tail_id_is'] = 'Quick_GO'
Monarch_BP_BP['head_id_is'] = 'Quick_GO'
Monarch_BP_BP['relation'] = 'BiologicalProcess_BiologicalProcess'
Monarch_BP_BP['head_type'] = 'BiologicalProcess'
Monarch_BP_BP['tail_type'] = 'BiologicalProcess'

Monarch_BP_BP['kg_source'] = 'Monarch_KG'
Monarch_BP_BP['kg_type'] = 'Generalised'
Monarch_BP_BP['species'] = 'Homo sapiens'
print(f"Monarch BP→BP: {len(Monarch_BP_BP):,} rows")
Monarch_BP_BP.head(3)
# Out:
# Monarch BP→BP: 53,115 rows
#          head        tail relation_type relation_source   kgsource  \
# 0  GO:0060524  GO:0003006   subclass_of      infores:go  MonarchKG
# 1  GO:0060524  GO:0060600   subclass_of      infores:go  MonarchKG
# 2  GO:0060524  GO:0060442    related_to      infores:go  MonarchKG
#
#                                            head_name          head_type  \
# 0  dichotomous subdivision of prostate epithelial...  BiologicalProcess
# 1  dichotomous subdivision of prostate epithelial...  BiologicalProcess
# 2  dichotomous subdivision of prostate epithelial...  BiologicalProcess
#
#   head_id_is  head_taxon  head_taxon_label  ... tail_taxon_label  \
# 0   Quick_GO         NaN               NaN  ...              NaN
# 1   Quick_GO         NaN               NaN  ...              NaN
# 2   Quick_GO         NaN               NaN  ...              NaN
#
#   head_taxon_name tail_taxon_name    head_type_clean    tail_type_clean  \
# ...

# %% [markdown]
# ### 1.2 Pheknowlator

# %%
Pheknowlator_BP_BP = pd.read_csv(PROC_DIR + 'pheknowlator/BiologicalProcess_BiologicalProcess.csv')
Pheknowlator_BP_BP.columns = Pheknowlator_BP_BP.columns.str.lower()

Pheknowlator_BP_BP['tail_id_is'] = 'Quick_GO'
Pheknowlator_BP_BP['head_id_is'] = 'Quick_GO'
Pheknowlator_BP_BP['relation'] = 'BiologicalProcess_BiologicalProcess'
Pheknowlator_BP_BP['head_type'] = 'BiologicalProcess'
Pheknowlator_BP_BP['tail_type'] = 'BiologicalProcess'
Pheknowlator_BP_BP['kg_source'] = 'pheknowlator'

Pheknowlator_BP_BP['kg_type'] = 'Generalised'
Pheknowlator_BP_BP['species'] = 'Homo sapiens'
print(f"Pheknowlator BP→BP: {len(Pheknowlator_BP_BP):,} rows")
Pheknowlator_BP_BP.head(3)
# Out:
# Pheknowlator BP→BP: 64,889 rows
#          head                             relation        tail  \
# 0  GO:0035377  BiologicalProcess_BiologicalProcess  GO:0006833
# 1  GO:0036113  BiologicalProcess_BiologicalProcess  GO:0036111
# 2  GO:1904253  BiologicalProcess_BiologicalProcess  GO:0062013
#
#            head_type          tail_type  \
# 0  BiologicalProcess  BiologicalProcess
# 1  BiologicalProcess  BiologicalProcess
# 2  BiologicalProcess  BiologicalProcess
#
#                                     head_detail_name  \
# 0                    transepithelial water transport
# 1   very long-chain fatty-acyl-CoA catabolic process
# 2  positive regulation of bile acid metabolic pro...
#
#                                     tail_detail_name head_id_is tail_id_is  \
# 0                                    water transport   Quick_GO   Quick_GO
# 1   very long-chain fatty-acyl-CoA metabolic process   Quick_GO   Quick_GO
# ...

# %% [markdown]
# ### 1.3 PrimeKG

# %%
PrimeKG_BP_BP = pd.read_csv(PROC_DIR + 'PrimeKG/PrimeKG_BiologicalProcess_BiologicalProcess.csv')
PrimeKG_BP_BP.columns = PrimeKG_BP_BP.columns.str.lower()

PrimeKG_BP_BP['tail_id_is'] = 'Quick_GO'
PrimeKG_BP_BP['head_id_is'] = 'Quick_GO'
PrimeKG_BP_BP['relation'] = 'BiologicalProcess_BiologicalProcess'
PrimeKG_BP_BP['head_type'] = 'BiologicalProcess'
PrimeKG_BP_BP['tail_type'] = 'BiologicalProcess'
PrimeKG_BP_BP['kg_source'] = 'PrimeKG'

PrimeKG_BP_BP['kg_type'] = 'Generalised'
PrimeKG_BP_BP['species'] = 'Homo sapiens'

print(f"PrimeKG BP→BP: {len(PrimeKG_BP_BP):,} rows")
PrimeKG_BP_BP.head(3)
# Out:
# PrimeKG BP→BP: 52,886 rows
#          head                             relation        tail  \
# 0  GO:0051612  BiologicalProcess_BiologicalProcess  GO:0051581
# 1  GO:0051612  BiologicalProcess_BiologicalProcess  GO:0043271
# 2  GO:0051612  BiologicalProcess_BiologicalProcess  GO:0051611
#
#            head_type relation_type          tail_type kg_source head_id_is  \
# 0  BiologicalProcess  parent-child  BiologicalProcess   PrimeKG   Quick_GO
# 1  BiologicalProcess  parent-child  BiologicalProcess   PrimeKG   Quick_GO
# 2  BiologicalProcess  parent-child  BiologicalProcess   PrimeKG   Quick_GO
#
#   tail_id_is                         head_detail_name  \
# 0   Quick_GO  negative regulation of serotonin uptake
# 1   Quick_GO  negative regulation of serotonin uptake
# 2   Quick_GO  negative regulation of serotonin uptake
#
#                                  tail_detail_name      kg_type       species
# 0  negative regulation of neurotransmitter uptake  Generalised  Homo sapiens
# ...

# %% [markdown]
# ### 1.4 TAR-KG

# %%
TARKG_BP_BP = pd.read_csv(PROC_DIR + 'TARKG/BiologicalProcess_BiologicalProcess.csv')
TARKG_BP_BP.columns = TARKG_BP_BP.columns.str.lower()

TARKG_BP_BP['tail_id_is'] = 'Quick_GO'
TARKG_BP_BP['head_id_is'] = 'Quick_GO'
TARKG_BP_BP['relation'] = 'BiologicalProcess_BiologicalProcess'
TARKG_BP_BP['head_type'] = 'BiologicalProcess'
TARKG_BP_BP['tail_type'] = 'BiologicalProcess'
TARKG_BP_BP['kg_source'] = 'TARKG'

TARKG_BP_BP['kg_type'] = 'Generalised'
TARKG_BP_BP['species'] = 'Homo sapiens'
print(f"TARKG BP→BP: {len(TARKG_BP_BP):,} rows")
TARKG_BP_BP.head(3)
# Out:
# TARKG BP→BP: 55,673 rows
#          head                             relation        tail  \
# 0  GO:1901349  BiologicalProcess_BiologicalProcess  GO:0071705
# 1  GO:0015707  BiologicalProcess_BiologicalProcess  GO:0071705
# 2  GO:0015747  BiologicalProcess_BiologicalProcess  GO:0071705
#
#            head_type relation_type          tail_type kg_source  \
# 0  BiologicalProcess          IS_A  BiologicalProcess     TARKG
# 1  BiologicalProcess          IS_A  BiologicalProcess     TARKG
# 2  BiologicalProcess          IS_A  BiologicalProcess     TARKG
#
#           head_detail_name             tail_detail_name head_id_is tail_id_is  \
# 0  glucosinolate transport  nitrogen compound transport   Quick_GO   Quick_GO
# 1        nitrite transport  nitrogen compound transport   Quick_GO   Quick_GO
# 2          urate transport  nitrogen compound transport   Quick_GO   Quick_GO
#
#               kg_index           kg  change      kg_type       species
# ...

# %% [markdown]
# ### 1.5 Crossbar

# %%
Crossbar_BP_BP = pd.read_csv(PROC_DIR + 'crossbar/BiologicalProcess_BiologicalProcess_Crossbar.csv')
Crossbar_BP_BP.columns = Crossbar_BP_BP.columns.str.lower()

Crossbar_BP_BP['tail_id_is'] = 'Quick_GO'
Crossbar_BP_BP['head_id_is'] = 'Quick_GO'
Crossbar_BP_BP['relation'] = 'BiologicalProcess_BiologicalProcess'
Crossbar_BP_BP['head_type'] = 'BiologicalProcess'
Crossbar_BP_BP['tail_type'] = 'BiologicalProcess'
Crossbar_BP_BP['kg_source'] = 'Crossbar'

Crossbar_BP_BP['kg_type'] = 'Generalised'
Crossbar_BP_BP['species'] = 'Homo sapiens'
print(f"Crossbar BP→BP: {len(Crossbar_BP_BP):,} rows")
Crossbar_BP_BP.head(3)
# Out:
# Crossbar BP→BP: 64,906 rows
#          head                             relation        tail  \
# 0  GO:0045218  BiologicalProcess_BiologicalProcess  GO:0034334
# 1  GO:0045219  BiologicalProcess_BiologicalProcess  GO:0010559
# 2  GO:0045219  BiologicalProcess_BiologicalProcess  GO:0045210
#
#            head_type          tail_type kg_source  \
# 0  BiologicalProcess  BiologicalProcess  Crossbar
# 1  BiologicalProcess  BiologicalProcess  Crossbar
# 2  BiologicalProcess  BiologicalProcess  Crossbar
#
#                 head_detail_name  \
# 0    zonula adherens maintenance
# 1  regulation of FasL production
# 2  regulation of FasL production
#
#                                   tail_detail_name head_id_is tail_id_is  \
# 0                    adherens junction maintenance   Quick_GO   Quick_GO
# 1  regulation of glycoprotein biosynthetic process   Quick_GO   Quick_GO
# 2                        FasL biosynthetic process   Quick_GO   Quick_GO
#
#        kg_type       species
# ...

# %% [markdown]
# ### 1.6 GPKG

# %%
GPKG_BP_BP = pd.read_csv(PROC_DIR + 'GPKG/BiologicalProcess_BiologicalProcess_GPKG.csv')
GPKG_BP_BP.columns = GPKG_BP_BP.columns.str.lower()

GPKG_BP_BP['tail_id_is'] = 'Quick_GO'
GPKG_BP_BP['head_id_is'] = 'Quick_GO'
GPKG_BP_BP['relation'] = 'BiologicalProcess_BiologicalProcess'
GPKG_BP_BP['head_type'] = 'BiologicalProcess'
GPKG_BP_BP['tail_type'] = 'BiologicalProcess'
GPKG_BP_BP['kg_source'] = 'GPKG'

GPKG_BP_BP['kg_type'] = 'Generalised'
GPKG_BP_BP['species'] = 'Homo sapiens'
print(f"GPKG BP→BP: {len(GPKG_BP_BP):,} rows")
GPKG_BP_BP.head(3)
# Out:
# GPKG BP→BP: 33,102 rows
#          head                             relation        tail  \
# 0  GO:0014842  BiologicalProcess_BiologicalProcess  GO:0014857
# 1  GO:0014842  BiologicalProcess_BiologicalProcess  GO:0014843
# 2  GO:0006816  BiologicalProcess_BiologicalProcess  GO:0070296
#
#            head_type relation_type          tail_type kg_source  \
# 0  BiologicalProcess     resembles  BiologicalProcess      GPKG
# 1  BiologicalProcess     resembles  BiologicalProcess      GPKG
# 2  BiologicalProcess     resembles  BiologicalProcess      GPKG
#
#                                     head_detail_name head_id_is  \
# 0  regulation of skeletal muscle satellite cell p...   Quick_GO
# 1  regulation of skeletal muscle satellite cell p...   Quick_GO
# 2                              calcium ion transport   Quick_GO
#
#                                     tail_detail_name tail_id_is      kg_type  \
# 0   regulation of skeletal muscle cell proliferation   Quick_GO  Generalised
# ...

# %% [markdown]
# ### 1.7 Aging data

# %%
Aging_literature_BP_BP = pd.read_csv(PROC_DIR + 'agextend_processed/Aging_Hallmarks_BiologicalProcess_BiologicalProcess_Manullly.csv')
Aging_literature_BP_BP.columns = Aging_literature_BP_BP.columns.str.lower()
Aging_literature_BP_BP['kg_source'] = 'Literature'
Aging_literature_BP_BP['kg_type'] = 'Aging'
Aging_literature_BP_BP['species'] = 'Homo sapiens'
Aging_literature_BP_BP
# Out:
#           head                             relation        tail  \
# 0   GO:1111111  BiologicalProcess_BiologicalProcess  GO:0006281
# 1   GO:1111111  BiologicalProcess_BiologicalProcess  GO:0006302
# 2   GO:1111111  BiologicalProcess_BiologicalProcess  GO:0006298
# 3   GO:1111111  BiologicalProcess_BiologicalProcess  GO:0006284
# 4   GO:1111111  BiologicalProcess_BiologicalProcess  GO:0006289
# ..         ...                                  ...         ...
# 89  GO:1111115  BiologicalProcess_BiologicalProcess  GO:0007568
# 90  GO:1111116  BiologicalProcess_BiologicalProcess  GO:0007568
# 91  GO:0090398  BiologicalProcess_BiologicalProcess  GO:0007568
# 92  GO:1111117  BiologicalProcess_BiologicalProcess  GO:0007568
# 93  GO:1111118  BiologicalProcess_BiologicalProcess  GO:0007568
#
#             head_type          tail_type head_id_is tail_id_is  \
# 0   BiologicalProcess  BiologicalProcess   Quick_GO   Quick_GO
# 1   BiologicalProcess  BiologicalProcess   Quick_GO   Quick_GO
# ...

# %% [markdown]
# ## 2 · Consolidate into Unified Schema
#
# All source DataFrames are aligned to `REQUIRED_COLS` (missing columns filled with `pd.NA`),
# then concatenated into `final_df`.

# %%
source_dfs = [
    Monarch_BP_BP,
    Pheknowlator_BP_BP,
    PrimeKG_BP_BP,
    TARKG_BP_BP,
    Crossbar_BP_BP,
    GPKG_BP_BP,
    Aging_literature_BP_BP
]

aligned = []
for df in source_dfs:
    df = df.copy()
    # Drop any duplicated columns that might have resulted from original CSVs
    df = df.loc[:, ~df.columns.duplicated()]
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
final_df = final_df.dropna(subset=['head_detail_name', 'tail_detail_name']).reset_index(drop=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 271,550
#               head                             relation        tail  \
# 0       GO:0035377  BiologicalProcess_BiologicalProcess  GO:0006833
# 1       GO:0036113  BiologicalProcess_BiologicalProcess  GO:0036111
# 2       GO:1904253  BiologicalProcess_BiologicalProcess  GO:0062013
# 3       GO:1902565  BiologicalProcess_BiologicalProcess  GO:1902563
# 4       GO:1900912  BiologicalProcess_BiologicalProcess  GO:1900911
# ...            ...                                  ...         ...
# 271545  GO:1111115  BiologicalProcess_BiologicalProcess  GO:0007568
# 271546  GO:1111116  BiologicalProcess_BiologicalProcess  GO:0007568
# 271547  GO:0090398  BiologicalProcess_BiologicalProcess  GO:0007568
# 271548  GO:1111117  BiologicalProcess_BiologicalProcess  GO:0007568
# 271549  GO:1111118  BiologicalProcess_BiologicalProcess  GO:0007568
#
#                 head_type relation_type          tail_type     kg_source  \
# ...

# %% [markdown]
# ## 3 · Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'BiologicalProcess_BiologicalProcess'}
# head_type           : {'BiologicalProcess'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {'resembles', 'parent-child', None, 'IS_A', 'PART_OF'}
# kg_source           : {'Crossbar', 'pheknowlator', 'GPKG', 'PrimeKG', 'TARKG', 'Literature'}
# head_id_is          : {'Quick_GO'}
# tail_id_is          : {'Quick_GO'}

# %% [markdown]
# ## 4 · NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type        129889                   0          129889
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %% [markdown]
# ## 5 · Deduplication
#
# Group on `(head, relation, tail)`. For `kg_source`, merge all unique sources with `::` delimiter.
# All other metadata columns take the first non-null value.

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'kg_type': 'first',
    'species': 'first'
    
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 271,550  |  After dedup: 113,292
#          head                             relation        tail  \
# 0  GO:0000001  BiologicalProcess_BiologicalProcess  GO:0048308
# 1  GO:0000001  BiologicalProcess_BiologicalProcess  GO:0048311
# 2  GO:0000002  BiologicalProcess_BiologicalProcess  GO:0000002
#
#            head_type relation_type          tail_type  \
# 0  BiologicalProcess  parent-child  BiologicalProcess
# 1  BiologicalProcess  parent-child  BiologicalProcess
# 2  BiologicalProcess          None  BiologicalProcess
#
#                                 kg_source head_id_is tail_id_is  \
# 0  Crossbar::PrimeKG::TARKG::pheknowlator   Quick_GO   Quick_GO
# 1  Crossbar::PrimeKG::TARKG::pheknowlator   Quick_GO   Quick_GO
# 2                            pheknowlator   Quick_GO   Quick_GO
#
#                    head_detail_name                  tail_detail_name  \
# 0         mitochondrion inheritance             organelle inheritance
# ...

# %% [markdown]
# ## 6 · Post-dedup NaN Audit & Source Distribution

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

display(pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
}))

print("\nkg_source values present:", set(final_df_dedup['kg_source']), set(final_df_dedup['kg_type']))
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type         22049                   0           22049
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0
# ...

# %% [markdown]
# ## 7 · Save Output

# %%
import os
os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 113,292 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/BIOLOGICALPROCESS_BIOLOGICALPROCESS/ALL_BIOLOGICALPROCESS_BIOLOGICALPROCESS.csv
