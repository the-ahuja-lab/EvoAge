# %%
import os
import pandas as pd
import numpy as np

BASE_DIR   = '/storage/Arushi/090526_EvoAge/kg_formation/'
PROC_DIR   = BASE_DIR + 'processed_data/'
DB_DIR     = BASE_DIR + 'data_collection/databases_for_mapping/'

OUT_PATH   = BASE_DIR + 'processed_data_relation_wise_merge/generalised/PMID_DISEASE/ALL_PMID_DISEASE.parquet'

REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

# %% [markdown]
# ## 2. Load KG Sources

# %% [markdown]
# #### CKG

# %%
CKG = pd.read_csv(PROC_DIR + 'CKG/File_16_PMID_Disease_CKG.csv')
CKG
# Out:
# /tmp/ipykernel_3058171/756830279.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   CKG = pd.read_csv(PROC_DIR + 'CKG/File_16_PMID_Disease_CKG.csv')
#                     Head                  Relation          Tail Head_type  \
# 0          PMID:20300260  MENTIONED_IN_PUBLICATION  DOID:0001816      PMID
# 1          PMID:19675708  MENTIONED_IN_PUBLICATION  DOID:0001816      PMID
# 2          PMID:19139624  MENTIONED_IN_PUBLICATION  DOID:0001816      PMID
# 3          PMID:19935795  MENTIONED_IN_PUBLICATION  DOID:0001816      PMID
# 4          PMID:20339539  MENTIONED_IN_PUBLICATION  DOID:0001816      PMID
# ...                  ...                       ...           ...       ...
# 192843418  PMID:33960521  MENTIONED_IN_PUBLICATION     DOID:9997      PMID
# 192843419  PMID:33893006  MENTIONED_IN_PUBLICATION     DOID:9997      PMID
# 192843420   PMID:8969606  MENTIONED_IN_PUBLICATION     DOID:9997      PMID
# 192843421   PMID:8502901  MENTIONED_IN_PUBLICATION     DOID:9997      PMID
# 192843422    PMID:139328  MENTIONED_IN_PUBLICATION     DOID:9997      PMID
#
#           Tail_type KG_Source               Tail_DO_name  \
# 0           Disease       CKG               angiosarcoma
# 1           Disease       CKG               angiosarcoma
# 2           Disease       CKG               angiosarcoma
# 3           Disease       CKG               angiosarcoma
# 4           Disease       CKG               angiosarcoma
# ...             ...       ...                        ...
# 192843418   Disease       CKG  peripartum cardiomyopathy
# 192843419   Disease       CKG  peripartum cardiomyopathy
# 192843420   Disease       CKG  peripartum cardiomyopathy
# 192843421   Disease       CKG  peripartum cardiomyopathy
# 192843422   Disease       CKG  peripartum cardiomyopathy
#
#                                              Tail_DO_Alt_ids Head_ID_IS  \
# 0          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# 1          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# 2          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# 3          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# 4          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# ...                                                      ...        ...
# 192843418  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
# 192843419  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
# 192843420  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
# 192843421  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
# 192843422  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
#
#                 Tail_ID_IS
# 0          DiseaseOntology
# 1          DiseaseOntology
# 2          DiseaseOntology
# 3          DiseaseOntology
# 4          DiseaseOntology
# ...                    ...
# 192843418  DiseaseOntology
# 192843419  DiseaseOntology
# 192843420  DiseaseOntology
# 192843421  DiseaseOntology
# 192843422  DiseaseOntology
#
# [192843423 rows x 10 columns]

# %%
CKG.columns = CKG.columns.str.lower()
CKG.rename(columns={'tail_do_name': 'tail_detail_name'}, inplace=True)
CKG['relation'] = 'PMID_Disease'
CKG['tail_type'] = 'Disease'
CKG['kg_type'] = 'Generalised'
CKG['kg_source'] = 'CKG'
CKG['species'] = 'Homo species'
CKG
# Out:
#                     head      relation          tail head_type tail_type  \
# 0          PMID:20300260  PMID_Disease  DOID:0001816      PMID   Disease
# 1          PMID:19675708  PMID_Disease  DOID:0001816      PMID   Disease
# 2          PMID:19139624  PMID_Disease  DOID:0001816      PMID   Disease
# 3          PMID:19935795  PMID_Disease  DOID:0001816      PMID   Disease
# 4          PMID:20339539  PMID_Disease  DOID:0001816      PMID   Disease
# ...                  ...           ...           ...       ...       ...
# 192843418  PMID:33960521  PMID_Disease     DOID:9997      PMID   Disease
# 192843419  PMID:33893006  PMID_Disease     DOID:9997      PMID   Disease
# 192843420   PMID:8969606  PMID_Disease     DOID:9997      PMID   Disease
# 192843421   PMID:8502901  PMID_Disease     DOID:9997      PMID   Disease
# 192843422    PMID:139328  PMID_Disease     DOID:9997      PMID   Disease
#
#           kg_source           tail_detail_name  \
# 0               CKG               angiosarcoma
# 1               CKG               angiosarcoma
# 2               CKG               angiosarcoma
# 3               CKG               angiosarcoma
# 4               CKG               angiosarcoma
# ...             ...                        ...
# 192843418       CKG  peripartum cardiomyopathy
# 192843419       CKG  peripartum cardiomyopathy
# 192843420       CKG  peripartum cardiomyopathy
# 192843421       CKG  peripartum cardiomyopathy
# 192843422       CKG  peripartum cardiomyopathy
#
#                                              tail_do_alt_ids head_id_is  \
# 0          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# 1          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# 2          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# 3          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# 4          ICDO:9120/3|MESH:D006394|NCI:C3088|NCI:C9275|S...   PubmedID
# ...                                                      ...        ...
# 192843418  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
# 192843419  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
# 192843420  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
# 192843421  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
# 192843422  GARD:220|ICD10CM:O90.3|ICD9CM:674.5|NCI:C17160...   PubmedID
#
#                 tail_id_is      kg_type       species
# 0          DiseaseOntology  Generalised  Homo species
# 1          DiseaseOntology  Generalised  Homo species
# 2          DiseaseOntology  Generalised  Homo species
# 3          DiseaseOntology  Generalised  Homo species
# 4          DiseaseOntology  Generalised  Homo species
# ...                    ...          ...           ...
# 192843418  DiseaseOntology  Generalised  Homo species
# 192843419  DiseaseOntology  Generalised  Homo species
# 192843420  DiseaseOntology  Generalised  Homo species
# 192843421  DiseaseOntology  Generalised  Homo species
# 192843422  DiseaseOntology  Generalised  Homo species
#
# [192843423 rows x 12 columns]

# %%
SOURCE_DFS = [
              ('CKG', CKG)
             ]
for name, df in SOURCE_DFS:
    dupes = df.columns[df.columns.duplicated(keep=False)].unique().tolist()
    print(f"[{name}] {'duplicate columns: ' + str(dupes) if dupes else '✓ no duplicates'}")
# Out:
# [CKG] ✓ no duplicates

# %%
CONCAT_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name','kg_type', 'species'
]

df_list = []
for name, df in SOURCE_DFS:
    tmp = df.loc[:, ~df.columns.duplicated()].copy()
    for col in CONCAT_COLS:
        if col not in tmp.columns:
            tmp[col] = pd.NA
    df_list.append(tmp[CONCAT_COLS])

final_df = pd.concat(df_list, ignore_index=True)
print(f"Combined: {len(final_df):,} rows")
final_df
# Out:
# Combined: 192,843,423 rows
#                     head      relation          tail head_type relation_type  \
# 0          PMID:20300260  PMID_Disease  DOID:0001816      PMID          <NA>
# 1          PMID:19675708  PMID_Disease  DOID:0001816      PMID          <NA>
# 2          PMID:19139624  PMID_Disease  DOID:0001816      PMID          <NA>
# 3          PMID:19935795  PMID_Disease  DOID:0001816      PMID          <NA>
# 4          PMID:20339539  PMID_Disease  DOID:0001816      PMID          <NA>
# ...                  ...           ...           ...       ...           ...
# 192843418  PMID:33960521  PMID_Disease     DOID:9997      PMID          <NA>
# 192843419  PMID:33893006  PMID_Disease     DOID:9997      PMID          <NA>
# 192843420   PMID:8969606  PMID_Disease     DOID:9997      PMID          <NA>
# 192843421   PMID:8502901  PMID_Disease     DOID:9997      PMID          <NA>
# 192843422    PMID:139328  PMID_Disease     DOID:9997      PMID          <NA>
#
#           tail_type kg_source head_id_is       tail_id_is head_detail_name  \
# 0           Disease       CKG   PubmedID  DiseaseOntology             <NA>
# 1           Disease       CKG   PubmedID  DiseaseOntology             <NA>
# 2           Disease       CKG   PubmedID  DiseaseOntology             <NA>
# 3           Disease       CKG   PubmedID  DiseaseOntology             <NA>
# 4           Disease       CKG   PubmedID  DiseaseOntology             <NA>
# ...             ...       ...        ...              ...              ...
# 192843418   Disease       CKG   PubmedID  DiseaseOntology             <NA>
# 192843419   Disease       CKG   PubmedID  DiseaseOntology             <NA>
# 192843420   Disease       CKG   PubmedID  DiseaseOntology             <NA>
# 192843421   Disease       CKG   PubmedID  DiseaseOntology             <NA>
# 192843422   Disease       CKG   PubmedID  DiseaseOntology             <NA>
#
#                     tail_detail_name      kg_type       species
# 0                       angiosarcoma  Generalised  Homo species
# 1                       angiosarcoma  Generalised  Homo species
# 2                       angiosarcoma  Generalised  Homo species
# 3                       angiosarcoma  Generalised  Homo species
# 4                       angiosarcoma  Generalised  Homo species
# ...                              ...          ...           ...
# 192843418  peripartum cardiomyopathy  Generalised  Homo species
# 192843419  peripartum cardiomyopathy  Generalised  Homo species
# 192843420  peripartum cardiomyopathy  Generalised  Homo species
# 192843421  peripartum cardiomyopathy  Generalised  Homo species
# 192843422  peripartum cardiomyopathy  Generalised  Homo species
#
# [192843423 rows x 13 columns]

# %%
final_df['tail_id_is'] = 'DOID'
final_df = final_df[~final_df['tail_detail_name'].isna()]
final_df
# Out:
#                     head      relation          tail head_type relation_type  \
# 0          PMID:20300260  PMID_Disease  DOID:0001816      PMID          <NA>
# 1          PMID:19675708  PMID_Disease  DOID:0001816      PMID          <NA>
# 2          PMID:19139624  PMID_Disease  DOID:0001816      PMID          <NA>
# 3          PMID:19935795  PMID_Disease  DOID:0001816      PMID          <NA>
# 4          PMID:20339539  PMID_Disease  DOID:0001816      PMID          <NA>
# ...                  ...           ...           ...       ...           ...
# 192843418  PMID:33960521  PMID_Disease     DOID:9997      PMID          <NA>
# 192843419  PMID:33893006  PMID_Disease     DOID:9997      PMID          <NA>
# 192843420   PMID:8969606  PMID_Disease     DOID:9997      PMID          <NA>
# 192843421   PMID:8502901  PMID_Disease     DOID:9997      PMID          <NA>
# 192843422    PMID:139328  PMID_Disease     DOID:9997      PMID          <NA>
#
#           tail_type kg_source head_id_is tail_id_is head_detail_name  \
# 0           Disease       CKG   PubmedID       DOID             <NA>
# 1           Disease       CKG   PubmedID       DOID             <NA>
# 2           Disease       CKG   PubmedID       DOID             <NA>
# 3           Disease       CKG   PubmedID       DOID             <NA>
# 4           Disease       CKG   PubmedID       DOID             <NA>
# ...             ...       ...        ...        ...              ...
# 192843418   Disease       CKG   PubmedID       DOID             <NA>
# 192843419   Disease       CKG   PubmedID       DOID             <NA>
# 192843420   Disease       CKG   PubmedID       DOID             <NA>
# 192843421   Disease       CKG   PubmedID       DOID             <NA>
# 192843422   Disease       CKG   PubmedID       DOID             <NA>
#
#                     tail_detail_name      kg_type       species
# 0                       angiosarcoma  Generalised  Homo species
# 1                       angiosarcoma  Generalised  Homo species
# 2                       angiosarcoma  Generalised  Homo species
# 3                       angiosarcoma  Generalised  Homo species
# 4                       angiosarcoma  Generalised  Homo species
# ...                              ...          ...           ...
# 192843418  peripartum cardiomyopathy  Generalised  Homo species
# 192843419  peripartum cardiomyopathy  Generalised  Homo species
# 192843420  peripartum cardiomyopathy  Generalised  Homo species
# 192843421  peripartum cardiomyopathy  Generalised  Homo species
# 192843422  peripartum cardiomyopathy  Generalised  Homo species
#
# [192843423 rows x 13 columns]

# %%
import pandas as pd
import numpy as np

# Vectorized hash using numpy — avoids Python string ops entirely
keys = (
    pd.util.hash_array(final_df['head'].to_numpy()) ^
    pd.util.hash_array(final_df['relation'].to_numpy()) * 2654435761 ^
    pd.util.hash_array(final_df['tail'].to_numpy()) * 40503
)

# Keep first occurrence of each hash
mask = ~pd.Series(keys).duplicated(keep='first').to_numpy()
final_df = final_df.iloc[mask].reset_index(drop=True)

print(f"After dedup: {len(final_df):,} rows")
final_df
# Out:
# After dedup: 192,843,423 rows
#                     head      relation          tail head_type relation_type  \
# 0          PMID:20300260  PMID_Disease  DOID:0001816      PMID          <NA>
# 1          PMID:19675708  PMID_Disease  DOID:0001816      PMID          <NA>
# 2          PMID:19139624  PMID_Disease  DOID:0001816      PMID          <NA>
# 3          PMID:19935795  PMID_Disease  DOID:0001816      PMID          <NA>
# 4          PMID:20339539  PMID_Disease  DOID:0001816      PMID          <NA>
# ...                  ...           ...           ...       ...           ...
# 192843418  PMID:33960521  PMID_Disease     DOID:9997      PMID          <NA>
# 192843419  PMID:33893006  PMID_Disease     DOID:9997      PMID          <NA>
# 192843420   PMID:8969606  PMID_Disease     DOID:9997      PMID          <NA>
# 192843421   PMID:8502901  PMID_Disease     DOID:9997      PMID          <NA>
# 192843422    PMID:139328  PMID_Disease     DOID:9997      PMID          <NA>
#
#           tail_type kg_source head_id_is tail_id_is head_detail_name  \
# 0           Disease       CKG   PubmedID       DOID             <NA>
# 1           Disease       CKG   PubmedID       DOID             <NA>
# 2           Disease       CKG   PubmedID       DOID             <NA>
# 3           Disease       CKG   PubmedID       DOID             <NA>
# 4           Disease       CKG   PubmedID       DOID             <NA>
# ...             ...       ...        ...        ...              ...
# 192843418   Disease       CKG   PubmedID       DOID             <NA>
# 192843419   Disease       CKG   PubmedID       DOID             <NA>
# 192843420   Disease       CKG   PubmedID       DOID             <NA>
# 192843421   Disease       CKG   PubmedID       DOID             <NA>
# 192843422   Disease       CKG   PubmedID       DOID             <NA>
#
#                     tail_detail_name      kg_type       species
# 0                       angiosarcoma  Generalised  Homo species
# 1                       angiosarcoma  Generalised  Homo species
# 2                       angiosarcoma  Generalised  Homo species
# 3                       angiosarcoma  Generalised  Homo species
# 4                       angiosarcoma  Generalised  Homo species
# ...                              ...          ...           ...
# 192843418  peripartum cardiomyopathy  Generalised  Homo species
# 192843419  peripartum cardiomyopathy  Generalised  Homo species
# 192843420  peripartum cardiomyopathy  Generalised  Homo species
# 192843421  peripartum cardiomyopathy  Generalised  Homo species
# 192843422  peripartum cardiomyopathy  Generalised  Homo species
#
# [192843423 rows x 13 columns]

# %%
os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)
final_df.to_parquet(OUT_PATH, index=False)
print(f"Saved {len(final_df):,} rows → {OUT_PATH}")
# Out:
# Saved 192,843,423 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/PMID_CELLULARCOMPONENT/ALL_PMID_CELLULARCOMPONENT.parquet

# %%
#
