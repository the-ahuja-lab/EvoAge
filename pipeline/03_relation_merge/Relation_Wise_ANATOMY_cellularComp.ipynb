# %% [markdown]
# # ANATOMY ↔ GENE Relation-Wise Merge
#
# Merges ANATOMY–GENE triples from multiple KG sources (DRKG, PrimeKG, Hetionet, TARKG),
# aligns to a common schema, deduplicates by `(head, relation, tail)`, and saves the result.

# %% [markdown]
# ## 0. Configuration

# %%
import os
import pandas as pd
import numpy as np

# ── Base directories ──────────────────────────────────────────────────────────
BASE_DIR  = '/storage/Arushi/090526_EvoAge/kg_formation/'
PROC_DIR  = BASE_DIR + 'processed_data/'
PROC_DIR  = BASE_DIR + 'processed_data/'


# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH  = BASE_DIR + 'processed_data_relation_wise_merge/generalised/ANATOMY_CELLCOMP/ALL_ANATOMY_CELLCOMP.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

# %% [markdown]
# ## 1. Build Lookup Dictionaries

# %%
UBERON = pd.read_csv(f'{BASE_DIR}data_collection/databases_for_mapping/uberon/Uberon_ID_Name_non_dup.csv')
UBERON_dict = dict(zip(UBERON['UBERON ID'], UBERON['Name']))
# UBERON_dict

# %%
# MESH mapping to map tail (GO_ID) to name
go_db = pd.read_csv(f'{BASE_DIR}data_collection/databases_for_mapping/MESH/MESH_GO_ID_NAME.csv')
GO_dict = dict(zip(go_db['id'], go_db['name']))
del go_db

# %% [markdown]
# ## 2. Load Individual KG Sources

# %% [markdown]
# ### 2a. Monarch

# %%
Monarch_Anatomy_cellularComp = pd.read_csv(f'{BASE_DIR}processed_data/Monarch/Human/Human_AnatomicalEntity_CellularComponent_Monarch.csv')
Monarch_Anatomy_cellularComp.columns = Monarch_Anatomy_cellularComp.columns.str.lower()
Monarch_Anatomy_cellularComp['head_detail_name'] = Monarch_Anatomy_cellularComp['head'].map(UBERON_dict)
Monarch_Anatomy_cellularComp['tail_detail_name'] = Monarch_Anatomy_cellularComp['tail'].map(GO_dict)

print(f"DRKG:     {len(Monarch_Anatomy_cellularComp):,} rows | columns: {list(Monarch_Anatomy_cellularComp.columns)}")
Monarch_Anatomy_cellularComp['kg_type'] = 'Generalised'
Monarch_Anatomy_cellularComp['species'] = 'Homo sapiens'
Monarch_Anatomy_cellularComp['kg_source'] = 'Monarch_KG'

Monarch_Anatomy_cellularComp
# Out:
# DRKG:     71 rows | columns: ['head', 'tail', 'relation_type', 'relation_source', 'kgsource', 'head_name', 'head_type', 'head_id_is', 'head_taxon', 'head_taxon_label', 'tail_name', 'tail_type', 'tail_id_is', 'tail_taxon', 'tail_taxon_label', 'head_taxon_name', 'tail_taxon_name', 'head_type_clean', 'tail_type_clean', 'relation', 'species_species', 'head_detail_name', 'tail_detail_name']
#               head        tail relation_type relation_source   kgsource  \
# 0   UBERON:0000022  GO:0045095    related_to  infores:uberon  MonarchKG
# 1   UBERON:0000054  GO:0070451    related_to  infores:uberon  MonarchKG
# 2   UBERON:0000121  GO:0005581    related_to  infores:uberon  MonarchKG
# 3   UBERON:0000122  GO:0043005    related_to  infores:uberon  MonarchKG
# 4   UBERON:0000123  GO:0043209    related_to  infores:uberon  MonarchKG
# ..             ...         ...           ...             ...        ...
# 66  UBERON:0018687  GO:0005604    related_to  infores:uberon  MonarchKG
# 67  UBERON:0022317  GO:0030425    related_to  infores:uberon  MonarchKG
# 68  UBERON:0022318  GO:0043025    related_to  infores:uberon  MonarchKG
# 69  UBERON:4000020  GO:0031012   subclass_of  infores:uberon  MonarchKG
# 70  UBERON:4000059  GO:0031012   subclass_of  infores:uberon  MonarchKG
#
#                            head_name         head_type head_id_is  head_taxon  \
# 0                            feather  AnatomicalEntity     UBERON         NaN
# 1                             macula  AnatomicalEntity     UBERON         NaN
# 2                        perineurium  AnatomicalEntity     UBERON         NaN
# 3           neuron projection bundle  AnatomicalEntity     UBERON         NaN
# 4                        endoneurium  AnatomicalEntity     UBERON         NaN
# ..                               ...               ...        ...         ...
# 66           glial limiting membrane  AnatomicalEntity     UBERON         NaN
# 67          olfactory cortex layer 1  AnatomicalEntity     UBERON         NaN
# 68          olfactory cortex layer 2  AnatomicalEntity     UBERON         NaN
# 69  mineralized extracellular matrix  AnatomicalEntity     UBERON         NaN
# 70         avascular GAG-rich matrix  AnatomicalEntity     UBERON         NaN
#
#     head_taxon_label  ... tail_taxon_name   head_type_clean  \
# 0                NaN  ...             NaN  AnatomicalEntity
# 1                NaN  ...             NaN  AnatomicalEntity
# 2                NaN  ...             NaN  AnatomicalEntity
# 3                NaN  ...             NaN  AnatomicalEntity
# 4                NaN  ...             NaN  AnatomicalEntity
# ..               ...  ...             ...               ...
# 66               NaN  ...             NaN  AnatomicalEntity
# 67               NaN  ...             NaN  AnatomicalEntity
# 68               NaN  ...             NaN  AnatomicalEntity
# 69               NaN  ...             NaN  AnatomicalEntity
# 70               NaN  ...             NaN  AnatomicalEntity
#
#       tail_type_clean                            relation  species_species  \
# 0   CellularComponent  AnatomicalEntity_CellularComponent              NaN
# 1   CellularComponent  AnatomicalEntity_CellularComponent              NaN
# 2   CellularComponent  AnatomicalEntity_CellularComponent              NaN
# 3   CellularComponent  AnatomicalEntity_CellularComponent              NaN
# 4   CellularComponent  AnatomicalEntity_CellularComponent              NaN
# ..                ...                                 ...              ...
# 66  CellularComponent  AnatomicalEntity_CellularComponent              NaN
# 67  CellularComponent  AnatomicalEntity_CellularComponent              NaN
# 68  CellularComponent  AnatomicalEntity_CellularComponent              NaN
# 69  CellularComponent  AnatomicalEntity_CellularComponent              NaN
# 70  CellularComponent  AnatomicalEntity_CellularComponent              NaN
#
#                     head_detail_name      tail_detail_name      kg_type  \
# 0                            feather      keratin filament  Generalised
# 1                             macula             cell hair  Generalised
# 2                        perineurium       collagen trimer  Generalised
# 3           neuron projection bundle     neuron projection  Generalised
# 4                        endoneurium         myelin sheath  Generalised
# ..                               ...                   ...          ...
# 66           glial limiting membrane     basement membrane  Generalised
# 67          olfactory cortex layer 1              dendrite  Generalised
# 68          olfactory cortex layer 2    neuronal cell body  Generalised
# 69  mineralized extracellular matrix  extracellular matrix  Generalised
# 70         avascular GAG-rich matrix  extracellular matrix  Generalised
#
#          species   kg_source
# 0   Homo sapiens  Monarch_KG
# 1   Homo sapiens  Monarch_KG
# 2   Homo sapiens  Monarch_KG
# 3   Homo sapiens  Monarch_KG
# 4   Homo sapiens  Monarch_KG
# ..           ...         ...
# 66  Homo sapiens  Monarch_KG
# 67  Homo sapiens  Monarch_KG
# 68  Homo sapiens  Monarch_KG
# 69  Homo sapiens  Monarch_KG
# 70  Homo sapiens  Monarch_KG
#
# [71 rows x 26 columns]

# %%
Monarch_Anatomy_cellularComp[Monarch_Anatomy_cellularComp['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, tail, relation_type, relation_source, kgsource, head_name, head_type, head_id_is, head_taxon, head_taxon_label, tail_name, tail_type, tail_id_is, tail_taxon, tail_taxon_label, head_taxon_name, tail_taxon_name, head_type_clean, tail_type_clean, relation, species_species, head_detail_name, tail_detail_name, kg_type, species, kg_source]
# Index: []
#
# [0 rows x 26 columns]

# %%
Monarch_Anatomy_cellularComp[Monarch_Anatomy_cellularComp['tail_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, tail, relation_type, relation_source, kgsource, head_name, head_type, head_id_is, head_taxon, head_taxon_label, tail_name, tail_type, tail_id_is, tail_taxon, tail_taxon_label, head_taxon_name, tail_taxon_name, head_type_clean, tail_type_clean, relation, species_species, head_detail_name, tail_detail_name, kg_type, species, kg_source]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## 3. Align Schemas and Concatenate

# %%
source_dfs = [
    Monarch_Anatomy_cellularComp,
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df['species'] = 'Homo sapiens'
final_df
# Out:
# Consolidated rows: 71
#               head                            relation        tail  \
# 0   UBERON:0000022  AnatomicalEntity_CellularComponent  GO:0045095
# 1   UBERON:0000054  AnatomicalEntity_CellularComponent  GO:0070451
# 2   UBERON:0000121  AnatomicalEntity_CellularComponent  GO:0005581
# 3   UBERON:0000122  AnatomicalEntity_CellularComponent  GO:0043005
# 4   UBERON:0000123  AnatomicalEntity_CellularComponent  GO:0043209
# ..             ...                                 ...         ...
# 66  UBERON:0018687  AnatomicalEntity_CellularComponent  GO:0005604
# 67  UBERON:0022317  AnatomicalEntity_CellularComponent  GO:0030425
# 68  UBERON:0022318  AnatomicalEntity_CellularComponent  GO:0043025
# 69  UBERON:4000020  AnatomicalEntity_CellularComponent  GO:0031012
# 70  UBERON:4000059  AnatomicalEntity_CellularComponent  GO:0031012
#
#            head_type relation_type          tail_type   kg_source head_id_is  \
# 0   AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 1   AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 2   AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 3   AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 4   AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# ..               ...           ...                ...         ...        ...
# 66  AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 67  AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 68  AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 69  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG     UBERON
# 70  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG     UBERON
#
#    tail_id_is                  head_detail_name      tail_detail_name  \
# 0          GO                           feather      keratin filament
# 1          GO                            macula             cell hair
# 2          GO                       perineurium       collagen trimer
# 3          GO          neuron projection bundle     neuron projection
# 4          GO                       endoneurium         myelin sheath
# ..        ...                               ...                   ...
# 66         GO           glial limiting membrane     basement membrane
# 67         GO          olfactory cortex layer 1              dendrite
# 68         GO          olfactory cortex layer 2    neuronal cell body
# 69         GO  mineralized extracellular matrix  extracellular matrix
# 70         GO         avascular GAG-rich matrix  extracellular matrix
#
#         kg_type       species
# 0   Generalised  Homo sapiens
# 1   Generalised  Homo sapiens
# 2   Generalised  Homo sapiens
# 3   Generalised  Homo sapiens
# 4   Generalised  Homo sapiens
# ..          ...           ...
# 66  Generalised  Homo sapiens
# 67  Generalised  Homo sapiens
# 68  Generalised  Homo sapiens
# 69  Generalised  Homo sapiens
# 70  Generalised  Homo sapiens
#
# [71 rows x 13 columns]

# %% [markdown]
# ## 4. QC — NaN Check Before Name Repair

# %%
def nan_summary(df):
    true_nan   = df.isna().sum()
    string_nan = df.apply(lambda c: c.astype(str).str.upper().eq('NAN').sum())
    return pd.DataFrame({
        'NaN_count':          true_nan,
        "'NAN'_string_count": string_nan,
        'Total_NaN_like':     true_nan + string_nan
    })

nan_summary(final_df)
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %% [markdown]
# ## 6. Deduplicate and Add Schema Columns
#
# Group by `(head, relation, tail)` and collapse duplicate `kg_source` values with `::` separator.

# %%
GROUP_COLS = ['head', 'relation', 'tail']

def merge_sources(x):
    return '::'.join(sorted(set(x.dropna())))

final_df_dedup = final_df.groupby(GROUP_COLS, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'kg_type': merge_sources,
    'species': 'first',
})

# Enforce final column order
final_df_dedup = final_df_dedup[REQUIRED_COLS]

print(f"After deduplication: {len(final_df_dedup):,} rows")
final_df_dedup.head()
# Out:
# After deduplication: 71 rows
#              head                            relation        tail  \
# 0  UBERON:0000022  AnatomicalEntity_CellularComponent  GO:0045095
# 1  UBERON:0000054  AnatomicalEntity_CellularComponent  GO:0070451
# 2  UBERON:0000121  AnatomicalEntity_CellularComponent  GO:0005581
# 3  UBERON:0000122  AnatomicalEntity_CellularComponent  GO:0043005
# 4  UBERON:0000123  AnatomicalEntity_CellularComponent  GO:0043209
#
#           head_type relation_type          tail_type   kg_source head_id_is  \
# 0  AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 1  AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 2  AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 3  AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
# 4  AnatomicalEntity    related_to  CellularComponent  Monarch_KG     UBERON
#
#   tail_id_is          head_detail_name   tail_detail_name      kg_type  \
# 0         GO                   feather   keratin filament  Generalised
# 1         GO                    macula          cell hair  Generalised
# 2         GO               perineurium    collagen trimer  Generalised
# 3         GO  neuron projection bundle  neuron projection  Generalised
# 4         GO               endoneurium      myelin sheath  Generalised
#
#         species
# 0  Homo sapiens
# 1  Homo sapiens
# 2  Homo sapiens
# 3  Homo sapiens
# 4  Homo sapiens

# %%
print("\nkg_source values present:", set(final_df_dedup['kg_source']))
# Out:
# kg_source values present: {'Monarch_KG'}

# %%
print("\nkg_type values present:", set(final_df_dedup['kg_type']))
# Out:
# kg_type values present: {'Generalised'}

# %% [markdown]
# ## 7. QC — NaN Check After Deduplication

# %%
nan_summary(final_df_dedup)
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %%
final_df_dedup['head_species'] = 'Homo sapiens'
final_df_dedup['tail_species'] = 'Homo sapiens'

# %% [markdown]
# ## 8. Save Output

# %%
os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 71 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/ANATOMY_CELLCOMP/ALL_ANATOMY_CELLCOMP.csv

# %%
#
