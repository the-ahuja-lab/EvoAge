# %%
import os
import pandas as pd
import numpy as np

# %%
# ── Base directories ──────────────────────────────────────────────────────────
BASE_DIR   = '/storage/Arushi/090526_EvoAge/kg_formation/'
PROC_DIR   = BASE_DIR + 'processed_data/'
DB_DIR     = BASE_DIR + 'data_collection/databases_for_mapping/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH   = BASE_DIR + 'processed_data_relation_wise_merge/generalised/CHEMICAL_PROMOTES_BIOLOGICALPROCESS/ALL_CHEMICAL_PROMOTES_BIOLOGICALPROCESS_Human.parquet'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

# %%
Pubchem = pd.read_pickle(DB_DIR + 'pubchem/combined_df.pkl')
Pubchem_IUPAC_CID_Dict  = dict(zip(Pubchem['PUBCHEM_COMPOUND_CID'], Pubchem['PUBCHEM_IUPAC_NAME']))
del Pubchem
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 5
#       2 Pubchem_IUPAC_CID_Dict  = dict(zip(Pubchem['PUBCHEM_COMPOUND_CID'], Pubchem['PUBCHEM_IUPAC_NAME']))
#       3 del Pubchem
# ----> 5 GO = pd.read_csv(MAPPING_DIR + 'MESH/MESH_GO_ID_NAME.csv')
#       6 GO_dict = dict(zip(GO['id'], GO['name']))
#       7 del GO
#
# NameError: name 'MAPPING_DIR' is not defined

# %%
GO = pd.read_csv(DB_DIR + 'MESH/MESH_GO_ID_NAME.csv')
GO_dict = dict(zip(GO['id'], GO['name']))
del GO

# %%
# AgeAnnoMO
Agextend = pd.read_csv(PROC_DIR + 'agextend_processed/CHEM_BioP_Hallmarks/All_Chemical_Promotes_BioPro(Hallmarks).csv')
Agextend.columns = Agextend.columns.str.lower()
Agextend.rename(columns={'relation_source': 'kg_source'}, inplace=True)
Agextend['kg_type'] = 'Aging'
Agextend['species'] = 'Homo sapiens'
Agextend
# Out:
#             head                                   relation        tail  \
# 0          31703  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 1       10297043  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 2       24771867  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 3       24856041  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 4      135398495  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# ...          ...                                        ...         ...
# 47331      60750  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47332    9802860  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47333      23205  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47334  135499583  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47335  135430795  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
#
#             head_type          tail_type  \
# 0      ChemicalEntity  BiologicalProcess
# 1      ChemicalEntity  BiologicalProcess
# 2      ChemicalEntity  BiologicalProcess
# 3      ChemicalEntity  BiologicalProcess
# 4      ChemicalEntity  BiologicalProcess
# ...               ...                ...
# 47331  ChemicalEntity  BiologicalProcess
# 47332  ChemicalEntity  BiologicalProcess
# 47333  ChemicalEntity  BiologicalProcess
# 47334  ChemicalEntity  BiologicalProcess
# 47335  ChemicalEntity  BiologicalProcess
#
#                                         head_detail_name  \
# 0      (7S,9S)-7-[(2R,4S,5S,6S)-4-amino-5-hydroxy-6-m...
# 1      6-[4-[(4-ethylpiperazin-1-yl)methyl]phenyl]-N-...
# 2      4-[[9-chloro-7-(2-fluoro-6-methoxyphenyl)-5H-p...
# 3      N-[4-[3-(2-aminopyrimidin-4-yl)pyridin-2-yl]ox...
# 4      1-cyclopropyl-3-[5-[6-(morpholin-4-ylmethyl)-1...
# ...                                                  ...
# 47331  4-amino-1-[(2R,4R,5R)-3,3-difluoro-4-hydroxy-5...
# 47332  (1S,3S,6S,10R,12R,13R,16S,19S)-16-methoxy-3,10...
# 47333  (3aR,5R,5aR,8aR,9S,9aS)-9-hydroxy-5,8a-dimethy...
# 47334  [[(1S,4R)-4-(2-amino-6-oxo-1H-purin-9-yl)cyclo...
# 47335  [[(2S,5R)-5-(2-amino-6-oxo-1H-purin-9-yl)oxola...
#
#                                          head_smile_name     tail_detail_name  \
# 0      C[C@H]1[C@H]([C@H](C[C@@H](O1)O[C@H]2C[C@@](CC...  cellular senescence
# 1      CCN1CCN(CC1)CC2=CC=C(C=C2)C3=CC4=C(N3)N=CN=C4N...  cellular senescence
# 2      COC1=C(C(=CC=C1)F)C2=NCC3=CN=C(N=C3C4=C2C=C(C=...  cellular senescence
# 3      CC1=CSC(=C1)C2=NN=C(C3=CC=CC=C32)NC4=CC=C(C=C4...  cellular senescence
# 4      C1CC1NC(=O)NC2=C(NN=C2)C3=NC4=C(N3)C=C(C=C4)CN...  cellular senescence
# ...                                                  ...                  ...
# 47331  C1=CN(C(=O)N=C1N)[C@H]2C([C@@H]([C@H](O2)CO)O)...   telomere attrition
# 47332  C[C@@H]1CCC[C@H]2C=C([C@H](C[C@@]23[C@H]4[C@](...   telomere attrition
# 47333  C[C@@H]1C[C@@H]2[C@H]([C@@H]([C@]3([C@H]1C=CC3...   telomere attrition
# 47334  C1[C@@H](C=C[C@@H]1N2C=NC3=C2N=C(NC3=O)N)COP(=...   telomere attrition
# 47335  C1C[C@@H](O[C@@H]1COP(=O)(O)OP(=O)(O)OP(=O)(O)...   telomere attrition
#
#       kg_source       species head_id_is tail_id_is  \
# 0      AgeXtend  Homo sapiens    Pubchem   Quick_GO
# 1      AgeXtend  Homo sapiens    Pubchem   Quick_GO
# 2      AgeXtend  Homo sapiens    Pubchem   Quick_GO
# 3      AgeXtend  Homo sapiens    Pubchem   Quick_GO
# 4      AgeXtend  Homo sapiens    Pubchem   Quick_GO
# ...         ...           ...        ...        ...
# 47331  AgeXtend  Homo sapiens    Pubchem   Quick_GO
# 47332  AgeXtend  Homo sapiens    Pubchem   Quick_GO
# 47333  AgeXtend  Homo sapiens    Pubchem   Quick_GO
# 47334  AgeXtend  Homo sapiens    Pubchem   Quick_GO
# 47335  AgeXtend  Homo sapiens    Pubchem   Quick_GO
#
#                                      name/title/synonyms  \
# 0                    Doxorubicin/Doxorubicin/doxorubicin
# 1      AEE788/(R)-6-(4-((4-Ethylpiperazin-1-yl)methyl...
# 2                          Alisertib/Alisertib/Alisertib
# 3      AMG 900/N-(4-(3-(2-aminopyrimidin-4-yl)pyridin...
# 4      AT9283/1-Cyclopropyl-3-(3-(5-(morpholinomethyl...
# ...                                                  ...
# 47331                                                NaN
# 47332                                                NaN
# 47333                                                NaN
# 47334                                                NaN
# 47335                                                NaN
#
#                                              source kg_type
# 0        https://doi.org/10.1016/j.jjcc.2019.05.002   Aging
# 1      https://doi.org/10.1016/j.celrep.2017.09.085   Aging
# 2      https://doi.org/10.1016/j.celrep.2017.09.085   Aging
# 3      https://doi.org/10.1016/j.celrep.2017.09.085   Aging
# 4      https://doi.org/10.1016/j.celrep.2017.09.085   Aging
# ...                                             ...     ...
# 47331       https://doi.org/10.3390/cancers12071901   Aging
# 47332       https://doi.org/10.3390/cancers12071901   Aging
# 47333       https://doi.org/10.3390/cancers12071901   Aging
# 47334       https://doi.org/10.3390/cancers12071901   Aging
# 47335       https://doi.org/10.3390/cancers12071901   Aging
#
# [47336 rows x 15 columns]

# %%
SOURCE_DFS = [
    ('Agextend', Agextend),
]

for name, df in SOURCE_DFS:
    dupes = df.columns[df.columns.duplicated(keep=False)].unique().tolist()
    if dupes:
        print(f'\n[{name}] duplicate columns: {dupes}')
        for col in dupes:
            for i, (_, s) in enumerate(df.loc[:, df.columns == col].items()):
                print(f"  '{col}' occurrence {i} → sample: {s.dropna().head(3).tolist()}")
    else:
        print(f'[{name}] ✓ no duplicates')
# Out:
# [Agextend] ✓ no duplicates

# %%
CONCAT_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

df_list = []
for name, df in SOURCE_DFS:
    tmp = df.loc[:, ~df.columns.duplicated()].copy()
    for col in CONCAT_COLS:
        if col not in tmp.columns:
            tmp[col] = pd.NA
    df_list.append(tmp[CONCAT_COLS])

final_df = pd.concat(df_list, ignore_index=True)
print(f'Combined: {len(final_df):,} rows')
final_df
# Out:
# Combined: 47,336 rows
#             head                                   relation        tail  \
# 0          31703  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 1       10297043  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 2       24771867  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 3       24856041  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 4      135398495  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# ...          ...                                        ...         ...
# 47331      60750  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47332    9802860  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47333      23205  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47334  135499583  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47335  135430795  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
#
#             head_type relation_type          tail_type kg_source head_id_is  \
# 0      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 1      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 2      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 3      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 4      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# ...               ...           ...                ...       ...        ...
# 47331  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 47332  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 47333  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 47334  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 47335  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
#
#       tail_id_is                                   head_detail_name  \
# 0       Quick_GO  (7S,9S)-7-[(2R,4S,5S,6S)-4-amino-5-hydroxy-6-m...
# 1       Quick_GO  6-[4-[(4-ethylpiperazin-1-yl)methyl]phenyl]-N-...
# 2       Quick_GO  4-[[9-chloro-7-(2-fluoro-6-methoxyphenyl)-5H-p...
# 3       Quick_GO  N-[4-[3-(2-aminopyrimidin-4-yl)pyridin-2-yl]ox...
# 4       Quick_GO  1-cyclopropyl-3-[5-[6-(morpholin-4-ylmethyl)-1...
# ...          ...                                                ...
# 47331   Quick_GO  4-amino-1-[(2R,4R,5R)-3,3-difluoro-4-hydroxy-5...
# 47332   Quick_GO  (1S,3S,6S,10R,12R,13R,16S,19S)-16-methoxy-3,10...
# 47333   Quick_GO  (3aR,5R,5aR,8aR,9S,9aS)-9-hydroxy-5,8a-dimethy...
# 47334   Quick_GO  [[(1S,4R)-4-(2-amino-6-oxo-1H-purin-9-yl)cyclo...
# 47335   Quick_GO  [[(2S,5R)-5-(2-amino-6-oxo-1H-purin-9-yl)oxola...
#
#           tail_detail_name kg_type       species
# 0      cellular senescence   Aging  Homo sapiens
# 1      cellular senescence   Aging  Homo sapiens
# 2      cellular senescence   Aging  Homo sapiens
# 3      cellular senescence   Aging  Homo sapiens
# 4      cellular senescence   Aging  Homo sapiens
# ...                    ...     ...           ...
# 47331   telomere attrition   Aging  Homo sapiens
# 47332   telomere attrition   Aging  Homo sapiens
# 47333   telomere attrition   Aging  Homo sapiens
# 47334   telomere attrition   Aging  Homo sapiens
# 47335   telomere attrition   Aging  Homo sapiens
#
# [47336 rows x 13 columns]

# %%
GROUP_COLS = ['head', 'relation', 'tail']

def merge_sources(x):
    return '::'.join(sorted(set(x.dropna())))

final_df_dedup = final_df.groupby(GROUP_COLS, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':         merge_sources,
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'kg_type': merge_sources,
    'species': 'first',
})
print(f'After deduplication: {len(final_df_dedup):,} rows')
final_df_dedup = final_df_dedup[REQUIRED_COLS]
final_df_dedup.head()
# Out:
# After deduplication: 47,336 rows
#    head                                   relation        tail  \
# 0     6  ChemicalEntity_Promotes_BiologicalProcess  GO:1111111
# 1    86  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 2   109  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 3   190  ChemicalEntity_Promotes_BiologicalProcess  GO:1111111
# 4   237  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
#
#         head_type relation_type          tail_type kg_source head_id_is  \
# 0  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 1  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 2  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 3  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 4  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
#
#   tail_id_is                                   head_detail_name  \
# 0   Quick_GO                        1-chloro-2,4-dinitrobenzene
# 1   Quick_GO                      2-amino-3-hydroxybenzoic acid
# 2   Quick_GO                    2-amino-3-sulfinopropanoic acid
# 3   Quick_GO                                   7H-purin-6-amine
# 4   Quick_GO  4-N-(6-chloro-2-methoxyacridin-9-yl)-1-N,1-N-d...
#
#          tail_detail_name kg_type       species
# 0     genomic instability   Aging  Homo sapiens
# 1  epigenetic alterations   Aging  Homo sapiens
# 2  epigenetic alterations   Aging  Homo sapiens
# 3     genomic instability   Aging  Homo sapiens
# 4  epigenetic alterations   Aging  Homo sapiens

# %%
def nan_summary(df):
    true_nan   = df.isna().sum()
    string_nan = df.apply(lambda c: c.astype(str).str.upper().eq('NAN').sum())
    return pd.DataFrame({
        'NaN_count':          true_nan,
        "'NAN'_string_count": string_nan,
        'Total_NaN_like':     true_nan + string_nan
    })

nan_summary(final_df_dedup)
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type         47336                   0           47336
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name         51                   0              51
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %%
final_df_dedup[final_df_dedup['head_detail_name'].isna()]
# Out:
#             head                                   relation        tail  \
# 686        10038  ChemicalEntity_Promotes_BiologicalProcess  GO:1111111
# 687        10039  ChemicalEntity_Promotes_BiologicalProcess  GO:1111111
# 3752      263463  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 5388      652954  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 6652      666049  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 6682      666291  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 24272    3404071  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 27950    4889893  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 27988    4898241  ChemicalEntity_Promotes_BiologicalProcess  GO:1111113
# 31180    6079422  ChemicalEntity_Promotes_BiologicalProcess  GO:1111114
# 31470    6323490  ChemicalEntity_Promotes_BiologicalProcess  GO:1111116
# 31480    6327657  ChemicalEntity_Promotes_BiologicalProcess  GO:1111111
#
ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# 4      135398495  ChemicalEntity_Promotes_BiologicalProcess  GO:0090398
# ...          ...                                        ...         ...
# 47331      60750  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47332    9802860  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47333      23205  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47334  135499583  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
# 47335  135430795  ChemicalEntity_Promotes_BiologicalProcess  GO:1111112
#
#             head_type relation_type          tail_type kg_source head_id_is  \
# 0      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 1      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 2      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 3      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 4      ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# ...               ...           ...                ...       ...        ...
# 47331  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 47332  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 47333  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 47334  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 47335  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
#
#       tail_id_is                                   head_detail_name  \
# 0       Quick_GO  (7S,9S)-7-[(2R,4S,5S,6S)-4-amino-5-hydroxy-6-m...
# 1       Quick_GO  6-[4-[(4-ethylpiperazin-1-yl)methyl]phenyl]-N-...
# 2       Quick_GO  4-[[9-chloro-7-(2-fluoro-6-methoxyphenyl)-5H-p...
# 3       Quick_GO  N-[4-[3-(2-aminopyrimidin-4-yl)pyridin-2-yl]ox...
# 4       Quick_GO  1-cyclopropyl-3-[5-[6-(morpholin-4-ylmethyl)-1...
# ...          ...                                                ...
# 47331   Quick_GO  4-amino-1-[(2R,4R,5R)-3,3-difluoro-4-hydroxy-5...
# 47332   Quick_GO  (1S,3S,6S,10R,12R,13R,16S,19S)-16-methoxy-3,10...
# 47333   Quick_GO  (3aR,5R,5aR,8aR,9S,9aS)-9-hydroxy-5,8a-dimethy...
# 47334   Quick_GO  [[(1S,4R)-4-(2-amino-6-oxo-1H-purin-9-yl)cyclo...
# 47335   Quick_GO  [[(2S,5R)-5-(2-amino-6-oxo-1H-purin-9-yl)oxola...
#
#           tail_detail_name kg_type       species
# 0      cellular senescence   Aging  Homo sapiens
# 1      cellular senescence   Aging  Homo sapiens
# 2      cellular senescence   Aging  Homo sapiens
# 3      cellular senescence   Aging  Homo sapiens
# 4      cellular senescence   Aging  Homo sapiens
# ...                    ...     ...           ...
# 47331   telomere attrition   Aging  Homo sapiens
# 47332   telomere attrition   Aging  Homo sapiens
# 47333   telomere attrition   Aging  Homo sapiens
# 47334   telomere attrition   Aging  Homo sapiens
# 47335   telomere attrition   Aging  Homo sapiens
#
# [47336 rows x 13 columns]

# %%
nan_summary(final_df_dedup)
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type         47336                   0           47336
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name         51                   0              51
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %%
os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)
final_df_dedup.to_parquet(OUT_PATH, index=False)
print(f'Saved {len(final_df_dedup):,} rows → {OUT_PATH}')
# Out:
# Saved 47,336 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/CHEMICAL_PROMOTES_BIOLOGICALPROCESS/ALL_CHEMICAL_PROMOTES_BIOLOGICALPROCESS_Human.parquet

# %%
#
