# %% [markdown]
# # CellularComponent → CellularComponent Relation Pipeline
#
# Builds a unified, deduplicated edge table for the **CellularComponent–CellularComponent** relation.
#
# **Output schema:** `head | relation | tail | head_type | relation_type | tail_type | kg_source | head_id_is | tail_id_is | head_detail_name | tail_detail_name`
#
# ---
# **Sources included:**
# - Monarch
# - Pheknowlator
# - PrimeKG
# - TAR-KG
# - Crossbar
# - GPKG
#
# **Base paths:**
# - KG data: `/storage/Arushi/090526_EvoAge/kg_formation/`
# - Processed KG files: `/storage/Arushi/090526_EvoAge/kg_formation/processed_data/`

# %% [markdown]
# ## 0 · Imports & Base Paths

# %%
import pandas as pd
import os

BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
PROC_DIR     = BASE_DIR + 'processed_data/'
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/CELLULARCOMPONENT_CELLULARCOMPONENT/ALL_CELLULARCOMPONENT_CELLULARCOMPONENT.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

# %% [markdown]
# ## 1 · Load Source Files

# %%
# Monarch
Monarch = pd.read_csv(PROC_DIR + 'Monarch/Human/Human_CellularComponent_CellularComponent_Monarch.csv')
Monarch.columns = Monarch.columns.str.lower()
Monarch['tail_id_is'] = 'Quick_GO'
Monarch['head_id_is'] = 'Quick_GO'
Monarch['relation'] = 'CellularComponent_CellularComponent'
Monarch['head_type'] = 'CellularComponent'
Monarch['tail_type'] = 'CellularComponent'
Monarch = Monarch.rename(columns={"kgsource":"kg_source"})
print(f"Monarch: {len(Monarch):,} rows")
Monarch =  Monarch.rename(columns={
    'head_name': 'head_detail_name',
    'tail_name': 'tail_detail_name'
})
Monarch['kg_source'] = 'Monarch_KG'
Monarch['kg_type'] = 'Generalised'
Monarch['species'] = 'Homo sapiens'
Monarch
# Out:
# Monarch: 6,627 rows
#             head        tail relation_type relation_source   kg_source  \
# 0     GO:0060987  GO:0032994   subclass_of      infores:go  Monarch_KG
# 1     GO:0061174  GO:0043195   subclass_of      infores:go  Monarch_KG
# 2     GO:0061175  GO:0043195   subclass_of      infores:go  Monarch_KG
# 3     GO:0061176  GO:0061174   subclass_of      infores:go  Monarch_KG
# 4     GO:0061177  GO:0061174   subclass_of      infores:go  Monarch_KG
# ...          ...         ...           ...             ...         ...
# 6622  GO:0060417  GO:0110165   subclass_of      infores:go  Monarch_KG
# 6623  GO:0060417  GO:0005737    related_to      infores:go  Monarch_KG
# 6624  GO:0060418  GO:0110165   subclass_of      infores:go  Monarch_KG
# 6625  GO:0060418  GO:0060417    related_to      infores:go  Monarch_KG
# 6626  GO:0060473  GO:0030141   subclass_of      infores:go  Monarch_KG
#
#              head_detail_name          head_type head_id_is  head_taxon  \
# ...

# %%
Monarch.columns
# Out:
# Index(['head', 'tail', 'relation_type', 'relation_source', 'kg_source',
#        'head_detail_name', 'head_type', 'head_id_is', 'head_taxon',
#        'head_taxon_label', 'tail_detail_name', 'tail_type', 'tail_id_is',
#        'tail_taxon', 'tail_taxon_label', 'head_taxon_name', 'tail_taxon_name',
#        'head_type_clean', 'tail_type_clean', 'relation', 'species_species',
#        'kg_type', 'species'],
#       dtype='object')

# %%
# Pheknowlator
Pheknowlator = pd.read_csv(PROC_DIR + 'pheknowlator/CellularComponent_CellularComponent.csv')
Pheknowlator.columns = Pheknowlator.columns.str.lower()
Pheknowlator['tail_id_is'] = 'Quick_GO'
Pheknowlator['head_id_is'] = 'Quick_GO'
Pheknowlator['relation'] = 'CellularComponent_CellularComponent'
Pheknowlator['head_type'] = 'CellularComponent'
Pheknowlator['tail_type'] = 'CellularComponent'
Pheknowlator['kg_source'] = 'pheknowlator'

Pheknowlator['kg_type'] = 'Generalised'
Pheknowlator['species'] = 'Homo sapiens'
print(f"Pheknowlator: {len(Pheknowlator):,} rows")
# Out:
# Pheknowlator: 7,480 rows

# %%
# PrimeKG
PrimeKG = pd.read_csv(PROC_DIR + 'PrimeKG/PrimeKG_cellcomp_cellcomp.csv')
PrimeKG.columns = PrimeKG.columns.str.lower()
PrimeKG['tail_id_is'] = 'Quick_GO'
PrimeKG['head_id_is'] = 'Quick_GO'
PrimeKG['relation'] = 'CellularComponent_CellularComponent'
PrimeKG['head_type'] = 'CellularComponent'
PrimeKG['tail_type'] = 'CellularComponent'
PrimeKG['kg_source'] = 'PrimeKG'

PrimeKG['kg_type'] = 'Generalised'
PrimeKG['species'] = 'Homo sapiens'
print(f"PrimeKG: {len(PrimeKG):,} rows")
# Out:
# PrimeKG: 4,845 rows

# %%
# TARKG
TARKG = pd.read_csv(PROC_DIR + 'TARKG/CellularComponent_CellularComponent.csv')
TARKG.columns = TARKG.columns.str.lower()
TARKG['tail_id_is'] = 'Quick_GO'
TARKG['head_id_is'] = 'Quick_GO'
TARKG['relation'] = 'CellularComponent_CellularComponent'
TARKG['head_type'] = 'CellularComponent'
TARKG['tail_type'] = 'CellularComponent'
TARKG['kg_source'] = 'TARKG'
TARKG['kg_type'] = 'Generalised'
TARKG['species'] = 'Homo sapiens'
print(f"TARKG: {len(TARKG):,} rows")
# Out:
# TARKG: 5,414 rows

# %%
# TARKG_2
TARKG_2 = pd.read_csv(PROC_DIR + 'TARKG/CellularComponent_CellularComponent_2.csv')
TARKG_2.columns = TARKG_2.columns.str.lower()
TARKG_2['tail_id_is'] = 'Quick_GO'
TARKG_2['head_id_is'] = 'Quick_GO'
TARKG_2['relation'] = 'CellularComponent_CellularComponent'
TARKG_2['head_type'] = 'CellularComponent'
TARKG_2['tail_type'] = 'CellularComponent'
TARKG_2['kg_source'] = 'TARKG_2'
TARKG_2['kg_type'] = 'Generalised'
TARKG_2['species'] = 'Homo sapiens'
print(f"TARKG_2: {len(TARKG_2):,} rows")
# Out:
# TARKG_2: 6,524 rows

# %%
# Crossbar
Crossbar = pd.read_csv(PROC_DIR + 'crossbar/CellularComponent_CellularComponent_Crossbar.csv')
Crossbar.columns = Crossbar.columns.str.lower()
Crossbar['tail_id_is'] = 'Quick_GO'
Crossbar['head_id_is'] = 'Quick_GO'
Crossbar['relation'] = 'CellularComponent_CellularComponent'
Crossbar['head_type'] = 'CellularComponent'
Crossbar['tail_type'] = 'CellularComponent'
Crossbar['kg_source'] = 'Crossbar'
Crossbar['kg_type'] = 'Generalised'
Crossbar['species'] = 'Homo sapiens'
print(f"Crossbar: {len(Crossbar):,} rows")
# Out:
# Crossbar: 6,488 rows

# %%
# GPKG
GPKG = pd.read_csv(PROC_DIR + 'GPKG/CellularComponent_CellularComponent_GPKG.csv')
GPKG.columns = GPKG.columns.str.lower()
GPKG['tail_id_is'] = 'Quick_GO'
GPKG['head_id_is'] = 'Quick_GO'
GPKG['relation'] = 'CellularComponent_CellularComponent'
GPKG['head_type'] = 'CellularComponent'
GPKG['tail_type'] = 'CellularComponent'
GPKG['kg_source'] = 'GPKG'
GPKG['kg_type'] = 'Generalised'
GPKG['species'] = 'Homo sapiens'
print(f"GPKG: {len(GPKG):,} rows")
# Out:
# GPKG: 793 rows

# %% [markdown]
# ## 2 · Consolidate into Unified Schema

# %%
source_dfs = [Monarch, Pheknowlator, PrimeKG, TARKG, TARKG_2, Crossbar, GPKG]
aligned = []
for df in source_dfs:
    df = df.copy()
    df = df.loc[:, ~df.columns.duplicated()]
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])
final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 38,171
#              head                             relation        tail  \
# 0      GO:0060987  CellularComponent_CellularComponent  GO:0032994
# 1      GO:0061174  CellularComponent_CellularComponent  GO:0043195
# 2      GO:0061175  CellularComponent_CellularComponent  GO:0043195
# 3      GO:0061176  CellularComponent_CellularComponent  GO:0061174
# 4      GO:0061177  CellularComponent_CellularComponent  GO:0061174
# ...           ...                                  ...         ...
# 38166  GO:0005929  CellularComponent_CellularComponent  GO:0097730
# 38167  GO:0005929  CellularComponent_CellularComponent  GO:0097729
# 38168  GO:0045179  CellularComponent_CellularComponent  GO:0097575
# 38169  GO:0005902  CellularComponent_CellularComponent  GO:0097454
# 38170  GO:0060205  CellularComponent_CellularComponent  GO:0070931
#
#                head_type relation_type          tail_type   kg_source  \
# ...

# %%
set(final_df['relation']),set(final_df['head_type']),set(final_df['tail_type']),set(final_df['kg_source']),set(final_df['head_id_is']),set(final_df['tail_id_is']),  set(final_df['kg_type']), set(final_df['species'])
# Out:
# ({'CellularComponent_CellularComponent'},
#  {'CellularComponent'},
#  {'CellularComponent'},
#  {'Crossbar',
#   'GPKG',
#   'Monarch_KG',
#   'PrimeKG',
#   'TARKG',
#   'TARKG_2',
#   'pheknowlator'},
#  {'Quick_GO'},
#  {'Quick_GO'},
#  {'Generalised'},
#  {'Homo sapiens'})

# %%
# Count true NaN values
true_nan_count = final_df.isna().sum()

# Count string 'NAN' values (case-insensitive)
string_nan_count = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

# Combine both counts
nan_summary = pd.DataFrame({
    'NaN_count': true_nan_count,
    "'NAN'_string_count": string_nan_count,
    'Total_NaN_like': true_nan_count + string_nan_count
})
nan_summary
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type         13968                   0           13968
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %% [markdown]
# ## 3 · Deduplication

# %%
def merge_sources(x):
    return '::'.join(sorted(set(x.dropna())))
group_cols = ['head', 'relation', 'tail']
final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type': 'first', 'relation_type': 'first', 'tail_type': 'first',
    'kg_source': merge_sources, 'head_id_is': 'first', 'tail_id_is': 'first',
    'head_detail_name': 'first', 'tail_detail_name': 'first',"kg_type":merge_sources,"species":"first"
})
print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
# Out:
# Before dedup: 38,171  |  After dedup: 11,575

# %%
# Count true NaN values
true_nan_count = final_df_dedup.isna().sum()

# Count string 'NAN' values (case-insensitive)
string_nan_count = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

# Combine both counts
nan_summary = pd.DataFrame({
    'NaN_count': true_nan_count,
    "'NAN'_string_count": string_nan_count,
    'Total_NaN_like': true_nan_count + string_nan_count
})
nan_summary
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type          3353                   0            3353
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %% [markdown]
# ## 4 · Save Output

# %%
import os
os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 11,575 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/CELLULARCOMPONENT_CELLULARCOMPONENT/ALL_CELLULARCOMPONENT_CELLULARCOMPONENT.csv
