# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_gene_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_biologicalprocess/Mouse_gene_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Mouse_gene_biologicalprocess’: File exists

# %%
#

# %%
# Mouse = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Mus_musculus.gene_info',
#     sep='\t',
    
# )
# # Mouse["LocusTag"] = Mouse["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Mouse_symbol2Locus_dict = dict(zip(Mouse['Symbol'], Mouse['LocusTag']))
# # Mouse
# # Mouse_symbol2Locus_dict
# Mouse

# %% [markdown]
# # agingatlas

# %%
agingatlas = pd.read_csv(PROC_DIR + 'agingatlas/Mouse/Mouse_Gene_BiologicalProcess.csv')
agingatlas.columns = agingatlas.columns.str.lower()
agingatlas = agingatlas[~agingatlas['head_detail_name'].isna()]

agingatlas['kg_type'] = 'Aging'

print(f"agingatlas: {len(agingatlas):,} rows")
agingatlas['head_id_is'] = 'NCBI_ID'
agingatlas['tail_id_is'] = 'Quick_GO'
agingatlas['species'] = 'Mus musculus'
agingatlas['kg_source'] = 'AgingAtlas'


agingatlas
# Out:
# agingatlas: 400 rows
#       head                relation        tail head_type          tail_type  \
# 0      A2m  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# 1     Abl1  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# 2    Adcy1  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# 3    Adcy2  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# 4    Adcy3  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# ..     ...                     ...         ...       ...                ...
# 395  Stub1  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# 396  Sumf1  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# 397  Sumo1  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# 398   Sun1  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
# 399    Syk  Gene_BiologicalProcess  GO:0007568      Gene  BiologicalProcess
#
#                                    head_detail_name tail_detail_name  \
# 0                             alpha-2-macroglobulin            aging
# 1    c-abl oncogene 1, non-receptor tyrosine kinase            aging
# 2                               adenylate cyclase 1            aging
# 3                               adenylate cyclase 2            aging
# 4                               adenylate cyclase 3            aging
# ..                                              ...              ...
# 395   Stip1 homology and U-Box containing protein 1            aging
# 396                    Sulfatase Modifying Factor 1            aging
# 397                 small ubiquitin-like modifier 1            aging
# 398              Sad1 and UNC84 domain containing 1            aging
# 399                          spleen tyrosine kinase            aging
#
#     head_id_is tail_id_is relation_source       species symbol  \
# 0      NCBI_ID   Quick_GO     aging_atlas  Mus musculus    A2m
# 1      NCBI_ID   Quick_GO     aging_atlas  Mus musculus   Abl1
# 2      NCBI_ID   Quick_GO     aging_atlas  Mus musculus  Adcy1
# 3      NCBI_ID   Quick_GO     aging_atlas  Mus musculus  Adcy2
# 4      NCBI_ID   Quick_GO     aging_atlas  Mus musculus  Adcy3
# ..         ...        ...             ...           ...    ...
# 395    NCBI_ID   Quick_GO     aging_atlas  Mus musculus  Stub1
# 396    NCBI_ID   Quick_GO     aging_atlas  Mus musculus  Sumf1
# 397    NCBI_ID   Quick_GO     aging_atlas  Mus musculus  Sumo1
# 398    NCBI_ID   Quick_GO     aging_atlas  Mus musculus   Sun1
# 399    NCBI_ID   Quick_GO     aging_atlas  Mus musculus    Syk
#
#                                 gene_set   kegg_id  \
# 0                                 others   unknown
# 1                    genomic instability  mmu04110
# 2    altered intercellular communication  mmu04211
# 3    altered intercellular communication  mmu04211
# 4    altered intercellular communication  mmu04211
# ..                                   ...       ...
# 395                 loss of proteostasis   unknown
# 396                               others  mmu04142
# 397                  genomic instability   unknown
# 398                               others   unknown
# 399                  NF-ÎºB related gene  mmu04064
#
#                         kegg_name  \
# 0                         Unknown
# 1                      Cell cycle
# 2    Longevity regulating pathway
# 3    Longevity regulating pathway
# 4    Longevity regulating pathway
# ..                            ...
# 395                       Unknown
# 396                      Lysosome
# 397                       Unknown
# 398                       Unknown
# 399  NF-kappa B signaling pathway
#
#                                        literature_name  \
# 0    The primary sequence and the subunit structure...
# 1    Functional interaction between DNA-PK and c-Ab...
# 2    Loss of adenylyl cyclase I activity disrupts p...
# 3    BGEM: an in situ hybridization database of gen...
# 4    Disruption of the type III adenylyl cyclase ge...
# ..                                                 ...
# 395  Age-related expression of STUB1 in senescence-...
# 396  High-throughput screening of mouse gene knocko...
# 397  SUMO-1 Conjugation to Topoisomerase I: A Possi...
# 398  Reversal of laminopathies: the curious case of...
# 399  miR-25-3p promotes endothelial cell angiogenes...
#
#                         literature_link    data_type kg_type   kg_source
# 0    10.1111/j.1432-1033.1992.tb17424.x  Associative   Aging  AgingAtlas
# 1                      10.1038/386732a0  Associative   Aging  AgingAtlas
# 2                           10.1038/980  Associative   Aging  AgingAtlas
# 3          10.1371/journal.pbio.0040086  Associative   Aging  AgingAtlas
# 4         10.1016/s0896-6273(00)00060-x  Associative   Aging  AgingAtlas
# ..                                  ...          ...     ...         ...
# 395             10.1126/science.1102895  Associative   Aging  AgingAtlas
# 396              0.1038/boneres.2014.34  Associative   Aging  AgingAtlas
# 397             10.1126/science.1102896  Associative   Aging  AgingAtlas
# 398             10.1126/science.1102897  Associative   Aging  AgingAtlas
# 399               10.18632/aging.103834  Associative   Aging  AgingAtlas
#
# [400 rows x 20 columns]

# %% [markdown]
# # AgeAnnoMO

# %%
AgeAnnoMO = pd.read_csv(PROC_DIR + 'ageanno_processed_mo/AgeAnnoMO_Mouse_Gene_BiologicalProcess.csv')
AgeAnnoMO.columns = AgeAnnoMO.columns.str.lower()
AgeAnnoMO = AgeAnnoMO[~AgeAnnoMO['head_detail_name'].isna()]

AgeAnnoMO['kg_type'] = 'Aging'
AgeAnnoMO['tail_type'] = 'BiologicalProcess'
print(f"AgeAnnoMO: {len(AgeAnnoMO):,} rows")
AgeAnnoMO['head_id_is'] = 'NCBI_ID'
AgeAnnoMO['tail_id_is'] = 'Quick_GO'
AgeAnnoMO['species'] = 'Mus musculus'
AgeAnnoMO['kg_source'] = 'AgeAnnoMO'
AgeAnnoMO
# Out:
# AgeAnnoMO: 2,547 rows
#          head                relation        tail head_type  \
# 0     Tsc22d3  Gene_BiologicalProcess  GO:1111113      Gene
# 1     Mir3475  Gene_BiologicalProcess  GO:1111113      Gene
# 2      Begain  Gene_BiologicalProcess  GO:1111113      Gene
# 3      Pgrmc1  Gene_BiologicalProcess  GO:1111113      Gene
# 4      Ubqln2  Gene_BiologicalProcess  GO:1111113      Gene
# ...       ...                     ...         ...       ...
# 2542   Dlgap1  Gene_BiologicalProcess  GO:1111113      Gene
# 2543     Eea1  Gene_BiologicalProcess  GO:1111113      Gene
# 2544     Tle4  Gene_BiologicalProcess  GO:1111113      Gene
# 2545   Zmynd8  Gene_BiologicalProcess  GO:1111113      Gene
# 2546   Acvrl1  Gene_BiologicalProcess  GO:1111113      Gene
#
#               tail_type relation_source       species        tail_detail_name  \
# 0     BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# 1     BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# 2     BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# 3     BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# 4     BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# ...                 ...             ...           ...                     ...
# 2542  BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# 2543  BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# 2544  BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# 2545  BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
# 2546  BiologicalProcess       AgeAnnoMO  Mus musculus  Epigenetic Alterations
#
#                                 head_detail_name head_id_is tail_id_is  \
# 0                  TSC22 domain family, member 3    NCBI_ID   Quick_GO
# 1                                  microRNA 3475    NCBI_ID   Quick_GO
# 2     brain-enriched guanylate kinase-associated    NCBI_ID   Quick_GO
# 3     progesterone receptor membrane component 1    NCBI_ID   Quick_GO
# 4                                    ubiquilin 2    NCBI_ID   Quick_GO
# ...                                          ...        ...        ...
# 2542                    DLG associated protein 1    NCBI_ID   Quick_GO
# 2543                    early endosome antigen 1    NCBI_ID   Quick_GO
# 2544         transducin-like enhancer of split 4    NCBI_ID   Quick_GO
# 2545         zinc finger, MYND-type containing 8    NCBI_ID   Quick_GO
# 2546          activin A receptor, type II-like 1    NCBI_ID   Quick_GO
#
#      kg_type  kg_source
# 0      Aging  AgeAnnoMO
# 1      Aging  AgeAnnoMO
# 2      Aging  AgeAnnoMO
# 3      Aging  AgeAnnoMO
# 4      Aging  AgeAnnoMO
# ...      ...        ...
# 2542   Aging  AgeAnnoMO
# 2543   Aging  AgeAnnoMO
# 2544   Aging  AgeAnnoMO
# 2545   Aging  AgeAnnoMO
# 2546   Aging  AgeAnnoMO
#
# [2547 rows x 13 columns]

# %% [markdown]
# # GenDR

# %%
Gendr = pd.read_csv(PROC_DIR + 'gendr/Mouse/Mouse_GenDR_Gene_BioProcess.csv')
Gendr.columns = Gendr.columns.str.lower()
Gendr = Gendr[~Gendr['head_detail_name'].isna()]

Gendr['kg_type'] = 'Aging'
Gendr['tail_type'] = 'BiologicalProcess'
Gendr['relation'] = 'Gene_BiologicalProcess'

Gendr['species'] = 'Mus musculus'
print(f"Gendr: {len(Gendr):,} rows")
Gendr['head_id_is'] = 'NCBI_ID'
Gendr['tail_id_is'] = 'Quick_GO'
Gendr['kg_source'] = 'GenDR'
Gendr
# Out:
# Gendr: 7 rows
#     head                relation        tail head_type          tail_type  \
# 0    Ghr  Gene_BiologicalProcess  GO:0061771      Gene  BiologicalProcess
# 1  Adcy5  Gene_BiologicalProcess  GO:0061771      Gene  BiologicalProcess
# 2  Sirt1  Gene_BiologicalProcess  GO:0061771      Gene  BiologicalProcess
# 3    Npy  Gene_BiologicalProcess  GO:0061771      Gene  BiologicalProcess
# 4  Prop1  Gene_BiologicalProcess  GO:0061771      Gene  BiologicalProcess
# 5   Pck1  Gene_BiologicalProcess  GO:0061771      Gene  BiologicalProcess
# 6  Foxo3  Gene_BiologicalProcess  GO:0061771      Gene  BiologicalProcess
#
#                                  head_detail_name  \
# 0                         growth hormone receptor
# 1                             adenylate cyclase 5
# 2                                       sirtuin 1
# 3                                  neuropeptide Y
# 4                paired like homeodomain factor 1
# 5  phosphoenolpyruvate carboxykinase 1, cytosolic
# 6                                 forkhead box O3
#
#                   tail_detail_name relation_source       species kg_type  \
# 0  response to caloric restriction           GenDR  Mus musculus   Aging
# 1  response to caloric restriction           GenDR  Mus musculus   Aging
# 2  response to caloric restriction           GenDR  Mus musculus   Aging
# 3  response to caloric restriction           GenDR  Mus musculus   Aging
# 4  response to caloric restriction           GenDR  Mus musculus   Aging
# 5  response to caloric restriction           GenDR  Mus musculus   Aging
# 6  response to caloric restriction           GenDR  Mus musculus   Aging
#
#   head_id_is tail_id_is kg_source
# 0    NCBI_ID   Quick_GO     GenDR
# 1    NCBI_ID   Quick_GO     GenDR
# 2    NCBI_ID   Quick_GO     GenDR
# 3    NCBI_ID   Quick_GO     GenDR
# 4    NCBI_ID   Quick_GO     GenDR
# 5    NCBI_ID   Quick_GO     GenDR
# 6    NCBI_ID   Quick_GO     GenDR

# %%
# monarch[monarch['head_detail_name'].isna()]
# ! ls /storage/Arushi/090526_EvoAge/kg_formation/processed_data/Monarch/Monarch_final/Mouse

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    agingatlas, AgeAnnoMO, Gendr, #Gendr
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 2,954
#        head                relation        tail head_type relation_type  \
# 0       A2m  Gene_BiologicalProcess  GO:0007568      Gene          None
# 1      Abl1  Gene_BiologicalProcess  GO:0007568      Gene          None
# 2     Adcy1  Gene_BiologicalProcess  GO:0007568      Gene          None
# 3     Adcy2  Gene_BiologicalProcess  GO:0007568      Gene          None
# 4     Adcy3  Gene_BiologicalProcess  GO:0007568      Gene          None
# ...     ...                     ...         ...       ...           ...
# 2949  Sirt1  Gene_BiologicalProcess  GO:0061771      Gene          None
# 2950    Npy  Gene_BiologicalProcess  GO:0061771      Gene          None
# 2951  Prop1  Gene_BiologicalProcess  GO:0061771      Gene          None
# 2952   Pck1  Gene_BiologicalProcess  GO:0061771      Gene          None
# 2953  Foxo3  Gene_BiologicalProcess  GO:0061771      Gene          None
#
#               tail_type   kg_source kg_type head_id_is tail_id_is  \
# 0     BiologicalProcess  AgingAtlas   Aging    NCBI_ID   Quick_GO
# 1     BiologicalProcess  AgingAtlas   Aging    NCBI_ID   Quick_GO
# 2     BiologicalProcess  AgingAtlas   Aging    NCBI_ID   Quick_GO
# 3     BiologicalProcess  AgingAtlas   Aging    NCBI_ID   Quick_GO
# 4     BiologicalProcess  AgingAtlas   Aging    NCBI_ID   Quick_GO
# ...                 ...         ...     ...        ...        ...
# 2949  BiologicalProcess       GenDR   Aging    NCBI_ID   Quick_GO
# 2950  BiologicalProcess       GenDR   Aging    NCBI_ID   Quick_GO
# 2951  BiologicalProcess       GenDR   Aging    NCBI_ID   Quick_GO
# 2952  BiologicalProcess       GenDR   Aging    NCBI_ID   Quick_GO
# 2953  BiologicalProcess       GenDR   Aging    NCBI_ID   Quick_GO
#
#                                     head_detail_name  \
# 0                              alpha-2-macroglobulin
# 1     c-abl oncogene 1, non-receptor tyrosine kinase
# 2                                adenylate cyclase 1
# 3                                adenylate cyclase 2
# 4                                adenylate cyclase 3
# ...                                              ...
# 2949                                       sirtuin 1
# 2950                                  neuropeptide Y
# 2951                paired like homeodomain factor 1
# 2952  phosphoenolpyruvate carboxykinase 1, cytosolic
# 2953                                 forkhead box O3
#
#                      tail_detail_name       species
# 0                               aging  Mus musculus
# 1                               aging  Mus musculus
# 2                               aging  Mus musculus
# 3                               aging  Mus musculus
# 4                               aging  Mus musculus
# ...                               ...           ...
# 2949  response to caloric restriction  Mus musculus
# 2950  response to caloric restriction  Mus musculus
# 2951  response to caloric restriction  Mus musculus
# 2952  response to caloric restriction  Mus musculus
# 2953  response to caloric restriction  Mus musculus
#
# [2954 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'AgeAnnoMO', 'AgingAtlas', 'GenDR'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 2,954 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type          2954                   0            2954
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 2,954  |  After dedup: 2,817
#    head                relation        tail head_type relation_type  \
# 0  A1bg  Gene_BiologicalProcess  GO:1111113      Gene          None
# 1   A2m  Gene_BiologicalProcess  GO:0007568      Gene          None
# 2   A2m  Gene_BiologicalProcess  GO:1111113      Gene          None
#
#            tail_type   kg_source kg_type head_id_is tail_id_is  \
# 0  BiologicalProcess   AgeAnnoMO   Aging    NCBI_ID   Quick_GO
# 1  BiologicalProcess  AgingAtlas   Aging    NCBI_ID   Quick_GO
# 2  BiologicalProcess   AgeAnnoMO   Aging    NCBI_ID   Quick_GO
#
#          head_detail_name        tail_detail_name       species
# 0  alpha-1-B glycoprotein  Epigenetic Alterations  Mus musculus
# 1   alpha-2-macroglobulin                   aging  Mus musculus
# 2   alpha-2-macroglobulin  Epigenetic Alterations  Mus musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type          2817                   0            2817
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'AgeAnnoMO', 'AgingAtlas', 'GenDR'} kg_source
# AgeAnnoMO     2410
# AgingAtlas     400
# GenDR            7
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    2817
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 2,817 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_biologicalprocess/Mouse_gene_biologicalprocess.csv

# %%
# OUT_PATH
