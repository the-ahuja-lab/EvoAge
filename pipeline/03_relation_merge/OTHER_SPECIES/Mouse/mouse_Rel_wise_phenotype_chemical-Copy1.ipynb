# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_phenotype_chemical
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_phenotype_chemical/Mouse_phenotype_chemical.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Mouse_phenotype_chemical’: File exists

# %%
#

# %%
! ls /storage/Arushi/090526_EvoAge/kg_formation/processed_data/ageanno_processed_mo/ageanno_processed_mo/
# Out:
# ls: cannot access '/storage/Arushi/090526_EvoAge/kg_formation/processed_data/ageanno_processed_mo/ageanno_processed_mo/': No such file or directory

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Mouse/Mouse_Phenotype_ChemicalEntity.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch.rename(columns={
    'headtype': 'head_type',
    'tailtype': 'tail_type',
})
# monarch = monarch[~monarch['head_detail_name'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['species'] = 'M.musculus'
monarch['head_id_is'] = 'MP_ID'

print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 451 rows
#            head                  relation     tail  head_type relation_type  \
# 0    MP:0000180  Phenotype_ChemicalEntity     5997  Phenotype    related_to
# 1    MP:0000194  Phenotype_ChemicalEntity  5460341  Phenotype    related_to
# 2    MP:0000195  Phenotype_ChemicalEntity  5460341  Phenotype    related_to
# 3    MP:0000362  Phenotype_ChemicalEntity      774  Phenotype    related_to
# 4    MP:0000676  Phenotype_ChemicalEntity      962  Phenotype    related_to
# ..          ...                       ...      ...        ...           ...
# 446  MP:0031655  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
# 447  MP:0031656  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
# 448  MP:0031657  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
# 449  MP:0031658  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
# 450  MP:0031659  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
#
#           tail_type relation_source                        head_detail_name  \
# 0    ChemicalEntity  infores:upheno  abnormal circulating cholesterol level
# 1    ChemicalEntity  infores:upheno     increased circulating calcium level
# 2    ChemicalEntity  infores:upheno     decreased circulating calcium level
# 3    ChemicalEntity  infores:upheno   decreased mast cell histamine storage
# 4    ChemicalEntity  infores:upheno             abnormal body water content
# ..              ...             ...                                     ...
# 446  ChemicalEntity  infores:upheno          abnormal brain magnesium level
# 447  ChemicalEntity  infores:upheno         decreased brain magnesium level
# 448  ChemicalEntity  infores:upheno         increased brain magnesium level
# 449  ChemicalEntity  infores:upheno               decreased magnesium level
# 450  ChemicalEntity  infores:upheno               increased magnesium level
#
#     tail_detail_name head_taxon_name  tail_taxon_name head_id_is tail_id_is  \
# 0        cholesterol    Mus musculus              NaN      MP_ID    PubChem
# 1       calcium atom    Mus musculus              NaN      MP_ID    PubChem
# 2       calcium atom    Mus musculus              NaN      MP_ID    PubChem
# 3          histamine    Mus musculus              NaN      MP_ID    PubChem
# 4              water    Mus musculus              NaN      MP_ID    PubChem
# ..               ...             ...              ...        ...        ...
# 446   magnesium atom    Mus musculus              NaN      MP_ID    PubChem
# 447   magnesium atom    Mus musculus              NaN      MP_ID    PubChem
# 448   magnesium atom    Mus musculus              NaN      MP_ID    PubChem
# 449   magnesium atom    Mus musculus              NaN      MP_ID    PubChem
# 450   magnesium atom    Mus musculus              NaN      MP_ID    PubChem
#
#                                        tail_iupac_name     species  \
# 0    (3S,8S,9S,10R,13R,14S,17R)-10,13-dimethyl-17-[...  M.musculus
# 1                                              calcium  M.musculus
# 2                                              calcium  M.musculus
# 3                       2-(1H-imidazol-5-yl)ethanamine  M.musculus
# 4                                              oxidane  M.musculus
# ..                                                 ...         ...
# 446                                          magnesium  M.musculus
# 447                                          magnesium  M.musculus
# 448                                          magnesium  M.musculus
# 449                                          magnesium  M.musculus
# 450                                          magnesium  M.musculus
#
#          kg_type   kg_source
# 0    Generalised  Monarch_KG
# 1    Generalised  Monarch_KG
# 2    Generalised  Monarch_KG
# 3    Generalised  Monarch_KG
# 4    Generalised  Monarch_KG
# ..           ...         ...
# 446  Generalised  Monarch_KG
# 447  Generalised  Monarch_KG
# 448  Generalised  Monarch_KG
# 449  Generalised  Monarch_KG
# 450  Generalised  Monarch_KG
#
# [451 rows x 17 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    monarch,
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 451
#            head                  relation     tail  head_type relation_type  \
# 0    MP:0000180  Phenotype_ChemicalEntity     5997  Phenotype    related_to
# 1    MP:0000194  Phenotype_ChemicalEntity  5460341  Phenotype    related_to
# 2    MP:0000195  Phenotype_ChemicalEntity  5460341  Phenotype    related_to
# 3    MP:0000362  Phenotype_ChemicalEntity      774  Phenotype    related_to
# 4    MP:0000676  Phenotype_ChemicalEntity      962  Phenotype    related_to
# ..          ...                       ...      ...        ...           ...
# 446  MP:0031655  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
# 447  MP:0031656  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
# 448  MP:0031657  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
# 449  MP:0031658  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
# 450  MP:0031659  Phenotype_ChemicalEntity  5462224  Phenotype    related_to
#
#           tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0    ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 1    ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 2    ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 3    ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 4    ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# ..              ...         ...          ...        ...        ...
# 446  ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 447  ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 448  ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 449  ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 450  ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
#
#                            head_detail_name tail_detail_name     species
# 0    abnormal circulating cholesterol level      cholesterol  M.musculus
# 1       increased circulating calcium level     calcium atom  M.musculus
# 2       decreased circulating calcium level     calcium atom  M.musculus
# 3     decreased mast cell histamine storage        histamine  M.musculus
# 4               abnormal body water content            water  M.musculus
# ..                                      ...              ...         ...
# 446          abnormal brain magnesium level   magnesium atom  M.musculus
# 447         decreased brain magnesium level   magnesium atom  M.musculus
# 448         increased brain magnesium level   magnesium atom  M.musculus
# 449               decreased magnesium level   magnesium atom  M.musculus
# 450               increased magnesium level   magnesium atom  M.musculus
#
# [451 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Phenotype_ChemicalEntity'}
# head_type           : {'Phenotype'}
# tail_type           : {'ChemicalEntity'}
# relation_type       : {'related_to'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'MP_ID'}
# tail_id_is          : {'PubChem'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 451 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 451  |  After dedup: 451
#          head                  relation     tail  head_type relation_type  \
# 0  MP:0000180  Phenotype_ChemicalEntity     5997  Phenotype    related_to
# 1  MP:0000194  Phenotype_ChemicalEntity  5460341  Phenotype    related_to
# 2  MP:0000195  Phenotype_ChemicalEntity  5460341  Phenotype    related_to
#
#         tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0  ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 1  ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
# 2  ChemicalEntity  Monarch_KG  Generalised      MP_ID    PubChem
#
#                          head_detail_name tail_detail_name     species
# 0  abnormal circulating cholesterol level      cholesterol  M.musculus
# 1     increased circulating calcium level     calcium atom  M.musculus
# 2     decreased circulating calcium level     calcium atom  M.musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    451
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    451
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 451 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_phenotype_chemical/Mouse_phenotype_chemical.csv

# %%
# OUT_PATH
