# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_phenotype_cellularcomponent
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_phenotype_cellularcomponent/Mouse_phenotype_cellularcomponent.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Mouse_phenotype_cellularcomponent’: File exists

# %%
#

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Mouse/Mouse_Phenotype_CellularComponent.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch.rename(columns={
    'headtype': 'head_type',
    'tailtype': 'tail_type',
})
# monarch = monarch[~monarch['head_detail_name'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['species'] = 'M.musculus'
monarch['head_id_is'] = 'MP_ID'

print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 354 rows
#            head                     relation        tail  head_type  \
# 0    MP:0000731  Phenotype_CellularComponent  GO:0005581  Phenotype
# 1    MP:0001053  Phenotype_CellularComponent  GO:0031594  Phenotype
# 2    MP:0001805  Phenotype_CellularComponent  GO:0071736  Phenotype
# 3    MP:0001806  Phenotype_CellularComponent  GO:0071754  Phenotype
# 4    MP:0001807  Phenotype_CellularComponent  GO:0071746  Phenotype
# ..          ...                          ...         ...        ...
# 349  MP:0031388  Phenotype_CellularComponent  GO:0002177  Phenotype
# 350  MP:0031408  Phenotype_CellularComponent  GO:0061827  Phenotype
# 351  MP:0031409  Phenotype_CellularComponent  GO:0061827  Phenotype
# 352  MP:0031410  Phenotype_CellularComponent  GO:0036126  Phenotype
# 353  MP:0031620  Phenotype_CellularComponent  GO:0033391  Phenotype
#
#     relation_type          tail_type relation_source  \
# 0      related_to  CellularComponent  infores:upheno
# 1      related_to  CellularComponent  infores:upheno
# 2      related_to  CellularComponent  infores:upheno
# 3      related_to  CellularComponent  infores:upheno
# 4      related_to  CellularComponent  infores:upheno
# ..            ...                ...             ...
# 349    related_to  CellularComponent  infores:upheno
# 350    related_to  CellularComponent  infores:upheno
# 351    related_to  CellularComponent  infores:upheno
# 352    related_to  CellularComponent  infores:upheno
# 353    related_to  CellularComponent  infores:upheno
#
#                                  head_detail_name  \
# 0    increased collagen deposition in the muscles
# 1       abnormal neuromuscular synapse morphology
# 2                             decreased IgG level
# 3                             decreased IgM level
# 4                             decreased IgA level
# ..                                            ...
# 349                              absent manchette
# 350                            multi-headed sperm
# 351                           double-headed sperm
# 352                           biflagellated sperm
# 353           abnormal chromatoid body morphology
#
#                             tail_detail_name head_taxon_name  tail_taxon_name  \
# 0                            collagen trimer    Mus musculus              NaN
# 1                     neuromuscular junction    Mus musculus              NaN
# 2    IgG immunoglobulin complex, circulating    Mus musculus              NaN
# 3    IgM immunoglobulin complex, circulating    Mus musculus              NaN
# 4    IgA immunoglobulin complex, circulating    Mus musculus              NaN
# ..                                       ...             ...              ...
# 349                                manchette    Mus musculus              NaN
# 350                               sperm head    Mus musculus              NaN
# 351                               sperm head    Mus musculus              NaN
# 352                          sperm flagellum    Mus musculus              NaN
# 353                          chromatoid body    Mus musculus              NaN
#
#     head_id_is tail_id_is     species      kg_type   kg_source
# 0        MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# 1        MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# 2        MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# 3        MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# 4        MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# ..         ...        ...         ...          ...         ...
# 349      MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# 350      MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# 351      MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# 352      MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
# 353      MP_ID   Quick_GO  M.musculus  Generalised  Monarch_KG
#
# [354 rows x 16 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    monarch,
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 354
#            head                     relation        tail  head_type  \
# 0    MP:0000731  Phenotype_CellularComponent  GO:0005581  Phenotype
# 1    MP:0001053  Phenotype_CellularComponent  GO:0031594  Phenotype
# 2    MP:0001805  Phenotype_CellularComponent  GO:0071736  Phenotype
# 3    MP:0001806  Phenotype_CellularComponent  GO:0071754  Phenotype
# 4    MP:0001807  Phenotype_CellularComponent  GO:0071746  Phenotype
# ..          ...                          ...         ...        ...
# 349  MP:0031388  Phenotype_CellularComponent  GO:0002177  Phenotype
# 350  MP:0031408  Phenotype_CellularComponent  GO:0061827  Phenotype
# 351  MP:0031409  Phenotype_CellularComponent  GO:0061827  Phenotype
# 352  MP:0031410  Phenotype_CellularComponent  GO:0036126  Phenotype
# 353  MP:0031620  Phenotype_CellularComponent  GO:0033391  Phenotype
#
#     relation_type          tail_type   kg_source      kg_type head_id_is  \
# 0      related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 1      related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 2      related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 3      related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 4      related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# ..            ...                ...         ...          ...        ...
# 349    related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 350    related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 351    related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 352    related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 353    related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
#
#     tail_id_is                              head_detail_name  \
# 0     Quick_GO  increased collagen deposition in the muscles
# 1     Quick_GO     abnormal neuromuscular synapse morphology
# 2     Quick_GO                           decreased IgG level
# 3     Quick_GO                           decreased IgM level
# 4     Quick_GO                           decreased IgA level
# ..         ...                                           ...
# 349   Quick_GO                              absent manchette
# 350   Quick_GO                            multi-headed sperm
# 351   Quick_GO                           double-headed sperm
# 352   Quick_GO                           biflagellated sperm
# 353   Quick_GO           abnormal chromatoid body morphology
#
#                             tail_detail_name     species
# 0                            collagen trimer  M.musculus
# 1                     neuromuscular junction  M.musculus
# 2    IgG immunoglobulin complex, circulating  M.musculus
# 3    IgM immunoglobulin complex, circulating  M.musculus
# 4    IgA immunoglobulin complex, circulating  M.musculus
# ..                                       ...         ...
# 349                                manchette  M.musculus
# 350                               sperm head  M.musculus
# 351                               sperm head  M.musculus
# 352                          sperm flagellum  M.musculus
# 353                          chromatoid body  M.musculus
#
# [354 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Phenotype_CellularComponent'}
# head_type           : {'Phenotype'}
# tail_type           : {'CellularComponent'}
# relation_type       : {'related_to'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'MP_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 354 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 354  |  After dedup: 354
#          head                     relation        tail  head_type  \
# 0  MP:0000731  Phenotype_CellularComponent  GO:0005581  Phenotype
# 1  MP:0001053  Phenotype_CellularComponent  GO:0031594  Phenotype
# 2  MP:0001805  Phenotype_CellularComponent  GO:0071736  Phenotype
#
#   relation_type          tail_type   kg_source      kg_type head_id_is  \
# 0    related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 1    related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
# 2    related_to  CellularComponent  Monarch_KG  Generalised      MP_ID
#
#   tail_id_is                              head_detail_name  \
# 0   Quick_GO  increased collagen deposition in the muscles
# 1   Quick_GO     abnormal neuromuscular synapse morphology
# 2   Quick_GO                           decreased IgG level
#
#                           tail_detail_name     species
# 0                          collagen trimer  M.musculus
# 1                   neuromuscular junction  M.musculus
# 2  IgG immunoglobulin complex, circulating  M.musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    354
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    354
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 354 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_phenotype_cellularcomponent/Mouse_phenotype_cellularcomponent.csv

# %%
# OUT_PATH
