# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_gene_gene
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_gene/Mouse_gene_gene.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Mouse = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Mus_musculus.gene_info',
#     sep='\t',
    
# )
# # Mouse["LocusTag"] = Mouse["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Mouse_symbol2Locus_dict = dict(zip(Mouse['Symbol'], Mouse['LocusTag']))
# # Mouse
# # Mouse_symbol2Locus_dict
# Mouse

# %% [markdown]
# # STRING

# %%
string = pd.read_csv(PROC_DIR + 'string/mmus/string_MOUSE_GENE_GENE.csv')
string.columns = string.columns.str.lower()
string = string[~string['head_detail_name'].isna()]

string['kg_type'] = 'Generalised'
string['species'] = 'M.musculus'
print(f"string: {len(string):,} rows")
string['head_id_is'] = 'NCBI_ID'
string['tail_id_is'] = 'NCBI_ID'
string
# Out:
# string: 12,418,376 rows
#                    head   relation     tail head_type  relation_type  \
# 0         0610010K14Rik  Gene_Gene    Actr5      Gene            NaN
# 1         0610010K14Rik  Gene_Gene    Actr8      Gene            NaN
# 2         0610010K14Rik  Gene_Gene      Ak6      Gene            NaN
# 3         0610010K14Rik  Gene_Gene    Akap8      Gene            NaN
# 4         0610010K14Rik  Gene_Gene    Ap2s1      Gene            NaN
# ...                 ...        ...      ...       ...            ...
# 12418371         mt-Nd6  Gene_Gene   mt-Nd2      Gene            NaN
# 12418372         mt-Nd6  Gene_Gene   mt-Nd3      Gene            NaN
# 12418373         mt-Nd6  Gene_Gene   mt-Nd4      Gene            NaN
# 12418374         mt-Nd6  Gene_Gene  mt-Nd4l      Gene            NaN
# 12418375         mt-Nd6  Gene_Gene   mt-Nd5      Gene            NaN
#
#          tail_type head_id_is tail_id_is  \
# 0             Gene    NCBI_ID    NCBI_ID
# 1             Gene    NCBI_ID    NCBI_ID
# 2             Gene    NCBI_ID    NCBI_ID
# 3             Gene    NCBI_ID    NCBI_ID
# 4             Gene    NCBI_ID    NCBI_ID
# ...            ...        ...        ...
# 12418371      Gene    NCBI_ID    NCBI_ID
# 12418372      Gene    NCBI_ID    NCBI_ID
# 12418373      Gene    NCBI_ID    NCBI_ID
# 12418374      Gene    NCBI_ID    NCBI_ID
# 12418375      Gene    NCBI_ID    NCBI_ID
#
#                                            head_detail_name  \
# 0         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 1         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 2         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 3         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 4         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# ...                                                     ...
# 12418371  mitochondrially encoded NADH dehydrogenase 6 [...
# 12418372  mitochondrially encoded NADH dehydrogenase 6 [...
# 12418373  mitochondrially encoded NADH dehydrogenase 6 [...
# 12418374  mitochondrially encoded NADH dehydrogenase 6 [...
# 12418375  mitochondrially encoded NADH dehydrogenase 6 [...
#
#                                            tail_detail_name     species  \
# 0         ARP5 actin-related protein 5 [Source:MGI Symbo...  M.musculus
# 1         ARP8 actin-related protein 8 [Source:MGI Symbo...  M.musculus
# 2         adenylate kinase 6 [Source:MGI Symbol;Acc:MGI:...  M.musculus
# 3         A kinase anchor protein 8 [Source:MGI Symbol;A...  M.musculus
# 4         adaptor-related protein complex 2, sigma 1 sub...  M.musculus
# ...                                                     ...         ...
# 12418371  mitochondrially encoded NADH dehydrogenase 2 [...  M.musculus
# 12418372  mitochondrially encoded NADH dehydrogenase 3 [...  M.musculus
# 12418373  mitochondrially encoded NADH dehydrogenase 4 [...  M.musculus
# 12418374  mitochondrially encoded NADH dehydrogenase 4L ...  M.musculus
# 12418375  mitochondrially encoded NADH dehydrogenase 5 [...  M.musculus
#
#          kg_source      kg_type
# 0           STRING  Generalised
# 1           STRING  Generalised
# 2           STRING  Generalised
# 3           STRING  Generalised
# 4           STRING  Generalised
# ...            ...          ...
# 12418371    STRING  Generalised
# 12418372    STRING  Generalised
# 12418373    STRING  Generalised
# 12418374    STRING  Generalised
# 12418375    STRING  Generalised
#
# [12418376 rows x 13 columns]

# %%
string[string['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, relation, tail, head_type, relation_type, tail_type, head_id_is, tail_id_is, head_detail_name, tail_detail_name, species, kg_source, kg_type]
# Index: []

# %%
string[string['head']=='Ccdc80']
# Out:
#            head   relation           tail head_type  relation_type tail_type  \
# 1516198  Ccdc80  Gene_Gene  2310022B05Rik      Gene            NaN      Gene
# 1516199  Ccdc80  Gene_Gene       AY074887      Gene            NaN      Gene
# 1516200  Ccdc80  Gene_Gene        Aadacl2      Gene            NaN      Gene
# 1516201  Ccdc80  Gene_Gene          Abce1      Gene            NaN      Gene
# 1516202  Ccdc80  Gene_Gene         Abi3bp      Gene            NaN      Gene
# ...         ...        ...            ...       ...            ...       ...
# 1517025  Ccdc80  Gene_Gene            Zfx      Gene            NaN      Gene
# 1517026  Ccdc80  Gene_Gene           Zfy1      Gene            NaN      Gene
# 1517027  Ccdc80  Gene_Gene           Zfy2      Gene            NaN      Gene
# 1517028  Ccdc80  Gene_Gene          Zgpat      Gene            NaN      Gene
# 1517029  Ccdc80  Gene_Gene           Zhx3      Gene            NaN      Gene
#
#         head_id_is tail_id_is  \
# 1516198    NCBI_ID    NCBI_ID
# 1516199    NCBI_ID    NCBI_ID
# 1516200    NCBI_ID    NCBI_ID
# 1516201    NCBI_ID    NCBI_ID
# 1516202    NCBI_ID    NCBI_ID
# ...            ...        ...
# 1517025    NCBI_ID    NCBI_ID
# 1517026    NCBI_ID    NCBI_ID
# 1517027    NCBI_ID    NCBI_ID
# 1517028    NCBI_ID    NCBI_ID
# 1517029    NCBI_ID    NCBI_ID
#
#                                           head_detail_name  \
# 1516198  coiled-coil domain containing 80 [Source:MGI S...
# 1516199  coiled-coil domain containing 80 [Source:MGI S...
# 1516200  coiled-coil domain containing 80 [Source:MGI S...
# 1516201  coiled-coil domain containing 80 [Source:MGI S...
# 1516202  coiled-coil domain containing 80 [Source:MGI S...
# ...                                                    ...
# 1517025  coiled-coil domain containing 80 [Source:MGI S...
# 1517026  coiled-coil domain containing 80 [Source:MGI S...
# 1517027  coiled-coil domain containing 80 [Source:MGI S...
# 1517028  coiled-coil domain containing 80 [Source:MGI S...
# 1517029  coiled-coil domain containing 80 [Source:MGI S...
#
#                                           tail_detail_name     species  \
# 1516198  RIKEN cDNA 2310022B05 gene [Source:MGI Symbol;...  M.musculus
# 1516199  cDNA sequence AY074887 [Source:MGI Symbol;Acc:...  M.musculus
# 1516200  arylacetamide deacetylase like 2 [Source:MGI S...  M.musculus
# 1516201  ATP-binding cassette, sub-family E member 1 [S...  M.musculus
# 1516202  ABI family member 3 binding protein [Source:MG...  M.musculus
# ...                                                    ...         ...
# 1517025  zinc finger protein X-linked [Source:MGI Symbo...  M.musculus
# 1517026  zinc finger protein 1, Y-linked [Source:MGI Sy...  M.musculus
# 1517027  zinc finger protein 2, Y-linked [Source:MGI Sy...  M.musculus
# 1517028  zinc finger, CCCH-type with G patch domain [So...  M.musculus
# 1517029  zinc fingers and homeoboxes 3 [Source:MGI Symb...  M.musculus
#
#         kg_source      kg_type
# 1516198    STRING  Generalised
# 1516199    STRING  Generalised
# 1516200    STRING  Generalised
# 1516201    STRING  Generalised
# 1516202    STRING  Generalised
# ...           ...          ...
# 1517025    STRING  Generalised
# 1517026    STRING  Generalised
# 1517027    STRING  Generalised
# 1517028    STRING  Generalised
# 1517029    STRING  Generalised
#
# [832 rows x 13 columns]

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Mouse/GENE_GENE_Mouse_Mouse.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head_detail_name'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['species'] = 'M.musculus'
monarch['head_id_is'] = 'NCBI_ID'
monarch['tail_id_is'] = 'NCBI_ID'
print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 263,309 rows
#           head   relation      tail head_type   relation_type tail_type  \
# 0        Gnai3  Gene_Gene      Rgs4      Gene  interacts_with      Gene
# 1        Gnai3  Gene_Gene      Gnb4      Gene  interacts_with      Gene
# 2        Gnai3  Gene_Gene      Gnaq      Gene  interacts_with      Gene
# 3        Gnai3  Gene_Gene     Nucb1      Gene  interacts_with      Gene
# 4        Gnai3  Gene_Gene     Htr1f      Gene  interacts_with      Gene
# ...        ...        ...       ...       ...             ...       ...
# 263904    Spop  Gene_Gene      Spop      Gene  interacts_with      Gene
# 263905    Pak1  Gene_Gene      Rac1      Gene  interacts_with      Gene
# 263906    Wdr4  Gene_Gene  Arhgap17      Gene  interacts_with      Gene
# 263907  Nhlrc1  Gene_Gene     Epm2a      Gene  interacts_with      Gene
# 263908   Epm2a  Gene_Gene    Nhlrc1      Gene  interacts_with      Gene
#
#         relation_source   kg_source  \
# 0        infores:string  Monarch_KG
# 1        infores:string  Monarch_KG
# 2        infores:string  Monarch_KG
# 3        infores:string  Monarch_KG
# 4        infores:string  Monarch_KG
# ...                 ...         ...
# 263904  infores:biogrid  Monarch_KG
# 263905  infores:biogrid  Monarch_KG
# 263906  infores:biogrid  Monarch_KG
# 263907  infores:biogrid  Monarch_KG
# 263908  infores:biogrid  Monarch_KG
#
#                                          head_detail_name  \
# 0                              G protein subunit alpha i3
# 1                              G protein subunit alpha i3
# 2                              G protein subunit alpha i3
# 3                              G protein subunit alpha i3
# 4                              G protein subunit alpha i3
# ...                                                   ...
# 263904                       speckle-type BTB/POZ protein
# 263905                      p21 (RAC1) activated kinase 1
# 263906                                 WD repeat domain 4
# 263907                            NHL repeat containing 1
# 263908  epilepsy, progressive myoclonic epilepsy, type...
#
#                                          tail_detail_name head_taxon_name  \
# 0                      regulator of G-protein signaling 4    Mus musculus
# 1       guanine nucleotide binding protein (G protein)...    Mus musculus
# 2       guanine nucleotide binding protein, alpha q po...    Mus musculus
# 3                                          nucleobindin 1    Mus musculus
# 4             5-hydroxytryptamine (serotonin) receptor 1F    Mus musculus
# ...                                                   ...             ...
# 263904                       speckle-type BTB/POZ protein    Mus musculus
# 263905                          Rac family small GTPase 1    Mus musculus
# 263906                   Rho GTPase activating protein 17    Mus musculus
# 263907  epilepsy, progressive myoclonic epilepsy, type...    Mus musculus
# 263908                            NHL repeat containing 1    Mus musculus
#
#        tail_taxon_name head_id_is tail_id_is    head_name    tail_name  \
# 0         Mus musculus    NCBI_ID    NCBI_ID    MGI:95773   MGI:108409
# 1         Mus musculus    NCBI_ID    NCBI_ID    MGI:95773   MGI:104581
# 2         Mus musculus    NCBI_ID    NCBI_ID    MGI:95773    MGI:95776
# 3         Mus musculus    NCBI_ID    NCBI_ID    MGI:95773    MGI:97388
# 4         Mus musculus    NCBI_ID    NCBI_ID    MGI:95773    MGI:99842
# ...                ...        ...        ...          ...          ...
# 263904    Mus musculus    NCBI_ID    NCBI_ID  MGI:1343085  MGI:1343085
# 263905    Mus musculus    NCBI_ID    NCBI_ID  MGI:1339975    MGI:97845
# 263906    Mus musculus    NCBI_ID    NCBI_ID  MGI:1889002  MGI:1917747
# 263907    Mus musculus    NCBI_ID    NCBI_ID  MGI:2145264  MGI:1341085
# 263908    Mus musculus    NCBI_ID    NCBI_ID  MGI:1341085  MGI:2145264
#
#            species      kg_type
# 0       M.musculus  Generalised
# 1       M.musculus  Generalised
# 2       M.musculus  Generalised
# 3       M.musculus  Generalised
# 4       M.musculus  Generalised
# ...            ...          ...
# 263904  M.musculus  Generalised
# 263905  M.musculus  Generalised
# 263906  M.musculus  Generalised
# 263907  M.musculus  Generalised
# 263908  M.musculus  Generalised
#
# [263309 rows x 18 columns]

# %%
monarch[monarch['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, relation, tail, head_type, relation_type, tail_type, relation_source, kg_source, head_detail_name, tail_detail_name, head_taxon_name, tail_taxon_name, head_id_is, tail_id_is, head_name, tail_name, species, kg_type]
# Index: []

# %% [markdown]
# # MouseNet

# %%
mousenet = pd.read_csv(PROC_DIR + 'mousenet/mousenet_MOUSE_GENE_GENE.csv')

mousenet.columns = mousenet.columns.str.lower()
mousenet = mousenet[~mousenet['head_detail_name'].isna()]
mousenet['kg_type'] = 'Generalised'
mousenet['species'] = 'M.musculus'
mousenet['species'] = 'M.musculus'
mousenet['kg_source'] = 'Mouse_Net'

mousenet['head_id_is'] = 'NCBI_ID'
mousenet['tail_id_is'] = 'NCBI_ID'
print(f"mousenet: {len(mousenet):,} rows")
mousenet
# Out:
# mousenet: 698,626 rows
#                  head   relation      tail head_type  relation_type tail_type  \
# 0       1110004F10Rik  Gene_Gene  Aasdhppt      Gene            NaN      Gene
# 1       1110004F10Rik  Gene_Gene   Ankrd17      Gene            NaN      Gene
# 2       1110004F10Rik  Gene_Gene      Bzw2      Gene            NaN      Gene
# 3       1110004F10Rik  Gene_Gene   Chordc1      Gene            NaN      Gene
# 4       1110004F10Rik  Gene_Gene     Cmtr1      Gene            NaN      Gene
# ...               ...        ...       ...       ...            ...       ...
# 698621           Zzz3  Gene_Gene    Yeats2      Gene            NaN      Gene
# 698622           Zzz3  Gene_Gene     Zbtb9      Gene            NaN      Gene
# 698623           Zzz3  Gene_Gene    Zfp212      Gene            NaN      Gene
# 698624           Zzz3  Gene_Gene   Zfp36l2      Gene            NaN      Gene
# 698625           Zzz3  Gene_Gene  Zkscan17      Gene            NaN      Gene
#
#        head_id_is tail_id_is                     head_detail_name  \
# 0         NCBI_ID    NCBI_ID           RIKEN cDNA 1110004F10 gene
# 1         NCBI_ID    NCBI_ID           RIKEN cDNA 1110004F10 gene
# 2         NCBI_ID    NCBI_ID           RIKEN cDNA 1110004F10 gene
# 3         NCBI_ID    NCBI_ID           RIKEN cDNA 1110004F10 gene
# 4         NCBI_ID    NCBI_ID           RIKEN cDNA 1110004F10 gene
# ...           ...        ...                                  ...
# 698621    NCBI_ID    NCBI_ID  zinc finger, ZZ domain containing 3
# 698622    NCBI_ID    NCBI_ID  zinc finger, ZZ domain containing 3
# 698623    NCBI_ID    NCBI_ID  zinc finger, ZZ domain containing 3
# 698624    NCBI_ID    NCBI_ID  zinc finger, ZZ domain containing 3
# 698625    NCBI_ID    NCBI_ID  zinc finger, ZZ domain containing 3
#
#                                          tail_detail_name     species  \
# 0       aminoadipate-semialdehyde dehydrogenase-phosph...  M.musculus
# 1                                ankyrin repeat domain 17  M.musculus
# 2                   basic leucine zipper and W2 domains 2  M.musculus
# 3         cysteine and histidine rich domain containing 1  M.musculus
# 4                                 cap methyltransferase 1  M.musculus
# ...                                                   ...         ...
# 698621                          YEATS domain containing 2  M.musculus
# 698622            zinc finger and BTB domain containing 9  M.musculus
# 698623                            Zinc finger protein 212  M.musculus
# 698624            zinc finger protein 36, C3H type-like 2  M.musculus
# 698625          zinc finger with KRAB and SCAN domains 17  M.musculus
#
#         kg_source      kg_type
# 0       Mouse_Net  Generalised
# 1       Mouse_Net  Generalised
# 2       Mouse_Net  Generalised
# 3       Mouse_Net  Generalised
# 4       Mouse_Net  Generalised
# ...           ...          ...
# 698621  Mouse_Net  Generalised
# 698622  Mouse_Net  Generalised
# 698623  Mouse_Net  Generalised
# 698624  Mouse_Net  Generalised
# 698625  Mouse_Net  Generalised
#
# [698626 rows x 13 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    string, monarch, mousenet
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 13,380,311
#                    head   relation      tail head_type relation_type  \
# 0         0610010K14Rik  Gene_Gene     Actr5      Gene           NaN
# 1         0610010K14Rik  Gene_Gene     Actr8      Gene           NaN
# 2         0610010K14Rik  Gene_Gene       Ak6      Gene           NaN
# 3         0610010K14Rik  Gene_Gene     Akap8      Gene           NaN
# 4         0610010K14Rik  Gene_Gene     Ap2s1      Gene           NaN
# ...                 ...        ...       ...       ...           ...
# 13380306           Zzz3  Gene_Gene    Yeats2      Gene           NaN
# 13380307           Zzz3  Gene_Gene     Zbtb9      Gene           NaN
# 13380308           Zzz3  Gene_Gene    Zfp212      Gene           NaN
# 13380309           Zzz3  Gene_Gene   Zfp36l2      Gene           NaN
# 13380310           Zzz3  Gene_Gene  Zkscan17      Gene           NaN
#
#          tail_type  kg_source      kg_type head_id_is tail_id_is  \
# 0             Gene     STRING  Generalised    NCBI_ID    NCBI_ID
# 1             Gene     STRING  Generalised    NCBI_ID    NCBI_ID
# 2             Gene     STRING  Generalised    NCBI_ID    NCBI_ID
# 3             Gene     STRING  Generalised    NCBI_ID    NCBI_ID
# 4             Gene     STRING  Generalised    NCBI_ID    NCBI_ID
# ...            ...        ...          ...        ...        ...
# 13380306      Gene  Mouse_Net  Generalised    NCBI_ID    NCBI_ID
# 13380307      Gene  Mouse_Net  Generalised    NCBI_ID    NCBI_ID
# 13380308      Gene  Mouse_Net  Generalised    NCBI_ID    NCBI_ID
# 13380309      Gene  Mouse_Net  Generalised    NCBI_ID    NCBI_ID
# 13380310      Gene  Mouse_Net  Generalised    NCBI_ID    NCBI_ID
#
#                                            head_detail_name  \
# 0         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 1         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 2         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 3         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 4         RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# ...                                                     ...
# 13380306                zinc finger, ZZ domain containing 3
# 13380307                zinc finger, ZZ domain containing 3
# 13380308                zinc finger, ZZ domain containing 3
# 13380309                zinc finger, ZZ domain containing 3
# 13380310                zinc finger, ZZ domain containing 3
#
#                                            tail_detail_name     species
# 0         ARP5 actin-related protein 5 [Source:MGI Symbo...  M.musculus
# 1         ARP8 actin-related protein 8 [Source:MGI Symbo...  M.musculus
# 2         adenylate kinase 6 [Source:MGI Symbol;Acc:MGI:...  M.musculus
# 3         A kinase anchor protein 8 [Source:MGI Symbol;A...  M.musculus
# 4         adaptor-related protein complex 2, sigma 1 sub...  M.musculus
# ...                                                     ...         ...
# 13380306                          YEATS domain containing 2  M.musculus
# 13380307            zinc finger and BTB domain containing 9  M.musculus
# 13380308                            Zinc finger protein 212  M.musculus
# 13380309            zinc finger protein 36, C3H type-like 2  M.musculus
# 13380310          zinc finger with KRAB and SCAN domains 17  M.musculus
#
# [13380311 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Gene'}
# head_type           : {'Gene'}
# tail_type           : {'Gene'}
# relation_type       : {nan, 'interacts_with'}
# kg_source           : {'Mouse_Net', 'STRING', 'Monarch_KG'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'NCBI_ID'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 596 unresolvable rows → 13,379,715 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type      13117002            13117002        26234004
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 13,379,715  |  After dedup: 12,868,597
#             head   relation   tail head_type relation_type tail_type  \
# 0  0610010K14Rik  Gene_Gene  Actr5      Gene          None      Gene
# 1  0610010K14Rik  Gene_Gene  Actr8      Gene          None      Gene
# 2  0610010K14Rik  Gene_Gene    Ak6      Gene          None      Gene
#
#   kg_source      kg_type head_id_is tail_id_is  \
# 0    STRING  Generalised    NCBI_ID    NCBI_ID
# 1    STRING  Generalised    NCBI_ID    NCBI_ID
# 2    STRING  Generalised    NCBI_ID    NCBI_ID
#
#                                     head_detail_name  \
# 0  RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 1  RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
# 2  RIKEN cDNA 0610010K14 gene [Source:MGI Symbol;...
#
#                                     tail_detail_name     species
# 0  ARP5 actin-related protein 5 [Source:MGI Symbo...  M.musculus
# 1  ARP8 actin-related protein 8 [Source:MGI Symbo...  M.musculus
# 2  adenylate kinase 6 [Source:MGI Symbol;Acc:MGI:...  M.musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type      12618302                   0        12618302
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG::Mouse_Net', 'Monarch_KG::STRING', 'Mouse_Net', 'STRING', 'Mouse_Net::STRING', 'Monarch_KG', 'Monarch_KG::Mouse_Net::STRING'} kg_source
# STRING                           11962203
# Mouse_Net                          432631
# Mouse_Net::STRING                  223468
# Monarch_KG::STRING                 190535
# Monarch_KG::Mouse_Net::STRING       42170
# Monarch_KG                          17233
# Monarch_KG::Mouse_Net                 357
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    12868597
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 12,868,597 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_gene/Mouse_gene_gene.csv

# %%
OUT_PATH
# Out:
# '/storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_gene/Mouse_gene_gene.csv'

# %%
#
