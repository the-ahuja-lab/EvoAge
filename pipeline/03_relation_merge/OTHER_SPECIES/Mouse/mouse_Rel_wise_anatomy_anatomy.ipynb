# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_anatomy_anatomy
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_anatomy_anatomy/Mouse_anatomy_anatomy.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Mouse = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Mus_musculus.gene_info',
#     sep='\t',
    
# )
# # Mouse["LocusTag"] = Mouse["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Mouse_symbol2Locus_dict = dict(zip(Mouse['Symbol'], Mouse['LocusTag']))
# # Mouse
# # Mouse_symbol2Locus_dict
# Mouse

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Mouse/Mouse_AnatomicalEntity_AnatomicalEntity.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch.rename(columns={
    'headtype': 'head_type',
    'tailtype': 'tail_type',
})
# monarch = monarch[~monarch['head_detail_name'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['species'] = 'M.musculus'
monarch['relation'] = 'AnatomicalEntity_AnatomicalEntity'
monarch['head_type'] = 'AnatomicalEntity'
monarch['tail_type'] = 'AnatomicalEntity'

print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 4,579 rows
#              head                           relation         tail  \
# 0     EMAPA:16032  AnatomicalEntity_AnatomicalEntity  EMAPA:31859
# 1     EMAPA:16033  AnatomicalEntity_AnatomicalEntity  EMAPA:36032
# 2     EMAPA:16034  AnatomicalEntity_AnatomicalEntity  EMAPA:31859
# 3     EMAPA:16036  AnatomicalEntity_AnatomicalEntity  EMAPA:36032
# 4     EMAPA:16037  AnatomicalEntity_AnatomicalEntity  EMAPA:36032
# ...           ...                                ...          ...
# 4574  EMAPA:38234  AnatomicalEntity_AnatomicalEntity  EMAPA:35263
# 4575  EMAPA:38235  AnatomicalEntity_AnatomicalEntity  EMAPA:35263
# 4576  EMAPA:38236  AnatomicalEntity_AnatomicalEntity  EMAPA:38235
# 4577  EMAPA:38237  AnatomicalEntity_AnatomicalEntity  EMAPA:38235
# 4578  EMAPA:38238  AnatomicalEntity_AnatomicalEntity  EMAPA:35178
#
#              head_type relation_type         tail_type relation_source  \
# 0     AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# 1     AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# 2     AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# 3     AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# 4     AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# ...                ...           ...               ...             ...
# 4574  AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# 4575  AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# 4576  AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# 4577  AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
# 4578  AnatomicalEntity   subclass_of  AnatomicalEntity   infores:emapa
#
#                       head_detail_name                 tail_detail_name  \
# 0                     first polar body                       polar body
# 1                  1-cell stage embryo                     early embryo
# 2                    second polar body                       polar body
# 3                  2-cell stage embryo                     early embryo
# 4                4-8 cell stage embryo                     early embryo
# ...                                ...                              ...
# 4574         cranial suture mesenchyme                   cranial suture
# 4575   cranial suture osteogenic front                   cranial suture
# 4576   coronal suture osteogenic front  cranial suture osteogenic front
# 4577  lambdoid suture osteogenic front  cranial suture osteogenic front
# 4578          exocoelomic cavity fluid          body fluid or substance
#
#      head_taxon_name tail_taxon_name head_id_is tail_id_is     species  \
# 0       Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# 1       Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# 2       Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# 3       Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# 4       Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# ...              ...             ...        ...        ...         ...
# 4574    Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# 4575    Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# 4576    Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# 4577    Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
# 4578    Mus musculus    Mus musculus      EMAPA      EMAPA  M.musculus
#
#           kg_type   kg_source
# 0     Generalised  Monarch_KG
# 1     Generalised  Monarch_KG
# 2     Generalised  Monarch_KG
# 3     Generalised  Monarch_KG
# 4     Generalised  Monarch_KG
# ...           ...         ...
# 4574  Generalised  Monarch_KG
# 4575  Generalised  Monarch_KG
# 4576  Generalised  Monarch_KG
# 4577  Generalised  Monarch_KG
# 4578  Generalised  Monarch_KG
#
# [4579 rows x 16 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    monarch,
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 4,579
#              head                           relation         tail  \
# 0     EMAPA:16032  AnatomicalEntity_AnatomicalEntity  EMAPA:31859
# 1     EMAPA:16033  AnatomicalEntity_AnatomicalEntity  EMAPA:36032
# 2     EMAPA:16034  AnatomicalEntity_AnatomicalEntity  EMAPA:31859
# 3     EMAPA:16036  AnatomicalEntity_AnatomicalEntity  EMAPA:36032
# 4     EMAPA:16037  AnatomicalEntity_AnatomicalEntity  EMAPA:36032
# ...           ...                                ...          ...
# 4574  EMAPA:38234  AnatomicalEntity_AnatomicalEntity  EMAPA:35263
# 4575  EMAPA:38235  AnatomicalEntity_AnatomicalEntity  EMAPA:35263
# 4576  EMAPA:38236  AnatomicalEntity_AnatomicalEntity  EMAPA:38235
# 4577  EMAPA:38237  AnatomicalEntity_AnatomicalEntity  EMAPA:38235
# 4578  EMAPA:38238  AnatomicalEntity_AnatomicalEntity  EMAPA:35178
#
#              head_type relation_type         tail_type   kg_source  \
# 0     AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 1     AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 2     AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 3     AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 4     AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# ...                ...           ...               ...         ...
# 4574  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 4575  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 4576  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 4577  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 4578  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
#
#           kg_type head_id_is tail_id_is                  head_detail_name  \
# 0     Generalised      EMAPA      EMAPA                  first polar body
# 1     Generalised      EMAPA      EMAPA               1-cell stage embryo
# 2     Generalised      EMAPA      EMAPA                 second polar body
# 3     Generalised      EMAPA      EMAPA               2-cell stage embryo
# 4     Generalised      EMAPA      EMAPA             4-8 cell stage embryo
# ...           ...        ...        ...                               ...
# 4574  Generalised      EMAPA      EMAPA         cranial suture mesenchyme
# 4575  Generalised      EMAPA      EMAPA   cranial suture osteogenic front
# 4576  Generalised      EMAPA      EMAPA   coronal suture osteogenic front
# 4577  Generalised      EMAPA      EMAPA  lambdoid suture osteogenic front
# 4578  Generalised      EMAPA      EMAPA          exocoelomic cavity fluid
#
#                      tail_detail_name     species
# 0                          polar body  M.musculus
# 1                        early embryo  M.musculus
# 2                          polar body  M.musculus
# 3                        early embryo  M.musculus
# 4                        early embryo  M.musculus
# ...                               ...         ...
# 4574                   cranial suture  M.musculus
# 4575                   cranial suture  M.musculus
# 4576  cranial suture osteogenic front  M.musculus
# 4577  cranial suture osteogenic front  M.musculus
# 4578          body fluid or substance  M.musculus
#
# [4579 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'AnatomicalEntity_AnatomicalEntity'}
# head_type           : {'AnatomicalEntity'}
# tail_type           : {'AnatomicalEntity'}
# relation_type       : {'subclass_of'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'EMAPA'}
# tail_id_is          : {'EMAPA'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 4,579 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 4,579  |  After dedup: 4,579
#           head                           relation         tail  \
# 0  EMAPA:16032  AnatomicalEntity_AnatomicalEntity  EMAPA:31859
# 1  EMAPA:16033  AnatomicalEntity_AnatomicalEntity  EMAPA:36032
# 2  EMAPA:16034  AnatomicalEntity_AnatomicalEntity  EMAPA:31859
#
#           head_type relation_type         tail_type   kg_source      kg_type  \
# 0  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG  Generalised
# 1  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG  Generalised
# 2  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG  Generalised
#
#   head_id_is tail_id_is     head_detail_name tail_detail_name     species
# 0      EMAPA      EMAPA     first polar body       polar body  M.musculus
# 1      EMAPA      EMAPA  1-cell stage embryo     early embryo  M.musculus
# 2      EMAPA      EMAPA    second polar body       polar body  M.musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    4579
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    4579
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 4,579 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_anatomy_anatomy/Mouse_anatomy_anatomy.csv

# %%
# OUT_PATH
