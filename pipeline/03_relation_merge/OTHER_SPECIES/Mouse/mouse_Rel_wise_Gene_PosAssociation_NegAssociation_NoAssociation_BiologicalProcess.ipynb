# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'


# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Mouse = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Mus_musculus.gene_info',
#     sep='\t',
    
# )
# # Mouse["LocusTag"] = Mouse["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Mouse_symbol2Locus_dict = dict(zip(Mouse['Symbol'], Mouse['LocusTag']))
# # Mouse
# # Mouse_symbol2Locus_dict
# Mouse

# %% [markdown]
# # DAA POSITIVE Association

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_gene_POS_ASS_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_POS_ASS_biologicalprocess/Mouse_gene_POS_ASS_biologicalprocess.csv'

# %%
DAA = pd.read_csv(PROC_DIR + 'digitalagingatlas/Mouse/DAA_Mouse_Gene_Pos_BiologicalProcess.csv')
DAA.columns = DAA.columns.str.lower()
DAA = DAA[~DAA['head_detail_name'].isna()]

DAA['kg_type'] = 'Aging'

print(f"DAA: {len(DAA):,} rows")
DAA['head_id_is'] = 'NCBI_ID'
DAA['tail_id_is'] = 'Quick_GO'
DAA['species'] = 'Mus musculus'
DAA['tail_detail_name'] = 'aging'
DAA['kg_source'] = 'DAA'
DAA['relation'] = 'Gene_PositivelyAssociatedWith_BiologicalProcess'
DAA
# Out:
# DAA: 307 rows
#         head                                         relation        tail  \
# 0       Abat  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 1      Dhcr7  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 2      Acta1  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 3      Alcam  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 4     Adam25  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# ..       ...                                              ...         ...
# 302   Zbtb16  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 303  Zcchc18  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 304    Zfp62  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 305    Zfp64  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 306    Zfp68  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
#
#     head_type          tail_type                            head_detail_name  \
# 0        Gene  BiologicalProcess            4-aminobutyrate aminotransferase
# 1        Gene  BiologicalProcess              7-dehydrocholesterol reductase
# 2        Gene  BiologicalProcess              actin alpha 1, skeletal muscle
# 3        Gene  BiologicalProcess  activated leukocyte cell adhesion molecule
# 4        Gene  BiologicalProcess             ADAM metallopeptidase domain 25
# ..        ...                ...                                         ...
# 302      Gene  BiologicalProcess    zinc finger and BTB domain containing 16
# 303      Gene  BiologicalProcess      zinc finger, CCHC domain containing 18
# 304      Gene  BiologicalProcess                      zinc finger protein 62
# 305      Gene  BiologicalProcess                      zinc finger protein 64
# 306      Gene  BiologicalProcess                      zinc finger protein 68
#
#        relation_source       species    data_type kg_type head_id_is  \
# 0    DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# 1    DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# 2    DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# 3    DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# 4    DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# ..                 ...           ...          ...     ...        ...
# 302  DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# 303  DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# 304  DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# 305  DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
# 306  DigitalAgingAtlas  Mus musculus  Associative   Aging    NCBI_ID
#
#     tail_id_is tail_detail_name kg_source
# 0     Quick_GO            aging       DAA
# 1     Quick_GO            aging       DAA
# 2     Quick_GO            aging       DAA
# 3     Quick_GO            aging       DAA
# 4     Quick_GO            aging       DAA
# ..         ...              ...       ...
# 302   Quick_GO            aging       DAA
# 303   Quick_GO            aging       DAA
# 304   Quick_GO            aging       DAA
# 305   Quick_GO            aging       DAA
# 306   Quick_GO            aging       DAA
#
# [307 rows x 14 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    DAA, 
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 307
#         head                                         relation        tail  \
# 0       Abat  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 1      Dhcr7  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 2      Acta1  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 3      Alcam  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 4     Adam25  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# ..       ...                                              ...         ...
# 302   Zbtb16  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 303  Zcchc18  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 304    Zfp62  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 305    Zfp64  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 306    Zfp68  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
#
#     head_type relation_type          tail_type kg_source kg_type head_id_is  \
# 0        Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 1        Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 2        Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 3        Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 4        Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# ..        ...           ...                ...       ...     ...        ...
# 302      Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 303      Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 304      Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 305      Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 306      Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
#
#     tail_id_is                            head_detail_name tail_detail_name  \
# 0     Quick_GO            4-aminobutyrate aminotransferase            aging
# 1     Quick_GO              7-dehydrocholesterol reductase            aging
# 2     Quick_GO              actin alpha 1, skeletal muscle            aging
# 3     Quick_GO  activated leukocyte cell adhesion molecule            aging
# 4     Quick_GO             ADAM metallopeptidase domain 25            aging
# ..         ...                                         ...              ...
# 302   Quick_GO    zinc finger and BTB domain containing 16            aging
# 303   Quick_GO      zinc finger, CCHC domain containing 18            aging
# 304   Quick_GO                      zinc finger protein 62            aging
# 305   Quick_GO                      zinc finger protein 64            aging
# 306   Quick_GO                      zinc finger protein 68            aging
#
#           species
# 0    Mus musculus
# 1    Mus musculus
# 2    Mus musculus
# 3    Mus musculus
# 4    Mus musculus
# ..            ...
# 302  Mus musculus
# 303  Mus musculus
# 304  Mus musculus
# 305  Mus musculus
# 306  Mus musculus
#
# [307 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_PositivelyAssociatedWith_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'DAA'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 307 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           307                   0             307
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 307  |  After dedup: 297
#             head                                         relation        tail  \
# 0  1600029I14Rik  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 1  1700056E22Rik  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
# 2  1810044D09Rik  Gene_PositivelyAssociatedWith_BiologicalProcess  GO:0007568
#
#   head_type relation_type          tail_type kg_source kg_type head_id_is  \
# 0      Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 1      Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
# 2      Gene          None  BiologicalProcess       DAA   Aging    NCBI_ID
#
#   tail_id_is            head_detail_name tail_detail_name       species
# 0   Quick_GO  RIKEN cDNA 1600029I14 gene            aging  Mus musculus
# 1   Quick_GO  RIKEN cDNA 1700056E22 gene            aging  Mus musculus
# 2   Quick_GO  RIKEN cDNA 1810044D09 gene            aging  Mus musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           297                   0             297
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'DAA'} kg_source
# DAA    297
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    297
# Name: count, dtype: int64

# %%
# ! mkdir Mouse_gene_POS_ASS_biologicalprocess

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 297 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_POS_ASS_biologicalprocess/Mouse_gene_POS_ASS_biologicalprocess.csv

# %%
# OUT_PATH

# %% [markdown]
# # DAA NEGATIVE Association

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_gene_NEG_ASS_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_NEG_ASS_biologicalprocess/Mouse_gene_NEG_ASS_biologicalprocess.csv'

# %%
DAA = pd.read_csv(PROC_DIR + 'digitalagingatlas/Mouse/DAA_Mouse_Gene_Neg_BiologicalProcess.csv')
DAA.columns = DAA.columns.str.lower()
DAA = DAA[~DAA['head_detail_name'].isna()]

DAA['kg_type'] = 'Aging'

print(f"DAA: {len(DAA):,} rows")
DAA['head_id_is'] = 'NCBI_ID'
DAA['tail_id_is'] = 'Quick_GO'
DAA['species'] = 'Mus musculus'
DAA['tail_detail_name'] = 'aging'
DAA['kg_source'] = 'DAA'
DAA['relation'] = 'Gene_NegativelyAssociatedWith_BiologicalProcess'
DAA
# Out:
# DAA: 217 rows
#         head                                         relation        tail  \
# 0    Abhd14a  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# 1      Actc1  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# 2      Acsm2  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# 3      Acss1  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# 4      Acot7  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# ..       ...                                              ...         ...
# 212    Zfhx3  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# 213    Zmym1  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# 214   Zfp251  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# 215    Zfp84  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
# 216     Zzz3  Gene_NegativelyAssociatedWith_BiologicalProcess  GO:0007568
#
#     head_type          tail_type  \
# 0        Gene  BiologicalProcess
# 1        Gene  BiologicalProcess
# 2        Gene  BiologicalProcess
# 3        Gene  BiologicalProcess
# 4        Gene  BiologicalProcess
# ..        ...                ...
# 212      Gene  BiologicalProcess
# 213      Gene  BiologicalProcess
# 214      Gene  BiologicalProcess
# 215      Gene  BiologicalProcess
# 216      Gene  BiologicalProcess
#
#                                      head_detail_name    relation_source  \
# 0                   abhydrolase domain containing 14A  DigitalAgingAtlas
# 1                      actin, alpha, cardiac muscle 1  DigitalAgingAtlas
# 2    acyl-CoA synthetase medium-chain family member 2  DigitalAgingAtlas
# 3     acyl-CoA synthetase short-chain family member 1  DigitalAgingAtlas
# 4                             acyl-CoA thioesterase 7  DigitalAgingAtlas
# ..                                                ...                ...
# 212                            zinc finger homeobox 3  DigitalAgingAtlas
# 213              zinc finger, MYM domain containing 1  DigitalAgingAtlas
# 214                           zinc finger protein 251  DigitalAgingAtlas
# 215                            zinc finger protein 84  DigitalAgingAtlas
# 216               zinc finger, ZZ domain containing 3  DigitalAgingAtlas
#
#           species    data_type kg_type head_id_is tail_id_is tail_detail_name  \
# 0    Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 1    Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 2    Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 3    Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 4    Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# ..            ...          ...     ...        ...        ...              ...
# 212  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 213  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 214  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 215  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 216  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
#
#     kg_source
# 0         DAA
# 1         DAA
# 2         DAA
# 3         DAA
# 4         DAA
# ..        ...
# 212       DAA
# 213       DAA
# 214       DAA
# 215       DAA
# 216       DAA
#
# [217 rows x 14 columns]

# %%
for col in ['relation', 'head_type', 'tail_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(DAA[col])}")
# Out:
# relation            : {'Gene_NegativelyAssociatedWith_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# kg_source           : {'DAA'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
! mkdir Mouse_gene_NEG_ASS_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Mouse_gene_NEG_ASS_biologicalprocess’: File exists

# %%
DAA.to_csv(OUT_PATH, index=False)
print(f"Saved {len(DAA):,} rows → {OUT_PATH}")
# Out:
# Saved 217 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_NEG_ASS_biologicalprocess/Mouse_gene_NEG_ASS_biologicalprocess.csv

# %% [markdown]
# # DAA NOT Association

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_gene_NOT_ASS_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_NOT_ASS_biologicalprocess/Mouse_gene_NOT_ASS_biologicalprocess.csv'

# %%
DAA = pd.read_csv(PROC_DIR + 'digitalagingatlas/Mouse/DAA_Mouse_Gene_Not_BiologicalProcess.csv')
DAA.columns = DAA.columns.str.lower()
DAA = DAA[~DAA['head_detail_name'].isna()]

DAA['kg_type'] = 'Aging'

print(f"DAA: {len(DAA):,} rows")
DAA['head_id_is'] = 'NCBI_ID'
DAA['tail_id_is'] = 'Quick_GO'
DAA['species'] = 'Mus musculus'
DAA['tail_detail_name'] = 'aging'
DAA['kg_source'] = 'DAA'
DAA['relation'] = 'Gene_NotAssociatedWith_BiologicalProcess'
DAA
# Out:
# DAA: 24 rows
#              head                                  relation        tail  \
# 0           Ap2m1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 1          Brms1l  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 2          Commd4  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 3          Cox6a1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 4           Dmbt1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 5           Dip2b  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 6        AI596487  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 7           Foxl1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 8            Fmc1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 9           Gtf2i  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 10           Gad1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 11          Grhpr  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 12       Hsp90aa1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 13          Mcfd2  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 14          Myoz1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 15         Ndufb4  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 16         Ndufb5  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 17            Ank  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 18          Prpf6  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 19         Rad23b  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 20  2310033P09Rik  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 21         Ahcyl1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 22        Sec61a1  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
# 23       Slc25a11  Gene_NotAssociatedWith_BiologicalProcess  GO:0007568
#
#    head_type          tail_type  \
# 0       Gene  BiologicalProcess
# 1       Gene  BiologicalProcess
# 2       Gene  BiologicalProcess
# 3       Gene  BiologicalProcess
# 4       Gene  BiologicalProcess
# 5       Gene  BiologicalProcess
# 6       Gene  BiologicalProcess
# 7       Gene  BiologicalProcess
# 8       Gene  BiologicalProcess
# 9       Gene  BiologicalProcess
# 10      Gene  BiologicalProcess
# 11      Gene  BiologicalProcess
# 12      Gene  BiologicalProcess
# 13      Gene  BiologicalProcess
# 14      Gene  BiologicalProcess
# 15      Gene  BiologicalProcess
# 16      Gene  BiologicalProcess
# 17      Gene  BiologicalProcess
# 18      Gene  BiologicalProcess
# 19      Gene  BiologicalProcess
# 20      Gene  BiologicalProcess
# 21      Gene  BiologicalProcess
# 22      Gene  BiologicalProcess
# 23      Gene  BiologicalProcess
#
#                                      head_detail_name    relation_source  \
# 0     adaptor-related protein complex 2, mu 1 subunit  DigitalAgingAtlas
# 1          breast cancer metastasis-suppressor 1-like  DigitalAgingAtlas
# 2                            COMM domain containing 4  DigitalAgingAtlas
# 3                    cytochrome c oxidase subunit 6A1  DigitalAgingAtlas
# 4                 deleted in malignant brain tumors 1  DigitalAgingAtlas
# 5               disco interacting protein 2 homolog B  DigitalAgingAtlas
# 6                         expressed sequence AI596487  DigitalAgingAtlas
# 7                                     forkhead box L1  DigitalAgingAtlas
# 8   formation of mitochondrial complex V assembly ...  DigitalAgingAtlas
# 9                   general transcription factor II I  DigitalAgingAtlas
# 10                          glutamate decarboxylase 1  DigitalAgingAtlas
# 11     glyoxylate reductase/hydroxypyruvate reductase  DigitalAgingAtlas
# 12  heat shock protein 90, alpha (cytosolic), clas...  DigitalAgingAtlas
# 13           multiple coagulation factor deficiency 2  DigitalAgingAtlas
# 14                                         myozenin 1  DigitalAgingAtlas
# 15          NADH:ubiquinone oxidoreductase subunit B4  DigitalAgingAtlas
# 16          NADH:ubiquinone oxidoreductase subunit B5  DigitalAgingAtlas
# 17                              progressive ankylosis  DigitalAgingAtlas
# 18                         pre-mRNA splicing factor 6  DigitalAgingAtlas
# 19  RAD23 homolog B, nucleotide excision repair pr...  DigitalAgingAtlas
# 20                         RIKEN cDNA 2310033P09 gene  DigitalAgingAtlas
# 21            S-adenosylhomocysteine hydrolase-like 1  DigitalAgingAtlas
# 22                   SEC61 translocon subunit alpha 1  DigitalAgingAtlas
# 23  solute carrier family 25 (mitochondrial carrie...  DigitalAgingAtlas
#
#          species    data_type kg_type head_id_is tail_id_is tail_detail_name  \
# 0   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 1   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 2   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 3   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 4   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 5   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 6   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 7   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 8   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 9   Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 10  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 11  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 12  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 13  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 14  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 15  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 16  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 17  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 18  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 19  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 20  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 21  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 22  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
# 23  Mus musculus  Associative   Aging    NCBI_ID   Quick_GO            aging
#
#    kg_source
# 0        DAA
# 1        DAA
# 2        DAA
# 3        DAA
# 4        DAA
# 5        DAA
# 6        DAA
# 7        DAA
# 8        DAA
# 9        DAA
# 10       DAA
# 11       DAA
# 12       DAA
# 13       DAA
# 14       DAA
# 15       DAA
# 16       DAA
# 17       DAA
# 18       DAA
# 19       DAA
# 20       DAA
# 21       DAA
# 22       DAA
# 23       DAA

# %%
! mkdir Mouse_gene_NOT_ASS_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Mouse_gene_NOT_ASS_biologicalprocess’: File exists

# %%
DAA.to_csv(OUT_PATH, index=False)
print(f"Saved {len(DAA):,} rows → {OUT_PATH}")
# Out:
# Saved 24 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_NOT_ASS_biologicalprocess/Mouse_gene_NOT_ASS_biologicalprocess.csv
