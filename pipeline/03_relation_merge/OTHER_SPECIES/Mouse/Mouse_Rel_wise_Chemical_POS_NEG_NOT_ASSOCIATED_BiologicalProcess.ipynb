# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'


# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %% [markdown]
# # POSITIVE ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_chemical_positiveassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_chemical_positiveassociated_biologicalprocess/Mouse_chemical_positiveassociated_biologicalprocess.csv'

# %% [markdown]
# ### Drugage

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Mouse_CE_Pos_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_PositivelyAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 41 rows
#          head                                           relation        tail  \
# 0     6433176  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1        6047  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2        3293  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 3      638877  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 4      219042  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 5      443753  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 6      443297  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 7        9082  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 8        8249  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 9         586  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 10     124072  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 11       4091  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 12    5284616  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 13  134378124  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 14       4171  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 15  163284948  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 16     132999  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 17       1103  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 18       2353  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 19    2882155  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 20     169853  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 21      72281  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 22   56649450  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 23       4034  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 24       2244  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 25      12035  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 26      34007  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 27        896  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 28     164533  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 29       6099  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 30     439213  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 31       9756  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 32   54670067  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 33      26052  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 34      14985  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 35       4534  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 36       1493  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 37       1102  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 38     439924  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 39        750  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 40   24812758  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#          head_type          tail_type  \
# 0   ChemicalEntity  BiologicalProcess
# 1   ChemicalEntity  BiologicalProcess
# 2   ChemicalEntity  BiologicalProcess
# 3   ChemicalEntity  BiologicalProcess
# 4   ChemicalEntity  BiologicalProcess
# 5   ChemicalEntity  BiologicalProcess
# 6   ChemicalEntity  BiologicalProcess
# 7   ChemicalEntity  BiologicalProcess
# 8   ChemicalEntity  BiologicalProcess
# 9   ChemicalEntity  BiologicalProcess
# 10  ChemicalEntity  BiologicalProcess
# 11  ChemicalEntity  BiologicalProcess
# 12  ChemicalEntity  BiologicalProcess
# 13  ChemicalEntity  BiologicalProcess
# 14  ChemicalEntity  BiologicalProcess
# 15  ChemicalEntity  BiologicalProcess
# 16  ChemicalEntity  BiologicalProcess
# 17  ChemicalEntity  BiologicalProcess
# 18  ChemicalEntity  BiologicalProcess
# 19  ChemicalEntity  BiologicalProcess
# 20  ChemicalEntity  BiologicalProcess
# 21  ChemicalEntity  BiologicalProcess
# 22  ChemicalEntity  BiologicalProcess
# 23  ChemicalEntity  BiologicalProcess
# 24  ChemicalEntity  BiologicalProcess
# 25  ChemicalEntity  BiologicalProcess
# 26  ChemicalEntity  BiologicalProcess
# 27  ChemicalEntity  BiologicalProcess
# 28  ChemicalEntity  BiologicalProcess
# 29  ChemicalEntity  BiologicalProcess
# 30  ChemicalEntity  BiologicalProcess
# 31  ChemicalEntity  BiologicalProcess
# 32  ChemicalEntity  BiologicalProcess
# 33  ChemicalEntity  BiologicalProcess
# 34  ChemicalEntity  BiologicalProcess
# 35  ChemicalEntity  BiologicalProcess
# 36  ChemicalEntity  BiologicalProcess
# 37  ChemicalEntity  BiologicalProcess
# 38  ChemicalEntity  BiologicalProcess
# 39  ChemicalEntity  BiologicalProcess
# 40  ChemicalEntity  BiologicalProcess
#
#                                      head_detail_name  \
# 0       3-aminopropanenitrile;(E)-but-2-enedioic acid
# 1   (2S)-2-amino-3-(3,4-dihydroxyphenyl)propanoic ...
# 2               6-ethoxy-2,2,4-trimethyl-1H-quinoline
# 3              N-tert-butyl-1-phenylmethanimine oxide
# 4   (4S)-4-[[(2S)-2-aminopropanoyl]amino]-5-[[(2S)...
# 5   calcium;3-[[(2R)-2,4-dihydroxy-3,3-dimethylbut...
# 6                         hydroxylamine;hydrochloride
# 7                    2-aminoethanethiol;hydrochloride
# 8   1-(diaminomethylidene)-2-(2-phenylethyl)guanidine
# 9           2-[carbamimidoyl(methyl)amino]acetic acid
# 10  1,7-bis(4-hydroxy-3-methoxyphenyl)heptane-3,5-...
# 11       3-(diaminomethylidene)-1,1-dimethylguanidine
# 12  (1R,9S,12S,15R,16E,18R,19R,21R,23S,24E,26E,28E...
# 13  1-[(2R)-6-fluoro-3,4-dihydro-2H-chromen-2-yl]-...
# 14  1-[4-(2-methoxyethyl)phenoxy]-3-(propan-2-ylam...
# 15  (2S,5S)-5-[(2R,5S)-5-[(2R,5S,6R)-3,4-dihydroxy...
# 16  3-[3-[[(7S)-3,4-dimethoxy-7-bicyclo[4.2.0]octa...
# 17          N,N'-bis(3-aminopropyl)butane-1,4-diamine
# 18  16,17-dimethoxy-5,7-dioxa-13-azoniapentacyclo[...
# 19  2-[(6-phenyl-2,3,4,9-tetrahydro-1H-carbazol-1-...
# 20  (2R,3R,4S)-2-(3,4-dihydroxyphenyl)-4-[(2R,3R)-...
# 21  (2S)-5,7-dihydroxy-2-(3-hydroxy-4-methoxypheny...
# 22  (2S)-1-N-[4-methyl-5-[2-(1,1,1-trifluoro-2-met...
# 23  1-[(4-chlorophenyl)-phenylmethyl]-4-[(3-methyl...
# 24                            2-acetyloxybenzoic acid
# 25          (2R)-2-acetamido-3-sulfanylpropanoic acid
# 26                            oxovanadium(2+);sulfate
# 27      N-[2-(5-methoxy-1H-indol-3-yl)ethyl]acetamide
# 28                                 2-oxopentanedioate
# 29  [7-(dimethylamino)phenothiazin-3-ylidene]-dime...
# 30  (3R,4R,5S,6R)-3-amino-6-(hydroxymethyl)oxane-2...
# 31                               nickel(2+);diacetate
# 32  (2R)-2-[(1S)-1,2-dihydroxyethyl]-3,4-dihydroxy...
# 33                    disodium;dioxido(dioxo)tungsten
# 34  (2R)-2,5,7,8-tetramethyl-2-[(4R,8R)-4,8,12-tri...
# 35  4-[4-(3,4-dihydroxyphenyl)-2,3-dimethylbutyl]b...
# 36                                  2,4-dinitrophenol
# 37               N'-(3-aminopropyl)butane-1,4-diamine
# 38  1-[(2R,3R,4S,5R)-3,4-dihydroxy-5-(hydroxymethy...
# 39                                 2-aminoacetic acid
# 40  (2S,3R,4R,5S,6R)-2-[3-[[5-(4-fluorophenyl)thio...
#
#                                       head_smile_name relation_source  \
# 0                        C(CN)C#N.C(=C/C(=O)O)\C(=O)O         DrugAge
# 1                   C1=CC(=C(C=C1C[C@@H](C(=O)O)N)O)O         DrugAge
# 2                      CCOC1=CC2=C(C=C1)NC(C=C2C)(C)C         DrugAge
# 3                  CC(C)(C)/[N+](=C/C1=CC=CC=C1)/[O-]         DrugAge
# 4   C[C@@H](C(=O)N[C@@H](CCC(=O)O)C(=O)N[C@@H](CC(...         DrugAge
# 5   CC(C)(CO)[C@H](C(=O)NCCC(=O)[O-])O.CC(C)(CO)[C...         DrugAge
# 6                                               NO.Cl         DrugAge
# 7                                           C(CS)N.Cl         DrugAge
# 8                        C1=CC=C(C=C1)CCN=C(N)N=C(N)N         DrugAge
# 9                                   CN(CC(=O)O)C(=N)N         DrugAge
# 10  COC1=C(C=CC(=C1)CCC(=O)CC(=O)CCC2=CC(=C(C=C2)O...         DrugAge
# 11                                  CN(C)C(=N)N=C(N)N         DrugAge
# 12  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C/[C@H](C[...         DrugAge
# 13  C1CC2=C(C=CC(=C2)F)O[C@@H]1[C@@H](CNCC([C@H]3C...         DrugAge
# 14                     CC(C)NCC(COC1=CC=C(C=C1)CCOC)O         DrugAge
# 15  C[C@@H]1[C@H](C(C([C@H](O1)O[C@@H]2C(O[C@@H](C...         DrugAge
# 16  CN(CCCN1CCC2=CC(=C(C=C2CC1=O)OC)OC)C[C@H]3CC4=...         DrugAge
# 17                                   C(CCNCCCN)CNCCCN         DrugAge
# 18  COC1=C(C2=C[N+]3=C(C=C2C=C1)C4=CC5=C(C=C4CC3)O...         DrugAge
# 19     C1CC(C2=C(C1)C3=C(N2)C=CC(=C3)C4=CC=CC=C4)NCCO         DrugAge
# 20  C1[C@H]([C@H](OC2=C1C(=CC(=C2[C@@H]3[C@H]([C@H...         DrugAge
# 21  COC1=C(C=C(C=C1)[C@@H]2CC(=O)C3=C(C=C(C=C3O2)O...         DrugAge
# 22  CC1=C(SC(=N1)NC(=O)N2CCC[C@H]2C(=O)N)C3=CC(=NC...         DrugAge
# 23  CC1=CC(=CC=C1)CN2CCN(CC2)C(C3=CC=CC=C3)C4=CC=C...         DrugAge
# 24                           CC(=O)OC1=CC=CC=C1C(=O)O         DrugAge
# 25                            CC(=O)N[C@@H](CS)C(=O)O         DrugAge
# 26                          [O-]S(=O)(=O)[O-].O=[V+2]         DrugAge
# 27                     CC(=O)NCCC1=CNC2=C1C=C(C=C2)OC         DrugAge
# 28                        C(CC(=O)[O-])C(=O)C(=O)[O-]         DrugAge
# 29  CN(C)C1=CC2=C(C=C1)N=C3C=CC(=[N+](C)C)C=C3S2.[...         DrugAge
# 30         C([C@@H]1[C@H]([C@@H]([C@H](C(O1)O)N)O)O)O         DrugAge
# 31                       CC(=O)[O-].CC(=O)[O-].[Ni+2]         DrugAge
# 32               C([C@@H]([C@@H]1C(=C(C(=O)O1)O)O)O)O         DrugAge
# 33                    [O-][W](=O)(=O)[O-].[Na+].[Na+]         DrugAge
# 34  CC1=C(C2=C(CC[C@@](O2)(C)CCC[C@H](C)CCC[C@H](C...         DrugAge
# 35       CC(CC1=CC(=C(C=C1)O)O)C(C)CC2=CC(=C(C=C2)O)O         DrugAge
# 36           C1=CC(=C(C=C1[N+](=O)[O-])[N+](=O)[O-])O         DrugAge
# 37                                       C(CCNCCCN)CN         DrugAge
# 38  C1=CC(=C[N+](=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)...         DrugAge
# 39                                         C(C(=O)O)N         DrugAge
# 40  CC1=C(C=C(C=C1)[C@H]2[C@@H]([C@H]([C@@H]([C@H]...         DrugAge
#
#          species                       head_alt_name  ... age_at_initiation  \
# 0   Mus musculus    Beta-aminopropionitrile fumarate  ...          2 months
# 1   Mus musculus                            Levodopa  ...           1 month
# 2   Mus musculus                          Ethoxyquin  ...          3 months
# 3   Mus musculus    N-tert-butyl-alpha-phenylnitrone  ...       24.5 months
# 4   Mus musculus                         Epithalamin  ...               NaN
# 5   Mus musculus                Calcium pantothenate  ...           1 month
# 6   Mus musculus         Hydroxylamine hydrochloride  ...     after weaning
# 7   Mus musculus  2-mercaptoethylamine hydrochloride  ...     after weaning
# 8   Mus musculus                          Phenformin  ...        3.5 months
# 9   Mus musculus                            Creatine  ...         12 months
# 10  Mus musculus                  Tetrahydrocurcumin  ...         13 months
# 11  Mus musculus                           Metformin  ...          3 months
# 12  Mus musculus                           Rapamycin  ...         20 months
# 13  Mus musculus                           Nebivolol  ...         12 months
# 14  Mus musculus                          Metoprolol  ...         12 months
# 15  Mus musculus                            Acarbose  ...          4 months
# 16  Mus musculus                          Ivabradine  ...          3 months
# 17  Mus musculus                            Spermine  ...          4 months
# 18  Mus musculus                           Berberine  ...         18 months
# 19  Mus musculus                               CASIN  ...         18 months
# 20  Mus musculus                      Procyanidin C1  ...      24-27 months
# 21  Mus musculus                          Hesperetin  ...  19.5-23.5 months
# 22  Mus musculus                           Alpelisib  ...         12 months
# 23  Mus musculus                           Meclizine  ...         12 months
# 24  Mus musculus                             Aspirin  ...               NaN
# 25  Mus musculus                 N-acetyl-L-cysteine  ...               NaN
# 26  Mus musculus                     Vanadyl sulfate  ...               NaN
# 27  Mus musculus                           Melatonin  ...               NaN
# 28  Mus musculus                 Alpha-ketoglutarate  ...               NaN
# 29  Mus musculus                      Methylene blue  ...               NaN
# 30  Mus musculus                       D-glucosamine  ...               NaN
# 31  Mus musculus                   Nickelous acetate  ...               NaN
# 32  Mus musculus                       Ascorbic acid  ...               NaN
# 33  Mus musculus                    Sodium tungstate  ...               NaN
# 34  Mus musculus                           Vitamin E  ...               NaN
# 35  Mus musculus           Nordihydroguaiaretic acid  ...               NaN
# 36  Mus musculus                   2,4-dinitrophenol  ...               NaN
# 37  Mus musculus                          Spermidine  ...               NaN
# 38  Mus musculus               Nicotinamide riboside  ...               NaN
# 39  Mus musculus                             Glycine  ...               NaN
# 40  Mus musculus                       Canagliflozin  ...               NaN
#
#    treatment_duration avg_lifespan_change_percent  \
# 0           18 months                        5.00
# 1         until death                       28.00
# 2         until death                       20.00
# 3         until death                        4.00
# 4                 NaN                       11.00
# 5         until death                       20.00
# 6         until death                        7.00
# 7         until death                       26.00
# 8         until death                       21.00
# 9         until death                        9.00
# 10        until death                       11.00
# 11        until death                       38.00
# 12        until death                       13.00
# 13        until death                        6.00
# 14        until death                       10.00
# 15        until death                        5.00
# 16        until death                        6.00
# 17        until death                       14.00
# 18           4 months                       16.00
# 19             4 days                       10.00
# 20        until death                        9.00
# 21         3-6 months                        9.00
# 22        until death                       11.00
# 23        until death                        3.00
# 24                NaN                        8.00
# 25                NaN                       24.00
# 26                NaN                        0.17
# 27                NaN                        5.40
# 28                NaN                        4.80
# 29                NaN                        0.70
# 30                NaN                        5.60
# 31                NaN                        5.48
# 32                NaN                        8.60
# 33                NaN                       40.75
# 34                NaN                       15.00
# 35                NaN                       12.00
# 36                NaN                        7.10
# 37                NaN                       23.79
# 38                NaN                        4.70
# 39                NaN                        6.20
# 40                NaN                       14.00
#
#                                   dosage   pubmed_id kg_type  head_id_is  \
# 0                                    NaN         NaN   Aging     Pubchem
# 1                                    NaN         NaN   Aging     Pubchem
# 2                                    NaN         NaN   Aging     Pubchem
# 3                                    NaN         NaN   Aging     Pubchem
# 4                                    NaN         NaN   Aging     Pubchem
# 5                                    NaN         NaN   Aging     Pubchem
# 6                                    NaN         NaN   Aging     Pubchem
# 7                                    NaN         NaN   Aging     Pubchem
# 8                                    NaN         NaN   Aging     Pubchem
# 9                                    NaN         NaN   Aging     Pubchem
# 10                                   NaN         NaN   Aging     Pubchem
# 11                                   NaN         NaN   Aging     Pubchem
# 12                                   NaN         NaN   Aging     Pubchem
# 13                                   NaN         NaN   Aging     Pubchem
# 14                                   NaN         NaN   Aging     Pubchem
# 15                                   NaN         NaN   Aging     Pubchem
# 16                                   NaN         NaN   Aging     Pubchem
# 17                                   NaN         NaN   Aging     Pubchem
# 18                                   NaN         NaN   Aging     Pubchem
# 19                                   NaN         NaN   Aging     Pubchem
# 20                                   NaN         NaN   Aging     Pubchem
# 21                                   NaN         NaN   Aging     Pubchem
# 22                                   NaN         NaN   Aging     Pubchem
# 23                                   NaN         NaN   Aging     Pubchem
# 24                         21 mg/kg food  18631321.0   Aging     Pubchem
# 25                       10 g/L of water  20819793.0   Aging     Pubchem
# 26                                 5 ppm   1113210.0   Aging     Pubchem
# 27                               20 mg/l  11445596.0   Aging     Pubchem
# 28                              2% (w/w)  32877690.0   Aging     Pubchem
# 29                         27 mg/kg diet  24245565.0   Aging     Pubchem
# 30                               10 g/kg  24714520.0   Aging     Pubchem
# 31                                 5 ppm   1113210.0   Aging     Pubchem
# 32                                   1 %   6519438.0   Aging     Pubchem
# 33                                 5 ppm   1113210.0   Aging     Pubchem
# 34                             550 mg/kg  18257658.0   Aging     Pubchem
# 35                         2.5 g/kg food  18631321.0   Aging     Pubchem
# 36                                1 mg/L  18505478.0   Aging     Pubchem
# 37  Drinking water supplemented with 3mM  28386016.0   Aging     Pubchem
# 38                         400 mg/kg/day  27127236.0   Aging     Pubchem
# 39                                    8%  30916479.0   Aging     Pubchem
# 40                           30 mg/kg BW  32990681.0   Aging     Pubchem
#
#    tail_id_is kg_source tail_detail_name
# 0    Quick_GO   Drugage            aging
# 1    Quick_GO   Drugage            aging
# 2    Quick_GO   Drugage            aging
# 3    Quick_GO   Drugage            aging
# 4    Quick_GO   Drugage            aging
# 5    Quick_GO   Drugage            aging
# 6    Quick_GO   Drugage            aging
# 7    Quick_GO   Drugage            aging
# 8    Quick_GO   Drugage            aging
# 9    Quick_GO   Drugage            aging
# 10   Quick_GO   Drugage            aging
# 11   Quick_GO   Drugage            aging
# 12   Quick_GO   Drugage            aging
# 13   Quick_GO   Drugage            aging
# 14   Quick_GO   Drugage            aging
# 15   Quick_GO   Drugage            aging
# 16   Quick_GO   Drugage            aging
# 17   Quick_GO   Drugage            aging
# 18   Quick_GO   Drugage            aging
# 19   Quick_GO   Drugage            aging
# 20   Quick_GO   Drugage            aging
# 21   Quick_GO   Drugage            aging
# 22   Quick_GO   Drugage            aging
# 23   Quick_GO   Drugage            aging
# 24   Quick_GO   Drugage            aging
# 25   Quick_GO   Drugage            aging
# 26   Quick_GO   Drugage            aging
# 27   Quick_GO   Drugage            aging
# 28   Quick_GO   Drugage            aging
# 29   Quick_GO   Drugage            aging
# 30   Quick_GO   Drugage            aging
# 31   Quick_GO   Drugage            aging
# 32   Quick_GO   Drugage            aging
# 33   Quick_GO   Drugage            aging
# 34   Quick_GO   Drugage            aging
# 35   Quick_GO   Drugage            aging
# 36   Quick_GO   Drugage            aging
# 37   Quick_GO   Drugage            aging
# 38   Quick_GO   Drugage            aging
# 39   Quick_GO   Drugage            aging
# 40   Quick_GO   Drugage            aging
#
# [41 rows x 22 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 41
#          head                                           relation        tail  \
# 0     6433176  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1        6047  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2        3293  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 3      638877  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 4      219042  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 5      443753  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 6      443297  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 7        9082  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 8        8249  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 9         586  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 10     124072  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 11       4091  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 12    5284616  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 13  134378124  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 14       4171  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 15  163284948  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 16     132999  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 17       1103  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 18       2353  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 19    2882155  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 20     169853  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 21      72281  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 22   56649450  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 23       4034  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 24       2244  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 25      12035  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 26      34007  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 27        896  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 28     164533  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 29       6099  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 30     439213  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 31       9756  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 32   54670067  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 33      26052  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 34      14985  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 35       4534  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 36       1493  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 37       1102  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 38     439924  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 39        750  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 40   24812758  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#          head_type relation_type          tail_type kg_source kg_type  \
# 0   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 3   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 4   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 5   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 6   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 7   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 8   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 9   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 10  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 11  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 12  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 13  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 14  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 15  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 16  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 17  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 18  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 19  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 20  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 21  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 22  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 23  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 24  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 25  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 26  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 27  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 28  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 29  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 30  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 31  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 32  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 33  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 34  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 35  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 36  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 37  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 38  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 39  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 40  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#    head_id_is tail_id_is                                   head_detail_name  \
# 0     Pubchem   Quick_GO      3-aminopropanenitrile;(E)-but-2-enedioic acid
# 1     Pubchem   Quick_GO  (2S)-2-amino-3-(3,4-dihydroxyphenyl)propanoic ...
# 2     Pubchem   Quick_GO              6-ethoxy-2,2,4-trimethyl-1H-quinoline
# 3     Pubchem   Quick_GO             N-tert-butyl-1-phenylmethanimine oxide
# 4     Pubchem   Quick_GO  (4S)-4-[[(2S)-2-aminopropanoyl]amino]-5-[[(2S)...
# 5     Pubchem   Quick_GO  calcium;3-[[(2R)-2,4-dihydroxy-3,3-dimethylbut...
# 6     Pubchem   Quick_GO                        hydroxylamine;hydrochloride
# 7     Pubchem   Quick_GO                   2-aminoethanethiol;hydrochloride
# 8     Pubchem   Quick_GO  1-(diaminomethylidene)-2-(2-phenylethyl)guanidine
# 9     Pubchem   Quick_GO          2-[carbamimidoyl(methyl)amino]acetic acid
# 10    Pubchem   Quick_GO  1,7-bis(4-hydroxy-3-methoxyphenyl)heptane-3,5-...
# 11    Pubchem   Quick_GO       3-(diaminomethylidene)-1,1-dimethylguanidine
# 12    Pubchem   Quick_GO  (1R,9S,12S,15R,16E,18R,19R,21R,23S,24E,26E,28E...
# 13    Pubchem   Quick_GO  1-[(2R)-6-fluoro-3,4-dihydro-2H-chromen-2-yl]-...
# 14    Pubchem   Quick_GO  1-[4-(2-methoxyethyl)phenoxy]-3-(propan-2-ylam...
# 15    Pubchem   Quick_GO  (2S,5S)-5-[(2R,5S)-5-[(2R,5S,6R)-3,4-dihydroxy...
# 16    Pubchem   Quick_GO  3-[3-[[(7S)-3,4-dimethoxy-7-bicyclo[4.2.0]octa...
# 17    Pubchem   Quick_GO          N,N'-bis(3-aminopropyl)butane-1,4-diamine
# 18    Pubchem   Quick_GO  16,17-dimethoxy-5,7-dioxa-13-azoniapentacyclo[...
# 19    Pubchem   Quick_GO  2-[(6-phenyl-2,3,4,9-tetrahydro-1H-carbazol-1-...
# 20    Pubchem   Quick_GO  (2R,3R,4S)-2-(3,4-dihydroxyphenyl)-4-[(2R,3R)-...
# 21    Pubchem   Quick_GO  (2S)-5,7-dihydroxy-2-(3-hydroxy-4-methoxypheny...
# 22    Pubchem   Quick_GO  (2S)-1-N-[4-methyl-5-[2-(1,1,1-trifluoro-2-met...
# 23    Pubchem   Quick_GO  1-[(4-chlorophenyl)-phenylmethyl]-4-[(3-methyl...
# 24    Pubchem   Quick_GO                            2-acetyloxybenzoic acid
# 25    Pubchem   Quick_GO          (2R)-2-acetamido-3-sulfanylpropanoic acid
# 26    Pubchem   Quick_GO                            oxovanadium(2+);sulfate
# 27    Pubchem   Quick_GO      N-[2-(5-methoxy-1H-indol-3-yl)ethyl]acetamide
# 28    Pubchem   Quick_GO                                 2-oxopentanedioate
# 29    Pubchem   Quick_GO  [7-(dimethylamino)phenothiazin-3-ylidene]-dime...
# 30    Pubchem   Quick_GO  (3R,4R,5S,6R)-3-amino-6-(hydroxymethyl)oxane-2...
# 31    Pubchem   Quick_GO                               nickel(2+);diacetate
# 32    Pubchem   Quick_GO  (2R)-2-[(1S)-1,2-dihydroxyethyl]-3,4-dihydroxy...
# 33    Pubchem   Quick_GO                    disodium;dioxido(dioxo)tungsten
# 34    Pubchem   Quick_GO  (2R)-2,5,7,8-tetramethyl-2-[(4R,8R)-4,8,12-tri...
# 35    Pubchem   Quick_GO  4-[4-(3,4-dihydroxyphenyl)-2,3-dimethylbutyl]b...
# 36    Pubchem   Quick_GO                                  2,4-dinitrophenol
# 37    Pubchem   Quick_GO               N'-(3-aminopropyl)butane-1,4-diamine
# 38    Pubchem   Quick_GO  1-[(2R,3R,4S,5R)-3,4-dihydroxy-5-(hydroxymethy...
# 39    Pubchem   Quick_GO                                 2-aminoacetic acid
# 40    Pubchem   Quick_GO  (2S,3R,4R,5S,6R)-2-[3-[[5-(4-fluorophenyl)thio...
#
#    tail_detail_name       species
# 0             aging  Mus musculus
# 1             aging  Mus musculus
# 2             aging  Mus musculus
# 3             aging  Mus musculus
# 4             aging  Mus musculus
# 5             aging  Mus musculus
# 6             aging  Mus musculus
# 7             aging  Mus musculus
# 8             aging  Mus musculus
# 9             aging  Mus musculus
# 10            aging  Mus musculus
# 11            aging  Mus musculus
# 12            aging  Mus musculus
# 13            aging  Mus musculus
# 14            aging  Mus musculus
# 15            aging  Mus musculus
# 16            aging  Mus musculus
# 17            aging  Mus musculus
# 18            aging  Mus musculus
# 19            aging  Mus musculus
# 20            aging  Mus musculus
# 21            aging  Mus musculus
# 22            aging  Mus musculus
# 23            aging  Mus musculus
# 24            aging  Mus musculus
# 25            aging  Mus musculus
# 26            aging  Mus musculus
# 27            aging  Mus musculus
# 28            aging  Mus musculus
# 29            aging  Mus musculus
# 30            aging  Mus musculus
# 31            aging  Mus musculus
# 32            aging  Mus musculus
# 33            aging  Mus musculus
# 34            aging  Mus musculus
# 35            aging  Mus musculus
# 36            aging  Mus musculus
# 37            aging  Mus musculus
# 38            aging  Mus musculus
# 39            aging  Mus musculus
# 40            aging  Mus musculus

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'ChemicalEntity_PositivelyAssociatedWith_BiologicalProcess'}
# head_type           : {'ChemicalEntity'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'Drugage'}
# head_id_is          : {'Pubchem'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 41 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            41                   0              41
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 41  |  After dedup: 41
#    head                                           relation        tail  \
# 0   586  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1   750  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2   896  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#         head_type relation_type          tail_type kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#   head_id_is tail_id_is                               head_detail_name  \
# 0    Pubchem   Quick_GO      2-[carbamimidoyl(methyl)amino]acetic acid
# 1    Pubchem   Quick_GO                             2-aminoacetic acid
# 2    Pubchem   Quick_GO  N-[2-(5-methoxy-1H-indol-3-yl)ethyl]acetamide
#
#   tail_detail_name       species
# 0            aging  Mus musculus
# 1            aging  Mus musculus
# 2            aging  Mus musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            41                   0              41
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Drugage'} kg_source
# Drugage    41
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    41
# Name: count, dtype: int64

# %%
! mkdir Mouse_chemical_positiveassociated_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Mouse_chemical_positiveassociated_biologicalprocess’: File exists

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 41 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_chemical_positiveassociated_biologicalprocess/Mouse_chemical_positiveassociated_biologicalprocess.csv

# %%
# OUT_PATH

# %% [markdown]
# # NEGATIVE ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_chemical_negativeassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_chemical_negativeassociated_biologicalprocess/Mouse_chemical_negativeassociated_biologicalprocess.csv'

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Mouse_CE_Neg_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_NegativelyAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 9 rows
#        head                                           relation        tail  \
# 0     24012  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 1  22053264  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 2      5756  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 3      2719  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 4     10980  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 5   5280343  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 6      4654  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 7     84815  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 8      4091  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
#
#         head_type          tail_type  \
# 0  ChemicalEntity  BiologicalProcess
# 1  ChemicalEntity  BiologicalProcess
# 2  ChemicalEntity  BiologicalProcess
# 3  ChemicalEntity  BiologicalProcess
# 4  ChemicalEntity  BiologicalProcess
# 5  ChemicalEntity  BiologicalProcess
# 6  ChemicalEntity  BiologicalProcess
# 7  ChemicalEntity  BiologicalProcess
# 8  ChemicalEntity  BiologicalProcess
#
#                                     head_detail_name  \
# 0                                   trichloroalumane
# 1                                  4-phenylbutanoate
# 2  (8R,9S,13S,14S,16R,17R)-13-methyl-6,7,8,9,11,1...
# 3  4-N-(7-chloroquinolin-4-yl)-1-N,1-N-diethylpen...
# 4                               barium(2+);diacetate
# 5  2-(3,4-dihydroxyphenyl)-3,5,7-trihydroxychrome...
# 6           2-amino-3-(4-fluorophenyl)propanoic acid
# 7         (2R)-2-amino-4-methylsulfanylbutanoic acid
# 8       3-(diaminomethylidene)-1,1-dimethylguanidine
#
#                                      head_smile_name relation_source  \
# 0                                     [Al](Cl)(Cl)Cl         DrugAge
# 1                          C1=CC=C(C=C1)CCCC(=O)[O-]         DrugAge
# 2  C[C@]12CC[C@H]3[C@H]([C@@H]1C[C@H]([C@@H]2O)O)...         DrugAge
# 3             CCN(CC)CCCC(C)NC1=C2C=CC(=CC2=NC=C1)Cl         DrugAge
# 4                       CC(=O)[O-].CC(=O)[O-].[Ba+2]         DrugAge
# 5   C1=CC(=C(C=C1C2=C(C(=O)C3=C(C=C(C=C3O2)O)O)O)O)O         DrugAge
# 6                          C1=CC(=CC=C1CC(C(=O)O)N)F         DrugAge
# 7                                 CSCC[C@H](C(=O)O)N         DrugAge
# 8                                  CN(C)C(=N)N=C(N)N         DrugAge
#
#         species              head_alt_name  ... age_at_initiation  \
# 0  Mus musculus         Aluminium chloride  ...         20 months
# 1  Mus musculus           4-phenylbutyrate  ...          9 months
# 2  Mus musculus  16-alpha-hydroxyestradiol  ...         12 months
# 3  Mus musculus                Chloroquine  ...               NaN
# 4  Mus musculus             Barium acetate  ...               NaN
# 5  Mus musculus                  Quercetin  ...               NaN
# 6  Mus musculus      p-fluorophenylalanine  ...               NaN
# 7  Mus musculus                 Methionine  ...               NaN
# 8  Mus musculus                  Metformin  ...               NaN
#
#   treatment_duration avg_lifespan_change_percent         dosage   pubmed_id  \
# 0        until death                       -7.00            NaN         NaN
# 1        until death                       -2.00            NaN         NaN
# 2        until death                       -7.00            NaN         NaN
# 3                NaN                      -16.80     13.2 µg/mL   4788962.0
# 4                NaN                       -8.80          5 ppm   1113210.0
# 5                NaN                      -14.20      10 mg/day   7140862.0
# 6                NaN                      -15.43         0.4 mM    689376.0
# 7                NaN                      -16.90         0.05 M   6519211.0
# 8                NaN                       -1.53  100 mg/kg/day  33585467.0
#
#   kg_type  head_id_is tail_id_is kg_source tail_detail_name
# 0   Aging     Pubchem   Quick_GO   Drugage            aging
# 1   Aging     Pubchem   Quick_GO   Drugage            aging
# 2   Aging     Pubchem   Quick_GO   Drugage            aging
# 3   Aging     Pubchem   Quick_GO   Drugage            aging
# 4   Aging     Pubchem   Quick_GO   Drugage            aging
# 5   Aging     Pubchem   Quick_GO   Drugage            aging
# 6   Aging     Pubchem   Quick_GO   Drugage            aging
# 7   Aging     Pubchem   Quick_GO   Drugage            aging
# 8   Aging     Pubchem   Quick_GO   Drugage            aging
#
# [9 rows x 22 columns]

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
    
]
aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 9
#        head                                           relation        tail  \
# 0     24012  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 1  22053264  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 2      5756  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 3      2719  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 4     10980  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 5   5280343  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 6      4654  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 7     84815  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 8      4091  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
#
#         head_type relation_type          tail_type kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 3  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 4  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 5  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 6  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 7  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 8  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#   head_id_is tail_id_is                                   head_detail_name  \
# 0    Pubchem   Quick_GO                                   trichloroalumane
# 1    Pubchem   Quick_GO                                  4-phenylbutanoate
# 2    Pubchem   Quick_GO  (8R,9S,13S,14S,16R,17R)-13-methyl-6,7,8,9,11,1...
# 3    Pubchem   Quick_GO  4-N-(7-chloroquinolin-4-yl)-1-N,1-N-diethylpen...
# 4    Pubchem   Quick_GO                               barium(2+);diacetate
# 5    Pubchem   Quick_GO  2-(3,4-dihydroxyphenyl)-3,5,7-trihydroxychrome...
# 6    Pubchem   Quick_GO           2-amino-3-(4-fluorophenyl)propanoic acid
# 7    Pubchem   Quick_GO         (2R)-2-amino-4-methylsulfanylbutanoic acid
# 8    Pubchem   Quick_GO       3-(diaminomethylidene)-1,1-dimethylguanidine
#
#   tail_detail_name       species
# 0            aging  Mus musculus
# 1            aging  Mus musculus
# 2            aging  Mus musculus
# 3            aging  Mus musculus
# 4            aging  Mus musculus
# 5            aging  Mus musculus
# 6            aging  Mus musculus
# 7            aging  Mus musculus
# 8            aging  Mus musculus

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             9                   0               9
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
! mkdir Mouse_chemical_negativeassociated_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Mouse_chemical_negativeassociated_biologicalprocess’: File exists

# %%
final_df.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df):,} rows → {OUT_PATH}")
# Out:
# Saved 9 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_chemical_negativeassociated_biologicalprocess/Mouse_chemical_negativeassociated_biologicalprocess.csv

# %% [markdown]
# # NOT ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_chemical_notassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_chemical_notassociated_biologicalprocess/Mouse_chemical_notassociated_biologicalprocess.csv'

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Mouse_CE_Not_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_NotAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 61 rows
#         head                                           relation        tail  \
# 0       4654  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 1       3598  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 2   40473195  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 3    5280489  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 4       2726  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# ..       ...                                                ...         ...
# 56      5881  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 57    439924  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 58  44631884  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 59      2244  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 60  44250349  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
#
#          head_type          tail_type  \
# 0   ChemicalEntity  BiologicalProcess
# 1   ChemicalEntity  BiologicalProcess
# 2   ChemicalEntity  BiologicalProcess
# 3   ChemicalEntity  BiologicalProcess
# 4   ChemicalEntity  BiologicalProcess
# ..             ...                ...
# 56  ChemicalEntity  BiologicalProcess
# 57  ChemicalEntity  BiologicalProcess
# 58  ChemicalEntity  BiologicalProcess
# 59  ChemicalEntity  BiologicalProcess
# 60  ChemicalEntity  BiologicalProcess
#
#                                      head_detail_name  \
# 0            2-amino-3-(4-fluorophenyl)propanoic acid
# 1   3,4,6-trichloro-2-[(2,3,5-trichloro-6-hydroxyp...
# 2   [2-[(8S,9S,10R,11S,13S,14S,17R)-11,17-dihydrox...
# 3   1,3,3-trimethyl-2-[(1E,3E,5E,7E,9E,11E,13E,15E...
# 4   3-(2-chlorophenothiazin-10-yl)-N,N-dimethylpro...
# ..                                                ...
# 56  (3S,8R,9S,10R,13S,14S)-3-hydroxy-10,13-dimethy...
# 57  1-[(2R,3R,4S,5R)-3,4-dihydroxy-5-(hydroxymethy...
# 58  3-[(3-hydroxyphenyl)methyl]-5-methyl-1,3-benzo...
# 59                            2-acetyloxybenzoic acid
# 60  5-chloro-2-[[2-[2-[3-(furan-3-yl)anilino]-2-ox...
#
#                                       head_smile_name relation_source  \
# 0                           C1=CC(=CC=C1CC(C(=O)O)N)F         DrugAge
# 1   C1=C(C(=C(C(=C1Cl)Cl)CC2=C(C(=CC(=C2Cl)Cl)Cl)O...         DrugAge
# 2   C[C@]12C[C@@H]([C@H]3[C@H]([C@@H]1CC[C@@]2(C(=...         DrugAge
# 3   CC1=C(C(CCC1)(C)C)/C=C/C(=C/C=C/C(=C/C=C/C=C(/...         DrugAge
# 4              CN(C)CCCN1C2=CC=CC=C2SC3=C1C=C(C=C3)Cl         DrugAge
# ..                                                ...             ...
# 56  C[C@]12CC[C@H]3[C@H]([C@@H]1CCC2=O)CC=C4[C@@]3...         DrugAge
# 57  C1=CC(=C[N+](=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)...         DrugAge
# 58             CC1=CC2=C(C=C1)OC(=O)N2CC3=CC(=CC=C3)O         DrugAge
# 59                           CC(=O)OC1=CC=CC=C1C(=O)O         DrugAge
# 60  C1=CC(=CC(=C1)NC(=O)COCC(=O)NC2=C(C=C(C=C2)Cl)...         DrugAge
#
#          species                  head_alt_name  ...   age_at_initiation  \
# 0   Mus musculus          p-fluorophenylalanine  ...           12 months
# 1   Mus musculus                Hexachlorophene  ...             1 month
# 2   Mus musculus  Prednisolone sodium phosphate  ...          7.7 months
# 3   Mus musculus                  Beta-carotene  ...           20 months
# 4   Mus musculus                 Chlorpromazine  ...  9.7 or 10.7 months
# ..           ...                            ...  ...                 ...
# 56  Mus musculus         Dehydroepiandrosterone  ...                 NaN
# 57  Mus musculus          Nicotinamide riboside  ...                 NaN
# 58  Mus musculus                         MIF098  ...                 NaN
# 59  Mus musculus                        Aspirin  ...                 NaN
# 60  Mus musculus                         TM5441  ...                 NaN
#
#    treatment_duration avg_lifespan_change_percent    dosage   pubmed_id  \
# 0             4 weeks                       -5.00       NaN         NaN
# 1         until death                       -7.00       NaN         NaN
# 2         until death                        0.00       NaN         NaN
# 3         until death                      -10.00       NaN         NaN
# 4         until death                        0.00       NaN         NaN
# ..                ...                         ...       ...         ...
# 56                NaN                        2.35  25 μg/mL  10197641.0
# 57                NaN                        0.00  1000 ppm  33788371.0
# 58                NaN                       -1.00   240 ppm  33788371.0
# 59                NaN                       -1.00    60 ppm  30916479.0
# 60                NaN                       -4.00    60 ppm  30916479.0
#
#    kg_type  head_id_is tail_id_is kg_source tail_detail_name
# 0    Aging     Pubchem   Quick_GO   Drugage            aging
# 1    Aging     Pubchem   Quick_GO   Drugage            aging
# 2    Aging     Pubchem   Quick_GO   Drugage            aging
# 3    Aging     Pubchem   Quick_GO   Drugage            aging
# 4    Aging     Pubchem   Quick_GO   Drugage            aging
# ..     ...         ...        ...       ...              ...
# 56   Aging     Pubchem   Quick_GO   Drugage            aging
# 57   Aging     Pubchem   Quick_GO   Drugage            aging
# 58   Aging     Pubchem   Quick_GO   Drugage            aging
# 59   Aging     Pubchem   Quick_GO   Drugage            aging
# 60   Aging     Pubchem   Quick_GO   Drugage            aging
#
# [61 rows x 22 columns]

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
    
]
aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 61
#         head                                           relation        tail  \
# 0       4654  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 1       3598  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 2   40473195  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 3    5280489  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 4       2726  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# ..       ...                                                ...         ...
# 56      5881  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 57    439924  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 58  44631884  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 59      2244  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 60  44250349  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
#
#          head_type relation_type          tail_type kg_source kg_type  \
# 0   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 3   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 4   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# ..             ...           ...                ...       ...     ...
# 56  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 57  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 58  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 59  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 60  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#    head_id_is tail_id_is                                   head_detail_name  \
# 0     Pubchem   Quick_GO           2-amino-3-(4-fluorophenyl)propanoic acid
# 1     Pubchem   Quick_GO  3,4,6-trichloro-2-[(2,3,5-trichloro-6-hydroxyp...
# 2     Pubchem   Quick_GO  [2-[(8S,9S,10R,11S,13S,14S,17R)-11,17-dihydrox...
# 3     Pubchem   Quick_GO  1,3,3-trimethyl-2-[(1E,3E,5E,7E,9E,11E,13E,15E...
# 4     Pubchem   Quick_GO  3-(2-chlorophenothiazin-10-yl)-N,N-dimethylpro...
# ..        ...        ...                                                ...
# 56    Pubchem   Quick_GO  (3S,8R,9S,10R,13S,14S)-3-hydroxy-10,13-dimethy...
# 57    Pubchem   Quick_GO  1-[(2R,3R,4S,5R)-3,4-dihydroxy-5-(hydroxymethy...
# 58    Pubchem   Quick_GO  3-[(3-hydroxyphenyl)methyl]-5-methyl-1,3-benzo...
# 59    Pubchem   Quick_GO                            2-acetyloxybenzoic acid
# 60    Pubchem   Quick_GO  5-chloro-2-[[2-[2-[3-(furan-3-yl)anilino]-2-ox...
#
#    tail_detail_name       species
# 0             aging  Mus musculus
# 1             aging  Mus musculus
# 2             aging  Mus musculus
# 3             aging  Mus musculus
# 4             aging  Mus musculus
# ..              ...           ...
# 56            aging  Mus musculus
# 57            aging  Mus musculus
# 58            aging  Mus musculus
# 59            aging  Mus musculus
# 60            aging  Mus musculus
#
# [61 rows x 13 columns]

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            61                   0              61
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
! mkdir Mouse_chemical_notassociated_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Mouse_chemical_notassociated_biologicalprocess’: File exists

# %%
final_df.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df):,} rows → {OUT_PATH}")
# Out:
# Saved 61 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_chemical_notassociated_biologicalprocess/Mouse_chemical_notassociated_biologicalprocess.csv
