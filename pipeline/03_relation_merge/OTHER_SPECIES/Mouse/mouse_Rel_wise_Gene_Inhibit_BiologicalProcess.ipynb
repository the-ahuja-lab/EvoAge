# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_gene_inhibits_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_inhibits_biologicalprocess/Mouse_gene_inhibits_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Mouse_gene_inhibits_biologicalprocess’: File exists

# %%
#

# %%
# Mouse = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Mus_musculus.gene_info',
#     sep='\t',
    
# )
# # Mouse["LocusTag"] = Mouse["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Mouse_symbol2Locus_dict = dict(zip(Mouse['Symbol'], Mouse['LocusTag']))
# # Mouse
# # Mouse_symbol2Locus_dict
# Mouse

# %% [markdown]
# # Genage

# %%
Genage = pd.read_csv(PROC_DIR + 'genage/Mouse/Mouse_Gene_Inhibits_BiologicalProcess.csv')
Genage.columns = Genage.columns.str.lower()
Genage = Genage[~Genage['head_detail_name'].isna()]

Genage['kg_type'] = 'Aging'

print(f"Genage: {len(Genage):,} rows")
Genage['head_id_is'] = 'NCBI_ID'
Genage['tail_id_is'] = 'Quick_GO'
Genage['species'] = 'Mus musculus'
Genage['kg_source'] = 'Genage'

Genage
# Out:
# Genage: 83 rows
#        head                         relation        tail head_type  \
# 0   Arhgap1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1       Atm  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2       Atr  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3     Brca1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 4     Bub1b  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# ..      ...                              ...         ...       ...
# 78    Rbm38  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 79   Col1a1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 80  Siglece  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 81     Sod3  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 82    Mir17  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#             tail_type                                   head_detail_name  \
# 0   BiologicalProcess                    Rho GTPase activating protein 1
# 1   BiologicalProcess                      ataxia telangiectasia mutated
# 2   BiologicalProcess             ataxia telangiectasia and Rad3 related
# 3   BiologicalProcess                       breast cancer 1, early onset
# 4   BiologicalProcess  BUB1B, mitotic checkpoint serine/threonine kinase
# ..                ...                                                ...
# 78  BiologicalProcess                       RNA binding motif protein 38
# 79  BiologicalProcess                          collagen, type I, alpha 1
# 80  BiologicalProcess               sialic acid binding Ig-like lectin E
# 81  BiologicalProcess              superoxide dismutase 3, extracellular
# 82  BiologicalProcess                                        microRNA 17
#
#    tail_detail_name relation_source       species  data_type kg_type  \
# 0    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 1    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 2    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 3    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 4    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# ..              ...             ...           ...        ...     ...
# 78   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 79   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 80   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 81   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 82   obsolete aging         GeneAge  Mus musculus  Causative   Aging
#
#    head_id_is tail_id_is kg_source
# 0     NCBI_ID   Quick_GO    Genage
# 1     NCBI_ID   Quick_GO    Genage
# 2     NCBI_ID   Quick_GO    Genage
# 3     NCBI_ID   Quick_GO    Genage
# 4     NCBI_ID   Quick_GO    Genage
# ..        ...        ...       ...
# 78    NCBI_ID   Quick_GO    Genage
# 79    NCBI_ID   Quick_GO    Genage
# 80    NCBI_ID   Quick_GO    Genage
# 81    NCBI_ID   Quick_GO    Genage
# 82    NCBI_ID   Quick_GO    Genage
#
# [83 rows x 14 columns]

# %% [markdown]
# # AgingBank

# %%
AgingBank = pd.read_csv(PROC_DIR + 'agingbank/Mouse_AgingbankGene_inhibits_BioPro.csv')
AgingBank.columns = AgingBank.columns.str.lower()
AgingBank = AgingBank[~AgingBank['head_detail_name'].isna()]

AgingBank['kg_type'] = 'Aging'
AgingBank['tail_type'] = 'BiologicalProcess'
print(f"AgingBank: {len(AgingBank):,} rows")
AgingBank['head_id_is'] = 'NCBI_ID'
AgingBank['relation'] = 'Gene_Inhibits_BiologicalProcess'
AgingBank['tail_id_is'] = 'Quick_GO'
AgingBank['species'] = 'Mus musculus'
AgingBank['kg_source'] = 'AgingBank'
AgingBank
# Out:
# AgingBank: 17 rows
#        head                         relation        tail head_type  \
# 0     Aldh2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1      Bcl2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2      Bmi1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3     Hmox1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 4   Ankrd22  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 5       C4b  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 6      Lag3  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 7      Nqo1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 8    Pcdhb9  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 9     Prdx4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 10      H19  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 11    Norad  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 12     COX1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 13       Kl  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 14     Isl1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 15     Mfn2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 16     Mtbp  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#             tail_type  kg_source kg_type  \
# 0   BiologicalProcess  AgingBank   Aging
# 1   BiologicalProcess  AgingBank   Aging
# 2   BiologicalProcess  AgingBank   Aging
# 3   BiologicalProcess  AgingBank   Aging
# 4   BiologicalProcess  AgingBank   Aging
# 5   BiologicalProcess  AgingBank   Aging
# 6   BiologicalProcess  AgingBank   Aging
# 7   BiologicalProcess  AgingBank   Aging
# 8   BiologicalProcess  AgingBank   Aging
# 9   BiologicalProcess  AgingBank   Aging
# 10  BiologicalProcess  AgingBank   Aging
# 11  BiologicalProcess  AgingBank   Aging
# 12  BiologicalProcess  AgingBank   Aging
# 13  BiologicalProcess  AgingBank   Aging
# 14  BiologicalProcess  AgingBank   Aging
# 15  BiologicalProcess  AgingBank   Aging
# 16  BiologicalProcess  AgingBank   Aging
#
#                                      head_detail_name tail_detail_name  \
# 0             aldehyde dehydrogenase 2, mitochondrial            aging
# 1                          B cell leukemia/lymphoma 2            aging
# 2                  Bmi1 polycomb ring finger oncogene            aging
# 3                                    heme oxygenase 1            aging
# 4                            ankyrin repeat domain 22            aging
# 5                  complement C4B (Chido blood group)            aging
# 6                        lymphocyte-activation gene 3            aging
# 7                    NAD(P)H dehydrogenase, quinone 1            aging
# 8                                protocadherin beta 9            aging
# 9                                     peroxiredoxin 4            aging
# 10     H19, imprinted maternally expressed transcript            aging
# 11             non-coding RNA activated by DNA damage            aging
# 12                     cytochrome c oxidase subunit I            aging
# 13                                             klotho            aging
# 14         ISL1 transcription factor, LIM/homeodomain            aging
# 15                                        mitofusin 2            aging
# 16  Mdm2, transformed 3T3 cell double minute p53 b...            aging
#
#    head_id_is tail_id_is kg_type.1       species
# 0     NCBI_ID   Quick_GO     Aging  Mus musculus
# 1     NCBI_ID   Quick_GO     Aging  Mus musculus
# 2     NCBI_ID   Quick_GO     Aging  Mus musculus
# 3     NCBI_ID   Quick_GO     Aging  Mus musculus
# 4     NCBI_ID   Quick_GO     Aging  Mus musculus
# 5     NCBI_ID   Quick_GO     Aging  Mus musculus
# 6     NCBI_ID   Quick_GO     Aging  Mus musculus
# 7     NCBI_ID   Quick_GO     Aging  Mus musculus
# 8     NCBI_ID   Quick_GO     Aging  Mus musculus
# 9     NCBI_ID   Quick_GO     Aging  Mus musculus
# 10    NCBI_ID   Quick_GO     Aging  Mus musculus
# 11    NCBI_ID   Quick_GO     Aging  Mus musculus
# 12    NCBI_ID   Quick_GO     Aging  Mus musculus
# 13    NCBI_ID   Quick_GO     Aging  Mus musculus
# 14    NCBI_ID   Quick_GO     Aging  Mus musculus
# 15    NCBI_ID   Quick_GO     Aging  Mus musculus
# 16    NCBI_ID   Quick_GO     Aging  Mus musculus

# %%
AgingBank_2 = pd.read_csv(PROC_DIR + 'agingbank/Mouse_AgingbankGene_inhibits_BioPro_2.csv')
AgingBank_2.columns = AgingBank_2.columns.str.lower()
AgingBank_2 = AgingBank_2[~AgingBank_2['head_detail_name'].isna()]

AgingBank_2['kg_type'] = 'Aging'
AgingBank_2['relation'] = 'Gene_Inhibits_BiologicalProcess'

AgingBank_2['tail_type'] = 'BiologicalProcess'
print(f"AgingBank_2: {len(AgingBank_2):,} rows")
AgingBank_2['head_id_is'] = 'NCBI_ID'
AgingBank_2['tail_id_is'] = 'Quick_GO'
AgingBank_2['species'] = 'Mus musculus'
AgingBank_2['kg_source'] = 'AgingBank'
AgingBank_2
# Out:
# AgingBank_2: 1 rows
#    head                         relation        tail head_type  \
# 0  COX1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#            tail_type  kg_source kg_type                head_detail_name  \
# 0  BiologicalProcess  AgingBank   Aging  cytochrome c oxidase subunit I
#
#   tail_detail_name head_id_is tail_id_is kg_type.1       species
# 0            aging    NCBI_ID   Quick_GO     Aging  Mus musculus

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Genage, AgingBank, AgingBank_2
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 101
#         head                         relation        tail head_type  \
# 0    Arhgap1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1        Atm  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2        Atr  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3      Brca1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 4      Bub1b  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# ..       ...                              ...         ...       ...
# 96        Kl  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 97      Isl1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 98      Mfn2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 99      Mtbp  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 100     COX1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#     relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 1            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 2            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 3            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 4            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# ..            ...                ...        ...     ...        ...        ...
# 96           None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 97           None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 98           None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 99           None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 100          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
#
#                                       head_detail_name tail_detail_name  \
# 0                      Rho GTPase activating protein 1   obsolete aging
# 1                        ataxia telangiectasia mutated   obsolete aging
# 2               ataxia telangiectasia and Rad3 related   obsolete aging
# 3                         breast cancer 1, early onset   obsolete aging
# 4    BUB1B, mitotic checkpoint serine/threonine kinase   obsolete aging
# ..                                                 ...              ...
# 96                                              klotho            aging
# 97          ISL1 transcription factor, LIM/homeodomain            aging
# 98                                         mitofusin 2            aging
# 99   Mdm2, transformed 3T3 cell double minute p53 b...            aging
# 100                     cytochrome c oxidase subunit I            aging
#
#           species
# 0    Mus musculus
# 1    Mus musculus
# 2    Mus musculus
# 3    Mus musculus
# 4    Mus musculus
# ..            ...
# 96   Mus musculus
# 97   Mus musculus
# 98   Mus musculus
# 99   Mus musculus
# 100  Mus musculus
#
# [101 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Inhibits_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'Genage', 'AgingBank'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 101 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           101                   0             101
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 101  |  After dedup: 99
#       head                         relation        tail head_type  \
# 0   Adra1a  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1    Aldh2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2  Ankrd22  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#   relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 1          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 2          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
#
#                           head_detail_name tail_detail_name       species
# 0            adrenergic receptor, alpha 1a   obsolete aging  Mus musculus
# 1  aldehyde dehydrogenase 2, mitochondrial            aging  Mus musculus
# 2                 ankyrin repeat domain 22            aging  Mus musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            99                   0              99
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'AgingBank::Genage', 'Genage', 'AgingBank'} kg_source
# Genage               82
# AgingBank            16
# AgingBank::Genage     1
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    99
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 99 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_inhibits_biologicalprocess/Mouse_gene_inhibits_biologicalprocess.csv

# %%
# OUT_PATH
