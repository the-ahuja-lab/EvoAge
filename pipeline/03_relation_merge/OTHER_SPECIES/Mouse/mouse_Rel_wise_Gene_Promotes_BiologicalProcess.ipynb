# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_gene_promotes_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_promotes_biologicalprocess/Mouse_gene_promotes_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Mouse_gene_promotes_biologicalprocess’: File exists

# %%
#

# %%
# Mouse = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Mus_musculus.gene_info',
#     sep='\t',
    
# )
# # Mouse["LocusTag"] = Mouse["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Mouse_symbol2Locus_dict = dict(zip(Mouse['Symbol'], Mouse['LocusTag']))
# # Mouse
# # Mouse_symbol2Locus_dict
# Mouse

# %% [markdown]
# # Genage

# %%
Genage = pd.read_csv(PROC_DIR + 'genage/Mouse/Mouse_Gene_Promotes_BiologicalProcess.csv')
Genage.columns = Genage.columns.str.lower()
Genage = Genage[~Genage['head_detail_name'].isna()]

Genage['kg_type'] = 'Aging'

print(f"Genage: {len(Genage):,} rows")
Genage['head_id_is'] = 'NCBI_ID'
Genage['tail_id_is'] = 'Quick_GO'
Genage['species'] = 'Mus musculus'
Genage['kg_source'] = 'Genage'

Genage
# Out:
# Genage: 45 rows
#         head                         relation        tail head_type  \
# 0      Adcy5  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1     Cdkn1a  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2       Coq7  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3         Gh  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 4        Ghr  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 5      Ghrhr  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 6       Gpx4  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 7      Igf1r  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 8       Insr  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 9       Irs1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 10      Irs2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 11     Pappa  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 12    Pou1f1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 13     Prop1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 14      Shc1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 15     Surf1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 16     Terf2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 17    Agtr1a  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 18    Eef1e1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 19      Eps8  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 20       Htt  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 21     Kcna3  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 22   Slc13a1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 23  Trp53bp1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 24   Rps6kb1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 25   Prkar2b  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 26    Eif5a2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 27       Mif  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 28     Dgat1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 29     Gsta4  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 30      Mtor  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 31      Akt1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 32     Ikbkb  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 33      Ghrh  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 34  Serpine1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 35       Myc  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 36      Ctf1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 37     Trpv1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 38    Adra1b  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 39       Ubd  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 40      Mstn  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 41      Mtbp  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 42      Gmfb  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 43      Per2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 44      Akt2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#             tail_type                                   head_detail_name  \
# 0   BiologicalProcess                                adenylate cyclase 5
# 1   BiologicalProcess               cyclin dependent kinase inhibitor 1A
# 2   BiologicalProcess                                       demethyl-Q 7
# 3   BiologicalProcess                                     growth hormone
# 4   BiologicalProcess                            growth hormone receptor
# 5   BiologicalProcess          growth hormone releasing hormone receptor
# 6   BiologicalProcess                           glutathione peroxidase 4
# 7   BiologicalProcess              insulin-like growth factor I receptor
# 8   BiologicalProcess                                   insulin receptor
# 9   BiologicalProcess                       insulin receptor substrate 1
# 10  BiologicalProcess                       insulin receptor substrate 2
# 11  BiologicalProcess              pregnancy-associated plasma protein A
# 12  BiologicalProcess        POU domain, class 1, transcription factor 1
# 13  BiologicalProcess                   paired like homeodomain factor 1
# 14  BiologicalProcess  src homology 2 domain-containing transforming ...
# 15  BiologicalProcess                                     surfeit gene 1
# 16  BiologicalProcess                  telomeric repeat binding factor 2
# 17  BiologicalProcess                   angiotensin II receptor, type 1a
# 18  BiologicalProcess  eukaryotic translation elongation factor 1 eps...
# 19  BiologicalProcess  epidermal growth factor receptor pathway subst...
# 20  BiologicalProcess                                         huntingtin
# 21  BiologicalProcess  potassium voltage-gated channel, shaker-relate...
# 22  BiologicalProcess  solute carrier family 13 (sodium/sulfate sympo...
# 23  BiologicalProcess  transformation related protein 53 binding prot...
# 24  BiologicalProcess         ribosomal protein S6 kinase, polypeptide 1
# 25  BiologicalProcess  protein kinase, cAMP dependent regulatory, typ...
# 26  BiologicalProcess       eukaryotic translation initiation factor 5A2
# 27  BiologicalProcess  macrophage migration inhibitory factor (glycos...
# 28  BiologicalProcess                 diacylglycerol O-acyltransferase 1
# 29  BiologicalProcess                 glutathione S-transferase, alpha 4
# 30  BiologicalProcess             mechanistic target of rapamycin kinase
# 31  BiologicalProcess                     thymoma viral proto-oncogene 1
# 32  BiologicalProcess                    inhibitor of kappaB kinase beta
# 33  BiologicalProcess                   growth hormone releasing hormone
# 34  BiologicalProcess  serine (or cysteine) peptidase inhibitor, clad...
# 35  BiologicalProcess                          myelocytomatosis oncogene
# 36  BiologicalProcess                                    cardiotrophin 1
# 37  BiologicalProcess  transient receptor potential cation channel, s...
# 38  BiologicalProcess                      adrenergic receptor, alpha 1b
# 39  BiologicalProcess                                        ubiquitin D
# 40  BiologicalProcess                                          myostatin
# 41  BiologicalProcess  Mdm2, transformed 3T3 cell double minute p53 b...
# 42  BiologicalProcess                       glia maturation factor, beta
# 43  BiologicalProcess                           period circadian clock 2
# 44  BiologicalProcess                     thymoma viral proto-oncogene 2
#
#    tail_detail_name relation_source       species  data_type kg_type  \
# 0    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 1    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 2    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 3    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 4    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 5    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 6    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 7    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 8    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 9    obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 10   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 11   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 12   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 13   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 14   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 15   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 16   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 17   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 18   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 19   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 20   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 21   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 22   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 23   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 24   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 25   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 26   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 27   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 28   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 29   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 30   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 31   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 32   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 33   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 34   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 35   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 36   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 37   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 38   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 39   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 40   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 41   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 42   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 43   obsolete aging         GeneAge  Mus musculus  Causative   Aging
# 44   obsolete aging         GeneAge  Mus musculus  Causative   Aging
#
#    head_id_is tail_id_is kg_source
# 0     NCBI_ID   Quick_GO    Genage
# 1     NCBI_ID   Quick_GO    Genage
# 2     NCBI_ID   Quick_GO    Genage
# 3     NCBI_ID   Quick_GO    Genage
# 4     NCBI_ID   Quick_GO    Genage
# 5     NCBI_ID   Quick_GO    Genage
# 6     NCBI_ID   Quick_GO    Genage
# 7     NCBI_ID   Quick_GO    Genage
# 8     NCBI_ID   Quick_GO    Genage
# 9     NCBI_ID   Quick_GO    Genage
# 10    NCBI_ID   Quick_GO    Genage
# 11    NCBI_ID   Quick_GO    Genage
# 12    NCBI_ID   Quick_GO    Genage
# 13    NCBI_ID   Quick_GO    Genage
# 14    NCBI_ID   Quick_GO    Genage
# 15    NCBI_ID   Quick_GO    Genage
# 16    NCBI_ID   Quick_GO    Genage
# 17    NCBI_ID   Quick_GO    Genage
# 18    NCBI_ID   Quick_GO    Genage
# 19    NCBI_ID   Quick_GO    Genage
# 20    NCBI_ID   Quick_GO    Genage
# 21    NCBI_ID   Quick_GO    Genage
# 22    NCBI_ID   Quick_GO    Genage
# 23    NCBI_ID   Quick_GO    Genage
# 24    NCBI_ID   Quick_GO    Genage
# 25    NCBI_ID   Quick_GO    Genage
# 26    NCBI_ID   Quick_GO    Genage
# 27    NCBI_ID   Quick_GO    Genage
# 28    NCBI_ID   Quick_GO    Genage
# 29    NCBI_ID   Quick_GO    Genage
# 30    NCBI_ID   Quick_GO    Genage
# 31    NCBI_ID   Quick_GO    Genage
# 32    NCBI_ID   Quick_GO    Genage
# 33    NCBI_ID   Quick_GO    Genage
# 34    NCBI_ID   Quick_GO    Genage
# 35    NCBI_ID   Quick_GO    Genage
# 36    NCBI_ID   Quick_GO    Genage
# 37    NCBI_ID   Quick_GO    Genage
# 38    NCBI_ID   Quick_GO    Genage
# 39    NCBI_ID   Quick_GO    Genage
# 40    NCBI_ID   Quick_GO    Genage
# 41    NCBI_ID   Quick_GO    Genage
# 42    NCBI_ID   Quick_GO    Genage
# 43    NCBI_ID   Quick_GO    Genage
# 44    NCBI_ID   Quick_GO    Genage

# %% [markdown]
# # AgingBank

# %%
AgingBank = pd.read_csv(PROC_DIR + 'agingbank/Mouse_AgingbankGene_promotes_BioPro.csv')
AgingBank.columns = AgingBank.columns.str.lower()
AgingBank = AgingBank[~AgingBank['head_detail_name'].isna()]

AgingBank['kg_type'] = 'Aging'
AgingBank['relation'] = 'Gene_Promotes_BiologicalProcess'
AgingBank['tail_type'] = 'BiologicalProcess'
print(f"AgingBank: {len(AgingBank):,} rows")
AgingBank['head_id_is'] = 'NCBI_ID'
AgingBank['tail_id_is'] = 'Quick_GO'
AgingBank['species'] = 'Mus musculus'
AgingBank['kg_source'] = 'AgingBank'
AgingBank
# Out:
# AgingBank: 20 rows
#        head                         relation        tail head_type  \
# 0      Alpl  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1     Dctn1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2     Nrip1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3     Rras2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 4      Thy1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 5      Drd2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 6       H19  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 7    Homer1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 8   Gm14230  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 9     C1ql3  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 10    Gpr37  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 11     Igf2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 12     Mest  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 13     Ptk7  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 14   Srd5a2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 15     Cln5  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 16     Dkc1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 17   Ptpn11  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 18  Tmem135  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 19    Bach1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#             tail_type  kg_source kg_type  \
# 0   BiologicalProcess  AgingBank   Aging
# 1   BiologicalProcess  AgingBank   Aging
# 2   BiologicalProcess  AgingBank   Aging
# 3   BiologicalProcess  AgingBank   Aging
# 4   BiologicalProcess  AgingBank   Aging
# 5   BiologicalProcess  AgingBank   Aging
# 6   BiologicalProcess  AgingBank   Aging
# 7   BiologicalProcess  AgingBank   Aging
# 8   BiologicalProcess  AgingBank   Aging
# 9   BiologicalProcess  AgingBank   Aging
# 10  BiologicalProcess  AgingBank   Aging
# 11  BiologicalProcess  AgingBank   Aging
# 12  BiologicalProcess  AgingBank   Aging
# 13  BiologicalProcess  AgingBank   Aging
# 14  BiologicalProcess  AgingBank   Aging
# 15  BiologicalProcess  AgingBank   Aging
# 16  BiologicalProcess  AgingBank   Aging
# 17  BiologicalProcess  AgingBank   Aging
# 18  BiologicalProcess  AgingBank   Aging
# 19  BiologicalProcess  AgingBank   Aging
#
#                                      head_detail_name tail_detail_name  \
# 0             alkaline phosphatase, liver/bone/kidney            aging
# 1                                          dynactin 1            aging
# 2              nuclear receptor interacting protein 1            aging
# 3                related RAS viral (r-ras) oncogene 2            aging
# 4                        thymus cell antigen 1, theta            aging
# 5                                dopamine receptor D2            aging
# 6      H19, imprinted maternally expressed transcript            aging
# 7                         homer scaffolding protein 1            aging
# 8                                predicted gene 14230            aging
# 9                                          C1q-like 3            aging
# 10                      G protein-coupled receptor 37            aging
# 11                       insulin-like growth factor 2            aging
# 12                       mesoderm specific transcript            aging
# 13                     PTK7 protein tyrosine kinase 7            aging
# 14                        steroid 5 alpha-reductase 2            aging
# 15                  ceroid-lipofuscinosis, neuronal 5            aging
# 16                 dyskeratosis congenita 1, dyskerin            aging
# 17  protein tyrosine phosphatase, non-receptor typ...            aging
# 18                          transmembrane protein 135            aging
# 19  BTB and CNC homology 1, basic leucine zipper t...            aging
#
#    head_id_is tail_id_is kg_type.1       species
# 0     NCBI_ID   Quick_GO     Aging  Mus musculus
# 1     NCBI_ID   Quick_GO     Aging  Mus musculus
# 2     NCBI_ID   Quick_GO     Aging  Mus musculus
# 3     NCBI_ID   Quick_GO     Aging  Mus musculus
# 4     NCBI_ID   Quick_GO     Aging  Mus musculus
# 5     NCBI_ID   Quick_GO     Aging  Mus musculus
# 6     NCBI_ID   Quick_GO     Aging  Mus musculus
# 7     NCBI_ID   Quick_GO     Aging  Mus musculus
# 8     NCBI_ID   Quick_GO     Aging  Mus musculus
# 9     NCBI_ID   Quick_GO     Aging  Mus musculus
# 10    NCBI_ID   Quick_GO     Aging  Mus musculus
# 11    NCBI_ID   Quick_GO     Aging  Mus musculus
# 12    NCBI_ID   Quick_GO     Aging  Mus musculus
# 13    NCBI_ID   Quick_GO     Aging  Mus musculus
# 14    NCBI_ID   Quick_GO     Aging  Mus musculus
# 15    NCBI_ID   Quick_GO     Aging  Mus musculus
# 16    NCBI_ID   Quick_GO     Aging  Mus musculus
# 17    NCBI_ID   Quick_GO     Aging  Mus musculus
# 18    NCBI_ID   Quick_GO     Aging  Mus musculus
# 19    NCBI_ID   Quick_GO     Aging  Mus musculus

# %%
AgingBank_2 = pd.read_csv(PROC_DIR + 'agingbank/Mouse_AgingbankGene_promotes_BioPro_2.csv')
AgingBank_2.columns = AgingBank_2.columns.str.lower()
AgingBank_2 = AgingBank_2[~AgingBank_2['head_detail_name'].isna()]

AgingBank_2['kg_type'] = 'Aging'
AgingBank_2['relation'] = 'Gene_Promotes_BiologicalProcess'

AgingBank_2['tail_type'] = 'BiologicalProcess'
print(f"AgingBank_2: {len(AgingBank_2):,} rows")
AgingBank_2['head_id_is'] = 'NCBI_ID'
AgingBank_2['tail_id_is'] = 'Quick_GO'
AgingBank_2['species'] = 'Mus musculus'
AgingBank_2['kg_source'] = 'AgingBank'
AgingBank_2
# Out:
# AgingBank_2: 0 rows
# Empty DataFrame
# Columns: [head, relation, tail, head_type, tail_type, kg_source, kg_type, head_detail_name, tail_detail_name, head_id_is, tail_id_is, kg_type.1, species]
# Index: []

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Genage, AgingBank, AgingBank_2
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 65
#        head                         relation        tail head_type  \
# 0     Adcy5  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1    Cdkn1a  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2      Coq7  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3        Gh  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 4       Ghr  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# ..      ...                              ...         ...       ...
# 60     Cln5  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 61     Dkc1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 62   Ptpn11  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 63  Tmem135  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 64    Bach1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#    relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 1           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 2           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 3           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 4           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# ..           ...                ...        ...     ...        ...        ...
# 60          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 61          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 62          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 63          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 64          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
#
#                                      head_detail_name tail_detail_name  \
# 0                                 adenylate cyclase 5   obsolete aging
# 1                cyclin dependent kinase inhibitor 1A   obsolete aging
# 2                                        demethyl-Q 7   obsolete aging
# 3                                      growth hormone   obsolete aging
# 4                             growth hormone receptor   obsolete aging
# ..                                                ...              ...
# 60                  ceroid-lipofuscinosis, neuronal 5            aging
# 61                 dyskeratosis congenita 1, dyskerin            aging
# 62  protein tyrosine phosphatase, non-receptor typ...            aging
# 63                          transmembrane protein 135            aging
# 64  BTB and CNC homology 1, basic leucine zipper t...            aging
#
#          species
# 0   Mus musculus
# 1   Mus musculus
# 2   Mus musculus
# 3   Mus musculus
# 4   Mus musculus
# ..           ...
# 60  Mus musculus
# 61  Mus musculus
# 62  Mus musculus
# 63  Mus musculus
# 64  Mus musculus
#
# [65 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Promotes_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'AgingBank', 'Genage'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 65 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            65                   0              65
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 65  |  After dedup: 65
#      head                         relation        tail head_type  \
# 0   Adcy5  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1  Adra1b  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2  Agtr1a  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#   relation_type          tail_type kg_source kg_type head_id_is tail_id_is  \
# 0          None  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
# 1          None  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
# 2          None  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
#
#                    head_detail_name tail_detail_name       species
# 0               adenylate cyclase 5   obsolete aging  Mus musculus
# 1     adrenergic receptor, alpha 1b   obsolete aging  Mus musculus
# 2  angiotensin II receptor, type 1a   obsolete aging  Mus musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            65                   0              65
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'AgingBank', 'Genage'} kg_source
# Genage       45
# AgingBank    20
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    65
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 65 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_gene_promotes_biologicalprocess/Mouse_gene_promotes_biologicalprocess.csv

# %%
# OUT_PATH
