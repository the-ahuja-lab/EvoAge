# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Mouse_chemical_inhibits_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_chemical_inhibits_biologicalprocess/Mouse_chemical_inhibits_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %% [markdown]
# # AgeXtend

# %%
AgeXtend = pd.read_csv(PROC_DIR + 'agextend_processed/AgeXtend_Mouse_ChemicalEntity_Inhibits_BiologicalProcess.csv')
AgeXtend.columns = AgeXtend.columns.str.lower()
AgeXtend = AgeXtend[~AgeXtend['head_detail_name'].isna()]

AgeXtend['kg_type'] = 'Aging'

print(f"AgeXtend: {len(AgeXtend):,} rows")
AgeXtend['head_id_is'] = 'Pubchem'
AgeXtend['tail_id_is'] = 'Quick_GO'
AgeXtend['species'] = 'Mus musculus'
AgeXtend['kg_source'] = 'AgeXtend'

AgeXtend
# Out:
# AgeXtend: 7 rows
#        head                                   relation        tail  \
# 0   5319022  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 1   5280443  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 2      6072  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 3  73554535  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 4      4034  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 5      5991  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 6   5281233  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
#
#         head_type          tail_type  \
# 0  ChemicalEntity  BiologicalProcess
# 1  ChemicalEntity  BiologicalProcess
# 2  ChemicalEntity  BiologicalProcess
# 3  ChemicalEntity  BiologicalProcess
# 4  ChemicalEntity  BiologicalProcess
# 5  ChemicalEntity  BiologicalProcess
# 6  ChemicalEntity  BiologicalProcess
#
#                                     head_detail_name  \
# 0   (3Z)-3-butylidene-4,5-dihydro-2-benzofuran-1-one
# 1     5,7-dihydroxy-2-(4-hydroxyphenyl)chromen-4-one
# 2  1-[2,4-dihydroxy-6-[(2S,3R,4S,5S,6R)-3,4,5-tri...
# 3  (2R,6R)-6-[(7S,10S,13R,14R,15S,17R)-7,15-dihyd...
# 4  1-[(4-chlorophenyl)-phenylmethyl]-4-[(3-methyl...
# 5  (8R,9S,13S,14S,17R)-17-ethynyl-13-methyl-7,8,9...
# 6  bis[(2S,3R,4S,5S,6R)-3,4,5-trihydroxy-6-[[(2R,...
#
#                                      head_smile_name tail_detail_name  \
# 0                      CCC/C=C\1/C2=C(C=CCC2)C(=O)O1            aging
# 1         C1=CC(=CC=C1C2=CC(=O)C3=C(C=C(C=C3O2)O)O)O            aging
# 2  C1=CC(=CC=C1CCC(=O)C2=C(C=C(C=C2O[C@H]3[C@@H](...            aging
# 3  C[C@H](CC(=O)C[C@@H](C)C(=O)O)[C@H]1C[C@@H]([C...            aging
# 4  CC1=CC(=CC=C1)CN2CCN(CC2)C(C3=CC=CC=C3)C4=CC=C...            aging
# 5  C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@]2(C#C)O)CCC4...            aging
# 6  C/C(=C\C=C\C=C(\C=C\C=C(\C(=O)O[C@@H]1O[C@@H](...            aging
#
#   relation_source       species                                   data_source  \
# 0        AgeXtend  Mus musculus  https://doi.org/10.1016/j.phymed.2023.155216
# 1        AgeXtend  Mus musculus     https://doi.org/10.1016/j.mad.2023.111889
# 2        AgeXtend  Mus musculus   https://doi.org/10.1016/j.exger.2022.111769
# 3        AgeXtend  Mus musculus            https://doi.org/10.1111/acel.13686
# 4        AgeXtend  Mus musculus    https://doi.org/10.1007/s11357-023-01011-0
# 5        AgeXtend  Mus musculus            https://doi.org/10.1111/acel.13328
# 6        AgeXtend  Mus musculus  https://doi.org/10.22038/ajp.2017.21198.1801
#
#    anti_aging_status  anti_aging_prob kg_type head_id_is tail_id_is kg_source
# 0                  1         0.914950   Aging    Pubchem   Quick_GO  AgeXtend
# 1                  1         0.920326   Aging    Pubchem   Quick_GO  AgeXtend
# 2                  1         0.904648   Aging    Pubchem   Quick_GO  AgeXtend
# 3                  1         0.824924   Aging    Pubchem   Quick_GO  AgeXtend
# 4                  1         0.928011   Aging    Pubchem   Quick_GO  AgeXtend
# 5                  1         0.752881   Aging    Pubchem   Quick_GO  AgeXtend
# 6                  1         0.913811   Aging    Pubchem   Quick_GO  AgeXtend

# %% [markdown]
# # AgingAtlas

# %%
AgingAtlas = pd.read_csv(PROC_DIR + 'agingatlas/Mouse/Mouse_AgingAtlas_Chemical_Inhibit_BiologicalProcess_Geroprotectors.csv')
AgingAtlas.columns = AgingAtlas.columns.str.lower()
AgingAtlas = AgingAtlas[~AgingAtlas['head_detail_name'].isna()]

AgingAtlas['kg_type'] = 'Aging'
AgingAtlas['tail_type'] = 'BiologicalProcess'
print(f"AgingAtlas: {len(AgingAtlas):,} rows")
AgingAtlas['head_id_is'] = 'Pubchem'
AgingAtlas['tail_id_is'] = 'Quick_GO'
AgingAtlas['species'] = 'Mus musculus'
AgingAtlas['kg_source'] = 'AgingAtlas'
AgingAtlas
# Out:
# AgingAtlas: 33 rows
#          head                                   relation        tail  \
# 0        1567  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 1   139254081  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 2       68570  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 3   163284948  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 4        1983  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 5        2244  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 6         586  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 7      439213  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 8      219042  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 9        3293  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 10     439213  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 11     132999  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 12     265776  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 13        896  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 14       4091  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 15      84815  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 16       4171  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 17     462382  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 18      12035  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 19  134378124  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 20      14181  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 21       4534  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 22       8249  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 23    5280343  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 24    5284616  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 25    5280805  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 26      24934  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 27       1103  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 28   25232708  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 29       5311  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 30     124072  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 31   54670067  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 32      14985  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
#
#          head_type          tail_type  \
# 0   ChemicalEntity  BiologicalProcess
# 1   ChemicalEntity  BiologicalProcess
# 2   ChemicalEntity  BiologicalProcess
# 3   ChemicalEntity  BiologicalProcess
# 4   ChemicalEntity  BiologicalProcess
# 5   ChemicalEntity  BiologicalProcess
# 6   ChemicalEntity  BiologicalProcess
# 7   ChemicalEntity  BiologicalProcess
# 8   ChemicalEntity  BiologicalProcess
# 9   ChemicalEntity  BiologicalProcess
# 10  ChemicalEntity  BiologicalProcess
# 11  ChemicalEntity  BiologicalProcess
# 12  ChemicalEntity  BiologicalProcess
# 13  ChemicalEntity  BiologicalProcess
# 14  ChemicalEntity  BiologicalProcess
# 15  ChemicalEntity  BiologicalProcess
# 16  ChemicalEntity  BiologicalProcess
# 17  ChemicalEntity  BiologicalProcess
# 18  ChemicalEntity  BiologicalProcess
# 19  ChemicalEntity  BiologicalProcess
# 20  ChemicalEntity  BiologicalProcess
# 21  ChemicalEntity  BiologicalProcess
# 22  ChemicalEntity  BiologicalProcess
# 23  ChemicalEntity  BiologicalProcess
# 24  ChemicalEntity  BiologicalProcess
# 25  ChemicalEntity  BiologicalProcess
# 26  ChemicalEntity  BiologicalProcess
# 27  ChemicalEntity  BiologicalProcess
# 28  ChemicalEntity  BiologicalProcess
# 29  ChemicalEntity  BiologicalProcess
# 30  ChemicalEntity  BiologicalProcess
# 31  ChemicalEntity  BiologicalProcess
# 32  ChemicalEntity  BiologicalProcess
#
#                                      head_detail_name  \
# 0                                   2-sulfanylethanol
# 1   [(4E,6E,8R,9R,10E,12S,13R,14S,16R)-19-[2-(dime...
# 2   (8R,9S,13S,14S,17R)-13-methyl-6,7,8,9,11,12,14...
# 3   (2S,5S)-5-[(2R,5S)-5-[(2R,5S,6R)-3,4-dihydroxy...
# 4                        N-(4-hydroxyphenyl)acetamide
# 5                             2-acetyloxybenzoic acid
# 6           2-[carbamimidoyl(methyl)amino]acetic acid
# 7   (3R,4R,5S,6R)-3-amino-6-(hydroxymethyl)oxane-2...
# 8   (4S)-4-[[(2S)-2-aminopropanoyl]amino]-5-[[(2S)...
# 9               6-ethoxy-2,2,4-trimethyl-1H-quinoline
# 10  (3R,4R,5S,6R)-3-amino-6-(hydroxymethyl)oxane-2...
# 11  3-[3-[[(7S)-3,4-dimethoxy-7-bicyclo[4.2.0]octa...
# 12                          N-methylpyrimidin-2-amine
# 13      N-[2-(5-methoxy-1H-indol-3-yl)ethyl]acetamide
# 14       3-(diaminomethylidene)-1,1-dimethylguanidine
# 15         (2R)-2-amino-4-methylsulfanylbutanoic acid
# 16  1-[4-(2-methoxyethyl)phenoxy]-3-(propan-2-ylam...
# 17  benzyl N-[(2S)-4-methyl-1-[[(2S)-4-methyl-1-[[...
# 18          (2R)-2-acetamido-3-sulfanylpropanoic acid
# 19  1-[(2R)-6-fluoro-3,4-dihydro-2H-chromen-2-yl]-...
# 20  [(2R,3S,4R,5R)-5-(3-carbamoylpyridin-1-ium-1-y...
# 21  4-[4-(3,4-dihydroxyphenyl)-2,3-dimethylbutyl]b...
# 22  1-(diaminomethylidene)-2-(2-phenylethyl)guanidine
# 23  2-(3,4-dihydroxyphenyl)-3,5,7-trihydroxychrome...
# 24  (1R,9S,12S,15R,16E,18R,19R,21R,23S,24E,26E,28E...
# 25  2-(3,4-dihydroxyphenyl)-5,7-dihydroxy-3-[(2S,3...
# 26                                  disodium;selenite
# 27          N,N'-bis(3-aminopropyl)butane-1,4-diamine
# 28  N-[2-[3-(piperazin-1-ylmethyl)imidazo[2,1-b][1...
# 29                   N'-hydroxy-N-phenyloctanediamide
# 30  1,7-bis(4-hydroxy-3-methoxyphenyl)heptane-3,5-...
# 31  (2R)-2-[(1S)-1,2-dihydroxyethyl]-3,4-dihydroxy...
# 32  (2R)-2,5,7,8-tetramethyl-2-[(4R,8R)-4,8,12-tri...
#
#                                       head_smile_name  \
# 0                                              C(CS)O
# 1   C[C@H]1C[C@@H]([C@@H]([C@H](/C=C(/[C@H]([C@@H]...
# 2   C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@H]2O)CCC4=C3C...
# 3   C[C@@H]1[C@H](C(C([C@H](O1)O[C@@H]2C(O[C@@H](C...
# 4                               CC(=O)NC1=CC=C(C=C1)O
# 5                            CC(=O)OC1=CC=CC=C1C(=O)O
# 6                                   CN(CC(=O)O)C(=N)N
# 7          C([C@@H]1[C@H]([C@@H]([C@H](C(O1)O)N)O)O)O
# 8   C[C@@H](C(=O)N[C@@H](CCC(=O)O)C(=O)N[C@@H](CC(...
# 9                      CCOC1=CC2=C(C=C1)NC(C=C2C)(C)C
# 10         C([C@@H]1[C@H]([C@@H]([C@H](C(O1)O)N)O)O)O
# 11  CN(CCCN1CCC2=CC(=C(C=C2CC1=O)OC)OC)C[C@H]3CC4=...
# 12                                      CNC1=NC=CC=N1
# 13                     CC(=O)NCCC1=CNC2=C1C=C(C=C2)OC
# 14                                  CN(C)C(=N)N=C(N)N
# 15                                 CSCC[C@H](C(=O)O)N
# 16                     CC(C)NCC(COC1=CC=C(C=C1)CCOC)O
# 17  CC(C)C[C@@H](C=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H...
# 18                            CC(=O)N[C@@H](CS)C(=O)O
# 19  C1CC2=C(C=CC(=C2)F)O[C@@H]1[C@@H](CNCC([C@H]3C...
# 20  C1=CC(=C[N+](=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)...
# 21       CC(CC1=CC(=C(C=C1)O)O)C(C)CC2=CC(=C(C=C2)O)O
# 22                       C1=CC=C(C=C1)CCN=C(N)N=C(N)N
# 23   C1=CC(=C(C=C1C2=C(C(=O)C3=C(C=C(C=C3O2)O)O)O)O)O
# 24  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C/[C@H](C[...
# 25  C[C@H]1[C@@H]([C@H]([C@H]([C@@H](O1)OC[C@@H]2[...
# 26                       [O-][Se](=O)[O-].[Na+].[Na+]
# 27                                   C(CCNCCCN)CNCCCN
# 28  C1CN(CCN1)CC2=CSC3=NC(=CN23)C4=CC=CC=C4NC(=O)C...
# 29                   C1=CC=C(C=C1)NC(=O)CCCCCCC(=O)NO
# 30  COC1=C(C=CC(=C1)CCC(=O)CC(=O)CCC2=CC(=C(C=C2)O...
# 31               C([C@@H]([C@@H]1C(=C(C(=O)O1)O)O)O)O
# 32  CC1=C(C2=C(CC[C@@](O2)(C)CCC[C@H](C)CCC[C@H](C...
#
#              relation_source       species                    head_alt_name  \
# 0   Aging_Atlas_gerprotector  Mus musculus                2-mercaptoethanol
# 1   Aging_Atlas_gerprotector  Mus musculus                          17-DMAG
# 2   Aging_Atlas_gerprotector  Mus musculus                   17a-oestradiol
# 3   Aging_Atlas_gerprotector  Mus musculus                         Acarbose
# 4   Aging_Atlas_gerprotector  Mus musculus                    Acetaminophen
# 5   Aging_Atlas_gerprotector  Mus musculus                          Aspirin
# 6   Aging_Atlas_gerprotector  Mus musculus                         Creatine
# 7   Aging_Atlas_gerprotector  Mus musculus                    D-glucosamine
# 8   Aging_Atlas_gerprotector  Mus musculus                      Epithalamin
# 9   Aging_Atlas_gerprotector  Mus musculus                       Ethoxyquin
# 10  Aging_Atlas_gerprotector  Mus musculus                      Glucosamine
# 11  Aging_Atlas_gerprotector  Mus musculus                       Ivabradine
# 12  Aging_Atlas_gerprotector  Mus musculus                              JH4
# 13  Aging_Atlas_gerprotector  Mus musculus                        Melatonin
# 14  Aging_Atlas_gerprotector  Mus musculus                        Metformin
# 15  Aging_Atlas_gerprotector  Mus musculus                       Methionine
# 16  Aging_Atlas_gerprotector  Mus musculus                       Metoprolol
# 17  Aging_Atlas_gerprotector  Mus musculus                            MG132
# 18  Aging_Atlas_gerprotector  Mus musculus              N-acetyl-L-cysteine
# 19  Aging_Atlas_gerprotector  Mus musculus                        Nebivolol
# 20  Aging_Atlas_gerprotector  Mus musculus      Nicotinamide mononucleotide
# 21  Aging_Atlas_gerprotector  Mus musculus        Nordihydroguaiaretic acid
# 22  Aging_Atlas_gerprotector  Mus musculus                       Phenformin
# 23  Aging_Atlas_gerprotector  Mus musculus                        Quercetin
# 24  Aging_Atlas_gerprotector  Mus musculus                        Rapamycin
# 25  Aging_Atlas_gerprotector  Mus musculus                            Rutin
# 26  Aging_Atlas_gerprotector  Mus musculus                  Sodium selenite
# 27  Aging_Atlas_gerprotector  Mus musculus                         Spermine
# 28  Aging_Atlas_gerprotector  Mus musculus                          SRT1720
# 29  Aging_Atlas_gerprotector  Mus musculus  Suberoylanilide hydroxamic acid
# 30  Aging_Atlas_gerprotector  Mus musculus               Tetrahydrocurcumin
# 31  Aging_Atlas_gerprotector  Mus musculus                        Vitamin C
# 32  Aging_Atlas_gerprotector  Mus musculus                        Vitamin E
#
#          pmid         rnaseq  data_type tail_detail_name kg_type head_id_is  \
# 0     6334792  Not Available  Causative            aging   Aging    Pubchem
# 1    28871086  Not Available  Causative            aging   Aging    Pubchem
# 2    27312236  Not Available  Causative            aging   Aging    Pubchem
# 3    24245565  Not Available  Causative            aging   Aging    Pubchem
# 4   \t4788962  Not Available  Causative            aging   Aging    Pubchem
# 5     4788962  Not Available  Causative            aging   Aging    Pubchem
# 6    17416441  Not Available  Causative            aging   Aging    Pubchem
# 7    24714520  Not Available  Causative            aging   Aging    Pubchem
# 8     9701766  Not Available  Causative            aging   Aging    Pubchem
# 9    15653505  Not Available  Causative            aging   Aging    Pubchem
# 10   24714520  Not Available  Causative            aging   Aging    Pubchem
# 11   25589054  Not Available  Causative            aging   Aging    Pubchem
# 12   27617860  Not Available  Causative            aging   Aging    Pubchem
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'ChemicalEntity_Inhibits_BiologicalProcess'}
# head_type           : {'ChemicalEntity'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'AgeXtend', 'AgingAtlas'}
# head_id_is          : {'Pubchem'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 40 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            40                   0              40
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 40  |  After dedup: 39
#    head                                   relation        tail  \
# 0   586  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 1   896  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 2  1103  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
#
#         head_type relation_type          tail_type   kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 1  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 2  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
#
#   head_id_is tail_id_is                               head_detail_name  \
# 0    Pubchem   Quick_GO      2-[carbamimidoyl(methyl)amino]acetic acid
# 1    Pubchem   Quick_GO  N-[2-(5-methoxy-1H-indol-3-yl)ethyl]acetamide
# 2    Pubchem   Quick_GO      N,N'-bis(3-aminopropyl)butane-1,4-diamine
#
#   tail_detail_name       species
# 0            aging  Mus musculus
# 1            aging  Mus musculus
# 2            aging  Mus musculus

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            39                   0              39
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'AgeXtend', 'AgingAtlas'} kg_source
# AgingAtlas    32
# AgeXtend       7
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    39
# Name: count, dtype: int64

# %%
# ! mkdir Mouse_chemical_inhibits_biologicalprocess

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 39 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Mouse/Mouse_chemical_inhibits_biologicalprocess/Mouse_chemical_inhibits_biologicalprocess.csv

# %%
# OUT_PATH
