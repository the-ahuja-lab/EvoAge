# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_phenotype_cellularcomponent/Zebrafish_phenotype_cellularcomponent.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Zebrafish = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Danio_rerio.gene_info',
#     sep='\t',
    
# )
# # Zebrafish["LocusTag"] = Zebrafish["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Zebrafish_symbol2Locus_dict = dict(zip(Zebrafish['Symbol'], Zebrafish['LocusTag']))
# # Zebrafish
# # Zebrafish_symbol2Locus_dict
# Zebrafish

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Zebrafish/Zebra_Phenotype_CellularComponent.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
# monarch = monarch.rename(columns={'headtype': 'head_type', 'tailtype': 'tail_type'})

monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['species'] = 'D.rerio'
print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 5,378 rows
#             head                     relation        tail  head_type  \
# 0     ZP:0019682  Phenotype_CellularComponent  GO:0030424  Phenotype
# 1     ZP:0019700  Phenotype_CellularComponent  GO:0044297  Phenotype
# 2     ZP:0019701  Phenotype_CellularComponent  GO:0060091  Phenotype
# 3     ZP:0019702  Phenotype_CellularComponent  GO:0005929  Phenotype
# 4     ZP:0019703  Phenotype_CellularComponent  GO:0060091  Phenotype
# ...          ...                          ...         ...        ...
# 5373  ZP:0019604  Phenotype_CellularComponent  GO:0045495  Phenotype
# 5374  ZP:0019605  Phenotype_CellularComponent  GO:0031514  Phenotype
# 5375  ZP:0019607  Phenotype_CellularComponent  GO:0005892  Phenotype
# 5376  ZP:0019608  Phenotype_CellularComponent  GO:0005892  Phenotype
# 5377  ZP:0019611  Phenotype_CellularComponent  GO:0045178  Phenotype
#
#      relation_type          tail_type relation_source  \
# 0       related_to  CellularComponent  infores:upheno
# 1       related_to  CellularComponent  infores:upheno
# 2       related_to  CellularComponent  infores:upheno
# 3       related_to  CellularComponent  infores:upheno
# 4       related_to  CellularComponent  infores:upheno
# ...            ...                ...             ...
# 5373    related_to  CellularComponent  infores:upheno
# 5374    related_to  CellularComponent  infores:upheno
# 5375    related_to  CellularComponent  infores:upheno
# 5376    related_to  CellularComponent  infores:upheno
# 5377    related_to  CellularComponent  infores:upheno
#
#                                        head_detail_name  \
# 0     axon commissure of the tract of the commissure...
# 1     cell body photoreceptor cell mislocalised, abn...
# 2           kinocilium hair cell disorganized, abnormal
# 3                cilium olfactory pit swollen, abnormal
# 4       kinocilium hair cell decreased length, abnormal
# ...                                                 ...
# 5373  pole plasm oocyte stage I increased distributi...
# 5374  motile cilium Kupffer's vesicle increased leng...
# 5375  acetylcholine-gated channel complex myotome di...
# 5376  acetylcholine-gated channel complex myotome mi...
# 5377  basal part of cell otic epithelium decreased a...
#
#                          tail_detail_name head_taxon_name  tail_taxon_name  \
# 0                                    axon     Danio rerio              NaN
# 1                               cell body     Danio rerio              NaN
# 2                              kinocilium     Danio rerio              NaN
# 3                                  cilium     Danio rerio              NaN
# 4                              kinocilium     Danio rerio              NaN
# ...                                   ...             ...              ...
# 5373                           pole plasm     Danio rerio              NaN
# 5374                        motile cilium     Danio rerio              NaN
# 5375  acetylcholine-gated channel complex     Danio rerio              NaN
# 5376  acetylcholine-gated channel complex     Danio rerio              NaN
# 5377                   basal part of cell     Danio rerio              NaN
#
#      head_id_is tail_id_is  species      kg_type   kg_source
# 0       ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 1       ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 2       ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 3       ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 4       ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# ...         ...        ...      ...          ...         ...
# 5373    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 5374    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 5375    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 5376    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 5377    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
#
# [5378 rows x 16 columns]

# %%
monarch[monarch['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, relation, tail, head_type, relation_type, tail_type, relation_source, head_detail_name, tail_detail_name, head_taxon_name, tail_taxon_name, head_id_is, tail_id_is, species, kg_type, kg_source]
# Index: []

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 5,378
#             head                     relation        tail  head_type  \
# 0     ZP:0019682  Phenotype_CellularComponent  GO:0030424  Phenotype
# 1     ZP:0019700  Phenotype_CellularComponent  GO:0044297  Phenotype
# 2     ZP:0019701  Phenotype_CellularComponent  GO:0060091  Phenotype
# 3     ZP:0019702  Phenotype_CellularComponent  GO:0005929  Phenotype
# 4     ZP:0019703  Phenotype_CellularComponent  GO:0060091  Phenotype
# ...          ...                          ...         ...        ...
# 5373  ZP:0019604  Phenotype_CellularComponent  GO:0045495  Phenotype
# 5374  ZP:0019605  Phenotype_CellularComponent  GO:0031514  Phenotype
# 5375  ZP:0019607  Phenotype_CellularComponent  GO:0005892  Phenotype
# 5376  ZP:0019608  Phenotype_CellularComponent  GO:0005892  Phenotype
# 5377  ZP:0019611  Phenotype_CellularComponent  GO:0045178  Phenotype
#
#      relation_type          tail_type   kg_source      kg_type head_id_is  \
# 0       related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 1       related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 2       related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 3       related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 4       related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# ...            ...                ...         ...          ...        ...
# 5373    related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 5374    related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 5375    related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 5376    related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 5377    related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
#
#      tail_id_is                                   head_detail_name  \
# 0      Quick_GO  axon commissure of the tract of the commissure...
# 1      Quick_GO  cell body photoreceptor cell mislocalised, abn...
# 2      Quick_GO        kinocilium hair cell disorganized, abnormal
# 3      Quick_GO             cilium olfactory pit swollen, abnormal
# 4      Quick_GO    kinocilium hair cell decreased length, abnormal
# ...         ...                                                ...
# 5373   Quick_GO  pole plasm oocyte stage I increased distributi...
# 5374   Quick_GO  motile cilium Kupffer's vesicle increased leng...
# 5375   Quick_GO  acetylcholine-gated channel complex myotome di...
# 5376   Quick_GO  acetylcholine-gated channel complex myotome mi...
# 5377   Quick_GO  basal part of cell otic epithelium decreased a...
#
#                          tail_detail_name  species
# 0                                    axon  D.rerio
# 1                               cell body  D.rerio
# 2                              kinocilium  D.rerio
# 3                                  cilium  D.rerio
# 4                              kinocilium  D.rerio
# ...                                   ...      ...
# 5373                           pole plasm  D.rerio
# 5374                        motile cilium  D.rerio
# 5375  acetylcholine-gated channel complex  D.rerio
# 5376  acetylcholine-gated channel complex  D.rerio
# 5377                   basal part of cell  D.rerio
#
# [5378 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Phenotype_CellularComponent'}
# head_type           : {'Phenotype'}
# tail_type           : {'CellularComponent'}
# relation_type       : {'related_to'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'ZFIN_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 5,378 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 5,378  |  After dedup: 5,378
#          head                     relation        tail  head_type  \
# 0  ZP:0000089  Phenotype_CellularComponent  GO:0030424  Phenotype
# 1  ZP:0000090  Phenotype_CellularComponent  GO:0030424  Phenotype
# 2  ZP:0000216  Phenotype_CellularComponent  GO:0030424  Phenotype
#
#   relation_type          tail_type   kg_source      kg_type head_id_is  \
# 0    related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 1    related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
# 2    related_to  CellularComponent  Monarch_KG  Generalised    ZFIN_ID
#
#   tail_id_is                                   head_detail_name  \
# 0   Quick_GO  axon olfactory receptor cell decreased length,...
# 1   Quick_GO  axon olfactory receptor cell disorganized, abn...
# 2   Quick_GO        axon Mauthner neuron mislocalised, abnormal
#
#   tail_detail_name  species
# 0             axon  D.rerio
# 1             axon  D.rerio
# 2             axon  D.rerio

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    5378
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    5378
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 5,378 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_phenotype_cellularcomponent/Zebrafish_phenotype_cellularcomponent.csv

# %%
# OUT_PATH
