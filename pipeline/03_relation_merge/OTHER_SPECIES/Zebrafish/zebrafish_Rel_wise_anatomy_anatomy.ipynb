# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_anatomy_anatomy/Zebrafish_anatomy_anatomy.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Zebrafish = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Danio_rerio.gene_info',
#     sep='\t',
    
# )
# # Zebrafish["LocusTag"] = Zebrafish["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Zebrafish_symbol2Locus_dict = dict(zip(Zebrafish['Symbol'], Zebrafish['LocusTag']))
# # Zebrafish
# # Zebrafish_symbol2Locus_dict
# Zebrafish

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Zebrafish/Zebra_AnatomicalEntity_AnatomicalEntity.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
# monarch = monarch.rename(columns={'headtype': 'head_type', 'tailtype': 'tail_type'})

monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['species'] = 'D.rerio'
monarch['relation'] = 'AnatomicalEntity_AnatomicalEntity'
monarch['head_type'] = 'AnatomicalEntity'
monarch['tail_type'] = 'AnatomicalEntity'
print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 5,951 rows
#              head                           relation         tail  \
# 0     ZFA:0000000  AnatomicalEntity_AnatomicalEntity  ZFA:0001105
# 1     ZFA:0000001  AnatomicalEntity_AnatomicalEntity  ZFA:0001105
# 2     ZFA:0000001  AnatomicalEntity_AnatomicalEntity  ZFA:0000077
# 3     ZFA:0000001  AnatomicalEntity_AnatomicalEntity  ZFA:0000023
# 4     ZFA:0000003  AnatomicalEntity_AnatomicalEntity  ZFA:0009000
# ...           ...                                ...          ...
# 5946  ZFA:0009401  AnatomicalEntity_AnatomicalEntity  ZFA:0000035
# 5947  ZFA:0009402  AnatomicalEntity_AnatomicalEntity  ZFA:0009000
# 5948  ZFA:0009402  AnatomicalEntity_AnatomicalEntity  ZFA:0005065
# 5949  ZFA:0009403  AnatomicalEntity_AnatomicalEntity  ZFA:0009402
# 5950  ZFA:0009404  AnatomicalEntity_AnatomicalEntity  ZFA:0009402
#
#              head_type relation_type         tail_type relation_source  \
# 0     AnatomicalEntity   subclass_of  AnatomicalEntity     infores:zfa
# 1     AnatomicalEntity   subclass_of  AnatomicalEntity     infores:zfa
# 2     AnatomicalEntity    related_to  AnatomicalEntity     infores:zfa
# 3     AnatomicalEntity    related_to  AnatomicalEntity     infores:zfa
# 4     AnatomicalEntity   subclass_of  AnatomicalEntity     infores:zfa
# ...                ...           ...               ...             ...
# 5946  AnatomicalEntity    related_to  AnatomicalEntity     infores:zfa
# 5947  AnatomicalEntity   subclass_of  AnatomicalEntity     infores:zfa
# 5948  AnatomicalEntity    related_to  AnatomicalEntity     infores:zfa
# 5949  AnatomicalEntity   subclass_of  AnatomicalEntity     infores:zfa
# 5950  AnatomicalEntity   subclass_of  AnatomicalEntity     infores:zfa
#
#                    head_detail_name       tail_detail_name head_taxon_name  \
# 0                   Brachet's cleft    embryonic structure     Danio rerio
# 1                 Kupffer's vesicle    embryonic structure     Danio rerio
# 2                 Kupffer's vesicle               tail bud     Danio rerio
# 3                 Kupffer's vesicle  forerunner cell group     Danio rerio
# 4                      adaxial cell                   cell     Danio rerio
# ...                             ...                    ...             ...
# 5946                lens fiber cell                   lens     Danio rerio
# 5947               heart valve cell                   cell     Danio rerio
# 5948               heart valve cell            heart valve     Danio rerio
# 5949  heart valve interstitial cell       heart valve cell     Danio rerio
# 5950   heart valve endothelial cell       heart valve cell     Danio rerio
#
#      tail_taxon_name head_id_is tail_id_is  species      kg_type   kg_source
# 0        Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# 1        Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# 2        Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# 3        Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# 4        Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# ...              ...        ...        ...      ...          ...         ...
# 5946     Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# 5947     Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# 5948     Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# 5949     Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
# 5950     Danio rerio    ZFIN_ID    ZFIN_ID  D.rerio  Generalised  Monarch_KG
#
# [5951 rows x 16 columns]

# %%
monarch[monarch['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, relation, tail, head_type, relation_type, tail_type, relation_source, head_detail_name, tail_detail_name, head_taxon_name, tail_taxon_name, head_id_is, tail_id_is, species, kg_type, kg_source]
# Index: []

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 5,951
#              head                           relation         tail  \
# 0     ZFA:0000000  AnatomicalEntity_AnatomicalEntity  ZFA:0001105
# 1     ZFA:0000001  AnatomicalEntity_AnatomicalEntity  ZFA:0001105
# 2     ZFA:0000001  AnatomicalEntity_AnatomicalEntity  ZFA:0000077
# 3     ZFA:0000001  AnatomicalEntity_AnatomicalEntity  ZFA:0000023
# 4     ZFA:0000003  AnatomicalEntity_AnatomicalEntity  ZFA:0009000
# ...           ...                                ...          ...
# 5946  ZFA:0009401  AnatomicalEntity_AnatomicalEntity  ZFA:0000035
# 5947  ZFA:0009402  AnatomicalEntity_AnatomicalEntity  ZFA:0009000
# 5948  ZFA:0009402  AnatomicalEntity_AnatomicalEntity  ZFA:0005065
# 5949  ZFA:0009403  AnatomicalEntity_AnatomicalEntity  ZFA:0009402
# 5950  ZFA:0009404  AnatomicalEntity_AnatomicalEntity  ZFA:0009402
#
#              head_type relation_type         tail_type   kg_source  \
# 0     AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 1     AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 2     AnatomicalEntity    related_to  AnatomicalEntity  Monarch_KG
# 3     AnatomicalEntity    related_to  AnatomicalEntity  Monarch_KG
# 4     AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# ...                ...           ...               ...         ...
# 5946  AnatomicalEntity    related_to  AnatomicalEntity  Monarch_KG
# 5947  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 5948  AnatomicalEntity    related_to  AnatomicalEntity  Monarch_KG
# 5949  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
# 5950  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG
#
#           kg_type head_id_is tail_id_is               head_detail_name  \
# 0     Generalised    ZFIN_ID    ZFIN_ID                Brachet's cleft
# 1     Generalised    ZFIN_ID    ZFIN_ID              Kupffer's vesicle
# 2     Generalised    ZFIN_ID    ZFIN_ID              Kupffer's vesicle
# 3     Generalised    ZFIN_ID    ZFIN_ID              Kupffer's vesicle
# 4     Generalised    ZFIN_ID    ZFIN_ID                   adaxial cell
# ...           ...        ...        ...                            ...
# 5946  Generalised    ZFIN_ID    ZFIN_ID                lens fiber cell
# 5947  Generalised    ZFIN_ID    ZFIN_ID               heart valve cell
# 5948  Generalised    ZFIN_ID    ZFIN_ID               heart valve cell
# 5949  Generalised    ZFIN_ID    ZFIN_ID  heart valve interstitial cell
# 5950  Generalised    ZFIN_ID    ZFIN_ID   heart valve endothelial cell
#
#            tail_detail_name  species
# 0       embryonic structure  D.rerio
# 1       embryonic structure  D.rerio
# 2                  tail bud  D.rerio
# 3     forerunner cell group  D.rerio
# 4                      cell  D.rerio
# ...                     ...      ...
# 5946                   lens  D.rerio
# 5947                   cell  D.rerio
# 5948            heart valve  D.rerio
# 5949       heart valve cell  D.rerio
# 5950       heart valve cell  D.rerio
#
# [5951 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'AnatomicalEntity_AnatomicalEntity'}
# head_type           : {'AnatomicalEntity'}
# tail_type           : {'AnatomicalEntity'}
# relation_type       : {'related_to', 'subclass_of'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'ZFIN_ID'}
# tail_id_is          : {'ZFIN_ID'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 5,951 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 5,951  |  After dedup: 5,950
#           head                           relation         tail  \
# 0  ZFA:0000000  AnatomicalEntity_AnatomicalEntity  ZFA:0001105
# 1  ZFA:0000001  AnatomicalEntity_AnatomicalEntity  ZFA:0000023
# 2  ZFA:0000001  AnatomicalEntity_AnatomicalEntity  ZFA:0000077
#
#           head_type relation_type         tail_type   kg_source      kg_type  \
# 0  AnatomicalEntity   subclass_of  AnatomicalEntity  Monarch_KG  Generalised
# 1  AnatomicalEntity    related_to  AnatomicalEntity  Monarch_KG  Generalised
# 2  AnatomicalEntity    related_to  AnatomicalEntity  Monarch_KG  Generalised
#
#   head_id_is tail_id_is   head_detail_name       tail_detail_name  species
# 0    ZFIN_ID    ZFIN_ID    Brachet's cleft    embryonic structure  D.rerio
# 1    ZFIN_ID    ZFIN_ID  Kupffer's vesicle  forerunner cell group  D.rerio
# 2    ZFIN_ID    ZFIN_ID  Kupffer's vesicle               tail bud  D.rerio

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    5950
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    5950
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 5,950 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_anatomy_anatomy/Zebrafish_anatomy_anatomy.csv

# %%
# OUT_PATH
