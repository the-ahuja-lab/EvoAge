# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_phenotype_molecularfunction/Zebrafish_phenotype_molecularfunction.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Zebrafish = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Danio_rerio.gene_info',
#     sep='\t',
    
# )
# # Zebrafish["LocusTag"] = Zebrafish["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Zebrafish_symbol2Locus_dict = dict(zip(Zebrafish['Symbol'], Zebrafish['LocusTag']))
# # Zebrafish
# # Zebrafish_symbol2Locus_dict
# Zebrafish

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Zebrafish/Zebra_PhenotypicFeature_MolecularFunction.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
# monarch = monarch.rename(columns={'headtype': 'head_type', 'tailtype': 'tail_type'})

monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['species'] = 'D.rerio'
print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 455 rows
#            head                     relation        tail  head_type  \
# 0    ZP:0019874  Phenotype_MolecularFunction  GO:0004708  Phenotype
# 1    ZP:0019951  Phenotype_MolecularFunction  GO:0072320  Phenotype
# 2    ZP:0020011  Phenotype_MolecularFunction  GO:0097153  Phenotype
# 3    ZP:0020439  Phenotype_MolecularFunction  GO:0008475  Phenotype
# 4    ZP:0021430  Phenotype_MolecularFunction  GO:0008086  Phenotype
# ..          ...                          ...         ...        ...
# 450  ZP:0019079  Phenotype_MolecularFunction  GO:0004800  Phenotype
# 451  ZP:0019080  Phenotype_MolecularFunction  GO:0004800  Phenotype
# 452  ZP:0019486  Phenotype_MolecularFunction  GO:0004348  Phenotype
# 453  ZP:0019568  Phenotype_MolecularFunction  GO:0016772  Phenotype
# 454  ZP:0019572  Phenotype_MolecularFunction  GO:0015926  Phenotype
#
#     relation_type          tail_type relation_source  \
# 0      related_to  MolecularFunction  infores:upheno
# 1      related_to  MolecularFunction  infores:upheno
# 2      related_to  MolecularFunction  infores:upheno
# 3      related_to  MolecularFunction  infores:upheno
# 4      related_to  MolecularFunction  infores:upheno
# ..            ...                ...             ...
# 450    related_to  MolecularFunction  infores:upheno
# 451    related_to  MolecularFunction  infores:upheno
# 452    related_to  MolecularFunction  infores:upheno
# 453    related_to  MolecularFunction  infores:upheno
# 454    related_to  MolecularFunction  infores:upheno
#
#                                       head_detail_name  \
# 0    MAP kinase kinase activity process quality, ab...
# 1    volume-sensitive chloride channel activity dec...
# 2    cysteine-type endopeptidase activity involved ...
# 3    procollagen-lysine 5-dioxygenase activity disr...
# 4    light-activated voltage-gated calcium channel ...
# ..                                                 ...
# 450  thyroxine 5'-deiodinase activity disrupted, ab...
# 451  thyroxine 5'-deiodinase activity decreased pro...
# 452  glucosylceramidase activity decreased process ...
# 453  transferase activity, transferring phosphorus-...
# 454  glucosidase activity decreased process quality...
#
#                                       tail_detail_name head_taxon_name  \
# 0                           MAP kinase kinase activity     Danio rerio
# 1           volume-sensitive chloride channel activity     Danio rerio
# 2    obsolete cysteine-type endopeptidase activity ...     Danio rerio
# 3            procollagen-lysine 5-dioxygenase activity     Danio rerio
# 4    light-activated voltage-gated calcium channel ...     Danio rerio
# ..                                                 ...             ...
# 450                   thyroxine 5'-deiodinase activity     Danio rerio
# 451                   thyroxine 5'-deiodinase activity     Danio rerio
# 452                        glucosylceramidase activity     Danio rerio
# 453  transferase activity, transferring phosphorus-...     Danio rerio
# 454                               glucosidase activity     Danio rerio
#
#      tail_taxon_name head_id_is tail_id_is  species      kg_type   kg_source
# 0                NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 1                NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 2                NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 3                NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 4                NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# ..               ...        ...        ...      ...          ...         ...
# 450              NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 451              NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 452              NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 453              NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
# 454              NaN    ZFIN_ID   Quick_GO  D.rerio  Generalised  Monarch_KG
#
# [455 rows x 16 columns]

# %%
monarch[monarch['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, relation, tail, head_type, relation_type, tail_type, relation_source, head_detail_name, tail_detail_name, head_taxon_name, tail_taxon_name, head_id_is, tail_id_is, species, kg_type, kg_source]
# Index: []

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 455
#            head                     relation        tail  head_type  \
# 0    ZP:0019874  Phenotype_MolecularFunction  GO:0004708  Phenotype
# 1    ZP:0019951  Phenotype_MolecularFunction  GO:0072320  Phenotype
# 2    ZP:0020011  Phenotype_MolecularFunction  GO:0097153  Phenotype
# 3    ZP:0020439  Phenotype_MolecularFunction  GO:0008475  Phenotype
# 4    ZP:0021430  Phenotype_MolecularFunction  GO:0008086  Phenotype
# ..          ...                          ...         ...        ...
# 450  ZP:0019079  Phenotype_MolecularFunction  GO:0004800  Phenotype
# 451  ZP:0019080  Phenotype_MolecularFunction  GO:0004800  Phenotype
# 452  ZP:0019486  Phenotype_MolecularFunction  GO:0004348  Phenotype
# 453  ZP:0019568  Phenotype_MolecularFunction  GO:0016772  Phenotype
# 454  ZP:0019572  Phenotype_MolecularFunction  GO:0015926  Phenotype
#
#     relation_type          tail_type   kg_source      kg_type head_id_is  \
# 0      related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 1      related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 2      related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 3      related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 4      related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# ..            ...                ...         ...          ...        ...
# 450    related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 451    related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 452    related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 453    related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 454    related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
#
#     tail_id_is                                   head_detail_name  \
# 0     Quick_GO  MAP kinase kinase activity process quality, ab...
# 1     Quick_GO  volume-sensitive chloride channel activity dec...
# 2     Quick_GO  cysteine-type endopeptidase activity involved ...
# 3     Quick_GO  procollagen-lysine 5-dioxygenase activity disr...
# 4     Quick_GO  light-activated voltage-gated calcium channel ...
# ..         ...                                                ...
# 450   Quick_GO  thyroxine 5'-deiodinase activity disrupted, ab...
# 451   Quick_GO  thyroxine 5'-deiodinase activity decreased pro...
# 452   Quick_GO  glucosylceramidase activity decreased process ...
# 453   Quick_GO  transferase activity, transferring phosphorus-...
# 454   Quick_GO  glucosidase activity decreased process quality...
#
#                                       tail_detail_name  species
# 0                           MAP kinase kinase activity  D.rerio
# 1           volume-sensitive chloride channel activity  D.rerio
# 2    obsolete cysteine-type endopeptidase activity ...  D.rerio
# 3            procollagen-lysine 5-dioxygenase activity  D.rerio
# 4    light-activated voltage-gated calcium channel ...  D.rerio
# ..                                                 ...      ...
# 450                   thyroxine 5'-deiodinase activity  D.rerio
# 451                   thyroxine 5'-deiodinase activity  D.rerio
# 452                        glucosylceramidase activity  D.rerio
# 453  transferase activity, transferring phosphorus-...  D.rerio
# 454                               glucosidase activity  D.rerio
#
# [455 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Phenotype_MolecularFunction'}
# head_type           : {'Phenotype'}
# tail_type           : {'MolecularFunction'}
# relation_type       : {'related_to'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'ZFIN_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 455 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 455  |  After dedup: 455
#          head                     relation        tail  head_type  \
# 0  ZP:0000092  Phenotype_MolecularFunction  GO:0004853  Phenotype
# 1  ZP:0000690  Phenotype_MolecularFunction  GO:0005179  Phenotype
# 2  ZP:0000830  Phenotype_MolecularFunction  GO:0005248  Phenotype
#
#   relation_type          tail_type   kg_source      kg_type head_id_is  \
# 0    related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 1    related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
# 2    related_to  MolecularFunction  Monarch_KG  Generalised    ZFIN_ID
#
#   tail_id_is                                   head_detail_name  \
# 0   Quick_GO  uroporphyrinogen decarboxylase activity decrea...
# 1   Quick_GO    hormone activity decreased occurrence, abnormal
# 2   Quick_GO  voltage-gated sodium channel activity amplitud...
#
#                           tail_detail_name
# 0  uroporphyrinogen decarboxylase activity
# 1                         hormone activity
# 2    voltage-gated sodium channel activity

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    455
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    455
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 455 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_phenotype_molecularfunction/Zebrafish_phenotype_molecularfunction.csv

# %%
# OUT_PATH
