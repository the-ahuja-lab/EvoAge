# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_chemical_protein/Zebrafish_chemical_protein.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Zebrafish = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Danio_rerio.gene_info',
#     sep='\t',
    
# )
# # Zebrafish["LocusTag"] = Zebrafish["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Zebrafish_symbol2Locus_dict = dict(zip(Zebrafish['Symbol'], Zebrafish['LocusTag']))
# # Zebrafish
# # Zebrafish_symbol2Locus_dict
# Zebrafish

# %% [markdown]
# # bindingdb

# %%
bindingdb = pd.read_csv(PROC_DIR + 'bindingdb/Chemical_Protein_Zebra_BindingDB.csv')

bindingdb.columns = bindingdb.columns.str.lower()
bindingdb = bindingdb[~bindingdb['head_detail_name'].isna()]
bindingdb['kg_type'] = 'Generalised'
bindingdb['kg_source'] = 'Binding_DB'
bindingdb['species'] = 'D.rerio'
print(f"bindingdb: {len(bindingdb):,} rows")
bindingdb
# Out:
# bindingdb: 32 rows
#         head                relation    tail       head_type tail_type  \
# 0   71575543  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 1   71575213  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 2   71575641  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 3   71575640  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 4   71575546  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 5   71575545  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 6   71575544  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 7   71575542  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 8   71575541  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 9   71716376  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 10  71720643  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 11  71718823  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 12  71720012  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 13  71575438  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 14  71575437  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 15  71575436  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 16  71575327  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 17  71575326  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 18  71575325  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 19  71575324  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 20  71575323  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 21  71575322  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 22  71575215  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 23  71575214  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 24  71575212  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 25  71575211  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 26  71575210  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 27  71575116  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 28  71575115  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 29  71575114  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 30  71575113  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
# 31  71575112  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity   Protein
#
#      kg_source  species                                   head_detail_name  \
# 0   Binding_DB  D.rerio  1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 1   Binding_DB  D.rerio  1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 2   Binding_DB  D.rerio  1-[2-chloro-4-(trifluoromethyl)phenyl]-3-[4-(1...
# 3   Binding_DB  D.rerio  1-[3,5-bis(trifluoromethyl)phenyl]-3-[4-(1H-py...
# 4   Binding_DB  D.rerio  1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 5   Binding_DB  D.rerio  1-(3-fluorophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyr...
# 6   Binding_DB  D.rerio  1-(3-propan-2-ylphenyl)-3-[4-(1H-pyrazolo[3,4-...
# 7   Binding_DB  D.rerio  1-(4-morpholin-4-ylphenyl)-3-[4-(1H-pyrazolo[3...
# 8   Binding_DB  D.rerio  1-(4-fluorophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyr...
# 9   Binding_DB  D.rerio  1-(cyclohexylmethyl)-3-[4-(1H-pyrazolo[3,4-d]p...
# 10  Binding_DB  D.rerio  1-cyclohexyl-3-[4-(1H-pyrazolo[3,4-d]pyrimidin...
# 11  Binding_DB  D.rerio  1-(1-phenylethyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 12  Binding_DB  D.rerio  1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 13  Binding_DB  D.rerio  1-phenyl-3-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-y...
# 14  Binding_DB  D.rerio  2-(4-bromophenyl)-N-[4-(1H-pyrazolo[3,4-d]pyri...
# 15  Binding_DB  D.rerio  4-bromo-N-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yl...
# 16  Binding_DB  D.rerio  4-bromo-N-[3-(1H-pyrazolo[3,4-d]pyrimidin-4-yl...
# 17  Binding_DB  D.rerio  N-[3-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 18  Binding_DB  D.rerio  2-(4-bromophenyl)-N-[3-(1H-pyrazolo[3,4-d]pyri...
# 19  Binding_DB  D.rerio  N-[3-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 20  Binding_DB  D.rerio  1-(4-bromophenyl)-3-[3-(1H-pyrazolo[3,4-d]pyri...
# 21  Binding_DB  D.rerio  1-[3-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 22  Binding_DB  D.rerio  1-[4-(1-methylpyrazolo[3,4-d]pyrimidin-4-yl)ox...
# 23  Binding_DB  D.rerio  1-(3-methoxyphenyl)-3-[4-(1-methylpyrazolo[3,4...
# 24  Binding_DB  D.rerio  1-(2,3-dimethylphenyl)-3-[4-(1H-pyrazolo[3,4-d...
# 25  Binding_DB  D.rerio  1-(4-bromophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 26  Binding_DB  D.rerio  1-(3-methoxyphenyl)-3-[4-(1H-pyrazolo[3,4-d]py...
# 27  Binding_DB  D.rerio  1-(1-phenylethyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 28  Binding_DB  D.rerio  1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-ylamino)ph...
# 29  Binding_DB  D.rerio  1-(2,3-dimethylphenyl)-3-[4-(1H-pyrazolo[3,4-d...
# 30  Binding_DB  D.rerio  1-(4-bromophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 31  Binding_DB  D.rerio  1-(3-methoxyphenyl)-3-[4-(1H-pyrazolo[3,4-d]py...
#
#                                       head_smile_name  \
# 0   C1=CC(=CC(=C1)NC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=C...
# 1   C1=CC(=CC=C1C(F)(F)F)NC(=O)NC2=CC=C(C=C2)OC3=N...
# 2   C1=CC(=CC=C1NC(=O)NC2=C(C=C(C=C2)C(F)(F)F)Cl)O...
# 3   C1=CC(=CC=C1NC(=O)NC2=CC(=CC(=C2)C(F)(F)F)C(F)...
# 4   C1=CC(=CC(=C1)OC(F)(F)F)NC(=O)NC2=CC=C(C=C2)OC...
# 5   C1=CC(=CC(=C1)F)NC(=O)NC2=CC=C(C=C2)OC3=NC=NC4...
# 6   CC(C)C1=CC(=CC=C1)NC(=O)NC2=CC=C(C=C2)OC3=NC=N...
# 7   C1COCCN1C2=CC=C(C=C2)NC(=O)NC3=CC=C(C=C3)OC4=N...
# 8   C1=CC(=CC=C1NC(=O)NC2=CC=C(C=C2)F)OC3=NC=NC4=C...
# 9   C1CCC(CC1)CNC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=C3C=NN4
# 10   C1CCC(CC1)NC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=C3C=NN4
# 11  CC(C1=CC=CC=C1)NC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=...
# 12  C1=CC(=CN=C1)NC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=C3...
# 13  C1=CC=C(C=C1)NC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=C3...
# 14  C1=CC(=CC=C1CC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=C3C...
# 15  C1=CC(=CC=C1C(=O)NC2=CC=C(C=C2)OC3=NC=NC4=C3C=...
# 16  C1=CC(=CC(=C1)OC2=NC=NC3=C2C=NN3)NC(=O)C4=CC=C...
# 17  C1=CC(=CC(=C1)OC2=NC=NC3=C2C=NN3)NC(=O)C4=CC=C...
# 18  C1=CC(=CC(=C1)OC2=NC=NC3=C2C=NN3)NC(=O)CC4=CC=...
# 19  C1=CC(=CC(=C1)OC2=NC=NC3=C2C=NN3)NC(=O)CC4=CC=...
# 20  C1=CC(=CC(=C1)OC2=NC=NC3=C2C=NN3)NC(=O)NC4=CC=...
# 21  C1=CC(=CC(=C1)OC2=NC=NC3=C2C=NN3)NC(=O)NC4=CC=...
# 22  CN1C2=C(C=N1)C(=NC=N2)OC3=CC=C(C=C3)NC(=O)NC4=...
# 23  CN1C2=C(C=N1)C(=NC=N2)OC3=CC=C(C=C3)NC(=O)NC4=...
# 24  CC1=C(C(=CC=C1)NC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=...
# 25  C1=CC(=CC=C1NC(=O)NC2=CC=C(C=C2)Br)OC3=NC=NC4=...
# 26  COC1=CC=CC(=C1)NC(=O)NC2=CC=C(C=C2)OC3=NC=NC4=...
# 27  CC(C1=CC=CC=C1)NC(=O)NC2=CC=C(C=C2)NC3=NC=NC4=...
# 28  C1=CC(=CC=C1C(F)(F)F)NC(=O)NC2=CC=C(C=C2)NC3=N...
# 29  CC1=C(C(=CC=C1)NC(=O)NC2=CC=C(C=C2)NC3=NC=NC4=...
# 30  C1=CC(=CC=C1NC2=NC=NC3=C2C=NN3)NC(=O)NC4=CC=C(...
# 31  COC1=CC=CC(=C1)NC(=O)NC2=CC=C(C=C2)NC3=NC=NC4=...
#
#                                      tail_detail_name head_id_is  tail_id_is  \
# 0   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 1   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 2   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 3   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 4   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 5   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 6   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 7   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 8   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 9   Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 10  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 11  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 12  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 13  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 14  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 15  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 16  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 17  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 18  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 19  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 20  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 21  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 22  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 23  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 24  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 25  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 26  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 27  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 28  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 29  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 30  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
# 31  Vascular endothelial growth factor receptor 2 ...    Pubchem  Uniprot_ID
#
#         kg_type
# 0   Generalised
# 1   Generalised
# 2   Generalised
# 3   Generalised
# 4   Generalised
# 5   Generalised
# 6   Generalised
# 7   Generalised
# 8   Generalised
# 9   Generalised
# 10  Generalised
# 11  Generalised
# 12  Generalised
# 13  Generalised
# 14  Generalised
# 15  Generalised
# 16  Generalised
# 17  Generalised
# 18  Generalised
# 19  Generalised
# 20  Generalised
# 21  Generalised
# 22  Generalised
# 23  Generalised
# 24  Generalised
# 25  Generalised
# 26  Generalised
# 27  Generalised
# 28  Generalised
# 29  Generalised
# 30  Generalised
# 31  Generalised

# %%
bindingdb[bindingdb['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, relation, tail, head_type, tail_type, kg_source, species, head_detail_name, head_smile_name, tail_detail_name, head_id_is, tail_id_is, kg_type]
# Index: []

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     bindingdb
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 32
#         head                relation    tail       head_type relation_type  \
# 0   71575543  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 1   71575213  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 2   71575641  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 3   71575640  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 4   71575546  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 5   71575545  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 6   71575544  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 7   71575542  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 8   71575541  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 9   71716376  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 10  71720643  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 11  71718823  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 12  71720012  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 13  71575438  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 14  71575437  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 15  71575436  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 16  71575327  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 17  71575326  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 18  71575325  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 19  71575324  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 20  71575323  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 21  71575322  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 22  71575215  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 23  71575214  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 24  71575212  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 25  71575211  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 26  71575210  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 27  71575116  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 28  71575115  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 29  71575114  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 30  71575113  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 31  71575112  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
#
#    tail_type   kg_source      kg_type head_id_is  tail_id_is  \
# 0    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 1    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 2    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 3    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 4    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 5    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 6    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 7    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 8    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 9    Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 10   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 11   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 12   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 13   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 14   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 15   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 16   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 17   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 18   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 19   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 20   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 21   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 22   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 23   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 24   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 25   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 26   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 27   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 28   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 29   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 30   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 31   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
#
#                                      head_detail_name  \
# 0   1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 1   1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 2   1-[2-chloro-4-(trifluoromethyl)phenyl]-3-[4-(1...
# 3   1-[3,5-bis(trifluoromethyl)phenyl]-3-[4-(1H-py...
# 4   1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 5   1-(3-fluorophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyr...
# 6   1-(3-propan-2-ylphenyl)-3-[4-(1H-pyrazolo[3,4-...
# 7   1-(4-morpholin-4-ylphenyl)-3-[4-(1H-pyrazolo[3...
# 8   1-(4-fluorophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyr...
# 9   1-(cyclohexylmethyl)-3-[4-(1H-pyrazolo[3,4-d]p...
# 10  1-cyclohexyl-3-[4-(1H-pyrazolo[3,4-d]pyrimidin...
# 11  1-(1-phenylethyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 12  1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 13  1-phenyl-3-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-y...
# 14  2-(4-bromophenyl)-N-[4-(1H-pyrazolo[3,4-d]pyri...
# 15  4-bromo-N-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-yl...
# 16  4-bromo-N-[3-(1H-pyrazolo[3,4-d]pyrimidin-4-yl...
# 17  N-[3-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 18  2-(4-bromophenyl)-N-[3-(1H-pyrazolo[3,4-d]pyri...
# 19  N-[3-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 20  1-(4-bromophenyl)-3-[3-(1H-pyrazolo[3,4-d]pyri...
# 21  1-[3-(1H-pyrazolo[3,4-d]pyrimidin-4-yloxy)phen...
# 22  1-[4-(1-methylpyrazolo[3,4-d]pyrimidin-4-yl)ox...
# 23  1-(3-methoxyphenyl)-3-[4-(1-methylpyrazolo[3,4...
# 24  1-(2,3-dimethylphenyl)-3-[4-(1H-pyrazolo[3,4-d...
# 25  1-(4-bromophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 26  1-(3-methoxyphenyl)-3-[4-(1H-pyrazolo[3,4-d]py...
# 27  1-(1-phenylethyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 28  1-[4-(1H-pyrazolo[3,4-d]pyrimidin-4-ylamino)ph...
# 29  1-(2,3-dimethylphenyl)-3-[4-(1H-pyrazolo[3,4-d...
# 30  1-(4-bromophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 31  1-(3-methoxyphenyl)-3-[4-(1H-pyrazolo[3,4-d]py...
#
#                                      tail_detail_name  species
# 0   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 1   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 2   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 3   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 4   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 5   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 6   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 7   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 8   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 9   Vascular endothelial growth factor receptor 2 ...  D.rerio
# 10  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 11  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 12  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 13  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 14  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 15  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 16  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 17  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 18  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 19  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 20  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 21  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 22  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 23  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 24  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 25  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 26  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 27  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 28  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 29  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 30  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 31  Vascular endothelial growth factor receptor 2 ...  D.rerio

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'ChemicalEntity_Protein'}
# head_type           : {'ChemicalEntity'}
# tail_type           : {'Protein'}
# relation_type       : {None}
# kg_source           : {'Binding_DB'}
# head_id_is          : {'Pubchem'}
# tail_id_is          : {'Uniprot_ID'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 32 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            32                   0              32
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 32  |  After dedup: 32
#        head                relation    tail       head_type relation_type  \
# 0  71575112  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 1  71575113  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
# 2  71575114  ChemicalEntity_Protein  Q5GIT4  ChemicalEntity          None
#
#   tail_type   kg_source      kg_type head_id_is  tail_id_is  \
# 0   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 1   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
# 2   Protein  Binding_DB  Generalised    Pubchem  Uniprot_ID
#
#                                     head_detail_name  \
# 0  1-(3-methoxyphenyl)-3-[4-(1H-pyrazolo[3,4-d]py...
# 1  1-(4-bromophenyl)-3-[4-(1H-pyrazolo[3,4-d]pyri...
# 2  1-(2,3-dimethylphenyl)-3-[4-(1H-pyrazolo[3,4-d...
#
#                                     tail_detail_name  species
# 0  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 1  Vascular endothelial growth factor receptor 2 ...  D.rerio
# 2  Vascular endothelial growth factor receptor 2 ...  D.rerio

# %%
final_df_dedup['species'] = 'D.rerio'

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            32                   0              32
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Binding_DB'} kg_source
# Binding_DB    32
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    32
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 32 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_chemical_protein/Zebrafish_chemical_protein.csv

# %%
# OUT_PATH
