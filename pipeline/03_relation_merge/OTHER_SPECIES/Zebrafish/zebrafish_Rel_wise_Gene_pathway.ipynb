# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_gene_pathway/Zebrafish_gene_pathway.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Zebrafish = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Danio_rerio.gene_info',
#     sep='\t',
    
# )
# # Zebrafish["LocusTag"] = Zebrafish["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Zebrafish_symbol2Locus_dict = dict(zip(Zebrafish['Symbol'], Zebrafish['LocusTag']))
# # Zebrafish
# # Zebrafish_symbol2Locus_dict
# Zebrafish

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Zebrafish/Zebra_Gene_Pathway.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'

monarch['species'] = 'D.rerio'
print(f"monarch: {len(monarch):,} rows")
monarch = monarch[~monarch['head'].str.contains(':')]
monarch
# Out:
# monarch: 10,394 rows
#          head      relation           tail head_type    relation_type  \
# 0      parvaa  Gene_Pathway   R-HSA-446343      Gene  participates_in
# 1      parvaa  Gene_Pathway   R-HSA-446388      Gene  participates_in
# 2      oxct1a  Gene_Pathway    R-HSA-77108      Gene  participates_in
# 3       ctdp1  Gene_Pathway  R-HSA-6796648      Gene  participates_in
# 4      sumo2b  Gene_Pathway   R-HSA-196791      Gene  participates_in
# ...       ...           ...            ...       ...              ...
# 10393  tyrp1b  Gene_Pathway  R-HSA-5662702      Gene  participates_in
# 10394   rab30  Gene_Pathway  R-HSA-8873719      Gene  participates_in
# 10395   ikbke  Gene_Pathway  R-HSA-9860927      Gene  participates_in
# 10396   rac3a  Gene_Pathway  R-HSA-4086400      Gene  participates_in
# 10397   rac3a  Gene_Pathway  R-HSA-9013423      Gene  participates_in
#
#       tail_type   relation_source  \
# 0       Pathway  infores:reactome
# 1       Pathway  infores:reactome
# 2       Pathway  infores:reactome
# 3       Pathway  infores:reactome
# 4       Pathway  infores:reactome
# ...         ...               ...
# 10393   Pathway  infores:reactome
# 10394   Pathway  infores:reactome
# 10395   Pathway  infores:reactome
# 10396   Pathway  infores:reactome
# 10397   Pathway  infores:reactome
#
#                                         head_detail_name  \
# 0                                        parvin, alpha a
# 1                                        parvin, alpha a
# 2                           3-oxoacid CoA transferase 1a
# 3      CTD (carboxy-terminal domain, RNA polymerase I...
# 4                       small ubiquitin like modifier 2b
# ...                                                  ...
# 10393                      tyrosinase-related protein 1b
# 10394                  RAB30, member RAS oncogene family
# 10395  inhibitor of nuclear factor kappa B kinase sub...
# 10396                         Rac family small GTPase 3a
# 10397                         Rac family small GTPase 3a
#
#                                         tail_detail_name head_taxon_name  \
# 0      Localization of the PINCH-ILK-PARVIN complex t...     Danio rerio
# 1      Regulation of cytoskeletal remodeling and cell...     Danio rerio
# 2                           Utilization of Ketone Bodies     Danio rerio
# 3       TP53 Regulates Transcription of DNA Repair Genes     Danio rerio
# 4                      Vitamin D (calciferol) metabolism     Danio rerio
# ...                                                  ...             ...
# 10393                               Melanin biosynthesis     Danio rerio
# 10394                            RAB geranylgeranylation     Danio rerio
# 10395  Turbulent (oscillatory, disturbed) flow shear ...     Danio rerio
# 10396                                     PCP/CE pathway     Danio rerio
# 10397                                  RAC3 GTPase cycle     Danio rerio
#
#       tail_taxon_name head_id_is tail_id_is head_name  species      kg_type  \
# 0        Homo sapiens       NCBI   Reactome    parvaa  D.rerio  Generalised
# 1        Homo sapiens       NCBI   Reactome    parvaa  D.rerio  Generalised
# 2        Homo sapiens       NCBI   Reactome    oxct1a  D.rerio  Generalised
# 3        Homo sapiens       NCBI   Reactome     ctdp1  D.rerio  Generalised
# 4        Homo sapiens       NCBI   Reactome    sumo2b  D.rerio  Generalised
# ...               ...        ...        ...       ...      ...          ...
# 10393    Homo sapiens       NCBI   Reactome    tyrp1b  D.rerio  Generalised
# 10394    Homo sapiens       NCBI   Reactome     rab30  D.rerio  Generalised
# 10395    Homo sapiens       NCBI   Reactome     ikbke  D.rerio  Generalised
# 10396    Homo sapiens       NCBI   Reactome     rac3a  D.rerio  Generalised
# 10397    Homo sapiens       NCBI   Reactome     rac3a  D.rerio  Generalised
#
#         kg_source
# 0      Monarch_KG
# 1      Monarch_KG
# 2      Monarch_KG
# 3      Monarch_KG
# 4      Monarch_KG
# ...           ...
# 10393  Monarch_KG
# 10394  Monarch_KG
# 10395  Monarch_KG
# 10396  Monarch_KG
# 10397  Monarch_KG
#
# [9877 rows x 17 columns]

# %%
monarch[monarch['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, relation, tail, head_type, relation_type, tail_type, relation_source, head_detail_name, tail_detail_name, head_taxon_name, tail_taxon_name, head_id_is, tail_id_is, head_name, species, kg_type, kg_source]
# Index: []

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 9,877
#         head      relation           tail head_type    relation_type  \
# 0     parvaa  Gene_Pathway   R-HSA-446343      Gene  participates_in
# 1     parvaa  Gene_Pathway   R-HSA-446388      Gene  participates_in
# 2     oxct1a  Gene_Pathway    R-HSA-77108      Gene  participates_in
# 3      ctdp1  Gene_Pathway  R-HSA-6796648      Gene  participates_in
# 4     sumo2b  Gene_Pathway   R-HSA-196791      Gene  participates_in
# ...      ...           ...            ...       ...              ...
# 9872  tyrp1b  Gene_Pathway  R-HSA-5662702      Gene  participates_in
# 9873   rab30  Gene_Pathway  R-HSA-8873719      Gene  participates_in
# 9874   ikbke  Gene_Pathway  R-HSA-9860927      Gene  participates_in
# 9875   rac3a  Gene_Pathway  R-HSA-4086400      Gene  participates_in
# 9876   rac3a  Gene_Pathway  R-HSA-9013423      Gene  participates_in
#
#      tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0      Pathway  Monarch_KG  Generalised       NCBI   Reactome
# 1      Pathway  Monarch_KG  Generalised       NCBI   Reactome
# 2      Pathway  Monarch_KG  Generalised       NCBI   Reactome
# 3      Pathway  Monarch_KG  Generalised       NCBI   Reactome
# 4      Pathway  Monarch_KG  Generalised       NCBI   Reactome
# ...        ...         ...          ...        ...        ...
# 9872   Pathway  Monarch_KG  Generalised       NCBI   Reactome
# 9873   Pathway  Monarch_KG  Generalised       NCBI   Reactome
# 9874   Pathway  Monarch_KG  Generalised       NCBI   Reactome
# 9875   Pathway  Monarch_KG  Generalised       NCBI   Reactome
# 9876   Pathway  Monarch_KG  Generalised       NCBI   Reactome
#
#                                        head_detail_name  \
# 0                                       parvin, alpha a
# 1                                       parvin, alpha a
# 2                          3-oxoacid CoA transferase 1a
# 3     CTD (carboxy-terminal domain, RNA polymerase I...
# 4                      small ubiquitin like modifier 2b
# ...                                                 ...
# 9872                      tyrosinase-related protein 1b
# 9873                  RAB30, member RAS oncogene family
# 9874  inhibitor of nuclear factor kappa B kinase sub...
# 9875                         Rac family small GTPase 3a
# 9876                         Rac family small GTPase 3a
#
#                                        tail_detail_name  species
# 0     Localization of the PINCH-ILK-PARVIN complex t...  D.rerio
# 1     Regulation of cytoskeletal remodeling and cell...  D.rerio
# 2                          Utilization of Ketone Bodies  D.rerio
# 3      TP53 Regulates Transcription of DNA Repair Genes  D.rerio
# 4                     Vitamin D (calciferol) metabolism  D.rerio
# ...                                                 ...      ...
# 9872                               Melanin biosynthesis  D.rerio
# 9873                            RAB geranylgeranylation  D.rerio
# 9874  Turbulent (oscillatory, disturbed) flow shear ...  D.rerio
# 9875                                     PCP/CE pathway  D.rerio
# 9876                                  RAC3 GTPase cycle  D.rerio
#
# [9877 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Pathway'}
# head_type           : {'Gene'}
# tail_type           : {'Pathway'}
# relation_type       : {'participates_in'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'NCBI'}
# tail_id_is          : {'Reactome'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 9,877 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 9,877  |  After dedup: 9,877
#    head      relation           tail head_type    relation_type tail_type  \
# 0  aaas  Gene_Pathway  R-HSA-8980692      Gene  participates_in   Pathway
# 1  aacs  Gene_Pathway    R-HSA-77111      Gene  participates_in   Pathway
# 2  aamp  Gene_Pathway   R-HSA-168638      Gene  participates_in   Pathway
#
#     kg_source      kg_type head_id_is tail_id_is  \
# 0  Monarch_KG  Generalised       NCBI   Reactome
# 1  Monarch_KG  Generalised       NCBI   Reactome
# 2  Monarch_KG  Generalised       NCBI   Reactome
#
#                                     head_detail_name  \
# 0  achalasia, adrenocortical insufficiency, alacr...
# 1                         acetoacetyl-CoA synthetase
# 2           angio-associated, migratory cell protein
#
#              tail_detail_name  species
# 0           RHOA GTPase cycle  D.rerio
# 1  Synthesis of Ketone Bodies  D.rerio
# 2    NOD1/2 Signaling Pathway  D.rerio

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    9877
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    9877
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 9,877 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_gene_pathway/Zebrafish_gene_pathway.csv

# %%
# OUT_PATH
