# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_gene_anatomy/Zebrafish_gene_anatomy.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Zebrafish/Gene_Zebra_Anatomy.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['species'] = 'D.rerio'
monarch['relation'] = 'Gene_AnatomicalEntity'
print(f"monarch: {len(monarch):,} rows")
monarch = monarch[~monarch['head'].str.contains(':')]
monarch
# Out:
# monarch: 521,207 rows
#            head               relation         tail head_type relation_type  \
# 0           myb  Gene_AnatomicalEntity  ZFA:0000033      Gene  expressed_in
# 1        ptpn12  Gene_AnatomicalEntity  ZFA:0000079      Gene  expressed_in
# 2         fgf24  Gene_AnatomicalEntity  ZFA:0001453      Gene  expressed_in
# 3         gata5  Gene_AnatomicalEntity  ZFA:0000038      Gene  expressed_in
# 4          exo1  Gene_AnatomicalEntity  ZFA:0000098      Gene  expressed_in
# ...         ...                    ...          ...       ...           ...
# 528404   ackr4a  Gene_AnatomicalEntity  ZFA:0001094      Gene  expressed_in
# 528406   kcnk5b  Gene_AnatomicalEntity  ZFA:0001093      Gene  expressed_in
# 528407   pik3r4  Gene_AnatomicalEntity  ZFA:0001094      Gene  expressed_in
# 528408   ywhaqb  Gene_AnatomicalEntity  ZFA:0001093      Gene  expressed_in
# 528409  pde4dip  Gene_AnatomicalEntity  ZFA:0001093      Gene  expressed_in
#
#                tail_type relation_source  \
# 0       AnatomicalEntity    infores:zfin
# 1       AnatomicalEntity    infores:zfin
# 2       AnatomicalEntity    infores:zfin
# 3       AnatomicalEntity    infores:zfin
# 4       AnatomicalEntity    infores:zfin
# ...                  ...             ...
# 528404  AnatomicalEntity    infores:zfin
# 528406  AnatomicalEntity    infores:zfin
# 528407  AnatomicalEntity    infores:zfin
# 528408  AnatomicalEntity    infores:zfin
# 528409  AnatomicalEntity    infores:zfin
#
#                                          head_detail_name  \
# 0       v-myb avian myeloblastosis viral oncogene homolog
# 1       protein tyrosine phosphatase non-receptor type 12
# 2                             fibroblast growth factor 24
# 3                                  GATA binding protein 5
# 4                                           exonuclease 1
# ...                                                   ...
# 528404                     atypical chemokine receptor 4a
# 528406          potassium channel, subfamily K, member 5b
# 528407    phosphoinositide-3-kinase, regulatory subunit 4
# 528408  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...
# 528409           phosphodiesterase 4D interacting protein
#
#                           tail_detail_name head_taxon_name  tail_taxon_name  \
# 0       intermediate cell mass of mesoderm     Danio rerio              NaN
# 1                            telencephalon     Danio rerio              NaN
# 2                       pectoral fin field     Danio rerio              NaN
# 3                                   margin     Danio rerio              NaN
# 4                     proliferative region     Danio rerio              NaN
# ...                                    ...             ...              ...
# 528404                      whole organism     Danio rerio              NaN
# 528406                         unspecified     Danio rerio              NaN
# 528407                      whole organism     Danio rerio              NaN
# 528408                         unspecified     Danio rerio              NaN
# 528409                         unspecified     Danio rerio              NaN
#
#        head_id_is tail_id_is head_name  species      kg_type   kg_source
# 0            NCBI    ZFIN_ID       myb  D.rerio  Generalised  Monarch_KG
# 1            NCBI    ZFIN_ID    ptpn12  D.rerio  Generalised  Monarch_KG
# 2            NCBI    ZFIN_ID     fgf24  D.rerio  Generalised  Monarch_KG
# 3            NCBI    ZFIN_ID     gata5  D.rerio  Generalised  Monarch_KG
# 4            NCBI    ZFIN_ID      exo1  D.rerio  Generalised  Monarch_KG
# ...           ...        ...       ...      ...          ...         ...
# 528404       NCBI    ZFIN_ID    ackr4a  D.rerio  Generalised  Monarch_KG
# 528406       NCBI    ZFIN_ID    kcnk5b  D.rerio  Generalised  Monarch_KG
# 528407       NCBI    ZFIN_ID    pik3r4  D.rerio  Generalised  Monarch_KG
# 528408       NCBI    ZFIN_ID    ywhaqb  D.rerio  Generalised  Monarch_KG
# 528409       NCBI    ZFIN_ID   pde4dip  D.rerio  Generalised  Monarch_KG
#
# [490952 rows x 17 columns]

# %%
monarch[monarch['head_detail_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [head, relation, tail, head_type, relation_type, tail_type, relation_source, head_detail_name, tail_detail_name, head_taxon_name, tail_taxon_name, head_id_is, tail_id_is, head_name, species, kg_type, kg_source]
# Index: []

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 490,952
#            head               relation         tail head_type relation_type  \
# 0           myb  Gene_AnatomicalEntity  ZFA:0000033      Gene  expressed_in
# 1        ptpn12  Gene_AnatomicalEntity  ZFA:0000079      Gene  expressed_in
# 2         fgf24  Gene_AnatomicalEntity  ZFA:0001453      Gene  expressed_in
# 3         gata5  Gene_AnatomicalEntity  ZFA:0000038      Gene  expressed_in
# 4          exo1  Gene_AnatomicalEntity  ZFA:0000098      Gene  expressed_in
# ...         ...                    ...          ...       ...           ...
# 490947   ackr4a  Gene_AnatomicalEntity  ZFA:0001094      Gene  expressed_in
# 490948   kcnk5b  Gene_AnatomicalEntity  ZFA:0001093      Gene  expressed_in
# 490949   pik3r4  Gene_AnatomicalEntity  ZFA:0001094      Gene  expressed_in
# 490950   ywhaqb  Gene_AnatomicalEntity  ZFA:0001093      Gene  expressed_in
# 490951  pde4dip  Gene_AnatomicalEntity  ZFA:0001093      Gene  expressed_in
#
#                tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 1       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 2       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 3       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 4       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# ...                  ...         ...          ...        ...        ...
# 490947  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 490948  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 490949  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 490950  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 490951  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
#
#                                          head_detail_name  \
# 0       v-myb avian myeloblastosis viral oncogene homolog
# 1       protein tyrosine phosphatase non-receptor type 12
# 2                             fibroblast growth factor 24
# 3                                  GATA binding protein 5
# 4                                           exonuclease 1
# ...                                                   ...
# 490947                     atypical chemokine receptor 4a
# 490948          potassium channel, subfamily K, member 5b
# 490949    phosphoinositide-3-kinase, regulatory subunit 4
# 490950  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...
# 490951           phosphodiesterase 4D interacting protein
#
#                           tail_detail_name  species
# 0       intermediate cell mass of mesoderm  D.rerio
# 1                            telencephalon  D.rerio
# 2                       pectoral fin field  D.rerio
# 3                                   margin  D.rerio
# 4                     proliferative region  D.rerio
# ...                                    ...      ...
# 490947                      whole organism  D.rerio
# 490948                         unspecified  D.rerio
# 490949                      whole organism  D.rerio
# 490950                         unspecified  D.rerio
# 490951                         unspecified  D.rerio
#
# [490952 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_AnatomicalEntity'}
# head_type           : {'Gene'}
# tail_type           : {'AnatomicalEntity'}
# relation_type       : {'expressed_in'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'NCBI'}
# tail_id_is          : {'ZFIN_ID'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 490,952 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 490,952  |  After dedup: 104,609
#    head               relation         tail head_type relation_type  \
# 0  ATP6  Gene_AnatomicalEntity  ZFA:0000123      Gene  expressed_in
# 1  ATP6  Gene_AnatomicalEntity  ZFA:0000303      Gene  expressed_in
# 2  ATP6  Gene_AnatomicalEntity  ZFA:0001094      Gene  expressed_in
#
#           tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 1  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 2  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
#
#             head_detail_name tail_detail_name  species
# 0  ATP synthase F0 subunit 6            liver  D.rerio
# 1  ATP synthase F0 subunit 6  female organism  D.rerio
# 2  ATP synthase F0 subunit 6   whole organism  D.rerio

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    104609
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    104609
# Name: count, dtype: int64

# %%
final_df_dedup
# Out:
#          head               relation         tail head_type relation_type  \
# 0        ATP6  Gene_AnatomicalEntity  ZFA:0000123      Gene  expressed_in
# 1        ATP6  Gene_AnatomicalEntity  ZFA:0000303      Gene  expressed_in
# 2        ATP6  Gene_AnatomicalEntity  ZFA:0001094      Gene  expressed_in
# 3        ATP6  Gene_AnatomicalEntity  ZFA:0005145      Gene  expressed_in
# 4        ATP8  Gene_AnatomicalEntity  ZFA:0000003      Gene  expressed_in
# ...       ...                    ...          ...       ...           ...
# 104604    zwi  Gene_AnatomicalEntity  ZFA:0000823      Gene  expressed_in
# 104605    zwi  Gene_AnatomicalEntity  ZFA:0000948      Gene  expressed_in
# 104606    zwi  Gene_AnatomicalEntity  ZFA:0001479      Gene  expressed_in
# 104607  zyg11  Gene_AnatomicalEntity  ZFA:0000303      Gene  expressed_in
# 104608  zyg11  Gene_AnatomicalEntity  ZFA:0001094      Gene  expressed_in
#
#                tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 1       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 2       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 3       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 4       AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# ...                  ...         ...          ...        ...        ...
# 104604  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 104605  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 104606  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 104607  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
# 104608  AnatomicalEntity  Monarch_KG  Generalised       NCBI    ZFIN_ID
#
#                                   head_detail_name    tail_detail_name  \
# 0                        ATP synthase F0 subunit 6               liver
# 1                        ATP synthase F0 subunit 6     female organism
# 2                        ATP synthase F0 subunit 6      whole organism
# 3                        ATP synthase F0 subunit 6              muscle
# 4                        ATP synthase F0 subunit 8        adaxial cell
# ...                                            ...                 ...
# 104604                                    zwilling        rhombomere 5
# 104605                                    zwilling        rhombomere 3
# 104606                                    zwilling  lateral line nerve
# 104607  zyg-11 family member, cell cycle regulator     female organism
# 104608  zyg-11 family member, cell cycle regulator      whole organism
#
#         species
# 0       D.rerio
# 1       D.rerio
# 2       D.rerio
# 3       D.rerio
# 4       D.rerio
# ...         ...
# 104604  D.rerio
# 104605  D.rerio
# 104606  D.rerio
# 104607  D.rerio
# 104608  D.rerio
#
# [104609 rows x 13 columns]

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 104,609 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Zebrafish/Zebrafish_gene_anatomy/Zebrafish_gene_anatomy.csv

# %%
# OUT_PATH
