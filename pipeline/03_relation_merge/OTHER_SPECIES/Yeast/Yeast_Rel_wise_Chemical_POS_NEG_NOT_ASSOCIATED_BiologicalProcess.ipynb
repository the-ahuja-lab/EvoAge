# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'


# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %% [markdown]
# # POSITIVE ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Yeast_chemical_positiveassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_chemical_positiveassociated_biologicalprocess/Yeast_chemical_positiveassociated_biologicalprocess.csv'

# %% [markdown]
# ### Drugage

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Yeast_CE_Pos_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_PositivelyAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 17 rows
#          head                                           relation        tail  \
# 0      445154  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1     5281614  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2     5281222  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 3        9903  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 4        6072  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 5       10621  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 6   169544354  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 7       91437  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 8      446541  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 9     5281316  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 10        936  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 11       2519  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 12       1102  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 13     162807  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 14       1493  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 15     439224  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 16      15103  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#          head_type          tail_type  \
# 0   ChemicalEntity  BiologicalProcess
# 1   ChemicalEntity  BiologicalProcess
# 2   ChemicalEntity  BiologicalProcess
# 3   ChemicalEntity  BiologicalProcess
# 4   ChemicalEntity  BiologicalProcess
# 5   ChemicalEntity  BiologicalProcess
# 6   ChemicalEntity  BiologicalProcess
# 7   ChemicalEntity  BiologicalProcess
# 8   ChemicalEntity  BiologicalProcess
# 9   ChemicalEntity  BiologicalProcess
# 10  ChemicalEntity  BiologicalProcess
# 11  ChemicalEntity  BiologicalProcess
# 12  ChemicalEntity  BiologicalProcess
# 13  ChemicalEntity  BiologicalProcess
# 14  ChemicalEntity  BiologicalProcess
# 15  ChemicalEntity  BiologicalProcess
# 16  ChemicalEntity  BiologicalProcess
#
#                                      head_detail_name  \
# 0   5-[(E)-2-(4-hydroxyphenyl)ethenyl]benzene-1,3-...
# 1   2-(3,4-dihydroxyphenyl)-3,7-dihydroxychromen-4...
# 2   (E)-1-(2,4-dihydroxyphenyl)-3-(3,4-dihydroxyph...
# 3   (4R)-4-[(3R,5R,8R,9S,10S,13R,14S,17R)-3-hydrox...
# 4   1-[2,4-dihydroxy-6-[(2S,3R,4S,5S,6R)-3,4,5-tri...
# 5   (2S)-5-hydroxy-2-(3-hydroxy-4-methoxyphenyl)-7...
# 6   (6R)-2-methyl-6-[(1S,2S,4S,6R,8R,9S,12S,13R)-5...
# 7   (1R,6S)-3-hydroxy-4-methyl-7-oxabicyclo[4.1.0]...
# 8   (E)-6-(4-hydroxy-6-methoxy-7-methyl-3-oxo-1H-2...
# 9   [(E,6R)-6-[(2S,8S,9R,10R,13R,14S,16R,17R)-2,16...
# 10                             pyridine-3-carboxamide
# 11                    1,3,7-trimethylpurine-2,6-dione
# 12               N'-(3-aminopropyl)butane-1,4-diamine
# 13  (2S,10S)-17,17-dimethyl-3,12,18-trioxapentacyc...
# 14                                  2,4-dinitrophenol
# 15  (2S)-2-(3-aminopropanoylamino)-3-(1H-imidazol-...
# 16               2-amino-4-methylselanylbutanoic acid
#
#                                       head_smile_name relation_source  \
# 0                C1=CC(=CC=C1/C=C/C2=CC(=CC(=C2)O)O)O         DrugAge
# 1     C1=CC(=C(C=C1C2=C(C(=O)C3=C(O2)C=C(C=C3)O)O)O)O         DrugAge
# 2        C1=CC(=C(C=C1/C=C/C(=O)C2=C(C=C(C=C2)O)O)O)O         DrugAge
# 3   C[C@H](CCC(=O)O)[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3...         DrugAge
# 4   C1=CC(=CC=C1CCC(=O)C2=C(C=C(C=C2O[C@H]3[C@@H](...         DrugAge
# 5   C[C@H]1[C@@H]([C@H]([C@H]([C@@H](O1)OC[C@@H]2[...         DrugAge
# 6   CC1CC[C@@]2(C([C@H]3[C@@H](O2)C[C@@H]4[C@@]3(C...         DrugAge
# 7                   CC1=C(C(=O)[C@H]2[C@@H](C1=O)O2)O         DrugAge
# 8      CC1=C2COC(=O)C2=C(C(=C1OC)C/C=C(\C)/CCC(=O)O)O         DrugAge
# 9   CC(=O)OC(C)(C)/C=C/C(=O)[C@@](C)([C@H]1[C@@H](...         DrugAge
# 10                                C1=CC(=CN=C1)C(=O)N         DrugAge
# 11                       CN1C=NC2=C1C(=O)N(C(=O)N2C)C         DrugAge
# 12                                       C(CCNCCCN)CN         DrugAge
# 13  CC1(C=CC2=C(O1)C=CC3=C2OC[C@@]4([C@H]3OC5=C4C=...         DrugAge
# 14           C1=CC(=C(C=C1[N+](=O)[O-])[N+](=O)[O-])O         DrugAge
# 15                C1=C(NC=N1)C[C@@H](C(=O)O)NC(=O)CCN         DrugAge
# 16                                  C[Se]CCC(C(=O)O)N         DrugAge
#
#                      species      head_alt_name  ... age_at_initiation  \
# 0   Saccharomyces cerevisiae        Resveratrol  ...               NaN
# 1   Saccharomyces cerevisiae            Fisetin  ...               NaN
# 2   Saccharomyces cerevisiae             Butein  ...               NaN
# 3   Saccharomyces cerevisiae   Lithocholic acid  ...               NaN
# 4   Saccharomyces cerevisiae         Phloridzin  ...               NaN
# 5   Saccharomyces cerevisiae         Hesperidin  ...               NaN
# 6   Saccharomyces cerevisiae  Nolinospiroside F  ...               NaN
# 7   Saccharomyces cerevisiae       Terreic acid  ...               NaN
# 8   Saccharomyces cerevisiae  Mycophenolic acid  ...               NaN
# 9   Saccharomyces cerevisiae     Cucurbitacin B  ...               NaN
# 10  Saccharomyces cerevisiae       Nicotinamide  ...               NaN
# 11  Saccharomyces cerevisiae           Caffeine  ...               NaN
# 12  Saccharomyces cerevisiae         Spermidine  ...               NaN
# 13  Saccharomyces cerevisiae       Glyceollin I  ...               NaN
# 14  Saccharomyces cerevisiae  2,4-dinitrophenol  ...               NaN
# 15  Saccharomyces cerevisiae          Carnosine  ...               NaN
# 16  Saccharomyces cerevisiae   Selenomethionine  ...               NaN
#
#    treatment_duration  avg_lifespan_change_percent      dosage   pubmed_id  \
# 0                 NaN                        70.00         NaN         NaN
# 1                 NaN                        55.00         NaN         NaN
# 2                 NaN                        31.00         NaN         NaN
# 3                 NaN                       100.00         NaN         NaN
# 4                 NaN                        33.33         NaN         NaN
# 5                 NaN                         4.60         NaN         NaN
# 6                 NaN                        22.60         NaN         NaN
# 7                 NaN                        15.00         NaN         NaN
# 8                 NaN                        20.00         NaN         NaN
# 9                 NaN                        38.13         NaN         NaN
# 10                NaN                        35.96        5 mM  27320176.0
# 11                NaN                        86.00  0.2-0.4 mM  18513215.0
# 12                NaN                       233.00        4 mM  19801973.0
# 13                NaN                        40.00     12.5 nM  24399048.0
# 14                NaN                        14.71       10 nM  15383542.0
# 15                NaN                        25.00       20 mM  27040824.0
# 16                NaN                        30.00    0.00061%  33783357.0
#
#    kg_type  head_id_is tail_id_is kg_source tail_detail_name
# 0    Aging     Pubchem   Quick_GO   Drugage            aging
# 1    Aging     Pubchem   Quick_GO   Drugage            aging
# 2    Aging     Pubchem   Quick_GO   Drugage            aging
# 3    Aging     Pubchem   Quick_GO   Drugage            aging
# 4    Aging     Pubchem   Quick_GO   Drugage            aging
# 5    Aging     Pubchem   Quick_GO   Drugage            aging
# 6    Aging     Pubchem   Quick_GO   Drugage            aging
# 7    Aging     Pubchem   Quick_GO   Drugage            aging
# 8    Aging     Pubchem   Quick_GO   Drugage            aging
# 9    Aging     Pubchem   Quick_GO   Drugage            aging
# 10   Aging     Pubchem   Quick_GO   Drugage            aging
# 11   Aging     Pubchem   Quick_GO   Drugage            aging
# 12   Aging     Pubchem   Quick_GO   Drugage            aging
# 13   Aging     Pubchem   Quick_GO   Drugage            aging
# 14   Aging     Pubchem   Quick_GO   Drugage            aging
# 15   Aging     Pubchem   Quick_GO   Drugage            aging
# 16   Aging     Pubchem   Quick_GO   Drugage            aging
#
# [17 rows x 22 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 17
#          head                                           relation        tail  \
# 0      445154  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1     5281614  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2     5281222  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 3        9903  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 4        6072  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 5       10621  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 6   169544354  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 7       91437  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 8      446541  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 9     5281316  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 10        936  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 11       2519  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 12       1102  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 13     162807  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 14       1493  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 15     439224  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 16      15103  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#          head_type relation_type          tail_type kg_source kg_type  \
# 0   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 3   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 4   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 5   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 6   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 7   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 8   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 9   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 10  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 11  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 12  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 13  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 14  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 15  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 16  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#    head_id_is tail_id_is                                   head_detail_name  \
# 0     Pubchem   Quick_GO  5-[(E)-2-(4-hydroxyphenyl)ethenyl]benzene-1,3-...
# 1     Pubchem   Quick_GO  2-(3,4-dihydroxyphenyl)-3,7-dihydroxychromen-4...
# 2     Pubchem   Quick_GO  (E)-1-(2,4-dihydroxyphenyl)-3-(3,4-dihydroxyph...
# 3     Pubchem   Quick_GO  (4R)-4-[(3R,5R,8R,9S,10S,13R,14S,17R)-3-hydrox...
# 4     Pubchem   Quick_GO  1-[2,4-dihydroxy-6-[(2S,3R,4S,5S,6R)-3,4,5-tri...
# 5     Pubchem   Quick_GO  (2S)-5-hydroxy-2-(3-hydroxy-4-methoxyphenyl)-7...
# 6     Pubchem   Quick_GO  (6R)-2-methyl-6-[(1S,2S,4S,6R,8R,9S,12S,13R)-5...
# 7     Pubchem   Quick_GO  (1R,6S)-3-hydroxy-4-methyl-7-oxabicyclo[4.1.0]...
# 8     Pubchem   Quick_GO  (E)-6-(4-hydroxy-6-methoxy-7-methyl-3-oxo-1H-2...
# 9     Pubchem   Quick_GO  [(E,6R)-6-[(2S,8S,9R,10R,13R,14S,16R,17R)-2,16...
# 10    Pubchem   Quick_GO                             pyridine-3-carboxamide
# 11    Pubchem   Quick_GO                    1,3,7-trimethylpurine-2,6-dione
# 12    Pubchem   Quick_GO               N'-(3-aminopropyl)butane-1,4-diamine
# 13    Pubchem   Quick_GO  (2S,10S)-17,17-dimethyl-3,12,18-trioxapentacyc...
# 14    Pubchem   Quick_GO                                  2,4-dinitrophenol
# 15    Pubchem   Quick_GO  (2S)-2-(3-aminopropanoylamino)-3-(1H-imidazol-...
# 16    Pubchem   Quick_GO               2-amino-4-methylselanylbutanoic acid
#
#    tail_detail_name                   species
# 0             aging  Saccharomyces cerevisiae
# 1             aging  Saccharomyces cerevisiae
# 2             aging  Saccharomyces cerevisiae
# 3             aging  Saccharomyces cerevisiae
# 4             aging  Saccharomyces cerevisiae
# 5             aging  Saccharomyces cerevisiae
# 6             aging  Saccharomyces cerevisiae
# 7             aging  Saccharomyces cerevisiae
# 8             aging  Saccharomyces cerevisiae
# 9             aging  Saccharomyces cerevisiae
# 10            aging  Saccharomyces cerevisiae
# 11            aging  Saccharomyces cerevisiae
# 12            aging  Saccharomyces cerevisiae
# 13            aging  Saccharomyces cerevisiae
# 14            aging  Saccharomyces cerevisiae
# 15            aging  Saccharomyces cerevisiae
# 16            aging  Saccharomyces cerevisiae

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'ChemicalEntity_PositivelyAssociatedWith_BiologicalProcess'}
# head_type           : {'ChemicalEntity'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'Drugage'}
# head_id_is          : {'Pubchem'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 17 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            17                   0              17
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 17  |  After dedup: 17
#    head                                           relation        tail  \
# 0   936  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1  1102  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2  1493  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#         head_type relation_type          tail_type kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#   head_id_is tail_id_is                      head_detail_name  \
# 0    Pubchem   Quick_GO                pyridine-3-carboxamide
# 1    Pubchem   Quick_GO  N'-(3-aminopropyl)butane-1,4-diamine
# 2    Pubchem   Quick_GO                     2,4-dinitrophenol
#
#   tail_detail_name                   species
# 0            aging  Saccharomyces cerevisiae
# 1            aging  Saccharomyces cerevisiae
# 2            aging  Saccharomyces cerevisiae

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            17                   0              17
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Drugage'} kg_source
# Drugage    17
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    17
# Name: count, dtype: int64

# %%
! mkdir Yeast_chemical_positiveassociated_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Yeast_chemical_positiveassociated_biologicalprocess’: File exists

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 17 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_chemical_positiveassociated_biologicalprocess/Yeast_chemical_positiveassociated_biologicalprocess.csv

# %%
# OUT_PATH

# %% [markdown]
# # NEGATIVE ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Yeast_chemical_negativeassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_chemical_negativeassociated_biologicalprocess/Yeast_chemical_negativeassociated_biologicalprocess.csv'

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Yeast_CE_Neg_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_NegativelyAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 1 rows
#      head                                           relation        tail  \
# 0  445154  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
#
#         head_type          tail_type  \
# 0  ChemicalEntity  BiologicalProcess
#
#                                     head_detail_name  \
# 0  5-[(E)-2-(4-hydroxyphenyl)ethenyl]benzene-1,3-...
#
#                         head_smile_name relation_source  \
# 0  C1=CC(=CC=C1/C=C/C2=CC(=CC(=C2)O)O)O         DrugAge
#
#                     species head_alt_name  ... age_at_initiation  \
# 0  Saccharomyces cerevisiae   Resveratrol  ...               NaN
#
#    treatment_duration  avg_lifespan_change_percent  dosage   pubmed_id  \
# 0                 NaN                        -34.8  100 µM  28412652.0
#
#   kg_type  head_id_is tail_id_is kg_source tail_detail_name
# 0   Aging     Pubchem   Quick_GO   Drugage            aging
#
# [1 rows x 22 columns]

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
    
]
aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 1
#      head                                           relation        tail  \
# 0  445154  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
#
#         head_type relation_type          tail_type kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#   head_id_is tail_id_is                                   head_detail_name  \
# 0    Pubchem   Quick_GO  5-[(E)-2-(4-hydroxyphenyl)ethenyl]benzene-1,3-...
#
#   tail_detail_name                   species
# 0            aging  Saccharomyces cerevisiae

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             1                   0               1
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
# ! mkdir Yeast_chemical_negativeassociated_biologicalprocess

# %%
final_df.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df):,} rows → {OUT_PATH}")
# Out:
# Saved 1 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_chemical_negativeassociated_biologicalprocess/Yeast_chemical_negativeassociated_biologicalprocess.csv

# %% [markdown]
# # NOT ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Yeast_chemical_notassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_chemical_notassociated_biologicalprocess/Yeast_chemical_notassociated_biologicalprocess.csv'

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Yeast_CE_Not_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_NotAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 7 rows
#         head                                           relation        tail  \
# 0     439213  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 1     439924  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 2      10917  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 3     162807  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 4  135398634  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 5     445154  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 6       6072  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
#
#         head_type          tail_type  \
# 0  ChemicalEntity  BiologicalProcess
# 1  ChemicalEntity  BiologicalProcess
# 2  ChemicalEntity  BiologicalProcess
# 3  ChemicalEntity  BiologicalProcess
# 4  ChemicalEntity  BiologicalProcess
# 5  ChemicalEntity  BiologicalProcess
# 6  ChemicalEntity  BiologicalProcess
#
#                                     head_detail_name  \
# 0  (3R,4R,5S,6R)-3-amino-6-(hydroxymethyl)oxane-2...
# 1  1-[(2R,3R,4S,5R)-3,4-dihydroxy-5-(hydroxymethy...
# 2     (3R)-3-hydroxy-4-(trimethylazaniumyl)butanoate
# 3  (2S,10S)-17,17-dimethyl-3,12,18-trioxapentacyc...
# 4                     2-amino-1,7-dihydropurin-6-one
# 5  5-[(E)-2-(4-hydroxyphenyl)ethenyl]benzene-1,3-...
# 6  1-[2,4-dihydroxy-6-[(2S,3R,4S,5S,6R)-3,4,5-tri...
#
#                                      head_smile_name relation_source  \
# 0         C([C@@H]1[C@H]([C@@H]([C@H](C(O1)O)N)O)O)O         DrugAge
# 1  C1=CC(=C[N+](=C1)[C@H]2[C@@H]([C@@H]([C@H](O2)...         DrugAge
# 2                    C[N+](C)(C)C[C@@H](CC(=O)[O-])O         DrugAge
# 3  CC1(C=CC2=C(O1)C=CC3=C2OC[C@@]4([C@H]3OC5=C4C=...         DrugAge
# 4                          C1=NC2=C(N1)C(=O)NC(=N2)N         DrugAge
# 5               C1=CC(=CC=C1/C=C/C2=CC(=CC(=C2)O)O)O         DrugAge
# 6  C1=CC(=CC=C1CCC(=O)C2=C(C=C(C=C2O[C@H]3[C@@H](...         DrugAge
#
#                     species          head_alt_name  ... age_at_initiation  \
# 0  Saccharomyces cerevisiae          D-glucosamine  ...               NaN
# 1  Saccharomyces cerevisiae  Nicotinamide riboside  ...               NaN
# 2  Saccharomyces cerevisiae            L-Carnitine  ...               NaN
# 3  Saccharomyces cerevisiae           Glyceollin I  ...               NaN
# 4  Saccharomyces cerevisiae                Guanine  ...               NaN
# 5  Saccharomyces cerevisiae            Resveratrol  ...               NaN
# 6  Saccharomyces cerevisiae             Phloridzin  ...               NaN
#
#   treatment_duration  avg_lifespan_change_percent     dosage   pubmed_id  \
# 0                NaN                         0.00        NaN         NaN
# 1                NaN                        20.00        NaN         NaN
# 2                NaN                        21.40        NaN         NaN
# 3                NaN                          NaN        NaN         NaN
# 4                NaN                        -2.99        NaN         NaN
# 5                NaN                         0.00  100 mg/ml  15684413.0
# 6                NaN                         5.79       1 μM  21597195.0
#
#   kg_type  head_id_is tail_id_is kg_source tail_detail_name
# 0   Aging     Pubchem   Quick_GO   Drugage            aging
# 1   Aging     Pubchem   Quick_GO   Drugage            aging
# 2   Aging     Pubchem   Quick_GO   Drugage            aging
# 3   Aging     Pubchem   Quick_GO   Drugage            aging
# 4   Aging     Pubchem   Quick_GO   Drugage            aging
# 5   Aging     Pubchem   Quick_GO   Drugage            aging
# 6   Aging     Pubchem   Quick_GO   Drugage            aging
#
# [7 rows x 22 columns]

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
    
]
aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 7
#         head                                           relation        tail  \
# 0     439213  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 1     439924  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 2      10917  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 3     162807  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 4  135398634  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 5     445154  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 6       6072  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
#
#         head_type relation_type          tail_type kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 3  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 4  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 5  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 6  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#   head_id_is tail_id_is                                   head_detail_name  \
# 0    Pubchem   Quick_GO  (3R,4R,5S,6R)-3-amino-6-(hydroxymethyl)oxane-2...
# 1    Pubchem   Quick_GO  1-[(2R,3R,4S,5R)-3,4-dihydroxy-5-(hydroxymethy...
# 2    Pubchem   Quick_GO     (3R)-3-hydroxy-4-(trimethylazaniumyl)butanoate
# 3    Pubchem   Quick_GO  (2S,10S)-17,17-dimethyl-3,12,18-trioxapentacyc...
# 4    Pubchem   Quick_GO                     2-amino-1,7-dihydropurin-6-one
# 5    Pubchem   Quick_GO  5-[(E)-2-(4-hydroxyphenyl)ethenyl]benzene-1,3-...
# 6    Pubchem   Quick_GO  1-[2,4-dihydroxy-6-[(2S,3R,4S,5S,6R)-3,4,5-tri...
#
#   tail_detail_name                   species
# 0            aging  Saccharomyces cerevisiae
# 1            aging  Saccharomyces cerevisiae
# 2            aging  Saccharomyces cerevisiae
# 3            aging  Saccharomyces cerevisiae
# 4            aging  Saccharomyces cerevisiae
# 5            aging  Saccharomyces cerevisiae
# 6            aging  Saccharomyces cerevisiae

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             7                   0               7
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
! mkdir Yeast_chemical_notassociated_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Yeast_chemical_notassociated_biologicalprocess’: File exists

# %%
final_df.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df):,} rows → {OUT_PATH}")
# Out:
# Saved 7 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_chemical_notassociated_biologicalprocess/Yeast_chemical_notassociated_biologicalprocess.csv
