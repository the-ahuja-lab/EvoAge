# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Yeast_gene_inhibits_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_gene_inhibits_biologicalprocess/Yeast_gene_inhibits_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Yeast_gene_inhibits_biologicalprocess’: File exists

# %%
#

# %% [markdown]
# # Genage

# %%
Genage = pd.read_csv(PROC_DIR + 'genage/Yeast/Yeast_Gene_Inhibits_BiologicalProcess.csv')
Genage.columns = Genage.columns.str.lower()
Genage = Genage[~Genage['head_detail_name'].isna()]

Genage['kg_type'] = 'Aging'

print(f"Genage: {len(Genage):,} rows")
Genage['head_id_is'] = 'NCBI_ID'
Genage['tail_id_is'] = 'Quick_GO'
Genage['species'] = 'Saccharomyces cerevisiae'
Genage['kg_source'] = 'Genage'

Genage
# Out:
# Genage: 50 rows
#        head                         relation        tail head_type  \
# 0      ATP2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1      DNA2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2      HAP4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3      SRS2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 4      HST2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 5      LAG2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 6      LAT1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 7      MPT5  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 8      MXR1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 9      NDE2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 10     NPT1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 11     PHB1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 12     PHB2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 13    RAD27  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 14     SGS1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 15     SOD1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 16     SOD2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 17     TLC1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 18     UMP1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 19     PNC1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 20     CTR1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 21     ISC1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 22     RIF1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 23     PET9  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 24     ACS2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 25     BNA6  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 26     AAT1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 27     AAT2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 28     GUT2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 29     MDH1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 30     MDH2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 31     CTF4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 32  YKL069W  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 33     BIR1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 34   NMA111  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 35     BMH2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 36     YFH1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 37     TPO1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 38     YOR1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 39     PGA3  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 40    CDC13  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 41     ZDS2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 42    NDT80  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 43     OSH6  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 44     HCM1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 45     MCA1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 46    CDC26  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 47     APC9  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 48     TSA1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 49    PHO84  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#             tail_type                                   head_detail_name  \
# 0   BiologicalProcess                     F1F0 ATP synthase subunit beta
# 1   BiologicalProcess  bifunctional ATP-dependent DNA helicase/ssDNA ...
# 2   BiologicalProcess                          transcription factor HAP4
# 3   BiologicalProcess                                  DNA helicase SRS2
# 4   BiologicalProcess                           histone deacetylase HST2
# 5   BiologicalProcess                                              Lag2p
# 6   BiologicalProcess      dihydrolipoyllysine-residue acetyltransferase
# 7   BiologicalProcess                                              Mpt5p
# 8   BiologicalProcess           peptide-methionine-S-sulfoxide reductase
# 9   BiologicalProcess  NADH-ubiquinone reductase (H(+)-translocating)...
# 10  BiologicalProcess               nicotinate phosphoribosyltransferase
# 11  BiologicalProcess                            prohibitin subunit PHB1
# 12  BiologicalProcess                            prohibitin subunit PHB2
# 13  BiologicalProcess                     multifunctional nuclease RAD27
# 14  BiologicalProcess                    ATP-dependent DNA helicase SGS1
# 15  BiologicalProcess                          superoxide dismutase SOD1
# 16  BiologicalProcess                          superoxide dismutase SOD2
# 17  BiologicalProcess                                                  -
# 18  BiologicalProcess                                              Ump1p
# 19  BiologicalProcess                                     nicotinamidase
# 20  BiologicalProcess                  high-affinity Cu transporter CTR1
# 21  BiologicalProcess         inositol phosphosphingolipid phospholipase
# 22  BiologicalProcess                           DNA-binding protein RIF1
# 23  BiologicalProcess                       ADP/ATP carrier protein PET9
# 24  BiologicalProcess                           acetate--CoA ligase ACS2
# 25  BiologicalProcess  nicotinate-nucleotide diphosphorylase (carboxy...
# 26  BiologicalProcess                        aspartate transaminase AAT1
# 27  BiologicalProcess                        aspartate transaminase AAT2
# 28  BiologicalProcess                 glycerol-3-phosphate dehydrogenase
# 29  BiologicalProcess                          malate dehydrogenase MDH1
# 30  BiologicalProcess                          malate dehydrogenase MDH2
# 31  BiologicalProcess                     chromatin-binding protein CTF4
# 32  BiologicalProcess                 L-methionine (R)-S-oxide reductase
# 33  BiologicalProcess                                           survivin
# 34  BiologicalProcess                                            Nma111p
# 35  BiologicalProcess                         14-3-3 family protein BMH2
# 36  BiologicalProcess                                        ferroxidase
# 37  BiologicalProcess                         polyamine transporter TPO1
# 38  BiologicalProcess              ATP-binding cassette transporter YOR1
# 39  BiologicalProcess                            cytochrome-b5 reductase
# 40  BiologicalProcess                     telomere-binding protein CDC13
# 41  BiologicalProcess                                              Zds2p
# 42  BiologicalProcess                         transcription factor NDT80
# 43  BiologicalProcess                     oxysterol-binding protein OSH6
# 44  BiologicalProcess                                              Hcm1p
# 45  BiologicalProcess            Ca(2+)-dependent cysteine protease MCA1
# 46  BiologicalProcess           anaphase promoting complex subunit CDC26
# 47  BiologicalProcess               anaphase promoting complex subunit 9
# 48  BiologicalProcess                        thioredoxin peroxidase TSA1
# 49  BiologicalProcess                        phosphate transporter PHO84
#
#    tail_detail_name relation_source                   species  data_type  \
# 0    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 1    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 2    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 3    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 4    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 5    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 6    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 7    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 8    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 9    obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 10   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 11   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 12   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 13   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 14   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 15   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 16   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 17   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 18   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 19   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 20   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 21   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 22   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 23   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 24   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 25   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 26   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 27   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 28   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 29   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 30   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 31   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 32   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 33   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 34   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 35   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 36   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 37   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 38   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 39   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 40   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 41   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 42   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 43   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 44   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 45   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 46   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 47   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 48   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
# 49   obsolete aging         GeneAge  Saccharomyces cerevisiae  Causative
#
#    head_alt_name kg_type head_id_is tail_id_is kg_source
# 0        YJR121W   Aging    NCBI_ID   Quick_GO    Genage
# 1        YHR164C   Aging    NCBI_ID   Quick_GO    Genage
# 2        YKL109W   Aging    NCBI_ID   Quick_GO    Genage
# 3        YJL092W   Aging    NCBI_ID   Quick_GO    Genage
# 4        YPL015C   Aging    NCBI_ID   Quick_GO    Genage
# 5        YOL025W   Aging    NCBI_ID   Quick_GO    Genage
# 6        YNL071W   Aging    NCBI_ID   Quick_GO    Genage
# 7        YGL178W   Aging    NCBI_ID   Quick_GO    Genage
# 8        YER042W   Aging    NCBI_ID   Quick_GO    Genage
# 9        YDL085W   Aging    NCBI_ID   Quick_GO    Genage
# 10       YOR209C   Aging    NCBI_ID   Quick_GO    Genage
# 11       YGR132C   Aging    NCBI_ID   Quick_GO    Genage
# 12       YGR231C   Aging    NCBI_ID   Quick_GO    Genage
# 13       YKL113C   Aging    NCBI_ID   Quick_GO    Genage
# 14       YMR190C   Aging    NCBI_ID   Quick_GO    Genage
# 15       YJR104C   Aging    NCBI_ID   Quick_GO    Genage
# 16       YHR008C   Aging    NCBI_ID   Quick_GO    Genage
# 17     YNCB0010W   Aging    NCBI_ID   Quick_GO    Genage
# 18       YBR173C   Aging    NCBI_ID   Quick_GO    Genage
# 19       YGL037C   Aging    NCBI_ID   Quick_GO    Genage
# 20       YPR124W   Aging    NCBI_ID   Quick_GO    Genage
# 21       YER019W   Aging    NCBI_ID   Quick_GO    Genage
# 22       YBR275C   Aging    NCBI_ID   Quick_GO    Genage
# 23       YBL030C   Aging    NCBI_ID   Quick_GO    Genage
# 24       YLR153C   Aging    NCBI_ID   Quick_GO    Genage
# 25       YFR047C   Aging    NCBI_ID   Quick_GO    Genage
# 26       YKL106W   Aging    NCBI_ID   Quick_GO    Genage
# 27       YLR027C   Aging    NCBI_ID   Quick_GO    Genage
# 28       YIL155C   Aging    NCBI_ID   Quick_GO    Genage
# 29       YKL085W   Aging    NCBI_ID   Quick_GO    Genage
# 30       YOL126C   Aging    NCBI_ID   Quick_GO    Genage
# 31       YPR135W   Aging    NCBI_ID   Quick_GO    Genage
# 32       YKL069W   Aging    NCBI_ID   Quick_GO    Genage
# 33       YJR089W   Aging    NCBI_ID   Quick_GO    Genage
# 34       YNL123W   Aging    NCBI_ID   Quick_GO    Genage
# 35       YDR099W   Aging    NCBI_ID   Quick_GO    Genage
# 36       YDL120W   Aging    NCBI_ID   Quick_GO    Genage
# 37       YLL028W   Aging    NCBI_ID   Quick_GO    Genage
# 38       YGR281W   Aging    NCBI_ID   Quick_GO    Genage
# 39       YML125C   Aging    NCBI_ID   Quick_GO    Genage
# 40       YDL220C   Aging    NCBI_ID   Quick_GO    Genage
# 41       YML109W   Aging    NCBI_ID   Quick_GO    Genage
# 42       YHR124W   Aging    NCBI_ID   Quick_GO    Genage
# 43       YKR003W   Aging    NCBI_ID   Quick_GO    Genage
# 44       YCR065W   Aging    NCBI_ID   Quick_GO    Genage
# 45       YOR197W   Aging    NCBI_ID   Quick_GO    Genage
# 46       YFR036W   Aging    NCBI_ID   Quick_GO    Genage
# 47       YLR102C   Aging    NCBI_ID   Quick_GO    Genage
# 48       YML028W   Aging    NCBI_ID   Quick_GO    Genage
# 49       YML123C   Aging    NCBI_ID   Quick_GO    Genage

# %% [markdown]
# # AgingBank

# %%
AgingBank = pd.read_csv(PROC_DIR + 'agingbank/yeast_AgingbankGene_inhibits_BioPro.csv')
AgingBank.columns = AgingBank.columns.str.lower()
AgingBank = AgingBank[~AgingBank['head_detail_name'].isna()]

AgingBank['tail_type'] = 'BiologicalProcess'
AgingBank['relation'] = 'Gene_Inhibits_BiologicalProcess'
print(f"AgingBank: {len(AgingBank):,} rows")
AgingBank['head_id_is'] = 'NCBI_ID'
AgingBank['tail_id_is'] = 'Quick_GO'
AgingBank['species'] = 'Saccharomyces cerevisiae'
AgingBank['kg_source'] = 'AgingBank'
AgingBank
# Out:
# AgingBank: 3 rows
#    head                         relation        tail head_type  \
# 0  FZO1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1  GCN4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3  SSB2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#            tail_type  kg_source kg_type  \
# 0  BiologicalProcess  AgingBank   Aging
# 1  BiologicalProcess  AgingBank   Aging
# 3  BiologicalProcess  AgingBank   Aging
#
#                                     head_detail_name tail_detail_name  \
# 0                                          mitofusin            aging
# 1  amino acid starvation-responsive transcription...            aging
# 3                           Hsp70 family ATPase SSB2            aging
#
#   head_id_is tail_id_is kg_type.1                   species
# 0    NCBI_ID   Quick_GO     Aging  Saccharomyces cerevisiae
# 1    NCBI_ID   Quick_GO     Aging  Saccharomyces cerevisiae
# 3    NCBI_ID   Quick_GO     Aging  Saccharomyces cerevisiae

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Genage, AgingBank
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 53
#        head                         relation        tail head_type  \
# 0      ATP2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1      DNA2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2      HAP4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3      SRS2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 4      HST2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 5      LAG2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 6      LAT1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 7      MPT5  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 8      MXR1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 9      NDE2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 10     NPT1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 11     PHB1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 12     PHB2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 13    RAD27  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 14     SGS1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 15     SOD1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 16     SOD2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 17     TLC1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 18     UMP1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 19     PNC1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 20     CTR1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 21     ISC1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 22     RIF1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 23     PET9  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 24     ACS2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 25     BNA6  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 26     AAT1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 27     AAT2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 28     GUT2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 29     MDH1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 30     MDH2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 31     CTF4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 32  YKL069W  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 33     BIR1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 34   NMA111  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 35     BMH2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 36     YFH1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 37     TPO1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 38     YOR1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 39     PGA3  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 40    CDC13  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 41     ZDS2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 42    NDT80  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 43     OSH6  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 44     HCM1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 45     MCA1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 46    CDC26  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 47     APC9  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 48     TSA1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 49    PHO84  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 50     FZO1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 51     GCN4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 52     SSB2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#    relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 1           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 2           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 3           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 4           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 5           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 6           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 7           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 8           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 9           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 10          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 11          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 12          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 13          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 14          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 15          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 16          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 17          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 18          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 19          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 20          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 21          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 22          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 23          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 24          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 25          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 26          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 27          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 28          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 29          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 30          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 31          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 32          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 33          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 34          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 35          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 36          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 37          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 38          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 39          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 40          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 41          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 42          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 43          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 44          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 45          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 46          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 47          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 48          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 49          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 50          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 51          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 52          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
#
#                                      head_detail_name tail_detail_name  \
# 0                      F1F0 ATP synthase subunit beta   obsolete aging
# 1   bifunctional ATP-dependent DNA helicase/ssDNA ...   obsolete aging
# 2                           transcription factor HAP4   obsolete aging
# 3                                   DNA helicase SRS2   obsolete aging
# 4                            histone deacetylase HST2   obsolete aging
# 5                                               Lag2p   obsolete aging
# 6       dihydrolipoyllysine-residue acetyltransferase   obsolete aging
# 7                                               Mpt5p   obsolete aging
# 8            peptide-methionine-S-sulfoxide reductase   obsolete aging
# 9   NADH-ubiquinone reductase (H(+)-translocating)...   obsolete aging
# 10               nicotinate phosphoribosyltransferase   obsolete aging
# 11                            prohibitin subunit PHB1   obsolete aging
# 12                            prohibitin subunit PHB2   obsolete aging
# 13                     multifunctional nuclease RAD27   obsolete aging
# 14                    ATP-dependent DNA helicase SGS1   obsolete aging
# 15                          superoxide dismutase SOD1   obsolete aging
# 16                          superoxide dismutase SOD2   obsolete aging
# 17                                                  -   obsolete aging
# 18                                              Ump1p   obsolete aging
# 19                                     nicotinamidase   obsolete aging
# 20                  high-affinity Cu transporter CTR1   obsolete aging
# 21         inositol phosphosphingolipid phospholipase   obsolete aging
# 22                           DNA-binding protein RIF1   obsolete aging
# 23                       ADP/ATP carrier protein PET9   obsolete aging
# 24                           acetate--CoA ligase ACS2   obsolete aging
# 25  nicotinate-nucleotide diphosphorylase (carboxy...   obsolete aging
# 26                        aspartate transaminase AAT1   obsolete aging
# 27                        aspartate transaminase AAT2   obsolete aging
# 28                 glycerol-3-phosphate dehydrogenase   obsolete aging
# 29                          malate dehydrogenase MDH1   obsolete aging
# 30                          malate dehydrogenase MDH2   obsolete aging
# 31                     chromatin-binding protein CTF4   obsolete aging
# 32                 L-methionine (R)-S-oxide reductase   obsolete aging
# 33                                           survivin   obsolete aging
# 34                                            Nma111p   obsolete aging
# 35                         14-3-3 family protein BMH2   obsolete aging
# 36                                        ferroxidase   obsolete aging
# 37                         polyamine transporter TPO1   obsolete aging
# 38              ATP-binding cassette transporter YOR1   obsolete aging
# 39                            cytochrome-b5 reductase   obsolete aging
# 40                     telomere-binding protein CDC13   obsolete aging
# 41                                              Zds2p   obsolete aging
# 42                         transcription factor NDT80   obsolete aging
# 43                     oxysterol-binding protein OSH6   obsolete aging
# 44                                              Hcm1p   obsolete aging
# 45            Ca(2+)-dependent cysteine protease MCA1   obsolete aging
# 46           anaphase promoting complex subunit CDC26   obsolete aging
# 47               anaphase promoting complex subunit 9   obsolete aging
# 48                        thioredoxin peroxidase TSA1   obsolete aging
# 49                        phosphate transporter PHO84   obsolete aging
# 50                                          mitofusin            aging
# 51  amino acid starvation-responsive transcription...            aging
# 52                           Hsp70 family ATPase SSB2            aging
#
#                      species
# 0   Saccharomyces cerevisiae
# 1   Saccharomyces cerevisiae
# 2   Saccharomyces cerevisiae
# 3   Saccharomyces cerevisiae
# 4   Saccharomyces cerevisiae
# 5   Saccharomyces cerevisiae
# 6   Saccharomyces cerevisiae
# 7   Saccharomyces cerevisiae
# 8   Saccharomyces cerevisiae
# 9   Saccharomyces cerevisiae
# 10  Saccharomyces cerevisiae
# 11  Saccharomyces cerevisiae
# 12  Saccharomyces cerevisiae
# 13  Saccharomyces cerevisiae
# 14  Saccharomyces cerevisiae
# 15  Saccharomyces cerevisiae
# 16  Saccharomyces cerevisiae
# 17  Saccharomyces cerevisiae
# 18  Saccharomyces cerevisiae
# 19  Saccharomyces cerevisiae
# 20  Saccharomyces cerevisiae
# 21  Saccharomyces cerevisiae
# 22  Saccharomyces cerevisiae
# 23  Saccharomyces cerevisiae
# 24  Saccharomyces cerevisiae
# 25  Saccharomyces cerevisiae
# 26  Saccharomyces cerevisiae
# 27  Saccharomyces cerevisiae
# 28  Saccharomyces cerevisiae
# 29  Saccharomyces cerevisiae
# 30  Saccharomyces cerevisiae
# 31  Saccharomyces cerevisiae
# 32  Saccharomyces cerevisiae
# 33  Saccharomyces cerevisiae
# 34  Saccharomyces cerevisiae
# 35  Saccharomyces cerevisiae
# 36  Saccharomyces cerevisiae
# 37  Saccharomyces cerevisiae
# 38  Saccharomyces cerevisiae
# 39  Saccharomyces cerevisiae
# 40  Saccharomyces cerevisiae
# 41  Saccharomyces cerevisiae
# 42  Saccharomyces cerevisiae
# 43  Saccharomyces cerevisiae
# 44  Saccharomyces cerevisiae
# 45  Saccharomyces cerevisiae
# 46  Saccharomyces cerevisiae
# 47  Saccharomyces cerevisiae
# 48  Saccharomyces cerevisiae
# 49  Saccharomyces cerevisiae
# 50  Saccharomyces cerevisiae
# 51  Saccharomyces cerevisiae
# 52  Saccharomyces cerevisiae

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Inhibits_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'AgingBank', 'Genage'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 53 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            53                   0              53
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 53  |  After dedup: 53
#    head                         relation        tail head_type relation_type  \
# 0  AAT1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene          None
# 1  AAT2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene          None
# 2  ACS2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene          None
#
#            tail_type kg_source kg_type head_id_is tail_id_is  \
# 0  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
# 1  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
# 2  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
#
#               head_detail_name tail_detail_name                   species
# 0  aspartate transaminase AAT1   obsolete aging  Saccharomyces cerevisiae
# 1  aspartate transaminase AAT2   obsolete aging  Saccharomyces cerevisiae
# 2     acetate--CoA ligase ACS2   obsolete aging  Saccharomyces cerevisiae

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            53                   0              53
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'AgingBank', 'Genage'} kg_source
# Genage       50
# AgingBank     3
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    53
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 53 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_gene_inhibits_biologicalprocess/Yeast_gene_inhibits_biologicalprocess.csv

# %%
# OUT_PATH

# %%
# !mkdir Yeast_gene_inhibits_biologicalprocess
