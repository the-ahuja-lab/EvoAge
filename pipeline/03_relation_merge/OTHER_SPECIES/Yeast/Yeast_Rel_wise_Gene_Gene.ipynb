# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast

# %% [markdown]
# # Databases Having Gene gene relation of yeast

# %%
# biogrid/biogrid_YEAST_GENE_GENE.csv
# biogrid/biogrid_YEAST_GENE_GENE_2.csv
# string/scer/string_YEAST_GENE_GENE.csv
# yeastnet/yeastnet_YEAST_GENE_GENE.csv

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Yeast_gene_gene
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_gene_gene/Yeast_Gene_Gene.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name'
]
# Out:
# mkdir: cannot create directory ‘Yeast_gene_gene’: File exists

# %% [markdown]
# # Biogrid

# %%
Biogrid_1 = pd.read_csv(PROC_DIR + 'biogrid/biogrid_YEAST_GENE_GENE.csv')
Biogrid_1['kg_type'] = 'Generalised'
Biogrid_1['kg_source'] = 'Biogrid'

print(f"Biogrid: {len(Biogrid_1):,} rows")
Biogrid_1
# Out:
# Biogrid: 121,617 rows
#            head   relation     tail head_type relation_type tail_type  \
# 0         Q0045  Gene_Gene  YBL005W      Gene     Gene_Gene      Gene
# 1         Q0045  Gene_Gene  YDL020C      Gene     Gene_Gene      Gene
# 2         Q0045  Gene_Gene  YFL031W      Gene     Gene_Gene      Gene
# 3         Q0045  Gene_Gene  YGL013C      Gene     Gene_Gene      Gene
# 4         Q0045  Gene_Gene  YIL101C      Gene     Gene_Gene      Gene
# ...         ...        ...      ...       ...           ...       ...
# 121612  YPR204W  Gene_Gene  YJR060W      Gene     Gene_Gene      Gene
# 121613  YPR204W  Gene_Gene  YKL032C      Gene     Gene_Gene      Gene
# 121614  YPR204W  Gene_Gene  YKL109W      Gene     Gene_Gene      Gene
# 121615  YPR204W  Gene_Gene  YML007W      Gene     Gene_Gene      Gene
# 121616  YPR204W  Gene_Gene  YPL038W      Gene     Gene_Gene      Gene
#
#        kg_source         head_id_is         tail_id_is  \
# 0        Biogrid  SGD_SysematicName  SGD_SysematicName
# 1        Biogrid  SGD_SysematicName  SGD_SysematicName
# 2        Biogrid  SGD_SysematicName  SGD_SysematicName
# 3        Biogrid  SGD_SysematicName  SGD_SysematicName
# 4        Biogrid  SGD_SysematicName  SGD_SysematicName
# ...          ...                ...                ...
# 121612   Biogrid  SGD_SysematicName  SGD_SysematicName
# 121613   Biogrid  SGD_SysematicName  SGD_SysematicName
# 121614   Biogrid  SGD_SysematicName  SGD_SysematicName
# 121615   Biogrid  SGD_SysematicName  SGD_SysematicName
# 121616   Biogrid  SGD_SysematicName  SGD_SysematicName
#
#                          head_detail_name  \
# 0          cytochrome c oxidase subunit 1
# 1          cytochrome c oxidase subunit 1
# 2          cytochrome c oxidase subunit 1
# 3          cytochrome c oxidase subunit 1
# 4          cytochrome c oxidase subunit 1
# ...                                   ...
# 121612  Y' element ATP-dependent helicase
# 121613  Y' element ATP-dependent helicase
# 121614  Y' element ATP-dependent helicase
# 121615  Y' element ATP-dependent helicase
# 121616  Y' element ATP-dependent helicase
#
#                                   tail_detail_name      species      kg_type
# 0        drug-responsive transcription factor PDR3  S.cerevisae  Generalised
# 1       stress-regulated transcription factor RPN4  S.cerevisae  Generalised
# 2                        transcription factor HAC1  S.cerevisae  Generalised
# 3        drug-responsive transcription factor PDR1  S.cerevisae  Generalised
# 4                                            Xbp1p  S.cerevisae  Generalised
# ...                                            ...          ...          ...
# 121612                                       Cbf1p  S.cerevisae  Generalised
# 121613    DNA-binding transcription repressor IXR1  S.cerevisae  Generalised
# 121614                   transcription factor HAP4  S.cerevisae  Generalised
# 121615       DNA-binding transcription factor YAP1  S.cerevisae  Generalised
# 121616                                      Met31p  S.cerevisae  Generalised
#
# [121617 rows x 13 columns]

# %%
Biogrid_2 = pd.read_csv(PROC_DIR + 'biogrid/biogrid_YEAST_GENE_GENE_2.csv')
Biogrid_2['kg_type'] = 'Generalised'
Biogrid_2['kg_source'] = 'Biogrid'
print(f"Biogrid: {len(Biogrid_2):,} rows")
Biogrid_2
# Out:
# Biogrid: 81,870 rows
#           head   relation     tail head_type relation_type tail_type  \
# 0        Q0115  Gene_Gene    Q0045      Gene     Gene_Gene      Gene
# 1        Q0115  Gene_Gene    Q0050      Gene     Gene_Gene      Gene
# 2        Q0115  Gene_Gene    Q0055      Gene     Gene_Gene      Gene
# 3        Q0115  Gene_Gene    Q0060      Gene     Gene_Gene      Gene
# 4        Q0115  Gene_Gene    Q0065      Gene     Gene_Gene      Gene
# ...        ...        ...      ...       ...           ...       ...
# 81865  YPR189W  Gene_Gene  YOR001W      Gene     Gene_Gene      Gene
# 81866  YPR189W  Gene_Gene  YOR063W      Gene     Gene_Gene      Gene
# 81867  YPR189W  Gene_Gene  YOR076C      Gene     Gene_Gene      Gene
# 81868  YPR189W  Gene_Gene  YOR096W      Gene     Gene_Gene      Gene
# 81869  YPR189W  Gene_Gene  YPL081W      Gene     Gene_Gene      Gene
#
#       kg_source         head_id_is         tail_id_is  \
# 0       Biogrid  SGD_SysematicName  SGD_SysematicName
# 1       Biogrid  SGD_SysematicName  SGD_SysematicName
# 2       Biogrid  SGD_SysematicName  SGD_SysematicName
# 3       Biogrid  SGD_SysematicName  SGD_SysematicName
# 4       Biogrid  SGD_SysematicName  SGD_SysematicName
# ...         ...                ...                ...
# 81865   Biogrid  SGD_SysematicName  SGD_SysematicName
# 81866   Biogrid  SGD_SysematicName  SGD_SysematicName
# 81867   Biogrid  SGD_SysematicName  SGD_SysematicName
# 81868   Biogrid  SGD_SysematicName  SGD_SysematicName
# 81869   Biogrid  SGD_SysematicName  SGD_SysematicName
#
#                                         head_detail_name  \
# 0                         cytochrome b mRNA maturase bI3
# 1                         cytochrome b mRNA maturase bI3
# 2                         cytochrome b mRNA maturase bI3
# 3                         cytochrome b mRNA maturase bI3
# 4                         cytochrome b mRNA maturase bI3
# ...                                                  ...
# 81865  SKI complex subunit tetratricopeptide repeat p...
# 81866  SKI complex subunit tetratricopeptide repeat p...
# 81867  SKI complex subunit tetratricopeptide repeat p...
# 81868  SKI complex subunit tetratricopeptide repeat p...
# 81869  SKI complex subunit tetratricopeptide repeat p...
#
#                                tail_detail_name      species      kg_type
# 0                cytochrome c oxidase subunit 1  S.cerevisae  Generalised
# 1      intron-encoded reverse transcriptase aI1  S.cerevisae  Generalised
# 2      intron-encoded reverse transcriptase aI2  S.cerevisae  Generalised
# 3           intron-encoded DNA endonuclease aI3  S.cerevisae  Generalised
# 4           intron-encoded DNA endonuclease aI4  S.cerevisae  Generalised
# ...                                         ...          ...          ...
# 81865             exosome nuclease subunit RRP6  S.cerevisae  Generalised
# 81866          ribosomal 60S subunit protein L3  S.cerevisae  Generalised
# 81867                                     Ski7p  S.cerevisae  Generalised
# 81868         ribosomal 40S subunit protein S7A  S.cerevisae  Generalised
# 81869         ribosomal 40S subunit protein S9A  S.cerevisae  Generalised
#
# [81870 rows x 13 columns]

# %% [markdown]
# # STRING

# %%
string = pd.read_csv(PROC_DIR + 'string/scer/string_YEAST_GENE_GENE.csv')
string['kg_type'] = 'Generalised'
string['kg_source'] = 'STRING'

print(f"string: {len(string):,} rows")
string
# Out:
# string: 2,743,780 rows
#             head   relation     tail head_type  relation_type tail_type  \
# 0          Q0045  Gene_Gene    Q0050      Gene            NaN      Gene
# 1          Q0045  Gene_Gene    Q0055      Gene            NaN      Gene
# 2          Q0045  Gene_Gene    Q0060      Gene            NaN      Gene
# 3          Q0045  Gene_Gene    Q0065      Gene            NaN      Gene
# 4          Q0045  Gene_Gene    Q0070      Gene            NaN      Gene
# ...          ...        ...      ...       ...            ...       ...
# 2743775  YPR204W  Gene_Gene  YPR190C      Gene            NaN      Gene
# 2743776  YPR204W  Gene_Gene  YPR192W      Gene            NaN      Gene
# 2743777  YPR204W  Gene_Gene  YPR201W      Gene            NaN      Gene
# 2743778  YPR204W  Gene_Gene  YPR202W      Gene            NaN      Gene
# 2743779  YPR204W  Gene_Gene  YPR203W      Gene            NaN      Gene
#
#         kg_source         head_id_is         tail_id_is  \
# 0          STRING  SGD_SysematicName  SGD_SysematicName
# 1          STRING  SGD_SysematicName  SGD_SysematicName
# 2          STRING  SGD_SysematicName  SGD_SysematicName
# 3          STRING  SGD_SysematicName  SGD_SysematicName
# 4          STRING  SGD_SysematicName  SGD_SysematicName
# ...           ...                ...                ...
# 2743775    STRING  SGD_SysematicName  SGD_SysematicName
# 2743776    STRING  SGD_SysematicName  SGD_SysematicName
# 2743777    STRING  SGD_SysematicName  SGD_SysematicName
# 2743778    STRING  SGD_SysematicName  SGD_SysematicName
# 2743779    STRING  SGD_SysematicName  SGD_SysematicName
#
#                           head_detail_name  \
# 0           cytochrome c oxidase subunit 1
# 1           cytochrome c oxidase subunit 1
# 2           cytochrome c oxidase subunit 1
# 3           cytochrome c oxidase subunit 1
# 4           cytochrome c oxidase subunit 1
# ...                                    ...
# 2743775  Y' element ATP-dependent helicase
# 2743776  Y' element ATP-dependent helicase
# 2743777  Y' element ATP-dependent helicase
# 2743778  Y' element ATP-dependent helicase
# 2743779  Y' element ATP-dependent helicase
#
#                                     tail_detail_name      species      kg_type
# 0           intron-encoded reverse transcriptase aI1  S.cerevisae  Generalised
# 1           intron-encoded reverse transcriptase aI2  S.cerevisae  Generalised
# 2                intron-encoded DNA endonuclease aI3  S.cerevisae  Generalised
# 3                intron-encoded DNA endonuclease aI4  S.cerevisae  Generalised
# 4          intron-encoded DNA endonuclease aI5 alpha  S.cerevisae  Generalised
# ...                                              ...          ...          ...
# 2743775  DNA-directed RNA polymerase III subunit C82  S.cerevisae  Generalised
# 2743776                                        Aqy1p  S.cerevisae  Generalised
# 2743777                                        Arr3p  S.cerevisae  Generalised
# 2743778                      uncharacterized protein  S.cerevisae  Generalised
# 2743779                      uncharacterized protein  S.cerevisae  Generalised
#
# [2743780 rows x 13 columns]

# %% [markdown]
# # Yeastnet

# %%
YEASTNET = pd.read_csv(PROC_DIR + 'yeastnet/yeastnet_YEAST_GENE_GENE.csv')
YEASTNET['kg_type'] = 'Generalised'
print(f"YEASTNET: {len(YEASTNET):,} rows")
YEASTNET
# Out:
# YEASTNET: 694,191 rows
#            head   relation     tail head_type  \
# 0         Q0045  Gene_Gene    Q0050      Gene
# 1         Q0045  Gene_Gene    Q0055      Gene
# 2         Q0045  Gene_Gene    Q0060      Gene
# 3         Q0045  Gene_Gene    Q0065      Gene
# 4         Q0045  Gene_Gene    Q0070      Gene
# ...         ...        ...      ...       ...
# 694186  YPR189W  Gene_Gene  YPR191W      Gene
# 694187  YPR190C  Gene_Gene  YPR191W      Gene
# 694188  YPR199C  Gene_Gene  YPR200C      Gene
# 694189  YPR199C  Gene_Gene  YPR201W      Gene
# 694190  YPR200C  Gene_Gene  YPR201W      Gene
#
#                                             relation_type tail_type kg_source  \
# 0                                             co-citation      Gene  YeastNet
# 1                                             co-citation      Gene  YeastNet
# 2                                             co-citation      Gene  YeastNet
# 3                                             co-citation      Gene  YeastNet
# 4       co-occurrence of protein domains between two c...      Gene  YeastNet
# ...                                                   ...       ...       ...
# 694186                                        co-citation      Gene  YeastNet
# 694187                                        co-citation      Gene  YeastNet
# 694188                                        co-citation      Gene  YeastNet
# 694189                                        co-citation      Gene  YeastNet
# 694190                                        co-citation      Gene  YeastNet
#
#                head_id_is         tail_id_is  \
# 0       SGD_SysematicName  SGD_SysematicName
# 1       SGD_SysematicName  SGD_SysematicName
# 2       SGD_SysematicName  SGD_SysematicName
# 3       SGD_SysematicName  SGD_SysematicName
# 4       SGD_SysematicName  SGD_SysematicName
# ...                   ...                ...
# 694186  SGD_SysematicName  SGD_SysematicName
# 694187  SGD_SysematicName  SGD_SysematicName
# 694188  SGD_SysematicName  SGD_SysematicName
# 694189  SGD_SysematicName  SGD_SysematicName
# 694190  SGD_SysematicName  SGD_SysematicName
#
#                                          head_detail_name  \
# 0                          cytochrome c oxidase subunit 1
# 1                          cytochrome c oxidase subunit 1
# 2                          cytochrome c oxidase subunit 1
# 3                          cytochrome c oxidase subunit 1
# 4                          cytochrome c oxidase subunit 1
# ...                                                   ...
# 694186  SKI complex subunit tetratricopeptide repeat p...
# 694187        DNA-directed RNA polymerase III subunit C82
# 694188                                              Arr1p
# 694189                                              Arr1p
# 694190                                              Arr2p
#
#                                    tail_detail_name      species      kg_type
# 0          intron-encoded reverse transcriptase aI1  S.cerevisae  Generalised
# 1          intron-encoded reverse transcriptase aI2  S.cerevisae  Generalised
# 2               intron-encoded DNA endonuclease aI3  S.cerevisae  Generalised
# 3               intron-encoded DNA endonuclease aI4  S.cerevisae  Generalised
# 4         intron-encoded DNA endonuclease aI5 alpha  S.cerevisae  Generalised
# ...                                             ...          ...          ...
# 694186  ubiquinol--cytochrome-c reductase subunit 2  S.cerevisae  Generalised
# 694187  ubiquinol--cytochrome-c reductase subunit 2  S.cerevisae  Generalised
# 694188                                        Arr2p  S.cerevisae  Generalised
# 694189                                        Arr3p  S.cerevisae  Generalised
# 694190                                        Arr3p  S.cerevisae  Generalised
#
# [694191 rows x 13 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Biogrid_1, Biogrid_2, string, YEASTNET
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 3,641,458
#             head   relation     tail head_type relation_type tail_type  \
# 0          Q0045  Gene_Gene  YBL005W      Gene     Gene_Gene      Gene
# 1          Q0045  Gene_Gene  YDL020C      Gene     Gene_Gene      Gene
# 2          Q0045  Gene_Gene  YFL031W      Gene     Gene_Gene      Gene
# 3          Q0045  Gene_Gene  YGL013C      Gene     Gene_Gene      Gene
# 4          Q0045  Gene_Gene  YIL101C      Gene     Gene_Gene      Gene
# ...          ...        ...      ...       ...           ...       ...
# 3641453  YPR189W  Gene_Gene  YPR191W      Gene   co-citation      Gene
# 3641454  YPR190C  Gene_Gene  YPR191W      Gene   co-citation      Gene
# 3641455  YPR199C  Gene_Gene  YPR200C      Gene   co-citation      Gene
# 3641456  YPR199C  Gene_Gene  YPR201W      Gene   co-citation      Gene
# 3641457  YPR200C  Gene_Gene  YPR201W      Gene   co-citation      Gene
#
#         kg_source      kg_type         head_id_is         tail_id_is  \
# 0         Biogrid  Generalised  SGD_SysematicName  SGD_SysematicName
# 1         Biogrid  Generalised  SGD_SysematicName  SGD_SysematicName
# 2         Biogrid  Generalised  SGD_SysematicName  SGD_SysematicName
# 3         Biogrid  Generalised  SGD_SysematicName  SGD_SysematicName
# 4         Biogrid  Generalised  SGD_SysematicName  SGD_SysematicName
# ...           ...          ...                ...                ...
# 3641453  YeastNet  Generalised  SGD_SysematicName  SGD_SysematicName
# 3641454  YeastNet  Generalised  SGD_SysematicName  SGD_SysematicName
# 3641455  YeastNet  Generalised  SGD_SysematicName  SGD_SysematicName
# 3641456  YeastNet  Generalised  SGD_SysematicName  SGD_SysematicName
# 3641457  YeastNet  Generalised  SGD_SysematicName  SGD_SysematicName
#
#                                           head_detail_name  \
# 0                           cytochrome c oxidase subunit 1
# 1                           cytochrome c oxidase subunit 1
# 2                           cytochrome c oxidase subunit 1
# 3                           cytochrome c oxidase subunit 1
# 4                           cytochrome c oxidase subunit 1
# ...                                                    ...
# 3641453  SKI complex subunit tetratricopeptide repeat p...
# 3641454        DNA-directed RNA polymerase III subunit C82
# 3641455                                              Arr1p
# 3641456                                              Arr1p
# 3641457                                              Arr2p
#
#                                     tail_detail_name
# 0          drug-responsive transcription factor PDR3
# 1         stress-regulated transcription factor RPN4
# 2                          transcription factor HAC1
# 3          drug-responsive transcription factor PDR1
# 4                                              Xbp1p
# ...                                              ...
# 3641453  ubiquinol--cytochrome-c reductase subunit 2
# 3641454  ubiquinol--cytochrome-c reductase subunit 2
# 3641455                                        Arr2p
# 3641456                                        Arr3p
# 3641457                                        Arr3p
#
# [3641458 rows x 12 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Gene'}
# head_type           : {'Gene'}
# tail_type           : {'Gene'}
# relation_type       : {'3-D protein structure of interacting orthologous proteins between two yeast proteins', 'small/medium-scale protein-protein interactions', nan, 'co-citation', 'similar genomic context of bacterial orthologs of two yeast genes', 'co-occurrence of protein domains between two coding genes', 'co-expression', 'high-throughput protein-protein interactions', 'Inferred links by similar profiles of genetic interaction partners', 'similar phylogenetic profiles between two yeast genes', 'Gene_Gene'}
# kg_source           : {'STRING', 'Biogrid', 'YeastNet'}
# head_id_is          : {'SGD_SysematicName'}
# tail_id_is          : {'SGD_SysematicName'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 3,641,458 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type       2743780             2743780         5487560
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 3,641,458  |  After dedup: 3,278,573
#     head   relation   tail head_type relation_type tail_type  \
# 0  Q0045  Gene_Gene  Q0050      Gene   co-citation      Gene
# 1  Q0045  Gene_Gene  Q0055      Gene   co-citation      Gene
# 2  Q0045  Gene_Gene  Q0060      Gene   co-citation      Gene
#
#           kg_source      kg_type         head_id_is         tail_id_is  \
# 0  STRING::YeastNet  Generalised  SGD_SysematicName  SGD_SysematicName
# 1  STRING::YeastNet  Generalised  SGD_SysematicName  SGD_SysematicName
# 2  STRING::YeastNet  Generalised  SGD_SysematicName  SGD_SysematicName
#
#                  head_detail_name                          tail_detail_name
# 0  cytochrome c oxidase subunit 1  intron-encoded reverse transcriptase aI1
# 1  cytochrome c oxidase subunit 1  intron-encoded reverse transcriptase aI2
# 2  cytochrome c oxidase subunit 1       intron-encoded DNA endonuclease aI3

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type       2406116                   0         2406116
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'STRING::YeastNet', 'Biogrid', 'Biogrid::STRING::YeastNet', 'Biogrid::STRING', 'Biogrid::YeastNet', 'STRING', 'YeastNet'} kg_source
# STRING                       2406116
# YeastNet                      423731
# STRING::YeastNet              245675
# Biogrid                       108967
# Biogrid::STRING                69299
# Biogrid::STRING::YeastNet      22690
# Biogrid::YeastNet               2095
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    3278573
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 3,278,573 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Yeast/Yeast_gene_gene/Yeast_Gene_Gene.csv
