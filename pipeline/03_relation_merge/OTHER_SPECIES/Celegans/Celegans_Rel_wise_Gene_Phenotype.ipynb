# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %% [markdown]
# # Databases Having Gene Phenotype relation of celegans

# %%
# gendr/Cele/Cele_GenDR_Gene_BioProcess.csv
# Monarch/Monarch_final/Celegans/Gene_Cele_BiologicalProcess.csv

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_gene_phenotype
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_phenotype/Celegans_gene_phenotype.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_gene_phenotype’: File exists

# %%
cele = pd.read_csv(
    f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Caenorhabditis_elegans.gene_info',
    sep='\t',
    
)
cele["LocusTag"] = cele["LocusTag"].str.replace("CELE_", "", regex=False)

cele_symbol2Locus_dict = dict(zip(cele['Symbol'], cele['LocusTag']))
cele
# cele_symbol2Locus_dict
# Out:
#        #tax_id    GeneID     Symbol    LocusTag Synonyms  \
# 0         6239    171590     homt-1    Y74C9A.3        -
# 1         6239    171591     nlp-40    Y74C9A.2        -
# 2         6239    171592     rcor-1    Y74C9A.4        -
# 3         6239    171593     sesn-1    Y74C9A.5        -
# 4         6239    171594      pgs-1    Y48G1C.4        -
# ...        ...       ...        ...         ...      ...
# 46922     6239  80510347     azyx-1    F42G4.11        -
# 46923     6239  80510348  F54D10.10   F54D10.10        -
# 46924     6239  80510349   F58B6.11    F58B6.11        -
# 46925     6239  80510350  Y34B4A.20   Y34B4A.20        -
# 46926     6239  80510351     ceh-44  Y54F10AM.4        -
#
#                                                  dbXrefs chromosome  \
# 0      WormBase:WBGene00022277|AllianceGenome:WB:WBGe...          I
# 1      WormBase:WBGene00022276|AllianceGenome:WB:WBGe...          I
# 2      WormBase:WBGene00022278|AllianceGenome:WB:WBGe...          I
# 3      WormBase:WBGene00022279|AllianceGenome:WB:WBGe...          I
# 4      WormBase:WBGene00021677|AllianceGenome:WB:WBGe...          I
# ...                                                  ...        ...
# 46922  WormBase:WBGene00306133|AllianceGenome:WB:WBGe...         II
# 46923  WormBase:WBGene00306132|AllianceGenome:WB:WBGe...         II
# 46924  WormBase:WBGene00306125|AllianceGenome:WB:WBGe...        III
# 46925  WormBase:WBGene00306131|AllianceGenome:WB:WBGe...          X
# 46926  WormBase:WBGene00000464|AllianceGenome:WB:WBGe...        III
#
#       map_location                                        description  \
# 0                -       Alpha N-terminal protein methyltransferase 1
# 1                -                                         Peptide P4
# 2                -                            REST corepressor rcor-1
# 3                -                                    Sestrin homolog
# 4                -  CDP-diacylglycerol--glycerol-3-phosphate 3-pho...
# ...            ...                                                ...
# 46922            -  Alternative N-terminal open reading frame of Z...
# 46923            -                            Uncharacterized protein
# 46924            -                            Uncharacterized protein
# 46925            -                            Uncharacterized protein
# 46926            -                   Homeobox protein cut-like ceh-44
#
#          type_of_gene Symbol_from_nomenclature_authority  \
# 0      protein-coding                             homt-1
# 1      protein-coding                             nlp-40
# 2      protein-coding                             rcor-1
# 3      protein-coding                             sesn-1
# 4      protein-coding                              pgs-1
# ...               ...                                ...
# 46922  protein-coding                             azyx-1
# 46923  protein-coding                          F54D10.10
# 46924  protein-coding                           F58B6.11
# 46925  protein-coding                          Y34B4A.20
# 46926  protein-coding                             ceh-44
#
#                    Full_name_from_nomenclature_authority Nomenclature_status  \
# 0           Alpha N-terminal protein methyltransferase 1                   O
# 1                                             Peptide P4                   O
# 2                                REST corepressor rcor-1                   O
# 3                                        Sestrin homolog                   O
# 4      CDP-diacylglycerol--glycerol-3-phosphate 3-pho...                   O
# ...                                                  ...                 ...
# 46922  Alternative N-terminal open reading frame of Z...                   O
# 46923                            Uncharacterized protein                   O
# 46924                            Uncharacterized protein                   O
# 46925                            Uncharacterized protein                   O
# 46926                   Homeobox protein cut-like ceh-44                   O
#
#                                       Other_designations  Modification_date  \
# 0           Alpha N-terminal protein methyltransferase 1           20250308
# 1                                             Peptide P4           20250308
# 2                                REST corepressor rcor-1           20250308
# 3                                        Sestrin homolog           20250308
# 4      CDP-diacylglycerol--glycerol-3-phosphate 3-pho...           20250308
# ...                                                  ...                ...
# 46922  Alternative N-terminal open reading frame of Z...           20250308
# 46923                            Uncharacterized protein           20241028
# 46924                            Uncharacterized protein           20241028
# 46925                            Uncharacterized protein           20241028
# 46926                   Homeobox protein cut-like ceh-44           20250308
#
#       Feature_type
# 0                -
# 1                -
# 2                -
# 3                -
# 4                -
# ...            ...
# 46922            -
# 46923            -
# 46924            -
# 46925            -
# 46926            -
#
# [46927 rows x 16 columns]

# %% [markdown]
# # Wormbase

# %%
wormbase = pd.read_csv(PROC_DIR + 'wormbase/wormbase_CELE_GENE_PHENOTYPE.csv')
wormbase.columns = wormbase.columns.str.lower()
wormbase['head'] = wormbase['head'].map(cele_symbol2Locus_dict).fillna(wormbase['head'])
wormbase['kg_type'] = 'Generalised'
wormbase['species'] = 'C.elegans'
wormbase['kg_source'] = 'WormBase'
wormbase['head_id_is'] = 'NCBI_ID'
wormbase['tail_id_is'] = ''

print(f"wormbase: {len(wormbase):,} rows")
wormbase
# Out:
# wormbase: 253,469 rows
#               head        relation                            tail head_type  \
# 0       Y110A7A.10  Gene_Phenotype              extended life span      Gene
# 1       Y110A7A.10  Gene_Phenotype       thermotolerance increased      Gene
# 2       Y110A7A.10  Gene_Phenotype         dauer formation variant      Gene
# 3       Y110A7A.10  Gene_Phenotype                slow development      Gene
# 4       Y110A7A.10  Gene_Phenotype                  DMPP resistant      Gene
# ...            ...             ...                             ...       ...
# 253464    Y24D9A.2  Gene_Phenotype    transgene expression reduced      Gene
# 253465    Y24D9A.2  Gene_Phenotype  transgene expression increased      Gene
# 253466      ZC53.6  Gene_Phenotype    transgene expression reduced      Gene
# 253467     R07B5.9  Gene_Phenotype    transgene expression reduced      Gene
# 253468     R07B5.9  Gene_Phenotype  transgene expression increased      Gene
#
#         tail_type                                   head_detail_name  \
# 0       Phenotype                      SH2 domain-containing protein
# 1       Phenotype                      SH2 domain-containing protein
# 2       Phenotype                      SH2 domain-containing protein
# 3       Phenotype                      SH2 domain-containing protein
# 4       Phenotype                      SH2 domain-containing protein
# ...           ...                                                ...
# 253464  Phenotype                      SET domain-containing protein
# 253465  Phenotype                      SET domain-containing protein
# 253466  Phenotype  Histone-lysine N-methyltransferase, H3 lysine-...
# 253467  Phenotype                   Histone acetyltransferase lsy-12
# 253468  Phenotype                   Histone acetyltransferase lsy-12
#
#        relation_source      kg_type    species kg_source head_id_is tail_id_is
# 0             wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# 1             wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# 2             wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# 3             wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# 4             wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# ...                ...          ...        ...       ...        ...        ...
# 253464        wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# 253465        wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# 253466        wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# 253467        wormbase  Generalised  C.elegans  WormBase    NCBI_ID
# 253468        wormbase  Generalised  C.elegans  WormBase    NCBI_ID
#
# [253469 rows x 12 columns]

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Celegans/Gene_Cele_Phenotype.csv')

monarch.columns = monarch.columns.str.lower()
monarch= monarch[~monarch['head'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['species'] = 'C.elegans'

monarch['head_id_is'] = 'NCBI_ID'
monarch['tail_id_is'] = 'WormBasePhenotype'

monarch['kg_source'] = 'Monarch_KG'
#

print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 24,819 rows
#            head        relation                 tail head_type  relation_type  \
# 0       F43C1.2  Gene_Phenotype  WBPhenotype:0001191      Gene  has_phenotype
# 1       C35B8.2  Gene_Phenotype  WBPhenotype:0000154      Gene  has_phenotype
# 2       C35B8.2  Gene_Phenotype  WBPhenotype:0000246      Gene  has_phenotype
# 3       C35B8.2  Gene_Phenotype  WBPhenotype:0000666      Gene  has_phenotype
# 4       C35B8.2  Gene_Phenotype  WBPhenotype:0000668      Gene  has_phenotype
# ...         ...             ...                  ...       ...            ...
# 26678   K02F2.3  Gene_Phenotype  WBPhenotype:0000062      Gene  has_phenotype
# 26679   K02F2.3  Gene_Phenotype  WBPhenotype:0000062      Gene  has_phenotype
# 26680   K08A8.2  Gene_Phenotype  WBPhenotype:0000414      Gene  has_phenotype
# 26681  F49E12.6  Gene_Phenotype  WBPhenotype:0000054      Gene  has_phenotype
# 26682  F49E12.6  Gene_Phenotype  WBPhenotype:0000054      Gene  has_phenotype
#
#        tail_type   relation_source  \
# 0      Phenotype  infores:wormbase
# 1      Phenotype  infores:wormbase
# 2      Phenotype  infores:wormbase
# 3      Phenotype  infores:wormbase
# 4      Phenotype  infores:wormbase
# ...          ...               ...
# 26678  Phenotype  infores:wormbase
# 26679  Phenotype  infores:wormbase
# 26680  Phenotype  infores:wormbase
# 26681  Phenotype  infores:wormbase
# 26682  Phenotype  infores:wormbase
#
#                                         head_detail_name  \
# 0                 Mitogen-activated protein kinase mpk-1
# 1                              Protein vav;Protein vav-1
# 2                              Protein vav;Protein vav-1
# 3                              Protein vav;Protein vav-1
# 4                              Protein vav;Protein vav-1
# ...                                                  ...
# 26678                       Splicing factor 3B subunit 3
# 26679                       Splicing factor 3B subunit 3
# 26680  HMG box domain-containing protein;Transcriptio...
# 26681                         Transcription factor efl-3
# 26682                         Transcription factor efl-3
#
#                            tail_detail_name         head_taxon_name  \
# 0      pharyngeal muscle physiology variant  Caenorhabditis elegans
# 1                        reduced brood size  Caenorhabditis elegans
# 2          defecation cycle variable length  Caenorhabditis elegans
# 3                         ovulation variant  Caenorhabditis elegans
# 4                       endomitotic oocytes  Caenorhabditis elegans
# ...                                     ...                     ...
# 26678                                lethal  Caenorhabditis elegans
# 26679                                lethal  Caenorhabditis elegans
# 26680              cell fate transformation  Caenorhabditis elegans
# 26681                         larval lethal  Caenorhabditis elegans
# 26682                         larval lethal  Caenorhabditis elegans
#
#        tail_taxon_name head_id_is         tail_id_is head_name    species  \
# 0                  NaN    NCBI_ID  WormBasePhenotype     mpk-1  C.elegans
# 1                  NaN    NCBI_ID  WormBasePhenotype     vav-1  C.elegans
# 2                  NaN    NCBI_ID  WormBasePhenotype     vav-1  C.elegans
# 3                  NaN    NCBI_ID  WormBasePhenotype     vav-1  C.elegans
# 4                  NaN    NCBI_ID  WormBasePhenotype     vav-1  C.elegans
# ...                ...        ...                ...       ...        ...
# 26678              NaN    NCBI_ID  WormBasePhenotype     teg-4  C.elegans
# 26679              NaN    NCBI_ID  WormBasePhenotype     teg-4  C.elegans
# 26680              NaN    NCBI_ID  WormBasePhenotype     sox-2  C.elegans
# 26681              NaN    NCBI_ID  WormBasePhenotype     efl-3  C.elegans
# 26682              NaN    NCBI_ID  WormBasePhenotype     efl-3  C.elegans
#
#            kg_type   kg_source
# 0      Generalised  Monarch_KG
# 1      Generalised  Monarch_KG
# 2      Generalised  Monarch_KG
# 3      Generalised  Monarch_KG
# 4      Generalised  Monarch_KG
# ...            ...         ...
# 26678  Generalised  Monarch_KG
# 26679  Generalised  Monarch_KG
# 26680  Generalised  Monarch_KG
# 26681  Generalised  Monarch_KG
# 26682  Generalised  Monarch_KG
#
# [24819 rows x 17 columns]

# %%
#

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    wormbase, monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 278,288
#               head        relation                       tail head_type  \
# 0       Y110A7A.10  Gene_Phenotype         extended life span      Gene
# 1       Y110A7A.10  Gene_Phenotype  thermotolerance increased      Gene
# 2       Y110A7A.10  Gene_Phenotype    dauer formation variant      Gene
# 3       Y110A7A.10  Gene_Phenotype           slow development      Gene
# 4       Y110A7A.10  Gene_Phenotype             DMPP resistant      Gene
# ...            ...             ...                        ...       ...
# 278283     K02F2.3  Gene_Phenotype        WBPhenotype:0000062      Gene
# 278284     K02F2.3  Gene_Phenotype        WBPhenotype:0000062      Gene
# 278285     K08A8.2  Gene_Phenotype        WBPhenotype:0000414      Gene
# 278286    F49E12.6  Gene_Phenotype        WBPhenotype:0000054      Gene
# 278287    F49E12.6  Gene_Phenotype        WBPhenotype:0000054      Gene
#
#         relation_type  tail_type   kg_source      kg_type head_id_is  \
# 0                None  Phenotype    WormBase  Generalised    NCBI_ID
# 1                None  Phenotype    WormBase  Generalised    NCBI_ID
# 2                None  Phenotype    WormBase  Generalised    NCBI_ID
# 3                None  Phenotype    WormBase  Generalised    NCBI_ID
# 4                None  Phenotype    WormBase  Generalised    NCBI_ID
# ...               ...        ...         ...          ...        ...
# 278283  has_phenotype  Phenotype  Monarch_KG  Generalised    NCBI_ID
# 278284  has_phenotype  Phenotype  Monarch_KG  Generalised    NCBI_ID
# 278285  has_phenotype  Phenotype  Monarch_KG  Generalised    NCBI_ID
# 278286  has_phenotype  Phenotype  Monarch_KG  Generalised    NCBI_ID
# 278287  has_phenotype  Phenotype  Monarch_KG  Generalised    NCBI_ID
#
#                tail_id_is                                   head_detail_name  \
# 0                                              SH2 domain-containing protein
# 1                                              SH2 domain-containing protein
# 2                                              SH2 domain-containing protein
# 3                                              SH2 domain-containing protein
# 4                                              SH2 domain-containing protein
# ...                   ...                                                ...
# 278283  WormBasePhenotype                       Splicing factor 3B subunit 3
# 278284  WormBasePhenotype                       Splicing factor 3B subunit 3
# 278285  WormBasePhenotype  HMG box domain-containing protein;Transcriptio...
# 278286  WormBasePhenotype                         Transcription factor efl-3
# 278287  WormBasePhenotype                         Transcription factor efl-3
#
#                 tail_detail_name    species
# 0                           None  C.elegans
# 1                           None  C.elegans
# 2                           None  C.elegans
# 3                           None  C.elegans
# 4                           None  C.elegans
# ...                          ...        ...
# 278283                    lethal  C.elegans
# 278284                    lethal  C.elegans
# 278285  cell fate transformation  C.elegans
# 278286             larval lethal  C.elegans
# 278287             larval lethal  C.elegans
#
# [278288 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Phenotype'}
# head_type           : {'Gene'}
# tail_type           : {'Phenotype'}
# relation_type       : {None, 'has_phenotype'}
# kg_source           : {'Monarch_KG', 'WormBase'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'', 'WormBasePhenotype'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 253,469 unresolvable rows → 24,819 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 24,819  |  After dedup: 16,400
#      head        relation                 tail head_type  relation_type  \
# 0  AC3.10  Gene_Phenotype  WBPhenotype:0000357      Gene  has_phenotype
# 1  AC3.10  Gene_Phenotype  WBPhenotype:0001360      Gene  has_phenotype
# 2  AC3.10  Gene_Phenotype  WBPhenotype:0001727      Gene  has_phenotype
#
#    tail_type   kg_source      kg_type head_id_is         tail_id_is  \
# 0  Phenotype  Monarch_KG  Generalised    NCBI_ID  WormBasePhenotype
# 1  Phenotype  Monarch_KG  Generalised    NCBI_ID  WormBasePhenotype
# 2  Phenotype  Monarch_KG  Generalised    NCBI_ID  WormBasePhenotype
#
#               head_detail_name            tail_detail_name    species
# 0  Palmitoyltransferase spe-10   unfertilized oocytes laid  C.elegans
# 1  Palmitoyltransferase spe-10  hermaphrodite self sterile  C.elegans
# 2  Palmitoyltransferase spe-10          body width variant  C.elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    16400
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    16400
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 16,400 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_phenotype/Celegans_gene_phenotype.csv

# %%
#
