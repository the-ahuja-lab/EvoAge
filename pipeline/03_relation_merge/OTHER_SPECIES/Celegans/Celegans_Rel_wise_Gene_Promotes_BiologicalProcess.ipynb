# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
! pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_gene_promotes_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_promotes_biologicalprocess/Celegans_gene_promotes_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_gene_promotes_biologicalprocess’: File exists

# %%
#

# %%
# Mouse = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Mus_musculus.gene_info',
#     sep='\t',
    
# )
# # Mouse["LocusTag"] = Mouse["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Mouse_symbol2Locus_dict = dict(zip(Mouse['Symbol'], Mouse['LocusTag']))
# # Mouse
# # Mouse_symbol2Locus_dict
# Mouse

# %% [markdown]
# # Genage

# %%
Genage = pd.read_csv(PROC_DIR + 'genage/Cele/Cele_Gene_Promotes_BiologicalProcess.csv')
Genage.columns = Genage.columns.str.lower()
Genage = Genage[~Genage['head_detail_name'].isna()]

Genage['kg_type'] = 'Aging'
Genage['relation'] = 'Gene_Promotes_BiologicalProcess'
print(f"Genage: {len(Genage):,} rows")
Genage['head_id_is'] = 'NCBI_ID'
Genage['tail_id_is'] = 'Quick_GO'
Genage['species'] = 'Caenorhabditis elegans'
Genage['kg_source'] = 'Genage'

Genage
# Out:
# Genage: 557 rows
#         head                         relation        tail head_type  \
# 0      aat-8  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1     acl-11  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2      aco-2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3      age-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 4      akt-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# ..       ...                              ...         ...       ...
# 552   unc-36  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 553   ergo-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 554  dot-1.1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 555    cyk-3  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 556    rpc-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#              tail_type                                   head_detail_name  \
# 0    BiologicalProcess                             Amino acid transporter
# 1    BiologicalProcess  Phospholipid/glycerol acyltransferase domain-c...
# 2    BiologicalProcess        putative aconitate hydratase, mitochondrial
# 3    BiologicalProcess                Phosphatidylinositol 3-kinase age-1
# 4    BiologicalProcess              Serine/threonine-protein kinase akt-1
# ..                 ...                                                ...
# 552  BiologicalProcess  VWFA domain-containing protein;Voltage-depende...
# 553  BiologicalProcess  Piwi domain-containing protein;Piwi-like prote...
# 554  BiologicalProcess  Histone-lysine N-methyltransferase, H3 lysine-...
# 555  BiologicalProcess        Ubiquitin carboxyl-terminal hydrolase cyk-3
# 556  BiologicalProcess                DNA-directed RNA polymerase subunit
#
#     tail_detail_name relation_source                 species  data_type  \
# 0     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 1     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 2     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 3     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 4     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# ..               ...             ...                     ...        ...
# 552   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 553   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 554   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 555   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 556   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
#
#     head_alt_name kg_type head_id_is tail_id_is kg_source
# 0           aat-8   Aging    NCBI_ID   Quick_GO    Genage
# 1          acl-11   Aging    NCBI_ID   Quick_GO    Genage
# 2           aco-2   Aging    NCBI_ID   Quick_GO    Genage
# 3           age-1   Aging    NCBI_ID   Quick_GO    Genage
# 4           akt-1   Aging    NCBI_ID   Quick_GO    Genage
# ..            ...     ...        ...        ...       ...
# 552        unc-36   Aging    NCBI_ID   Quick_GO    Genage
# 553        ergo-1   Aging    NCBI_ID   Quick_GO    Genage
# 554       dot-1.1   Aging    NCBI_ID   Quick_GO    Genage
# 555         cyk-3   Aging    NCBI_ID   Quick_GO    Genage
# 556         rpc-1   Aging    NCBI_ID   Quick_GO    Genage
#
# [557 rows x 15 columns]

# %% [markdown]
# # AgingBank

# %%
AgingBank = pd.read_csv(PROC_DIR + 'agingbank/Celegans_AgingbankGene_promotes_BioPro.csv')
AgingBank.columns = AgingBank.columns.str.lower()
AgingBank = AgingBank[~AgingBank['head_detail_name'].isna()]

AgingBank['kg_type'] = 'Aging'
AgingBank['relation'] = 'Gene_Promotes_BiologicalProcess'
AgingBank['tail_type'] = 'BiologicalProcess'
print(f"AgingBank: {len(AgingBank):,} rows")
AgingBank['head_id_is'] = 'NCBI_ID'
AgingBank['tail_id_is'] = 'Quick_GO'
AgingBank['species'] = 'Caenorhabditis elegans'
AgingBank['kg_source'] = 'AgingBank'
AgingBank
# Out:
# AgingBank: 21 rows
#        head                         relation        tail head_type  \
# 0     clk-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1    DAF-16  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2   mir-241  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3    miR-71  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 4    miR-83  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 5    mir-84  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 6    DAF-16  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 7    DAF-18  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 8    DAF-16  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 9     pcm-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 10   ATFS-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 11   DAF-16  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 12   DAF-16  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 13    DCT-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 14    ELT-2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 15    HEL-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 16   HLH-30  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 17    ins-6  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 18    MML-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 19    MXL-2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 20    PQM-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#             tail_type  kg_source kg_type  \
# 0   BiologicalProcess  AgingBank   Aging
# 1   BiologicalProcess  AgingBank   Aging
# 2   BiologicalProcess  AgingBank   Aging
# 3   BiologicalProcess  AgingBank   Aging
# 4   BiologicalProcess  AgingBank   Aging
# 5   BiologicalProcess  AgingBank   Aging
# 6   BiologicalProcess  AgingBank   Aging
# 7   BiologicalProcess  AgingBank   Aging
# 8   BiologicalProcess  AgingBank   Aging
# 9   BiologicalProcess  AgingBank   Aging
# 10  BiologicalProcess  AgingBank   Aging
# 11  BiologicalProcess  AgingBank   Aging
# 12  BiologicalProcess  AgingBank   Aging
# 13  BiologicalProcess  AgingBank   Aging
# 14  BiologicalProcess  AgingBank   Aging
# 15  BiologicalProcess  AgingBank   Aging
# 16  BiologicalProcess  AgingBank   Aging
# 17  BiologicalProcess  AgingBank   Aging
# 18  BiologicalProcess  AgingBank   Aging
# 19  BiologicalProcess  AgingBank   Aging
# 20  BiologicalProcess  AgingBank   Aging
#
#                                      head_detail_name tail_detail_name  \
# 0    5-demethoxyubiquinone hydroxylase, mitochondrial            aging
# 1                              Forkhead box protein O            aging
# 2                                               ncRNA            aging
# 3                                             miscRNA            aging
# 4                                               ncRNA            aging
# 5                                               ncRNA            aging
# 6                              Forkhead box protein O            aging
# 7   Phosphatidylinositol 3,4,5-trisphosphate 3-pho...            aging
# 8                              Forkhead box protein O            aging
# 9          Protein-L-isoaspartate O-methyltransferase            aging
# 10       Stress activated transcription factor atfs-1            aging
# 11                             Forkhead box protein O            aging
# 12                             Forkhead box protein O            aging
# 13                                       NIP3 homolog            aging
# 14                         Transcription factor elt-2            aging
# 15            Spliceosome RNA helicase DDX39B homolog            aging
# 16                        Helix-loop-helix protein 30            aging
# 17          putative insulin-like peptide beta-type 5            aging
# 18  BHLH domain-containing protein;Protein WBSCR14...            aging
# 19                         Max-like protein homolog 2            aging
# 20             Zinc finger transcription factor pqm-1            aging
#
#    head_id_is tail_id_is kg_type.1                 species
# 0     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 1     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 2     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 3     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 4     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 5     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 6     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 7     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 8     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 9     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 10    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 11    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 12    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 13    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 14    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 15    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 16    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 17    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 18    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 19    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 20    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Genage, AgingBank
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 578
#        head                         relation        tail head_type  \
# 0     aat-8  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1    acl-11  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2     aco-2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3     age-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 4     akt-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# ..      ...                              ...         ...       ...
# 573  HLH-30  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 574   ins-6  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 575   MML-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 576   MXL-2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 577   PQM-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#     relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 1            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 2            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 3            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 4            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# ..            ...                ...        ...     ...        ...        ...
# 573          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 574          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 575          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 576          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 577          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
#
#                                       head_detail_name tail_detail_name  \
# 0                               Amino acid transporter   obsolete aging
# 1    Phospholipid/glycerol acyltransferase domain-c...   obsolete aging
# 2          putative aconitate hydratase, mitochondrial   obsolete aging
# 3                  Phosphatidylinositol 3-kinase age-1   obsolete aging
# 4                Serine/threonine-protein kinase akt-1   obsolete aging
# ..                                                 ...              ...
# 573                        Helix-loop-helix protein 30            aging
# 574          putative insulin-like peptide beta-type 5            aging
# 575  BHLH domain-containing protein;Protein WBSCR14...            aging
# 576                         Max-like protein homolog 2            aging
# 577             Zinc finger transcription factor pqm-1            aging
#
#                     species
# 0    Caenorhabditis elegans
# 1    Caenorhabditis elegans
# 2    Caenorhabditis elegans
# 3    Caenorhabditis elegans
# 4    Caenorhabditis elegans
# ..                      ...
# 573  Caenorhabditis elegans
# 574  Caenorhabditis elegans
# 575  Caenorhabditis elegans
# 576  Caenorhabditis elegans
# 577  Caenorhabditis elegans
#
# [578 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Promotes_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'Genage', 'AgingBank'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 578 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           578                   0             578
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 578  |  After dedup: 571
#       head                         relation        tail head_type  \
# 0   ATFS-1  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1  B0024.4  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2  B0250.5  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#   relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 1          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 2          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
#
#                                     head_detail_name tail_detail_name  \
# 0       Stress activated transcription factor atfs-1            aging
# 1                    CUB_2 domain-containing protein   obsolete aging
# 2  putative 3-hydroxyisobutyrate dehydrogenase, m...   obsolete aging
#
#                   species
# 0  Caenorhabditis elegans
# 1  Caenorhabditis elegans
# 2  Caenorhabditis elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           571                   0             571
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Genage', 'AgingBank::Genage', 'AgingBank'} kg_source
# Genage               554
# AgingBank             16
# AgingBank::Genage      1
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    571
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 571 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_promotes_biologicalprocess/Celegans_gene_promotes_biologicalprocess.csv

# %%
# OUT_PATH
