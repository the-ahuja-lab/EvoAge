# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
# Gene → Anatomy
# Monarch/Monarch_final/Celegans/Gene_Cele_Anatomy.csv

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_gene_Anatomy
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_Anatomy/Celegans_gene_Anatomy.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_gene_Anatomy’: File exists

# %%
# !ls /storage/Arushi/090526_EvoAge/kg_formation/processed_data/Monarch/Monarch_final/Celegans/
# Out:
# Cele_AnatomicalEntity_AnatomicalEntity.csv    Gene_Cele_Anatomy.csv
# Cele_Gene_Pathway.csv			      Gene_Cele_BiologicalProcess.csv
# Cele_Phenotype_CellularComponent.csv	      Gene_Cele_CellularComponent.csv
# Cele_Phenotype_ChemicalEntity.csv	      Gene_Cele_MolecularFunction.csv
# Cele_PhenotypicFeature_BiologicalProcess.csv  Gene_Cele_Phenotype.csv
# Cele_PhenotypicFeature_MolecularFunction.csv  GENE_GENE_Cele_Cele.csv

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Celegans/Gene_Cele_Anatomy.csv')
monarch.columns = monarch.columns.str.lower()
monarch['kg_type'] = 'Generalised'
monarch['species'] = 'C.elegans'
monarch['relation'] = 'Gene_AnatomicalEntity'
monarch['tail_type'] = 'AnatomicalEntity'

monarch['kg_source'] = 'Monarch_KG'


print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 105,006 rows
#            head               relation          tail head_type relation_type  \
# 0       ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 1       ZK287.5  Gene_AnatomicalEntity  WBbt:0005784      Gene  expressed_in
# 2       ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 3       ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 4       ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# ...         ...                    ...           ...       ...           ...
# 105001  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 105002  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 105003  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 105004  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 105005  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
#
#                tail_type   relation_source    head_detail_name  \
# 0       AnatomicalEntity  infores:wormbase  RING-box protein 1
# 1       AnatomicalEntity  infores:wormbase  RING-box protein 1
# 2       AnatomicalEntity  infores:wormbase  RING-box protein 1
# 3       AnatomicalEntity  infores:wormbase  RING-box protein 1
# 4       AnatomicalEntity  infores:wormbase  RING-box protein 1
# ...                  ...               ...                 ...
# 105001  AnatomicalEntity  infores:wormbase  RING-box protein 1
# 105002  AnatomicalEntity  infores:wormbase  RING-box protein 1
# 105003  AnatomicalEntity  infores:wormbase  RING-box protein 1
# 105004  AnatomicalEntity  infores:wormbase  RING-box protein 1
# 105005  AnatomicalEntity  infores:wormbase  RING-box protein 1
#
#                     tail_detail_name         head_taxon_name  tail_taxon_name  \
# 0       C. elegans anatomical entity  Caenorhabditis elegans              NaN
# 1                          germ line  Caenorhabditis elegans              NaN
# 2       C. elegans anatomical entity  Caenorhabditis elegans              NaN
# 3       C. elegans anatomical entity  Caenorhabditis elegans              NaN
# 4       C. elegans anatomical entity  Caenorhabditis elegans              NaN
# ...                              ...                     ...              ...
# 105001  C. elegans anatomical entity  Caenorhabditis elegans              NaN
# 105002  C. elegans anatomical entity  Caenorhabditis elegans              NaN
# 105003  C. elegans anatomical entity  Caenorhabditis elegans              NaN
# 105004  C. elegans anatomical entity  Caenorhabditis elegans              NaN
# 105005  C. elegans anatomical entity  Caenorhabditis elegans              NaN
#
#        head_id_is       tail_id_is head_name    species      kg_type  \
# 0        WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# 1        WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# 2        WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# 3        WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# 4        WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# ...           ...              ...       ...        ...          ...
# 105001   WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# 105002   WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# 105003   WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# 105004   WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
# 105005   WormBase  WormBaseAnatomy     rbx-1  C.elegans  Generalised
#
#          kg_source
# 0       Monarch_KG
# 1       Monarch_KG
# 2       Monarch_KG
# 3       Monarch_KG
# 4       Monarch_KG
# ...            ...
# 105001  Monarch_KG
# 105002  Monarch_KG
# 105003  Monarch_KG
# 105004  Monarch_KG
# 105005  Monarch_KG
#
# [105006 rows x 17 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 105,006
#            head               relation          tail head_type relation_type  \
# 0       ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 1       ZK287.5  Gene_AnatomicalEntity  WBbt:0005784      Gene  expressed_in
# 2       ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 3       ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 4       ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# ...         ...                    ...           ...       ...           ...
# 105001  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 105002  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 105003  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 105004  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
# 105005  ZK287.5  Gene_AnatomicalEntity  WBbt:0000100      Gene  expressed_in
#
#                tail_type   kg_source      kg_type head_id_is       tail_id_is  \
# 0       AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 1       AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 2       AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 3       AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 4       AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# ...                  ...         ...          ...        ...              ...
# 105001  AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 105002  AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 105003  AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 105004  AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 105005  AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
#
#           head_detail_name              tail_detail_name    species
# 0       RING-box protein 1  C. elegans anatomical entity  C.elegans
# 1       RING-box protein 1                     germ line  C.elegans
# 2       RING-box protein 1  C. elegans anatomical entity  C.elegans
# 3       RING-box protein 1  C. elegans anatomical entity  C.elegans
# 4       RING-box protein 1  C. elegans anatomical entity  C.elegans
# ...                    ...                           ...        ...
# 105001  RING-box protein 1  C. elegans anatomical entity  C.elegans
# 105002  RING-box protein 1  C. elegans anatomical entity  C.elegans
# 105003  RING-box protein 1  C. elegans anatomical entity  C.elegans
# 105004  RING-box protein 1  C. elegans anatomical entity  C.elegans
# 105005  RING-box protein 1  C. elegans anatomical entity  C.elegans
#
# [105006 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_AnatomicalEntity'}
# head_type           : {'Gene'}
# tail_type           : {'AnatomicalEntity'}
# relation_type       : {'expressed_in'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'WormBase'}
# tail_id_is          : {'WormBaseAnatomy'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 105,006 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                    505                 505            1010
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name        505                 505            1010
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 105,006  |  After dedup: 65,039
#      head               relation          tail head_type relation_type  \
# 0  4R79.1  Gene_AnatomicalEntity  WBbt:0003708      Gene  expressed_in
# 1  4R79.1  Gene_AnatomicalEntity  WBbt:0003724      Gene  expressed_in
# 2  4R79.1  Gene_AnatomicalEntity  WBbt:0003742      Gene  expressed_in
#
#           tail_type   kg_source      kg_type head_id_is       tail_id_is  \
# 0  AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 1  AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
# 2  AnatomicalEntity  Monarch_KG  Generalised   WormBase  WormBaseAnatomy
#
#                                     head_detail_name tail_detail_name  \
# 0  Metalloendopeptidase;Zinc metalloproteinase nas-6              mc2
# 1  Metalloendopeptidase;Zinc metalloproteinase nas-6              pm6
# 2  Metalloendopeptidase;Zinc metalloproteinase nas-6              pm2
#
#      species
# 0  C.elegans
# 1  C.elegans
# 2  C.elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    65039
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    65039
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 65,039 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_Anatomy/Celegans_gene_Anatomy.csv

# %%
#
