# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# !mkdir Celegans_chemical_inhibits_biologicalprocess
# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_inhibits_biologicalprocess/Celegans_chemical_inhibits_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_inhibits_biologicalprocess’: File exists

# %% [markdown]
# # AgeXtend

# %%
AgeXtend = pd.read_csv(PROC_DIR + 'agextend_processed/AgeXtend_Cele_ChemicalEntity_Inhibits_BiologicalProcess.csv')
AgeXtend.columns = AgeXtend.columns.str.lower()
AgeXtend = AgeXtend[~AgeXtend['head_detail_name'].isna()]

AgeXtend['kg_type'] = 'Aging'

print(f"AgeXtend: {len(AgeXtend):,} rows")
AgeXtend['head_id_is'] = 'Pubchem'
AgeXtend['tail_id_is'] = 'Quick_GO'
AgeXtend['species'] = 'Caenorhabditis elegans'
AgeXtend['kg_source'] = 'AgeXtend'

AgeXtend
# Out:
# AgeXtend: 30 rows
#          head                                   relation        tail  \
# 0    12310232  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 1     6474310  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 2       65238  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 3   129845812  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 4       12433  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 5        6124  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 6         402  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 7       10146  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 8    10696082  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 9    12051803  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 10  123134739  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 11  168265116  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 12      72300  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 13  169553329  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 14    5282367  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 15      84298  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 16    5731430  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 17  101682254  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 18  146159367  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 19    4369359  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 20      60560  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 21    5281675  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 22       5570  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 23      68617  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 24    5281700  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 25     348154  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 26   16129800  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 27   25021165  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 28      66840  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 29    3593277  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
#
#          head_type          tail_type  \
# 0   ChemicalEntity  BiologicalProcess
# 1   ChemicalEntity  BiologicalProcess
# 2   ChemicalEntity  BiologicalProcess
# 3   ChemicalEntity  BiologicalProcess
# 4   ChemicalEntity  BiologicalProcess
# 5   ChemicalEntity  BiologicalProcess
# 6   ChemicalEntity  BiologicalProcess
# 7   ChemicalEntity  BiologicalProcess
# 8   ChemicalEntity  BiologicalProcess
# 9   ChemicalEntity  BiologicalProcess
# 10  ChemicalEntity  BiologicalProcess
# 11  ChemicalEntity  BiologicalProcess
# 12  ChemicalEntity  BiologicalProcess
# 13  ChemicalEntity  BiologicalProcess
# 14  ChemicalEntity  BiologicalProcess
# 15  ChemicalEntity  BiologicalProcess
# 16  ChemicalEntity  BiologicalProcess
# 17  ChemicalEntity  BiologicalProcess
# 18  ChemicalEntity  BiologicalProcess
# 19  ChemicalEntity  BiologicalProcess
# 20  ChemicalEntity  BiologicalProcess
# 21  ChemicalEntity  BiologicalProcess
# 22  ChemicalEntity  BiologicalProcess
# 23  ChemicalEntity  BiologicalProcess
# 24  ChemicalEntity  BiologicalProcess
# 25  ChemicalEntity  BiologicalProcess
# 26  ChemicalEntity  BiologicalProcess
# 27  ChemicalEntity  BiologicalProcess
# 28  ChemicalEntity  BiologicalProcess
# 29  ChemicalEntity  BiologicalProcess
#
#                                      head_detail_name  \
# 0   [(1S,4R,5R,6R,7S,8R,11R,13S,17S,18S,19R)-4,5,1...
# 1   (3R,5R)-3,5-bis[[(E)-3-(3,4-dihydroxyphenyl)pr...
# 2   [(2R,3R,4S,5R,6S)-3,4,5,6-tetrakis[(3,4,5-trih...
# 3          5-[(E)-2-phenylethenyl]benzene-1,2,4-triol
# 4                              2,2-dibromoacetic acid
# 5                           N,N-dimethylnitrous amide
# 6                                             sulfane
# 7   (6aR)-1,2-dimethoxy-6-methyl-5,6,6a,7-tetrahyd...
# 8   3,5,7-trihydroxy-2-[(2R,3R)-3-(4-hydroxy-3-met...
# 9   3,5,7-trihydroxy-2-[(2S,3S)-3-(4-hydroxy-3-met...
# 10  5,7-dihydroxy-2-(4-methoxyphenyl)-8-(3-methylb...
# 11  (2S,3R,4S,5S,6R)-2-[[(2S,4S,5S,10S)-5-hydroxy-...
# 12  2-(2-hydroxy-5-prop-2-enylphenyl)-4-prop-2-eny...
# 13  methyl (2R,6R)-2-methyl-4-oxo-6-[(10S,13R,14R,...
# 14  2-methyl-3-[(2E,6E,10E)-3,7,11,15-tetramethylh...
# 15  [(4S,7S,8S,11S)-2-oxo-8-[(2S,3R,4S,5S,6R)-3,4,...
# 16           3-hydroxy-8-methoxybenzo[c]chromen-6-one
# 17  2-[3,5-dihydroxy-4-[(2S,3R,4S,5S,6R)-3,4,5-tri...
# 18  [(1'R,2'R,3R,6R,11'R)-2',6-dihydroxy-2',6,9,11...
# 19  (3R)-3-amino-1-[3-(trifluoromethyl)-6,8-dihydr...
# 20  5-[[4-[2-(5-ethylpyridin-2-yl)ethoxy]phenyl]me...
# 21  2-(3,4-dihydroxyphenyl)-5,7-dihydroxy-8-[(2S,3...
# 22                1-methylpyridin-1-ium-3-carboxylate
# 23  (1S,4S)-4-(3,4-dichlorophenyl)-N-methyl-1,2,3,...
# 24  3,5-dihydroxy-7,8-dimethoxy-2-(4-methoxyphenyl...
# 25              3-(3,4-dihydroxyphenyl)propanoic acid
# 26  [4,5,6,12,20,21,22,25,26,30,31,32,38,46,47,48,...
# 27  (4-nitrophenyl) 4-[bis(1,3-benzodioxol-5-yl)-h...
# 28                  2-bromo-1-(4-nitrophenyl)ethanone
# 29                                     2-oxobutanoate
#
#                                       head_smile_name tail_detail_name  \
# 0   CCC(C)(C(=O)O[C@@H]1[C@H]2[C@H]([C@H]([C@]3([C...            aging
# 1   C1C(C[C@H](C([C@@H]1OC(=O)/C=C/C2=CC(=C(C=C2)O...            aging
# 2   C1=C(C=C(C(=C1O)O)O)C(=O)OC[C@@H]2[C@H]([C@@H]...            aging
# 3                C1=CC=C(C=C1)/C=C/C2=CC(=C(C=C2O)O)O            aging
# 4                                     C(C(=O)O)(Br)Br            aging
# 5                                            CN(C)N=O            aging
# 6                                                   S            aging
# 7        CN1CCC2=CC(=C(C3=C2[C@H]1CC4=CC=CC=C43)OC)OC            aging
# 8   COC1=C(C=CC(=C1)[C@@H]2[C@H](OC3=C(O2)C=C(C=C3...            aging
# 9   COC1=C(C=CC(=C1)[C@H]2[C@@H](OC3=C(O2)C=C(C=C3...            aging
# 10  C[C@H]1[C@@H]([C@H]([C@H](C(O1)OC2=C(OC3=C(C(=...            aging
# 11  C1=CO[C@H](C2C1[C@@H]([C@H]3[C@@]2(O3)CO)O)O[C...            aging
# 12           C=CCC1=CC(=C(C=C1)O)C2=C(C=CC(=C2)CC=C)O            aging
# 13  C[C@H](CC(=O)C[C@@H](C)C(=O)OC)[C@H]1CC(=O)[C@...            aging
# 14  CC1=C(C(=O)C2=CC=CC=C2C1=O)C/C=C(\C)/CC/C=C(\C...            aging
# 15  CC(=O)OCC1=C[C@H]2[C@H]3[C@@H]1[C@@H](OC=C3C(=...            aging
# 16              COC1=CC2=C(C=C1)C3=C(C=C(C=C3)O)OC2=O            aging
# 17  C1=C(C=C(C(=C1O)O[C@H]2[C@@H]([C@H]([C@@H]([C@...            aging
# 18  CC1=CCC2C1C3C(C(C[C@@]2(C)O)OC(=O)C)[C@@]4(C[C...            aging
# 19  C1CN2C(=NN=C2C(F)(F)F)CN1C(=O)C[C@@H](CC3=CC(=...            aging
# 20  CCC1=CN=C(C=C1)CCOC2=CC=C(C=C2)CC3C(=O)NC(=O)S...            aging
# 21  C1=CC(=C(C=C1C2=CC(=O)C3=C(O2)C(=C(C=C3O)O)[C@...            aging
# 22                         C[N+]1=CC=CC(=C1)C(=O)[O-]            aging
# 23   CN[C@H]1CC[C@H](C2=CC=CC=C12)C3=CC(=C(C=C3)Cl)Cl            aging
# 24  COC1=CC=C(C=C1)C2=C(C(=O)C3=C(O2)C(=C(C=C3O)OC...            aging
# 25                          C1=CC(=C(C=C1CCC(=O)O)O)O            aging
# 26  C1C2C3C(C(C(O2)O)OC(=O)C4=CC(=C(C(=C4OC5=C(C(=...            aging
# 27  C1CN(CCC1C(C2=CC3=C(C=C2)OCO3)(C4=CC5=C(C=C4)O...            aging
# 28                  C1=CC(=CC=C1C(=O)CBr)[N+](=O)[O-]            aging
# 29                                   CCC(=O)C(=O)[O-]            aging
#
#    relation_source                 species  \
# 0         AgeXtend  Caenorhabditis elegans
# 1         AgeXtend  Caenorhabditis elegans
# 2         AgeXtend  Caenorhabditis elegans
# 3         AgeXtend  Caenorhabditis elegans
# 4         AgeXtend  Caenorhabditis elegans
# 5         AgeXtend  Caenorhabditis elegans
# 6         AgeXtend  Caenorhabditis elegans
# 7         AgeXtend  Caenorhabditis elegans
# 8         AgeXtend  Caenorhabditis elegans
# 9         AgeXtend  Caenorhabditis elegans
# 10        AgeXtend  Caenorhabditis elegans
# 11        AgeXtend  Caenorhabditis elegans
# 12        AgeXtend  Caenorhabditis elegans
# 13        AgeXtend  Caenorhabditis elegans
# 14        AgeXtend  Caenorhabditis elegans
# 15        AgeXtend  Caenorhabditis elegans
# 16        AgeXtend  Caenorhabditis elegans
# 17        AgeXtend  Caenorhabditis elegans
# 18        AgeXtend  Caenorhabditis elegans
# 19        AgeXtend  Caenorhabditis elegans
# 20        AgeXtend  Caenorhabditis elegans
# 21        AgeXtend  Caenorhabditis elegans
# 22        AgeXtend  Caenorhabditis elegans
# 23        AgeXtend  Caenorhabditis elegans
# 24        AgeXtend  Caenorhabditis elegans
# 25        AgeXtend  Caenorhabditis elegans
# 26        AgeXtend  Caenorhabditis elegans
# 27        AgeXtend  Caenorhabditis elegans
# 28        AgeXtend  Caenorhabditis elegans
# 29        AgeXtend  Caenorhabditis elegans
#
#                                           data_source  anti_aging_status  \
# 0              https://doi.org/10.1055/s-0030-1270524                  1
# 1                  https://doi.org/10.1039/D1FO01383A                  1
# 2                   https://doi.org/10.1021/jf500210p                  1
# 3                  https://doi.org/10.1111/jphp.12657                  1
# 4   https://doi.org/10.1016/j.chemosphere.2014.12.002                  1
# 5   https://doi.org/10.1016/j.chemosphere.2014.12.002                  1
# 6               https://doi.org/10.18632/aging.101026                  1
# 7         https://doi.org/10.21203/rs.3.rs-3803683/v1                  1
# 8   https://doi.org/10.1016/j.freeradbiomed.2016.1...                  1
# 9   https://doi.org/10.1016/j.freeradbiomed.2016.1...                  1
# 10       https://doi.org/10.1371/journal.pone.0028835                  1
# 11                https://doi.org/10.1155/2015/524878                  1
# 12         https://doi.org/10.1038/s41598-024-53374-9                  1
# 13                 https://doi.org/10.1039/D3FO04166B                  1
# 14           https://doi.org/10.3389/fnut.2022.858481                  1
# 15                 https://doi.org/10.1039/D3FO01024D                  1
# 16       https://doi.org/10.1016/j.tetlet.2023.154389                  1
# 17          https://doi.org/10.3389/fphar.2022.931886                  1
# 18         https://doi.org/10.1007/s10522-022-09950-5                  1
# 19                  https://doi.org/10.1159/000534863                  0
# 20               https://doi.org/10.1155/2022/8496063                  1
# 21               https://doi.org/10.1155/2022/8878923                  1
# 22               https://doi.org/10.1155/2021/7656834                  1
# 23                  https://doi.org/10.1159/000536227                  1
# 24        https://doi.org/10.1016/j.exger.2019.02.016                  1
# 25          https://doi.org/10.3390/molecules26061517                  1
# 26                 https://doi.org/10.1039/C9FO02472G                  1
# 27          https://doi.org/10.1016/j.tma.2019.11.003                  1
# 28  https://bmcsystbiol.biomedcentral.com/articles...                  1
# 29  https://www.nature.com/articles/s41467-023-358...                  1
#
#     anti_aging_prob kg_type head_id_is tail_id_is kg_source
# 0          0.869033   Aging    Pubchem   Quick_GO  AgeXtend
# 1          0.916983   Aging    Pubchem   Quick_GO  AgeXtend
# 2          0.875139   Aging    Pubchem   Quick_GO  AgeXtend
# 3          0.804562   Aging    Pubchem   Quick_GO  AgeXtend
# 4          0.760685   Aging    Pubchem   Quick_GO  AgeXtend
# 5          0.824607   Aging    Pubchem   Quick_GO  AgeXtend
# 6          0.778948   Aging    Pubchem   Quick_GO  AgeXtend
# 7          0.675833   Aging    Pubchem   Quick_GO  AgeXtend
# 8          0.915577   Aging    Pubchem   Quick_GO  AgeXtend
# 9          0.915577   Aging    Pubchem   Quick_GO  AgeXtend
# 10         0.776624   Aging    Pubchem   Quick_GO  AgeXtend
# 11         0.868195   Aging    Pubchem   Quick_GO  AgeXtend
# 12         0.818627   Aging    Pubchem   Quick_GO  AgeXtend
# 13         0.788097   Aging    Pubchem   Quick_GO  AgeXtend
# 14         0.892791   Aging    Pubchem   Quick_GO  AgeXtend
# 15         0.929685   Aging    Pubchem   Quick_GO  AgeXtend
# 16         0.904384   Aging    Pubchem   Quick_GO  AgeXtend
# 17         0.896706   Aging    Pubchem   Quick_GO  AgeXtend
# 18         0.834726   Aging    Pubchem   Quick_GO  AgeXtend
# 19         0.257209   Aging    Pubchem   Quick_GO  AgeXtend
# 20         0.700610   Aging    Pubchem   Quick_GO  AgeXtend
# 21         0.875399   Aging    Pubchem   Quick_GO  AgeXtend
# 22         0.945799   Aging    Pubchem   Quick_GO  AgeXtend
# 23         0.864713   Aging    Pubchem   Quick_GO  AgeXtend
# 24         0.937446   Aging    Pubchem   Quick_GO  AgeXtend
# 25         0.725849   Aging    Pubchem   Quick_GO  AgeXtend
# 26         0.912859   Aging    Pubchem   Quick_GO  AgeXtend
# 27         0.709925   Aging    Pubchem   Quick_GO  AgeXtend
# 28         0.756218   Aging    Pubchem   Quick_GO  AgeXtend
# 29         0.855705   Aging    Pubchem   Quick_GO  AgeXtend

# %% [markdown]
# # AgingAtlas

# %%
AgingAtlas = pd.read_csv(PROC_DIR + 'agingatlas/Cele/Cele_AgingAtlas_Chemical_Inhibit_BiologicalProcess_Geroprotectors.csv')
AgingAtlas.columns = AgingAtlas.columns.str.lower()
AgingAtlas = AgingAtlas[~AgingAtlas['head_detail_name'].isna()]

AgingAtlas['kg_type'] = 'Aging'
AgingAtlas['tail_type'] = 'BiologicalProcess'
print(f"AgingAtlas: {len(AgingAtlas):,} rows")
AgingAtlas['head_id_is'] = 'Pubchem'
AgingAtlas['tail_id_is'] = 'Quick_GO'
AgingAtlas['species'] = 'Caenorhabditis elegans'
AgingAtlas['kg_source'] = 'AgingAtlas'
AgingAtlas
# Out:
# AgingAtlas: 220 rows
#         head                                   relation        tail  \
# 0       1983  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 1        176  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 2        199  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 3      71080  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 4        204  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# ..       ...                                        ...         ...
# 216   443955  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 217  5280795  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 218    14985  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 219  5280441  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 220   135191  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
#
#           head_type          tail_type  \
# 0    ChemicalEntity  BiologicalProcess
# 1    ChemicalEntity  BiologicalProcess
# 2    ChemicalEntity  BiologicalProcess
# 3    ChemicalEntity  BiologicalProcess
# 4    ChemicalEntity  BiologicalProcess
# ..              ...                ...
# 216  ChemicalEntity  BiologicalProcess
# 217  ChemicalEntity  BiologicalProcess
# 218  ChemicalEntity  BiologicalProcess
# 219  ChemicalEntity  BiologicalProcess
# 220  ChemicalEntity  BiologicalProcess
#
#                                       head_detail_name  \
# 0                         N-(4-hydroxyphenyl)acetamide
# 1                                          acetic acid
# 2                            2-(4-aminobutyl)guanidine
# 3                           (2R)-2-aminopropanoic acid
# 4                     (2,5-dioxoimidazolidin-4-yl)urea
# ..                                                 ...
# 216  ethyl (15S,19S)-15-ethyl-1,11-diazapentacyclo[...
# 217  (1S,3Z)-3-[(2E)-2-[(1R,3aS,7aR)-7a-methyl-1-[(...
# 218  (2R)-2,5,7,8-tetramethyl-2-[(4R,8R)-4,8,12-tri...
# 219  5,7-dihydroxy-2-(4-hydroxyphenyl)-8-[(2S,3R,4R...
# 220                    (3R,4S,5R)-oxane-2,3,4,5-tetrol
#
#                                        head_smile_name  \
# 0                                CC(=O)NC1=CC=C(C=C1)O
# 1                                              CC(=O)O
# 2                                       C(CCN=C(N)N)CN
# 3                                      C[C@H](C(=O)O)N
# 4                             C1(C(=O)NC(=O)N1)NC(=O)N
# ..                                                 ...
# 216  CC[C@@]12CCCN3[C@@H]1C4=C(CC3)C5=CC=CC=C5N4C(=...
# 217  C[C@H](CCCC(C)C)[C@H]1CC[C@@H]\2[C@@]1(CCC/C2=...
# 218  CC1=C(C2=C(CC[C@@](O2)(C)CCC[C@H](C)CCC[C@H](C...
# 219  C1=CC(=CC=C1C2=CC(=O)C3=C(O2)C(=C(C=C3O)O)[C@H...
# 220                  C1[C@H]([C@@H]([C@H](C(O1)O)O)O)O
#
#               relation_source                 species  head_alt_name  \
# 0    Aging_Atlas_gerprotector  Caenorhabditis elegans  Acetaminophen
# 1    Aging_Atlas_gerprotector  Caenorhabditis elegans    Acetic Acid
# 2    Aging_Atlas_gerprotector  Caenorhabditis elegans       Agmatine
# 3    Aging_Atlas_gerprotector  Caenorhabditis elegans        Alanine
# 4    Aging_Atlas_gerprotector  Caenorhabditis elegans      Allantoin
# ..                        ...                     ...            ...
# 216  Aging_Atlas_gerprotector  Caenorhabditis elegans    Vinpocetine
# 217  Aging_Atlas_gerprotector  Caenorhabditis elegans     Vitamin D3
# 218  Aging_Atlas_gerprotector  Caenorhabditis elegans      Vitamin E
# 219  Aging_Atlas_gerprotector  Caenorhabditis elegans        Vitexin
# 220  Aging_Atlas_gerprotector  Caenorhabditis elegans         Xylose
#
#            pmid         rnaseq  data_type tail_detail_name kg_type head_id_is  \
# 0      22114686  Not Available  Causative            aging   Aging    Pubchem
# 1    \t19837596  Not Available  Causative            aging   Aging    Pubchem
# 2      25643626  Not Available  Causative            aging   Aging    Pubchem
# 3      25643626  Not Available  Causative            aging   Aging    Pubchem
# 4      26676933  Not Available  Causative            aging   Aging    Pubchem
# ..          ...            ...        ...              ...     ...        ...
# 216    24134630  Not Available  Causative            aging   Aging    Pubchem
# 217    27783938  Not Available  Causative            aging   Aging    Pubchem
# 218     3374177  Not Available  Causative            aging   Aging    Pubchem
# 219    26535084  Not Available  Causative            aging   Aging    Pubchem
# 220    25643626  Not Available  Causative            aging   Aging    Pubchem
#
#     tail_id_is   kg_source
# 0     Quick_GO  AgingAtlas
# 1     Quick_GO  AgingAtlas
# 2     Quick_GO  AgingAtlas
# 3     Quick_GO  AgingAtlas
# 4     Quick_GO  AgingAtlas
# ..         ...         ...
# 216   Quick_GO  AgingAtlas
# 217   Quick_GO  AgingAtlas
# 218   Quick_GO  AgingAtlas
# 219   Quick_GO  AgingAtlas
# 220   Quick_GO  AgingAtlas
#
# [220 rows x 18 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    AgeXtend, AgingAtlas
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 250
#           head                                   relation        tail  \
# 0     12310232  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 1      6474310  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 2        65238  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 3    129845812  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 4        12433  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# ..         ...                                        ...         ...
# 245     443955  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 246    5280795  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 247      14985  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 248    5280441  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 249     135191  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
#
#           head_type relation_type          tail_type   kg_source kg_type  \
# 0    ChemicalEntity          None  BiologicalProcess    AgeXtend   Aging
# 1    ChemicalEntity          None  BiologicalProcess    AgeXtend   Aging
# 2    ChemicalEntity          None  BiologicalProcess    AgeXtend   Aging
# 3    ChemicalEntity          None  BiologicalProcess    AgeXtend   Aging
# 4    ChemicalEntity          None  BiologicalProcess    AgeXtend   Aging
# ..              ...           ...                ...         ...     ...
# 245  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 246  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 247  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 248  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 249  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
#
#     head_id_is tail_id_is                                   head_detail_name  \
# 0      Pubchem   Quick_GO  [(1S,4R,5R,6R,7S,8R,11R,13S,17S,18S,19R)-4,5,1...
# 1      Pubchem   Quick_GO  (3R,5R)-3,5-bis[[(E)-3-(3,4-dihydroxyphenyl)pr...
# 2      Pubchem   Quick_GO  [(2R,3R,4S,5R,6S)-3,4,5,6-tetrakis[(3,4,5-trih...
# 3      Pubchem   Quick_GO         5-[(E)-2-phenylethenyl]benzene-1,2,4-triol
# 4      Pubchem   Quick_GO                             2,2-dibromoacetic acid
# ..         ...        ...                                                ...
# 245    Pubchem   Quick_GO  ethyl (15S,19S)-15-ethyl-1,11-diazapentacyclo[...
# 246    Pubchem   Quick_GO  (1S,3Z)-3-[(2E)-2-[(1R,3aS,7aR)-7a-methyl-1-[(...
# 247    Pubchem   Quick_GO  (2R)-2,5,7,8-tetramethyl-2-[(4R,8R)-4,8,12-tri...
# 248    Pubchem   Quick_GO  5,7-dihydroxy-2-(4-hydroxyphenyl)-8-[(2S,3R,4R...
# 249    Pubchem   Quick_GO                    (3R,4S,5R)-oxane-2,3,4,5-tetrol
#
#     tail_detail_name                 species
# 0              aging  Caenorhabditis elegans
# 1              aging  Caenorhabditis elegans
# 2              aging  Caenorhabditis elegans
# 3              aging  Caenorhabditis elegans
# 4              aging  Caenorhabditis elegans
# ..               ...                     ...
# 245            aging  Caenorhabditis elegans
# 246            aging  Caenorhabditis elegans
# 247            aging  Caenorhabditis elegans
# 248            aging  Caenorhabditis elegans
# 249            aging  Caenorhabditis elegans
#
# [250 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'ChemicalEntity_Inhibits_BiologicalProcess'}
# head_type           : {'ChemicalEntity'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'AgingAtlas', 'AgeXtend'}
# head_id_is          : {'Pubchem'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 250 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           250                   0             250
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 250  |  After dedup: 246
#    head                                   relation        tail  \
# 0    72  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 1   176  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
# 2   199  ChemicalEntity_Inhibits_BiologicalProcess  GO:0007568
#
#         head_type relation_type          tail_type   kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 1  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 2  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
#
#   head_id_is tail_id_is           head_detail_name tail_detail_name  \
# 0    Pubchem   Quick_GO  3,4-dihydroxybenzoic acid            aging
# 1    Pubchem   Quick_GO                acetic acid            aging
# 2    Pubchem   Quick_GO  2-(4-aminobutyl)guanidine            aging
#
#                   species
# 0  Caenorhabditis elegans
# 1  Caenorhabditis elegans
# 2  Caenorhabditis elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           246                   0             246
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'AgingAtlas', 'AgeXtend::AgingAtlas', 'AgeXtend'} kg_source
# AgingAtlas              216
# AgeXtend                 27
# AgeXtend::AgingAtlas      3
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    246
# Name: count, dtype: int64

# %%
! mkdir Celegans_chemical_inhibits_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_inhibits_biologicalprocess’: File exists

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 246 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_inhibits_biologicalprocess/Celegans_chemical_inhibits_biologicalprocess.csv

# %%
# OUT_PATH
