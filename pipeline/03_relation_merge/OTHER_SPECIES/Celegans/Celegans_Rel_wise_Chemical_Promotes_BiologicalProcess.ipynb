# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_chemical_promotes_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_promotes_biologicalprocess/Celegans_chemical_promotes_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_promotes_biologicalprocess’: File exists

# %% [markdown]
# # AgingAtlas

# %%
AgingAtlas = pd.read_csv(PROC_DIR + 'agingatlas/Cele/Cele_AgingAtlas_Chemical_Promotes_BiologicalProcess_Geroprotectors.csv')
AgingAtlas.columns = AgingAtlas.columns.str.lower()
AgingAtlas = AgingAtlas[~AgingAtlas['head_detail_name'].isna()]

AgingAtlas['kg_type'] = 'Aging'
AgingAtlas['tail_type'] = 'BiologicalProcess'
print(f"AgingAtlas: {len(AgingAtlas):,} rows")
AgingAtlas['head_id_is'] = 'Pubchem'
AgingAtlas['tail_id_is'] = 'Quick_GO'
AgingAtlas['species'] = 'Caenorhabditis elegans'
AgingAtlas['kg_source'] = 'AgingAtlas'
AgingAtlas
# Out:
# AgingAtlas: 3 rows
#      head                                   relation        tail  \
# 0     586  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
# 1    5793  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
# 2  312145  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
#
#         head_type          tail_type  \
# 0  ChemicalEntity  BiologicalProcess
# 1  ChemicalEntity  BiologicalProcess
# 2  ChemicalEntity  BiologicalProcess
#
#                                     head_detail_name  \
# 0          2-[carbamimidoyl(methyl)amino]acetic acid
# 1  (3R,4S,5S,6R)-6-(hydroxymethyl)oxane-2,3,4,5-t...
# 2  [(1R,3R,5S,9R,18S)-18-(methoxymethyl)-1,5-dime...
#
#                                      head_smile_name  \
# 0                                  CN(CC(=O)O)C(=N)N
# 1         C([C@@H]1[C@H]([C@@H]([C@H](C(O1)O)O)O)O)O
# 2  CC(=O)O[C@@H]1C[C@]2([C@@H](CCC2=O)C3=C1[C@]4(...
#
#             relation_source                 species head_alt_name      pmid  \
# 0  Aging_Atlas_gerprotector  Caenorhabditis elegans      Creatine  25643626
# 1  Aging_Atlas_gerprotector  Caenorhabditis elegans     D-glucose  17908557
# 2  Aging_Atlas_gerprotector  Caenorhabditis elegans    Wortmannin  23543623
#
#           rnaseq  data_type tail_detail_name kg_type head_id_is tail_id_is  \
# 0  Not Available  Causative            aging   Aging    Pubchem   Quick_GO
# 1  Not Available  Causative            aging   Aging    Pubchem   Quick_GO
# 2  Not Available  Causative            aging   Aging    Pubchem   Quick_GO
#
#     kg_source
# 0  AgingAtlas
# 1  AgingAtlas
# 2  AgingAtlas

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
   AgingAtlas
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 3
#      head                                   relation        tail  \
# 0     586  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
# 1    5793  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
# 2  312145  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
#
#         head_type relation_type          tail_type   kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 1  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 2  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
#
#   head_id_is tail_id_is                                   head_detail_name  \
# 0    Pubchem   Quick_GO          2-[carbamimidoyl(methyl)amino]acetic acid
# 1    Pubchem   Quick_GO  (3R,4S,5S,6R)-6-(hydroxymethyl)oxane-2,3,4,5-t...
# 2    Pubchem   Quick_GO  [(1R,3R,5S,9R,18S)-18-(methoxymethyl)-1,5-dime...
#
#   tail_detail_name                 species
# 0            aging  Caenorhabditis elegans
# 1            aging  Caenorhabditis elegans
# 2            aging  Caenorhabditis elegans

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'ChemicalEntity_Promotes_BiologicalProcess'}
# head_type           : {'ChemicalEntity'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'AgingAtlas'}
# head_id_is          : {'Pubchem'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 3 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             3                   0               3
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 3  |  After dedup: 3
#      head                                   relation        tail  \
# 0     586  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
# 1    5793  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
# 2  312145  ChemicalEntity_Promotes_BiologicalProcess  GO:0007568
#
#         head_type relation_type          tail_type   kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 1  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
# 2  ChemicalEntity          None  BiologicalProcess  AgingAtlas   Aging
#
#   head_id_is tail_id_is                                   head_detail_name  \
# 0    Pubchem   Quick_GO          2-[carbamimidoyl(methyl)amino]acetic acid
# 1    Pubchem   Quick_GO  (3R,4S,5S,6R)-6-(hydroxymethyl)oxane-2,3,4,5-t...
# 2    Pubchem   Quick_GO  [(1R,3R,5S,9R,18S)-18-(methoxymethyl)-1,5-dime...
#
#   tail_detail_name                 species
# 0            aging  Caenorhabditis elegans
# 1            aging  Caenorhabditis elegans
# 2            aging  Caenorhabditis elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             3                   0               3
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'AgingAtlas'} kg_source
# AgingAtlas    3
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    3
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 3 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_promotes_biologicalprocess/Celegans_chemical_promotes_biologicalprocess.csv

# %%
# OUT_PATH
