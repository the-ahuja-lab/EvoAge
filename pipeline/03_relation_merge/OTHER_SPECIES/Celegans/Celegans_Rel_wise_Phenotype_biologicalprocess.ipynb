# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %% [markdown]
# # Databases Having Phenotype biologicalprocess relation of celegans

# %%
# Monarch/Monarch_final/Celegans/Cele_PhenotypicFeature_BiologicalProcess.csv

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_phenotype_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_phenotype_biologicalprocess/Celegans_phenotype_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_phenotype_biologicalprocess’: File exists

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Celegans/Cele_PhenotypicFeature_BiologicalProcess.csv')
monarch.columns = monarch.columns.str.lower()
monarch['kg_type'] = 'Generalised'
monarch['species'] = 'C.elegans'

monarch['kg_source'] = 'Monarch_KG'
#

print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 488 rows
#                     head                     relation        tail  head_type  \
# 0    WBPhenotype:0000005  Phenotype_BiologicalProcess  GO:0018991  Phenotype
# 1    WBPhenotype:0000013  Phenotype_BiologicalProcess  GO:0043053  Phenotype
# 2    WBPhenotype:0000015  Phenotype_BiologicalProcess  GO:0050918  Phenotype
# 3    WBPhenotype:0000018  Phenotype_BiologicalProcess  GO:0043050  Phenotype
# 4    WBPhenotype:0000019  Phenotype_BiologicalProcess  GO:0043050  Phenotype
# ..                   ...                          ...         ...        ...
# 483  WBPhenotype:0004022  Phenotype_BiologicalProcess  GO:0040011  Phenotype
# 484  WBPhenotype:0004024  Phenotype_BiologicalProcess  GO:0040011  Phenotype
# 485  WBPhenotype:0004025  Phenotype_BiologicalProcess  GO:0040011  Phenotype
# 486  WBPhenotype:0004030  Phenotype_BiologicalProcess  GO:0034606  Phenotype
# 487  WBPhenotype:0010001  Phenotype_BiologicalProcess  GO:0016049  Phenotype
#
#     relation_type          tail_type relation_source  \
# 0      related_to  BiologicalProcess  infores:upheno
# 1      related_to  BiologicalProcess  infores:upheno
# 2      related_to  BiologicalProcess  infores:upheno
# 3      related_to  BiologicalProcess  infores:upheno
# 4      related_to  BiologicalProcess  infores:upheno
# ..            ...                ...             ...
# 483    related_to  BiologicalProcess  infores:upheno
# 484    related_to  BiologicalProcess  infores:upheno
# 485    related_to  BiologicalProcess  infores:upheno
# 486    related_to  BiologicalProcess  infores:upheno
# 487    related_to  BiologicalProcess  infores:upheno
#
#                              head_detail_name  \
# 0                      hyperactive egg laying
# 1                             dauer defective
# 2               positive chemotaxis defective
# 3                pharyngeal pumping increased
# 4                  pharyngeal pumping reduced
# ..                                        ...
# 483  amplitude of sinusoidal movement variant
# 484            wavelength of movement variant
# 485              velocity of movement variant
# 486    male response to hermaphrodite variant
# 487                       cell growth variant
#
#                       tail_detail_name         head_taxon_name  \
# 0                  egg-laying behavior  Caenorhabditis elegans
# 1                          dauer entry  Caenorhabditis elegans
# 2                  positive chemotaxis  Caenorhabditis elegans
# 3          nematode pharyngeal pumping  Caenorhabditis elegans
# 4          nematode pharyngeal pumping  Caenorhabditis elegans
# ..                                 ...                     ...
# 483                         locomotion  Caenorhabditis elegans
# 484                         locomotion  Caenorhabditis elegans
# 485                         locomotion  Caenorhabditis elegans
# 486  response to hermaphrodite contact  Caenorhabditis elegans
# 487                        cell growth  Caenorhabditis elegans
#
#      tail_taxon_name         head_id_is tail_id_is    species      kg_type  \
# 0                NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# 1                NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# 2                NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# 3                NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# 4                NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# ..               ...                ...        ...        ...          ...
# 483              NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# 484              NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# 485              NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# 486              NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
# 487              NaN  WormBasePhenotype   Quick_GO  C.elegans  Generalised
#
#       kg_source
# 0    Monarch_KG
# 1    Monarch_KG
# 2    Monarch_KG
# 3    Monarch_KG
# 4    Monarch_KG
# ..          ...
# 483  Monarch_KG
# 484  Monarch_KG
# 485  Monarch_KG
# 486  Monarch_KG
# 487  Monarch_KG
#
# [488 rows x 16 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 488
#                     head                     relation        tail  head_type  \
# 0    WBPhenotype:0000005  Phenotype_BiologicalProcess  GO:0018991  Phenotype
# 1    WBPhenotype:0000013  Phenotype_BiologicalProcess  GO:0043053  Phenotype
# 2    WBPhenotype:0000015  Phenotype_BiologicalProcess  GO:0050918  Phenotype
# 3    WBPhenotype:0000018  Phenotype_BiologicalProcess  GO:0043050  Phenotype
# 4    WBPhenotype:0000019  Phenotype_BiologicalProcess  GO:0043050  Phenotype
# ..                   ...                          ...         ...        ...
# 483  WBPhenotype:0004022  Phenotype_BiologicalProcess  GO:0040011  Phenotype
# 484  WBPhenotype:0004024  Phenotype_BiologicalProcess  GO:0040011  Phenotype
# 485  WBPhenotype:0004025  Phenotype_BiologicalProcess  GO:0040011  Phenotype
# 486  WBPhenotype:0004030  Phenotype_BiologicalProcess  GO:0034606  Phenotype
# 487  WBPhenotype:0010001  Phenotype_BiologicalProcess  GO:0016049  Phenotype
#
#     relation_type          tail_type   kg_source      kg_type  \
# 0      related_to  BiologicalProcess  Monarch_KG  Generalised
# 1      related_to  BiologicalProcess  Monarch_KG  Generalised
# 2      related_to  BiologicalProcess  Monarch_KG  Generalised
# 3      related_to  BiologicalProcess  Monarch_KG  Generalised
# 4      related_to  BiologicalProcess  Monarch_KG  Generalised
# ..            ...                ...         ...          ...
# 483    related_to  BiologicalProcess  Monarch_KG  Generalised
# 484    related_to  BiologicalProcess  Monarch_KG  Generalised
# 485    related_to  BiologicalProcess  Monarch_KG  Generalised
# 486    related_to  BiologicalProcess  Monarch_KG  Generalised
# 487    related_to  BiologicalProcess  Monarch_KG  Generalised
#
#             head_id_is tail_id_is                          head_detail_name  \
# 0    WormBasePhenotype   Quick_GO                    hyperactive egg laying
# 1    WormBasePhenotype   Quick_GO                           dauer defective
# 2    WormBasePhenotype   Quick_GO             positive chemotaxis defective
# 3    WormBasePhenotype   Quick_GO              pharyngeal pumping increased
# 4    WormBasePhenotype   Quick_GO                pharyngeal pumping reduced
# ..                 ...        ...                                       ...
# 483  WormBasePhenotype   Quick_GO  amplitude of sinusoidal movement variant
# 484  WormBasePhenotype   Quick_GO            wavelength of movement variant
# 485  WormBasePhenotype   Quick_GO              velocity of movement variant
# 486  WormBasePhenotype   Quick_GO    male response to hermaphrodite variant
# 487  WormBasePhenotype   Quick_GO                       cell growth variant
#
#                       tail_detail_name    species
# 0                  egg-laying behavior  C.elegans
# 1                          dauer entry  C.elegans
# 2                  positive chemotaxis  C.elegans
# 3          nematode pharyngeal pumping  C.elegans
# 4          nematode pharyngeal pumping  C.elegans
# ..                                 ...        ...
# 483                         locomotion  C.elegans
# 484                         locomotion  C.elegans
# 485                         locomotion  C.elegans
# 486  response to hermaphrodite contact  C.elegans
# 487                        cell growth  C.elegans
#
# [488 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Phenotype_BiologicalProcess'}
# head_type           : {'Phenotype'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {'related_to'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'WormBasePhenotype'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 488 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 488  |  After dedup: 488
#                   head                     relation        tail  head_type  \
# 0  WBPhenotype:0000005  Phenotype_BiologicalProcess  GO:0018991  Phenotype
# 1  WBPhenotype:0000013  Phenotype_BiologicalProcess  GO:0043053  Phenotype
# 2  WBPhenotype:0000015  Phenotype_BiologicalProcess  GO:0050918  Phenotype
#
#   relation_type          tail_type   kg_source      kg_type  \
# 0    related_to  BiologicalProcess  Monarch_KG  Generalised
# 1    related_to  BiologicalProcess  Monarch_KG  Generalised
# 2    related_to  BiologicalProcess  Monarch_KG  Generalised
#
#           head_id_is tail_id_is               head_detail_name  \
# 0  WormBasePhenotype   Quick_GO         hyperactive egg laying
# 1  WormBasePhenotype   Quick_GO                dauer defective
# 2  WormBasePhenotype   Quick_GO  positive chemotaxis defective
#
#       tail_detail_name    species
# 0  egg-laying behavior  C.elegans
# 1          dauer entry  C.elegans
# 2  positive chemotaxis  C.elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    488
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    488
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 488 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_phenotype_biologicalprocess/Celegans_phenotype_biologicalprocess.csv

# %%
#
