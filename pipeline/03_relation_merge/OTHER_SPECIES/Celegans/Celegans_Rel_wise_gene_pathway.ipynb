# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_gene_pathway
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_pathway/Celegans_gene_pathway.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Celegans/Cele_Gene_Pathway.csv')
monarch.columns = monarch.columns.str.lower()
monarch['kg_type'] = 'Generalised'
monarch['species'] = 'C.elegans'

monarch['kg_source'] = 'Monarch_KG'


print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 12,698 rows
#             head      relation           tail head_type    relation_type  \
# 0       K03H1.13  Gene_Pathway  R-HSA-6787639      Gene  participates_in
# 1        W01A8.8  Gene_Pathway   R-HSA-381426      Gene  participates_in
# 2        W01A8.8  Gene_Pathway  R-HSA-8957275      Gene  participates_in
# 3      Y37A1B.17  Gene_Pathway   R-HSA-193648      Gene  participates_in
# 4      Y37A1B.17  Gene_Pathway   R-HSA-416482      Gene  participates_in
# ...          ...           ...            ...       ...              ...
# 12693  Y59A8B.25  Gene_Pathway  R-HSA-6811440      Gene  participates_in
# 12694    ZK863.9  Gene_Pathway  R-HSA-1236978      Gene  participates_in
# 12695    ZK863.9  Gene_Pathway   R-HSA-446203      Gene  participates_in
# 12696    ZK863.9  Gene_Pathway  R-HSA-5621480      Gene  participates_in
# 12697    ZK863.9  Gene_Pathway  R-HSA-6798695      Gene  participates_in
#
#       tail_type   relation_source  \
# 0       Pathway  infores:reactome
# 1       Pathway  infores:reactome
# 2       Pathway  infores:reactome
# 3       Pathway  infores:reactome
# 4       Pathway  infores:reactome
# ...         ...               ...
# 12693   Pathway  infores:reactome
# 12694   Pathway  infores:reactome
# 12695   Pathway  infores:reactome
# 12696   Pathway  infores:reactome
# 12697   Pathway  infores:reactome
#
#                                         head_detail_name  \
# 0                 L-fucokinase domain-containing protein
# 1                        DUF19 domain-containing protein
# 2                        DUF19 domain-containing protein
# 3      SH3 domain-containing GRB2-like protein;SH3 do...
# 4      SH3 domain-containing GRB2-like protein;SH3 do...
# ...                                                  ...
# 12693                   DUF727 domain-containing protein
# 12694            C-type lectin domain-containing protein
# 12695            C-type lectin domain-containing protein
# 12696            C-type lectin domain-containing protein
# 12697            C-type lectin domain-containing protein
#
#                                         tail_detail_name  \
# 0                                GDP-fucose biosynthesis
# 1      Regulation of Insulin-like Growth Factor (IGF)...
# 2             Post-translational protein phosphorylation
# 3                        NRAGE signals death through JNK
# 4                      G alpha (12/13) signalling events
# ...                                                  ...
# 12693    Retrograde transport at the Trans-Golgi-Network
# 12694  Cross-presentation of soluble exogenous antige...
# 12695                  Asparagine N-linked glycosylation
# 12696                                    Dectin-2 family
# 12697                           Neutrophil degranulation
#
#               head_taxon_name tail_taxon_name head_id_is tail_id_is  \
# 0      Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# 1      Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# 2      Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# 3      Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# 4      Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# ...                       ...             ...        ...        ...
# 12693  Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# 12694  Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# 12695  Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# 12696  Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
# 12697  Caenorhabditis elegans    Homo sapiens   WormBase   Reactome
#
#        head_name    species      kg_type   kg_source
# 0       K03H1.13  C.elegans  Generalised  Monarch_KG
# 1        W01A8.8  C.elegans  Generalised  Monarch_KG
# 2        W01A8.8  C.elegans  Generalised  Monarch_KG
# 3         dnbp-1  C.elegans  Generalised  Monarch_KG
# 4         dnbp-1  C.elegans  Generalised  Monarch_KG
# ...          ...        ...          ...         ...
# 12693  Y59A8B.25  C.elegans  Generalised  Monarch_KG
# 12694   clec-224  C.elegans  Generalised  Monarch_KG
# 12695   clec-224  C.elegans  Generalised  Monarch_KG
# 12696   clec-224  C.elegans  Generalised  Monarch_KG
# 12697   clec-224  C.elegans  Generalised  Monarch_KG
#
# [12698 rows x 17 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 12,698
#             head      relation           tail head_type    relation_type  \
# 0       K03H1.13  Gene_Pathway  R-HSA-6787639      Gene  participates_in
# 1        W01A8.8  Gene_Pathway   R-HSA-381426      Gene  participates_in
# 2        W01A8.8  Gene_Pathway  R-HSA-8957275      Gene  participates_in
# 3      Y37A1B.17  Gene_Pathway   R-HSA-193648      Gene  participates_in
# 4      Y37A1B.17  Gene_Pathway   R-HSA-416482      Gene  participates_in
# ...          ...           ...            ...       ...              ...
# 12693  Y59A8B.25  Gene_Pathway  R-HSA-6811440      Gene  participates_in
# 12694    ZK863.9  Gene_Pathway  R-HSA-1236978      Gene  participates_in
# 12695    ZK863.9  Gene_Pathway   R-HSA-446203      Gene  participates_in
# 12696    ZK863.9  Gene_Pathway  R-HSA-5621480      Gene  participates_in
# 12697    ZK863.9  Gene_Pathway  R-HSA-6798695      Gene  participates_in
#
#       tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0       Pathway  Monarch_KG  Generalised   WormBase   Reactome
# 1       Pathway  Monarch_KG  Generalised   WormBase   Reactome
# 2       Pathway  Monarch_KG  Generalised   WormBase   Reactome
# 3       Pathway  Monarch_KG  Generalised   WormBase   Reactome
# 4       Pathway  Monarch_KG  Generalised   WormBase   Reactome
# ...         ...         ...          ...        ...        ...
# 12693   Pathway  Monarch_KG  Generalised   WormBase   Reactome
# 12694   Pathway  Monarch_KG  Generalised   WormBase   Reactome
# 12695   Pathway  Monarch_KG  Generalised   WormBase   Reactome
# 12696   Pathway  Monarch_KG  Generalised   WormBase   Reactome
# 12697   Pathway  Monarch_KG  Generalised   WormBase   Reactome
#
#                                         head_detail_name  \
# 0                 L-fucokinase domain-containing protein
# 1                        DUF19 domain-containing protein
# 2                        DUF19 domain-containing protein
# 3      SH3 domain-containing GRB2-like protein;SH3 do...
# 4      SH3 domain-containing GRB2-like protein;SH3 do...
# ...                                                  ...
# 12693                   DUF727 domain-containing protein
# 12694            C-type lectin domain-containing protein
# 12695            C-type lectin domain-containing protein
# 12696            C-type lectin domain-containing protein
# 12697            C-type lectin domain-containing protein
#
#                                         tail_detail_name    species
# 0                                GDP-fucose biosynthesis  C.elegans
# 1      Regulation of Insulin-like Growth Factor (IGF)...  C.elegans
# 2             Post-translational protein phosphorylation  C.elegans
# 3                        NRAGE signals death through JNK  C.elegans
# 4                      G alpha (12/13) signalling events  C.elegans
# ...                                                  ...        ...
# 12693    Retrograde transport at the Trans-Golgi-Network  C.elegans
# 12694  Cross-presentation of soluble exogenous antige...  C.elegans
# 12695                  Asparagine N-linked glycosylation  C.elegans
# 12696                                    Dectin-2 family  C.elegans
# 12697                           Neutrophil degranulation  C.elegans
#
# [12698 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Pathway'}
# head_type           : {'Gene'}
# tail_type           : {'Pathway'}
# relation_type       : {'participates_in'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'WormBase'}
# tail_id_is          : {'Reactome'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 12,698 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 12,698  |  After dedup: 12,698
#       head      relation           tail head_type    relation_type tail_type  \
# 0  2RSSE.1  Gene_Pathway  R-HSA-8980692      Gene  participates_in   Pathway
# 1  2RSSE.1  Gene_Pathway  R-HSA-9013148      Gene  participates_in   Pathway
# 2  2RSSE.1  Gene_Pathway  R-HSA-9013149      Gene  participates_in   Pathway
#
#     kg_source      kg_type head_id_is tail_id_is  \
# 0  Monarch_KG  Generalised   WormBase   Reactome
# 1  Monarch_KG  Generalised   WormBase   Reactome
# 2  Monarch_KG  Generalised   WormBase   Reactome
#
#                     head_detail_name    tail_detail_name    species
# 0  Rho-GAP domain-containing protein   RHOA GTPase cycle  C.elegans
# 1  Rho-GAP domain-containing protein  CDC42 GTPase cycle  C.elegans
# 2  Rho-GAP domain-containing protein   RAC1 GTPase cycle  C.elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    12698
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    12698
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 12,698 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_pathway/Celegans_gene_pathway.csv

# %%
#
