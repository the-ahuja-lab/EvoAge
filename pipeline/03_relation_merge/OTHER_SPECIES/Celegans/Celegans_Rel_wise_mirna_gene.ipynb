# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_mirna_gene
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_mirna_gene/Celegans_mirna_gene.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_mirna_gene’: File exists

# %%
cele = pd.read_csv(
    f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Caenorhabditis_elegans.gene_info',
    sep='\t',
    
)
cele["LocusTag"] = cele["LocusTag"].str.replace("CELE_", "", regex=False)

cele_symbol2Locus_dict = dict(zip(cele['Symbol'], cele['LocusTag']))
cele
# cele_symbol2Locus_dict
# Out:
#        #tax_id    GeneID     Symbol    LocusTag Synonyms  \
# 0         6239    171590     homt-1    Y74C9A.3        -
# 1         6239    171591     nlp-40    Y74C9A.2        -
# 2         6239    171592     rcor-1    Y74C9A.4        -
# 3         6239    171593     sesn-1    Y74C9A.5        -
# 4         6239    171594      pgs-1    Y48G1C.4        -
# ...        ...       ...        ...         ...      ...
# 46922     6239  80510347     azyx-1    F42G4.11        -
# 46923     6239  80510348  F54D10.10   F54D10.10        -
# 46924     6239  80510349   F58B6.11    F58B6.11        -
# 46925     6239  80510350  Y34B4A.20   Y34B4A.20        -
# 46926     6239  80510351     ceh-44  Y54F10AM.4        -
#
#                                                  dbXrefs chromosome  \
# 0      WormBase:WBGene00022277|AllianceGenome:WB:WBGe...          I
# 1      WormBase:WBGene00022276|AllianceGenome:WB:WBGe...          I
# 2      WormBase:WBGene00022278|AllianceGenome:WB:WBGe...          I
# 3      WormBase:WBGene00022279|AllianceGenome:WB:WBGe...          I
# 4      WormBase:WBGene00021677|AllianceGenome:WB:WBGe...          I
# ...                                                  ...        ...
# 46922  WormBase:WBGene00306133|AllianceGenome:WB:WBGe...         II
# 46923  WormBase:WBGene00306132|AllianceGenome:WB:WBGe...         II
# 46924  WormBase:WBGene00306125|AllianceGenome:WB:WBGe...        III
# 46925  WormBase:WBGene00306131|AllianceGenome:WB:WBGe...          X
# 46926  WormBase:WBGene00000464|AllianceGenome:WB:WBGe...        III
#
#       map_location                                        description  \
# 0                -       Alpha N-terminal protein methyltransferase 1
# 1                -                                         Peptide P4
# 2                -                            REST corepressor rcor-1
# 3                -                                    Sestrin homolog
# 4                -  CDP-diacylglycerol--glycerol-3-phosphate 3-pho...
# ...            ...                                                ...
# 46922            -  Alternative N-terminal open reading frame of Z...
# 46923            -                            Uncharacterized protein
# 46924            -                            Uncharacterized protein
# 46925            -                            Uncharacterized protein
# 46926            -                   Homeobox protein cut-like ceh-44
#
#          type_of_gene Symbol_from_nomenclature_authority  \
# 0      protein-coding                             homt-1
# 1      protein-coding                             nlp-40
# 2      protein-coding                             rcor-1
# 3      protein-coding                             sesn-1
# 4      protein-coding                              pgs-1
# ...               ...                                ...
# 46922  protein-coding                             azyx-1
# 46923  protein-coding                          F54D10.10
# 46924  protein-coding                           F58B6.11
# 46925  protein-coding                          Y34B4A.20
# 46926  protein-coding                             ceh-44
#
#                    Full_name_from_nomenclature_authority Nomenclature_status  \
# 0           Alpha N-terminal protein methyltransferase 1                   O
# 1                                             Peptide P4                   O
# 2                                REST corepressor rcor-1                   O
# 3                                        Sestrin homolog                   O
# 4      CDP-diacylglycerol--glycerol-3-phosphate 3-pho...                   O
# ...                                                  ...                 ...
# 46922  Alternative N-terminal open reading frame of Z...                   O
# 46923                            Uncharacterized protein                   O
# 46924                            Uncharacterized protein                   O
# 46925                            Uncharacterized protein                   O
# 46926                   Homeobox protein cut-like ceh-44                   O
#
#                                       Other_designations  Modification_date  \
# 0           Alpha N-terminal protein methyltransferase 1           20250308
# 1                                             Peptide P4           20250308
# 2                                REST corepressor rcor-1           20250308
# 3                                        Sestrin homolog           20250308
# 4      CDP-diacylglycerol--glycerol-3-phosphate 3-pho...           20250308
# ...                                                  ...                ...
# 46922  Alternative N-terminal open reading frame of Z...           20250308
# 46923                            Uncharacterized protein           20241028
# 46924                            Uncharacterized protein           20241028
# 46925                            Uncharacterized protein           20241028
# 46926                   Homeobox protein cut-like ceh-44           20250308
#
#       Feature_type
# 0                -
# 1                -
# 2                -
# 3                -
# 4                -
# ...            ...
# 46922            -
# 46923            -
# 46924            -
# 46925            -
# 46926            -
#
# [46927 rows x 16 columns]

# %%
cele_symbol2Locus_dict
# Out:
# {'homt-1': 'Y74C9A.3',
#  'nlp-40': 'Y74C9A.2',
#  'rcor-1': 'Y74C9A.4',
#  'sesn-1': 'Y74C9A.5',
#  'pgs-1': 'Y48G1C.4',
#  'Y48G1C.5': 'Y48G1C.5',
#  'Y48G1C.6': 'Y48G1C.6',
#  'pid-2': 'Y48G1C.1',
#  'rab-11.1': 'F53G12.1',
#  'rpl-7': 'F53G12.10',
#  'F53G12.9': 'F53G12.9',
#  'F53G12.8': 'F53G12.8',
#  'col-45': 'F53G12.7',
#  'spe-8': 'F53G12.6',
#  'mex-3': 'F53G12.5',
#  'bli-3': 'F56C11.1',
#  'ptr-11': 'F56C11.2',
#  'cest-27': 'F56C11.6',
#  'F56C11.3': 'F56C11.3',
#  'puf-10': 'Y48G1BL.3',
#  'snpc-3.2': 'Y48G1BM.1',
#  'marc-4': 'C53D5.2',
#  'ztf-3': 'C53D5.4',
#  'C53D5.1': 'C53D5.1',
#  'C53D5.5': 'C53D5.5',
#  'xpo-2': 'Y48G1A.5',
#  'nol-14': 'Y48G1A.4',
#  'daf-25': 'Y48G1A.3',
#  'mbtr-1': 'Y48G1A.6',
#  'Y48G1A.2': 'Y48G1A.2',
#  'R119.1': 'R119.1',
#  'rnp-8': 'R119.7',
#  'R119.3': 'R119.3',
#  'taf-4': 'R119.6',
#  'R119.5': 'R119.5',
#  'otub-2': 'Y50C1A.1',
#  'C07F11.2': 'C07F11.2',
#  'tol-1': 'C07F11.1',
#  'W04C9.4': 'W04C9.4',
#  'cutl-13': 'W04C9.3',
#  'W04C9.2': 'W04C9.2',
#  'haf-4': 'W04C9.1',
#  'Y65B4BL.3': 'Y65B4BL.3',
#  'Y65B4BL.4': 'Y65B4BL.4',
#  'deps-1': 'Y65B4BL.2',
#  'acs-13': 'Y65B4BL.5',
#  'Y65B4BL.1': 'Y65B4BL.1',
#  'psf-3': 'Y65B4BR.8',
#  'icd-2': 'Y65B4BR.5',
#  'wwp-1': 'Y65B4BR.4',
#  'lpr-1': 'Y65B4BR.2',
#  'grl-16': 'Y65B4BR.6',
#  'hum-7': 'F56A6.2',
#  'eme-1': 'F56A6.4',
#  'sago-2': 'F56A6.1',
#  'vps-20': 'Y65B4A.3',
#  'Y65B4A.2': 'Y65B4A.2',
#  'cus-2': 'Y65B4A.1',
#  'Y65B4A.8': 'Y65B4A.8',
#  'Y65B4A.9': 'Y65B4A.9',
#  'hasp-2': 'Y18H1A.10',
#  'ptp-5.3': 'Y18H1A.1',
#  'Y18H1A.4': 'Y18H1A.4',
#  'Y18H1A.2': 'Y18H1A.2',
#  'hgap-1': 'Y18H1A.3',
#  'rec-1': 'Y18H1A.7',
#  'pif-1': 'Y18H1A.6',
#  'Y18H1A.9': 'Y18H1A.9',
#  'Y18H1A.8': 'Y18H1A.8',
#  'T06A4.3': 'T06A4.3',
#  'T06A4.1': 'T06A4.1',
#  'zfh-2': 'ZC123.3',
#  'ZC123.1': 'ZC123.1',
#  'cdk-14': 'ZC123.4',
#  'Y95B8A.6': 'Y95B8A.6',
#  'gpa-16': 'Y95B8A.5',
#  'mig-1': 'Y34D9B.1',
#  'cutl-20': 'F54A5.2',
#  'hmbx-1': 'F54A5.1',
#  'madf-6': 'C54G6.1',
#  'spp-17': 'C54G6.5',
#  'mrpl-38': 'Y34D9A.1',
#  'spd-1': 'Y34D9A.4',
#  'Y34D9A.3': 'Y34D9A.3',
#  'glrx-10': 'Y34D9A.6',
#  'gsa-1': 'R06A10.2',
#  'R06A10.4': 'R06A10.4',
#  'ceh-45': 'ZK993.1',
#  'aps-3': 'Y48G8AL.14',
#  'rpl-17': 'Y48G8AL.8',
#  'Y48G8AL.7': 'Y48G8AL.7',
#  'haf-6': 'Y48G8AL.11',
#  'smg-2': 'Y48G8AL.6',
#  'nsun-2': 'Y48G8AL.5',
#  'Y48G8AL.12': 'Y48G8AL.12',
#  'Y48G8AL.13': 'Y48G8AL.13',
#  'herc-1': 'Y48G8AL.1',
#  'Y48G8AR.2': 'Y48G8AR.2',
#  'K12C11.1': 'K12C11.1',
#  'set-29': 'Y92H12BR.6',
#  'Y92H12BR.2': 'Y92H12BR.2',
#  'Y92H12BR.3': 'Y92H12BR.3',
#  'Y92H12BR.4': 'Y92H12BR.4',
#  'mrpl-15': 'Y92H12BR.8',
#  'F37F2.2': 'F37F2.2',
#  'spe-15': 'F47G6.4',
#  'F47G6.3': 'F47G6.3',
#  'acs-16': 'F47G6.2',
#  'dyb-1': 'F47G6.1',
#  'Y92H12A.5': 'Y92H12A.5',
#  'Y92H12A.2': 'Y92H12A.2',
#  'Y92H12A.t1': 'Y92H12A.T1',
#  'src-1': 'Y92H12A.1',
#  'aatf-1': 'Y73E7A.2',
#  'Y73E7A.6': 'Y73E7A.6',
#  'Y73E7A.1': 'Y73E7A.1',
#  'Y73E7A.8': 'Y73E7A.8',
#  'mab-20': 'Y71G12B.20',
#  'pqn-88': 'Y71G12B.21',
#  'Y71G12B.18': 'Y71G12B.18',
#  'Y71G12B.17': 'Y71G12B.17',
#  'Y71G12B.23': 'Y71G12B.23',
#  'ubc-3': 'Y71G12B.15',
#  'atg-5': 'Y71G12B.12',
#  'tln-1': 'Y71G12B.11',
#  'mppa-1': 'Y71G12B.24',
#  'Y71G12B.10': 'Y71G12B.10',
#  'lin-65': 'Y71G12B.9',
#  'Y71G12B.25': 'Y71G12B.25',
#  'mtig-1': 'Y71G12B.26',
#  'ddx-27': 'Y71G12B.8',
#  'rml-5': 'Y71G12B.6',
#  'Y71G12B.27': 'Y71G12B.27',
#  'pghm-1': 'Y71G12B.4',
#  'chaf-2': 'Y71G12B.1',
#  'Y71G12B.28': 'Y71G12B.28',
#  'C53H9.2': 'C53H9.2',
#  'rpl-27': 'C53H9.1',
#  'egl-30': 'M01D7.7',
#  'emr-1': 'M01D7.6',
#  'nlp-12': 'M01D7.5',
#  'tag-96': 'M01D7.4',
#  'scm-1': 'M01D7.2',
#  'tub-2': 'Y71G12A.3',
#  'Y71G12A.4': 'Y71G12A.4',
#  'Y51F10.7': 'Y51F10.7',
#  'Y37E3.1': 'Y37E3.1',
#  'rpb-10': 'Y37E3.3',
#  'moag-4': 'Y37E3.4',
#  'arl-13': 'Y37E3.5',
#  'rplp-1': 'Y37E3.7',
#  'rpl-27A': 'Y37E3.8',
#  'phb-1': 'Y37E3.9',
#  'eif-2alpha': 'Y37E3.10',
#  'pcyt-2.1': 'Y37E3.11',
#  'iglr-3': 'Y37E3.13',
#  'fpn-1.1': 'Y37E3.16',
#  'npp-13': 'Y37E3.15',
#  'Y37E3.17': 'Y37E3.17',
#  'afd-1': 'W03F11.6',
#  'W03F11.5': 'W03F11.5',
#  'ule-1': 'W03F11.1',
#  'dct-9': 'W03F11.3',
#  'W03F11.4': 'W03F11.4',
#  'slc-17.6': 'F12B6.2',
#  'abt-2': 'F12B6.1',
#  'Y39G10AL.1': 'Y39G10AL.1',
#  'cdk-7': 'Y39G10AL.3',
#  'Y39G10AR.11': 'Y39G10AR.11',
#  'tpxl-1': 'Y39G10AR.12',
#  'epg-2': 'Y39G10AR.10',
#  'icp-1': 'Y39G10AR.13',
#  'Y39G10AR.9': 'Y39G10AR.9',
#  'nsun-4': 'Y39G10AR.21',
#  'tbca-1': 'Y39G10AR.20',
#  'eif-2gamma': 'Y39G10AR.8',
#  'mcm-4': 'Y39G10AR.14',
#  'Y39G10AR.15': 'Y39G10AR.15',
#  'Y39G10AR.16': 'Y39G10AR.16',
#  'dot-1.1': 'Y39G10AR.18',
#  'zwl-1': 'Y39G10AR.2',
#  'F23C8.13': 'F23C8.13',
#  'etfb-1': 'F23C8.5',
#  'did-2': 'F23C8.6',
#  'F23C8.8': 'F23C8.8',
#  'tipn-1': 'F23C8.9',
#  'ubxn-1': 'F23C8.4',
#  'inx-19': 'T16H5.1',
#  'Y74C10AL.2': 'Y74C10AL.2',
#  'abtm-1': 'Y74C10AR.3',
#  'Y74C10AR.2': 'Y74C10AR.2',
#  'eif-3.I': 'Y74C10AR.1',
#  'ddx-10': 'Y23H5B.6',
#  'Y23H5B.5': 'Y23H5B.5',
#  'Y23H5B.7': 'Y23H5B.7',
#  'ssp-19': 'C55C2.2',
#  'aat-5': 'C55C2.5',
#  'ptr-12': 'K07A3.2',
#  'K07A3.3': 'K07A3.3',
#  'ctn-1': 'Y23H5A.5',
#  'pid-3': 'Y23H5A.3',
#  'Y23H5A.2': 'Y23H5A.2',
#  'cars-1': 'Y23H5A.7',
#  'cars-2': 'Y23H5A.1',
#  'F40E3.5': 'F40E3.5',
#  'F32B5.6': 'F32B5.6',
#  'F32B5.7': 'F32B5.7',
#  'cpz-1': 'F32B5.8',
#  'msrp-1': 'F32B5.4',
#  'F32B5.1': 'F32B5.1',
#  'lin-17': 'Y71F9B.5',
#  'dnj-30': 'Y71F9B.16',
#  'snr-7': 'Y71F9B.4',
#  'yop-1': 'Y71F9B.3',
#  'Y71F9B.2': 'Y71F9B.2',
#  'lron-11': 'Y71F9B.8',
#  'plk-2': 'Y71F9B.7',
#  'Y71F9B.9': 'Y71F9B.9',
#  'sop-3': 'Y71F9B.10',
#  'Y71F9B.13': 'Y71F9B.13',
#  'W03D8.9': 'W03D8.9',
#  'W03D8.10': 'W03D8.10',
#  'W03D8.2': 'W03D8.2',
#  'itx-1': 'W03D8.6',
#  'W03D8.5': 'W03D8.5',
#  'W03D8.3': 'W03D8.3',
#  'pop-1': 'W10C8.2',
#  'W10C8.5': 'W10C8.5',
#  'Y71F9AL.10': 'Y71F9AL.10',
#  'rpl-10a': 'Y71F9AL.13',
#  'Y71F9AL.9': 'Y71F9AL.9',
#  'Y71F9AL.8': 'Y71F9AL.8',
#  'dnc-5': 'Y71F9AL.14',
#  'arx-1': 'Y71F9AL.16',
#  'Y71F9AL.25': 'Y71F9AL.25',
#  'Y71F9AL.6': 'Y71F9AL.6',
#  'copa-1': 'Y71F9AL.17',
#  'pph-7': 'Y71F9AL.4',
#  'Y71F9AL.2': 'Y71F9AL.2',
#  'Y71F9AL.1': 'Y71F9AL.1',
#  'trap-1': 'Y71F9AM.6',
#  'nxt-1': 'Y71F9AM.5',
#  'cogc-3': 'Y71F9AM.4',
#  'bam-2': 'Y71F9AR.1',
#  'supr-1': 'Y71F9AR.3',
#  'dnj-28': 'Y54E10BL.4',
#  'mek-2': 'Y54E10BL.6',
#  'col-48': 'Y54E10BL.2',
#  'nobh-1': 'Y54E10BR.4',
#  'rnf-126': 'Y54E10BR.3',
#  'sec-11': 'Y54E10BR.5',
#  'rpb-7': 'Y54E10BR.6',
#  'Y54E10BR.2': 'Y54E10BR.2',
#  'mod-5': 'Y54E10BR.7',
#  'ztf-23': 'Y54E10BR.8',
#  'pign-1': 'Y54E10BR.1',
#  'arx-7': 'M01B12.3',
#  'riok-1': 'M01B12.5',
#  'nhr-64': 'C45E1.1',
#  'C45E1.4': 'C45E1.4',
#  'lpd-6': 'K09H9.6',
#  'dscc-1': 'K09H9.2',
#  'vbh-1': 'Y54E10A.9',
#  'mrpl-17': 'Y54E10A.7',
#  'Y54E10A.6': 'Y54E10A.6',
#  'dnc-6': 'Y54E10A.5',
#  'Y54E10A.10': 'Y54E10A.10',
#  'Y54E10A.11': 'Y54E10A.11',
#  'syp-5': 'Y54E10A.12',
#  'fog-1': 'Y54E10A.4',
#  'cdt-1': 'Y54E10A.15',
#  'txl-1': 'Y54E10A.3',
#  'mab-31': 'Y54E10A.16',
#  'zip-4': 'Y44E3B.1',
#  'nol-58': 'W01B11.3',
#  'W01B11.6': 'W01B11.6',
#  'W01B11.1': 'W01B11.1',
#  'ace-2': 'Y44E3A.2',
#  'cdap-2': 'Y44E3A.4',
#  'edc-4': 'Y44E3A.6',
#  'W05F2.3': 'W05F2.3',
#  'W05F2.6': 'W05F2.6',
#  'cdk-2': 'K03E5.3',
#  'sep-1': 'Y47G6A.12',
#  'nefr-1': 'Y47G6A.28',
#  'msh-6': 'Y47G6A.11',
#  'spg-7': 'Y47G6A.10',
#  'Y47G6A.9': 'Y47G6A.9',
#  'crn-1': 'Y47G6A.8',
#  'Y47G6A.7': 'Y47G6A.7',
#  'Y47G6A.18': 'Y47G6A.18',
#  'pcaf-1': 'Y47G6A.6',
#  'Y47G6A.19': 'Y47G6A.19',
#  'rnp-6': 'Y47G6A.20',
#  'rde-10': 'Y47G6A.4',
#  'Y47G6A.21': 'Y47G6A.21',
#  'Y47G6A.22': 'Y47G6A.22',
#  'lpd-3': 'Y47G6A.23',
#  'mis-12': 'Y47G6A.24',
#  'Y47G6A.25': 'Y47G6A.25',
#  'inx-22': 'Y47G6A.2',
#  'inx-21': 'Y47G6A.1',
#  'Y47G6A.26': 'Y47G6A.26',
#  'jmjc-1': 'T28F2.4',
#  'ccb-1': 'T28F2.5',
#  'ftn-2': 'D1037.3',
#  'rab-8': 'D1037.4',
#  'D1037.1': 'D1037.1',
#  'ipla-4': 'D1037.5',
#  'msh-2': 'H26D21.2',
#  'hus-1': 'H26D21.1',
#  'glh-4': 'T12F5.3',
#  'larp-5': 'T12F5.5',
#  'inx-13': 'Y8G1A.2',
#  'inx-12': 'ZK770.3',
#  'acs-24': 'C32E8.6',
#  'pmlr-1': 'C32E8.5',
#  'C32E8.4': 'C32E8.4',
#  'tppp-1': 'C32E8.3',
#  'rpl-13': 'C32E8.2',
#  'ptr-2': 'C32E8.8',
#  'C32E8.9': 'C32E8.9',
#  'unc-11': 'C32E8.10',
#  'ubr-1': 'C32E8.11',
#  'npp-11': 'F53F10.5',
#  'F53F10.7': 'F53F10.7',
#  'unc-108': 'F53F10.4',
#  'mpc-2': 'F53F10.3',
#  'azin-1': 'F53F10.2',
#  'F53F10.1': 'F53F10.1',
#  'gsp-4': 'T03F1.5',
#  'T03F1.6': 'T03F1.6',
#  'T03F1.11': 'T03F1.11',
#  'guk-1': 'T03F1.8',
#  'hcp-4': 'T03F1.9',
#  'pgk-1': 'T03F1.3',
#  'coq-4': 'T03F1.2',
#  'clec-53': 'T03F1.10',
#  'uba-5': 'T03F1.1',
#  'T03F1.12': 'T03F1.12',
#  'syf-1': 'C50F2.3',
#  'C50F2.2': 'C50F2.2',
#  'C50F2.5': 'C50F2.5',
#  'fkb-5': 'C50F2.6',
#  'pbs-4': 'T20F5.2',
#  'mrrf-1': 'T20F5.3',
#  'T20F5.4': 'T20F5.4',
#  'T20F5.6': 'T20F5.6',
#  'T20F5.7': 'T20F5.7',
#  'egg-4': 'T21E3.1',
#  'lrp-2': 'T21E3.3',
#  'F47B3.6': 'F47B3.6',
#  'F47B3.7': 'F47B3.7',
#  'F47B3.1': 'F47B3.1',
#  'aars-2': 'F28H1.3',
#  'cpn-3': 'F28H1.2',
#  'F28H1.1': 'F28H1.1',
#  'unc-73': 'F55C7.7',
#  'unc-89': 'C09D1.1',
#  'acd-2': 'C24G7.4',
#  'cyb-2.2': 'H31G24.4',
#  'lin-44': 'E01A2.3',
#  'let-504': 'E01A2.4',
#  'srrt-1': 'E01A2.2',
#  'akir-1': 'E01A2.6',
#  'E01A2.1': 'E01A2.1',
#  'poml-2': 'E01A2.7',
#  'R12E2.15': 'R12E2.15',
#  'R12E2.14': 'R12E2.14',
#  'R12E2.7': 'R12E2.7',
#  'R12E2.8': 'R12E2.8',
#  'inx-15': 'R12E2.9',
#  'inx-16': 'R12E2.5',
#  'inx-17': 'R12E2.4',
#  'egg-5': 'R12E2.10',
#  'R12E2.11': 'R12E2.11',
#  'rpn-8': 'R12E2.3',
#  'R12E2.13': 'R12E2.13',
#  'suco-1': 'R12E2.2',
#  'kel-20': 'R12E2.1',
#  'ppw-1': 'C18E3.7',
#  'snrp-40.2': 'C18E3.5',
#  'C18E3.3': 'C18E3.3',
#  'hop-1': 'C18E3.8',
#  'swsn-2.2': 'C18E3.2',
#  'C18E3.1': 'C18E3.1',
#  'melo-2': 'C18E3.9',
#  'nab-1': 'C43E11.6',
#  'C43E11.5': 'C43E11.5',
#  'exoc-7': 'C43E11.8',
#  'tufm-2': 'C43E11.4',
#  'cogc-5': 'C43E11.11',
#  'met-1': 'C43E11.3',
#  'mus-81': 'C43E11.2',
#  'C43E11.9': 'C43E11.9',
#  'cdc-6': 'C43E11.10',
#  'acin-1': 'C43E11.1',
#  'Y47D9A.5': 'Y47D9A.5',
#  'scpl-3': 'Y47D9A.2',
#  'Y47D9A.1': 'Y47D9A.1',
#  'anc-1': 'ZK973.6',
#  'pdp-1': 'ZK973.3',
#  'ZK973.9': 'ZK973.9',
#  'lpd-5': 'ZK973.10',
#  'cec-10': 'ZK973.2',
#  'ZK973.11': 'ZK973.11',
#  'ZK973.1': 'ZK973.1',
#  'dhc-1': 'T21E12.4',
#  'eif-3.H': 'C41D11.2',
#  'cps-6': 'C41D11.8',
#  'cmt-1': 'C41D11.5',
#  'eri-7': 'C41D11.7',
#  'eri-6': 'C41D11.1',
#  'gcy-28': 'T01A4.1',
#  'mrpl-19': 'Y119C1B.4',
#  'rnf-145': 'Y119C1B.5',
#  'bet-1': 'Y119C1B.8',
#  'Y119C1B.1': 'Y119C1B.1',
#  'D1007.15': 'D1007.15',
#  'ceh-17': 'D1007.1',
#  'tmem-39': 'D1007.5',
#  'rps-10': 'D1007.6',
#  'rpl-24': 'D1007.12',
#  'nrd-1': 'D1007.7',
#  'eaf-1': 'D1007.16',
#  'D1007.8': 'D1007.8',
#  'C44E4.5': 'C44E4.5',
#  'ubr-4': 'C44E4.1',
#  'ssb-1': 'C44E4.4',
#  'acbp-1': 'C44E4.6',
#  'got-2.1': 'C44E4.3',
#  'lmd-2': 'B0041.3',
#  'rpl-4': 'B0041.4',
#  'B0041.5': 'B0041.5',
#  'ain-2': 'B0041.2',
#  'xnp-1': 'B0041.7',
#  'unc-57': 'T04D1.3',
#  'chd-7': 'T04D1.4',
#  'W09C3.4': 'W09C3.4',
#  'gsp-3': 'W09C3.6',
#  'W09C3.7': 'W09C3.7',
#  'ugt-26': 'C10H11.6',
#  'ugt-28': 'C10H11.4',
#  'ugt-25': 'C10H11.3',
#  'let-502': 'C10H11.9',
#  'viln-1': 'C10H11.1',
#  'kca-1': 'C10H11.10',
#  'kin-35': 'M04F3.3',
#  'rpa-2': 'M04F3.1',
#  'M04F3.5': 'M04F3.5',
#  'rpl-41.1': 'F54D7.6',
#  'rpl-41.2': 'F54D7.7',
#  'zig-7': 'F54D7.4',
#  'ept-1': 'F54D7.2',
#  'tofu-4': 'F57C9.7',
#  'htp-3': 'F57C9.5',
#  'F57C9.4': 'F57C9.4',
#  'pdxk-1': 'F57C9.1',
#  'rga-6': 'C01F4.2',
#  'glc-2': 'F25F8.2',
#  'F25F8.1': 'F25F8.1',
#  'unc-38': 'F21F3.5',
#  'icmt-1': 'F21F3.3',
#  'F21F3.2': 'F21F3.2',
#  'pgal-1': 'F21F3.1',
#  'F21F3.6': 'F21F3.6',
#  'imb-1': 'F28B3.8',
#  'mfsd-13.1': 'F28B3.5',
#  'F28B3.10': 'F28B3.10',
#  'F28B3.6': 'F28B3.6',
#  'him-1': 'F28B3.7',
#  'enu-3.3': 'W03G9.3',
#  'app-1': 'W03G9.4',
#  'snf-1': 'W03G9.1',
#  'paf-1': 'W03G9.6',
#  'cil-7': 'W03G9.7',
#  'dyf-1': 'F54C1.5',
#  'mes-3': 'F54C1.3',
#  'dom-3': 'F54C1.2',
#  'sst-20': 'F54C1.9',
#  'F54C1.1': 'F54C1.1',
#  'pat-10': 'F54C1.7',
#  'lfe-2': 'C46H11.4',
#  'phat-1': 'C46H11.8',
#  'phat-2': 'C46H11.9',
#  'C46H11.2': 'C46H11.2',
#  'C46H11.10': 'C46H11.10',
#  'fhod-1': 'C46H11.11',
#  'vha-16': 'C30F8.2',
#  'kin-32': 'C30F8.4',
#  'C30F8.3': 'C30F8.3',
#  'spe-5': 'Y110A7A.12',
#  'chp-1': 'Y110A7A.13',
#  'pas-3': 'Y110A7A.14',
#  'use-1': 'Y110A7A.11',
#  'aap-1': 'Y110A7A.10',
#  'Y110A7A.15': 'Y110A7A.15',
#  'elpc-1': 'Y110A7A.16',
#  'Y110A7A.9': 'Y110A7A.9',
#  'mat-1': 'Y110A7A.17',
#  'prp-31': 'Y110A7A.8',
#  'pfkb-1.1': 'Y110A7A.6',
#  'mtm-1': 'Y110A7A.5',
#  'tyms-1': 'Y110A7A.4',
#  'unc-63': 'Y110A7A.3',
#  'trf-2': 'Y110A7A.2',
#  'ppw-2': 'Y110A7A.18',
#  'let-630': 'Y110A7A.19',
#  'spd-5': 'F56A3.4',
#  'npp-6': 'F56A3.3',
#  'slx-1': 'F56A3.2',
#  'bro-1': 'F56A3.5',
#  'fncm-1': 'F56A3.1',
#  'osr-1': 'C32E12.3',
#  'sem-2': 'C32E12.5',
#  'C32E12.4': 'C32E12.4',
#  'mrpl-47': 'B0261.4',
#  'B0261.6': 'B0261.6',
#  'let-363': 'B0261.2',
#  'vep-1': 'B0261.1',
#  'B0261.7': 'B0261.7',
#  'C01G8.1': 'C01G8.1',
#  'cln-3.2': 'C01G8.2',
#  'dhs-1': 'C01G8.3',
#  'dnj-4': 'C01G8.4',
#  'erm-1': 'C01G8.5',
#  'hpo-32': 'C01G8.6',
#  'F48C1.6': 'F48C1.6',
#  'aman-3': 'F48C1.1',
#  'spe-11': 'F48C1.7',
#  'apm-1': 'F55A12.7',
#  'F55A12.5': 'F55A12.5',
#  'nath-10': 'F55A12.8',
#  'dhs-2': 'F55A12.4',
#  'ppk-1': 'F55A12.3',
#  'F55A12.2': 'F55A12.2',
#  'zhp-1': 'F55A12.10',
#  'tent-5': 'F55A12.9',
#  'C24A11.1': 'C24A11.1',
#  'frm-4': 'C24A11.8',
#  'coq-1': 'C24A11.9',
#  'erp-44.1': 'C30H7.2',
#  'F27C1.6': 'F27C1.6',
#  'F27C1.4': 'F27C1.4',
#  'F27C1.3': 'F27C1.3',
#  'atp-3': 'F27C1.7',
#  'F27C1.2': 'F27C1.2',
#  'dpy-5': 'F27C1.8',
#  'F27C1.1': 'F27C1.1',
#  'let-355': 'T05E8.3',
#  'C09D4.4': 'C09D4.4',
#  'rpl-19': 'C09D4.5',
#  'C09D4.3': 'C09D4.3',
#  'C09D4.1': 'C09D4.1',
#  'mrpl-24': 'F59A3.3',
#  'zipt-11': 'F59A3.4',
#  'cpd-1': 'F59A3.1',
#  'pup-3': 'F59A3.9',
#  'ostd-1': 'M01A10.3',
#  'tom-1': 'M01A10.2',
#  'pqn-52': 'M01E11.4',
#  'cey-3': 'M01E11.5',
#  'rmh-1': 'M01E11.3',
#  'klp-15': 'M01E11.6',
#  'ctnb-1': 'M01E11.2',
#  'tns-1': 'M01E11.7',
#  'vha-10': 'F46F11.5',
#  'trpp-8': 'F46F11.9',
#  'xrep-4': 'F46F11.6',
#  'cey-2': 'F46F11.2',
#  'F46F11.8': 'F46F11.8',
#  'F46F11.1': 'F46F11.1',
#  'col-53': 'M01A12.1',
#  'F55F8.2': 'F55F8.2',
#  'F55F8.3': 'F55F8.3',
#  'cir-1': 'F55F8.4',
#  'wdr-12': 'F55F8.5',
#  'F55F8.7': 'F55F8.7',
#  'ptr-10': 'F55F8.1',
#  'zipt-2.4': 'F55F8.9',
#  'dnj-21': 'T19B4.4',
#  'aprt-1': 'T19B4.3',
#  'unc-40': 'T19B4.7',
#  'npp-7': 'T19B4.2',
#  'lim-7': 'C04F1.3',
#  'C04F1.1': 'C04F1.1',
#  'rpt-5': 'F56H1.4',
#  'che-14': 'F56H1.1',
#  'ccpp-1': 'F56H1.5',
#  'hil-5': 'B0414.3',
#  'rnt-1': 'B0414.2',
#  'cpb-3': 'B0414.5',
#  'glh-3': 'B0414.6',
#  'mtk-1': 'B0414.7',
#  'vps-51': 'B0414.8',
#  'C32F10.4': 'C32F10.4',
#  'lin-35': 'C32F10.2',
#  'hmg-3': 'C32F10.5',
#  'nhr-2': 'C32F10.6',
#  'C32F10.8': 'C32F10.8',
#  'obr-4': 'C32F10.1',
#  'ceh-12': 'F33D11.4',
#  'gpaa-1': 'F33D11.9',
#  'dhhc-3': 'F33D11.12',
#  'F33D11.10': 'F33D11.10',
#  'vpr-1': 'F33D11.11',
#  'cdc-7': 'C34G6.5',
#  'noah-1': 'C34G6.6',
#  'pgp-2': 'C34G6.4',
#  'tyr-4': 'C34G6.2',
#  'stam-1': 'C34G6.7',
#  'B0207.5': 'B0207.5',
#  'B0207.6': 'B0207.6',
#  'air-2': 'B0207.4',
#  'gpa-14': 'B0207.3',
#  'avr-14': 'B0207.12',
#  'simr-1': 'C06A5.6',
#  'C06A5.3': 'C06A5.3',
#  'unc-94': 'C06A5.7',
#  'C06A5.8': 'C06A5.8',
#  'rnf-1': 'C06A5.9',
#  'csn-2': 'B0025.2',
#  'B0025.4': 'B0025.4',
#  'vps-34': 'B0025.1',
#  'szy-5': 'C27A12.2',
#  'ari-1.3': 'C27A12.6',
#  'ari-1.2': 'C27A12.7',
#  'ari-1.1': 'C27A12.8',
#  'pigo-1': 'C27A12.9',
#  'tres-1': 'ZK484.4',
#  'haf-9': 'ZK484.2',
#  'msrp-2': 'ZK484.5',
#  'ZK484.6': 'ZK484.6',
#  'oaz-1': 'ZK484.1',
#  'nspd-1': 'ZK484.8',
#  'spch-3': 'T27A3.4',
#  'ssp-16': 'T27A3.3',
#  'nse-1': 'T27A3.7',
#  'usp-5': 'T27A3.2',
#  'trak-1': 'T27A3.1',
#  'pept-3': 'F56F4.5',
#  'ttr-58': 'F56F4.1',
#  'T09B4.5': 'T09B4.5',
#  'T09B4.8': 'T09B4.8',
#  'tin-44': 'T09B4.9',
#  'chn-1': 'T09B4.10',
#  'T09B4.2': 'T09B4.2',
#  'pigv-1': 'T09B4.1',
#  'wshc-5': 'T05E7.3',
#  'T05E7.4': 'T05E7.4',
#  'vet-1': 'T05E7.5',
#  'T05E7.1': 'T05E7.1',
#  'ech-1.2': 'T08B2.7',
#  'fars-1': 'T08B2.9',
#  'rbm-5': 'T08B2.5',
#  'rps-17': 'T08B2.10',
#  'T08B2.11': 'T08B2.11',
#  'T08B2.12': 'T08B2.12',
#  'C48E7.7': 'C48E7.7',
#  'C48E7.6': 'C48E7.6',
#  'spp-15': 'C48E7.10',
#  'cebp-2': 'C48E7.11',
#  'lpd-2': 'C48E7.3',
#  'let-611': 'C48E7.2',
#  'C48E7.1': 'C48E7.1',
#  'oac-9': 'C48E7.8',
#  'C10G11.8': 'C10G11.8',
#  'spch-2': 'C10G11.9',
#  'chdp-1': 'C10G11.7',
#  'pnk-1': 'C10G11.5',
#  'F26B1.5': 'F26B1.5',
#  'ima-2': 'F26B1.3',
#  'hrpk-1': 'F26B1.2',
#  'let-381': 'F26B1.7',
#  'F26B1.1': 'F26B1.1',
#  'bli-4': 'K04F10.4',
#  'K04F10.3': 'K04F10.3',
#  'K04F10.7': 'K04F10.7',
#  'ZC308.4': 'ZC308.4',
#  'gld-2': 'ZC308.1',
#  'klu-2': 'ZC328.2',
#  'cuti-1': 'ZC328.1',
#  'ZC328.5': 'ZC328.5',
#  'san-1': 'ZC328.4',
#  'ZC328.3': 'ZC328.3',
#  'rbx-2': 'R10A10.2',
#  'ncbp-1': 'F37E3.1',
#  'snt-4': 'T23H2.2',
#  'T23H2.3': 'T23H2.3',
#  'npp-12': 'T23H2.1',
#  'knl-2': 'K06A5.4',
#  'acdh-3': 'K06A5.6',
#  'K06A5.3': 'K06A5.3',
#  'cdc-25.1': 'K06A5.7',
#  'uad-2': 'K06A5.1',
#  'nmtn-1': 'K06A5.8',
#  'dbr-1': 'C55B7.8',
#  'acdh-1': 'C55B7.4',
#  'C55B7.3': 'C55B7.3',
#  'gly-2': 'C55B7.2',
#  'glh-2': 'C55B7.1',
#  'T10E9.4': 'T10E9.4',
#  'nuo-2': 'T10E9.7',
#  'cpg-22': 'T10E9.3',
#  'T10E9.2': 'T10E9.2',
#  'T10E9.1': 'T10E9.1',
#  'acdh-4': 'T10E9.9',
#  'F57B10.8': 'F57B10.8',
#  'spg-20': 'F57B10.9',
#  'dad-1': 'F57B10.10',
#  'tre-1': 'F57B10.7',
#  'tmed-3': 'F57B10.5',
#  'bag-1': 'F57B10.11',
#  'mei-2': 'F57B10.12',
#  'syp-6': 'F57B10.4',
#  'ipgm-1': 'F57B10.3',
#  'D2092.4': 'D2092.4',
#  'D2092.8': 'D2092.8',
#  'ppfr-2': 'D2092.2',
#  'mctp-1': 'D2092.1',
#  'ZC581.3': 'ZC581.3',
#  'ZC581.9': 'ZC581.9',
#  'C17F3.1': 'C17F3.1',
#  'T23B3.5': 'T23B3.5',
#  'T23B3.1': 'T23B3.1',
#  'mec-6': 'W02D3.3',
#  'lbp-6': 'W02D3.5',
#  'smg-5': 'W02D3.8',
#  'dhod-1': 'W02D3.2',
#  'cytb-5.2': 'W02D3.1',
#  'unc-37': 'W02D3.9',
#  'hrpf-1': 'W02D3.11',
#  'gpc-2': 'F08B6.2',
#  'unc-87': 'F08B6.4',
#  'pqn-21': 'C37A2.5',
#  'cye-1': 'C37A2.4',
#  'acdh-5': 'C37A2.3',
#  'rplp-2.1': 'C37A2.7',
#  'pqn-20': 'C37A2.2',
#  'C37A2.8': 'C37A2.8',
#  'mek-5': 'E02D9.3',
#  'teg-4': 'K02F2.3',
#  'ahcy-1': 'K02F2.2',
#  'dpf-3': 'K02F2.1',
#  'dpy-14': 'H27M09.4',
#  'syp-4': 'H27M09.3',
#  'rpb-5': 'H27M09.2',
#  'sacy-1': 'H27M09.1',
#  'glh-1': 'T21G5.3',
#  'smz-2': 'T21G5.4',
#  'smg-1': 'C48B6.6',
#  'haps-1': 'C48B6.3',
#  'C48B6.2': 'C48B6.2',
#  'C48B6.10': 'C48B6.10',
#  'ztf-4': 'T10B11.3',
#  'cerk-1': 'T10B11.2',
#  'T10B11.6': 'T10B11.6',
#  'T10B11.8': 'T10B11.8',
#  'rege-1': 'C30F12.1',
#  'C30F12.2': 'C30F12.2',
#  'C30F12.3': 'C30F12.3',
#  'C30F12.4': 'C30F12.4',
#  'idhg-2': 'C30F12.7',
#  'ctg-1': 'H06O01.3',
#  'chd-1': 'H06O01.2',
#  'pdi-3': 'H06O01.1',
#  'ubql-1': 'F15C11.2',
#  'sem-4': 'F15C11.1',
#  'W01A8.2': 'W01A8.2',
#  'plin-1': 'W01A8.1',
#  'nuo-6': 'W01A8.4',
#  'tofu-5': 'W01A8.5',
#  'kin-14': 'F22D6.1',
#  'mstr-1': 'F22D6.2',
#  'nars-1': 'F22D6.3',
#  'prpf-4': 'F22D6.5',
#  'ekl-1': 'F22D6.6',
#  'col-60': 'F22D6.10',
#  'gly-18': 'F22D6.11',
#  'gly-19': 'F22D6.12',
#  'K10D3.6': 'K10D3.6',
#  'glr-3': 'K10D3.1',
#  'unc-14': 'K10D3.2',
#  'taf-11.2': 'K10D3.3',
#  'K10D3.4': 'K10D3.4',
#  'fecl-1': 'K07G5.6',
#  'crml-1': 'K07G5.1',
#  'plag-15': 'M05B5.4',
#  'hlh-2': 'M05B5.5',
#  'mlt-2': 'C01H6.2',
#  'nhr-23': 'C01H6.5',
#  'swsn-9': 'C01H6.7',
#  'hasp-1': 'C01H6.9',
#  'wago-1': 'R06C7.1',
#  'dhp-1': 'R06C7.3',
#  'cpg-3': 'R06C7.4',
#  'adsl-1': 'R06C7.5',
#  'lin-61': 'R06C7.7',
#  'bub-1': 'R06C7.8',
#  'ztf-15': 'R06C7.9',
#  'myo-1': 'R06C7.10',
#  'tyr-3': 'F21C3.2',
#  'rde-2': 'F21C3.4',
#  'pfd-6': 'F21C3.5',
#  'F13G3.3': 'F13G3.3',
#  'dylt-1': 'F13G3.4',
#  'ttx-7': 'F13G3.5',
#  'F13G3.7': 'F13G3.7',
#  'mrpl-13': 'F13G3.11',
#  'eat-5': 'F13G3.8',
#  'mif-3': 'F13G3.9',
#  'F52A8.1': 'F52A8.1',
#  'gpb-2': 'F52A8.2',
#  'F52A8.3': 'F52A8.3',
#  'glb-18': 'F52A8.4',
#  'gcsh-2': 'F52A8.5',
#  'kbrl-1': 'F52A8.6',
#  'inx-14': 'F07A5.1',
#  'spsp-1': 'F07A5.2',
#  'F07A5.4': 'F07A5.4',
#  'unc-15': 'F07A5.7',
#  'col-35': 'C15A11.1',
#  'sol-1': 'C15A11.3',
#  'col-7': 'C15A11.5',
#  'col-62': 'C15A11.6',
#  'C15A11.7': 'C15A11.7',
#  'unc-13': 'ZK524.2',
#  'spe-4': 'ZK524.1',
#  'lars-2': 'ZK524.3',
#  'ZK524.4': 'ZK524.4',
#  'T28F4.1': 'T28F4.1',
#  'T28F4.4': 'T28F4.4',
#  'T28F4.5': 'T28F4.5',
#  'pbrm-1': 'C26C6.1',
#  'goa-1': 'C26C6.2',
#  'nas-36': 'C26C6.3',
#  'dcp-66': 'C26C6.5',
#  'chs-1': 'T25G3.2',
#  'gpdh-3': 'T25G3.4',
#  'mans-1': 'D2030.1',
#  'D2030.2': 'D2030.2',
#  'D2030.3': 'D2030.3',
#  'ndub-7': 'D2030.4',
#  'mce-1': 'D2030.5',
#  'prg-1': 'D2030.6',
#  'D2030.7': 'D2030.7',
#  'D2030.8': 'D2030.8',
#  'wdr-23': 'D2030.9',
#  'aex-1': 'D2030.10',
#  'lrp-1': 'F29D11.1',
#  'capg-1': 'F29D11.2',
#  'F26A3.1': 'F26A3.1',
#  'rrf-1': 'F26A3.8',
#  'ego-1': 'F26A3.3',
#  'F26A3.4': 'F26A3.4',
#  'F26A3.7': 'F26A3.7',
#  'golg-5': 'T24B1.1',
#  'T23G11.7': 'T23G11.7',
#  'lron-9': 'T23G11.6',
#  'rlbp-1': 'T23G11.5',
#  'T23G11.4': 'T23G11.4',
#  'gld-1': 'T23G11.3',
#  'gna-2': 'T23G11.2',
#  'T23G11.1': 'T23G11.1',
#  'etfa-1': 'F27D4.1',
#  'lsy-22': 'F27D4.2',
#  'F27D4.4': 'F27D4.4',
#  'bckd-1B': 'F27D4.5',
#  'F27D4.6': 'F27D4.6',
#  'adr-1': 'H15N14.1',
#  'D2005.1': 'D2005.1',
#  'nlp-8': 'D2005.2',
#  'D2005.4': 'D2005.4',
#  'drh-3': 'D2005.5',
#  'glna-3': 'F30F8.2',
#  'F30F8.1': 'F30F8.1',
#  'gras-1': 'F30F8.3',
#  'F30F8.9': 'F30F8.9',
#  'taf-5': 'F30F8.8',
#  'apb-3': 'R11A5.1',
#  'nud-2': 'R11A5.2',
#  'R11A5.3': 'R11A5.3',
#  'pck-2': 'R11A5.4',
#  'suro-1': 'R11A5.7',
#  'F55D12.2': 'F55D12.2',
#  'F55D12.6': 'F55D12.6',
#  'F20G4.2': 'F20G4.2',
#  'smgl-1': 'F20G4.1',
#  'nmy-2': 'F20G4.3',
#  'T22C1.1': 'T22C1.1',
#  'glb-26': 'T22C1.2',
#  'pigu-1': 'T22C1.3',
#  'T22C1.5': 'T22C1.5',
#  'T22C1.6': 'T22C1.6',
#  'T22C1.8': 'T22C1.8',
#  'T22C1.9': 'T22C1.9',
#  'T22C1.11': 'T22C1.11',
#  'rbg-2': 'T22C1.10',
#  'H05L14.1': 'H05L14.1',
#  'H05L14.2': 'H05L14.2',
#  'C54G4.5': 'C54G4.5',
#  'C54G4.4': 'C54G4.4',
#  'C54G4.2': 'C54G4.2',
#  'rskn-2': 'C54G4.1',
#  'cyc-1': 'C54G4.8',
#  'C54G4.9': 'C54G4.9',
#  'eif-2beta': 'K04G2.1',
#  'aho-3': 'K04G2.2',
#  'cdc-48.3': 'K04G2.3',
#  'ath-1': 'K04G2.5',
#  'scbp-2': 'K04G2.11',
#  'vacl-14': 'K04G2.6',
#  'apr-1': 'K04G2.8',
#  'K04G2.10': 'K04G2.10',
#  'che-3': 'F18C12.1',
#  'rme-8': 'F18C12.2',
#  'F18C12.3': 'F18C12.3',
#  'spr-4': 'C09H6.1',
#  'lin-10': 'C09H6.2',
#  'mau-2': 'C09H6.3',
#  'T28B8.1': 'T28B8.1',
#  'ins-18': 'T28B8.2',
#  'kcnl-2': 'F08A10.1',
#  'dhs-3': 'T02E1.5',
#  'gla-3': 'T02E1.3',
#  'T02E1.2': 'T02E1.2',
#  'spe-12': 'T02E1.1',
#  'col-63': 'ZK265.2',
#  'sre-23': 'ZK265.5',
#  'T01G9.2': 'T01G9.2',
#  'kin-10': 'T01G9.6',
#  'npp-2': 'T01G9.4',
#  'mei-1': 'T01G9.5',
#  'abts-1': 'F52B5.1',
#  'F52B5.2': 'F52B5.2',
#  'ythc-2': 'F52B5.3',
#  'cep-1': 'F52B5.5',
#  'rpl-23A.2': 'F52B5.6',
#  'C34B7.1': 'C34B7.1',
#  'figo-1': 'C34B7.2',
#  'rsd-6': 'F16D3.2',
#  'tbcd-1': 'F16D3.4',
#  'T19A6.1': 'T19A6.1',
#  'ngp-1': 'T19A6.2',
#  'nepr-1': 'T19A6.3',
#  'lin-28': 'F02E9.2',
#  'F02E9.7': 'F02E9.7',
#  'sin-3': 'F02E9.4',
#  'F02E9.5': 'F02E9.5',
#  'F02E9.10': 'F02E9.10',
#  'dpt-1': 'F02E9.9',
#  'sod-2': 'F10D11.1',
#  'F10D11.2': 'F10D11.2',
#  'F10D11.5': 'F10D11.5',
#  'F10D11.6': 'F10D11.6',
#  'unc-120': 'D1081.2',
#  'zhp-2': 'D1081.9',
#  'lotr-1': 'D1081.7',
#  'cdc-5L': 'D1081.8',
#  'ceh-6': 'K02B12.1',
#  'sec-12': 'K02B12.3',
#  'tnsl-1': 'K02B12.5',
#  'K02B12.7': 'K02B12.7',
#  'zhp-3': 'K02B12.8',
#  'gpa-15': 'M04C7.1',
#  'gon-2': 'T01H8.5',
#  'rskn-1': 'T01H8.1',
#  'ran-4': 'R05D11.3',
#  'tmem-208': 'R05D11.5',
#  'R05D11.9': 'R05D11.9',
#  'ddx-52': 'R05D11.4',
#  'snrp-27': 'R05D11.7',
#  'edc-3': 'R05D11.8',
#  'F43G9.13': 'F43G9.13',
#  'idha-1': 'F43G9.1',
#  'slc-25A42': 'F43G9.3',
#  'cfim-1': 'F43G9.5',
#  'fer-1': 'F43G9.6',
#  'cpn-1': 'F43G9.9',
#  'mfap-1': 'F43G9.10',
#  'mog-7': 'F43G9.12',
#  'syx-17': 'VF39H2L.1',
#  'sig-7': 'F39H2.2',
#  'flp-22': 'F39H2.1',
#  'mrt-1': 'F39H2.5',
#  'syp-3': 'F39H2.4',
#  'F39H2.3': 'F39H2.3',
#  'K07A12.1': 'K07A12.1',
#  'egg-6': 'K07A12.2',
#  'hot-5': 'K07A12.6',
#  'hbs-1': 'K07A12.4',
#  'asg-1': 'K07A12.3',
#  'pbs-7': 'F39H11.5',
#  'F39H11.1': 'F39H11.1',
#  'tlf-1': 'F39H11.2',
#  'cdk-8': 'F39H11.3',
#  'cle-1': 'C36B1.1',
#  'pas-4': 'C36B1.4',
#  'rpb-3': 'C36B1.3',
#  'dhfr-1': 'C36B1.7',
#  ...}

# %% [markdown]
# # mirtarbase

# %%
mirtarbase = pd.read_csv(PROC_DIR + 'mirTARbase/cele/miRTarBase_Mirna_Gene.csv')
mirtarbase.columns = mirtarbase.columns.str.lower()
mirtarbase.rename(columns={
    "headtype":  "head_type",
    "tailtype": "tail_type",

}, inplace=True)

mirtarbase['kg_type'] = 'Generalised'
mirtarbase['tail'] = mirtarbase['tail'].map(cele_symbol2Locus_dict).fillna(mirtarbase['tail'])
mirtarbase['species'] = 'C.elegans'

mirtarbase['head_id_is'] = 'miRTarBase_ID'
mirtarbase['tail_id_is'] = 'NCBI_ID'

print(f"mirtarbase: {len(mirtarbase):,} rows")
mirtarbase
# Out:
# mirtarbase: 244 rows
#                head    relation      tail head_type tail_type   kg_source  \
# 0      cel-lsy-6-3p  Mirna_Gene   R03C1.3     Mirna      Gene  miRTarBase
# 1      cel-let-7-5p  Mirna_Gene   C12C8.3     Mirna      Gene  miRTarBase
# 2      cel-let-7-5p  Mirna_Gene  T25C12.1     Mirna      Gene  miRTarBase
# 3      cel-lin-4-5p  Mirna_Gene   F02E9.2     Mirna      Gene  miRTarBase
# 4      cel-lsy-6-3p  Mirna_Gene   R03C1.3     Mirna      Gene  miRTarBase
# ..              ...         ...       ...       ...       ...         ...
# 239   cel-miR-35-3p  Mirna_Gene  T23G11.3     Mirna      Gene  miRTarBase
# 240    cel-let-7-5p  Mirna_Gene   ZK112.2     Mirna      Gene  miRTarBase
# 241    cel-let-7-5p  Mirna_Gene   ZK112.2     Mirna      Gene  miRTarBase
# 242    cel-miR-1-3p  Mirna_Gene   W10D5.1     Mirna      Gene  miRTarBase
# 243  cel-miR-243-3p  Mirna_Gene   R13H8.1     Mirna      Gene  miRTarBase
#
#     head_detail_name                                   tail_detail_name  \
# 0       cel-lsy-6-3p                 Homeobox domain-containing protein
# 1       cel-let-7-5p                                     Protein lin-41
# 2       cel-let-7-5p                                     Protein lin-14
# 3       cel-lin-4-5p                                     Protein lin-28
# 4       cel-lsy-6-3p                 Homeobox domain-containing protein
# ..               ...                                                ...
# 239    cel-miR-35-3p    Female germline-specific tumor suppressor gld-1
# 240     cel-let-7-5p  B box-type domain-containing protein;B-box typ...
# 241     cel-let-7-5p  B box-type domain-containing protein;B-box typ...
# 242     cel-miR-1-3p                  MEF2 transcription factor homolog
# 243   cel-miR-243-3p                             Forkhead box protein O
#
#        species      kg_type     head_id_is tail_id_is
# 0    C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# 1    C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# 2    C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# 3    C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# 4    C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# ..         ...          ...            ...        ...
# 239  C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# 240  C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# 241  C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# 242  C.elegans  Generalised  miRTarBase_ID    NCBI_ID
# 243  C.elegans  Generalised  miRTarBase_ID    NCBI_ID
#
# [244 rows x 12 columns]

# %%
#

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    mirtarbase
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 244
#                head    relation      tail head_type relation_type tail_type  \
# 0      cel-lsy-6-3p  Mirna_Gene   R03C1.3     Mirna          None      Gene
# 1      cel-let-7-5p  Mirna_Gene   C12C8.3     Mirna          None      Gene
# 2      cel-let-7-5p  Mirna_Gene  T25C12.1     Mirna          None      Gene
# 3      cel-lin-4-5p  Mirna_Gene   F02E9.2     Mirna          None      Gene
# 4      cel-lsy-6-3p  Mirna_Gene   R03C1.3     Mirna          None      Gene
# ..              ...         ...       ...       ...           ...       ...
# 239   cel-miR-35-3p  Mirna_Gene  T23G11.3     Mirna          None      Gene
# 240    cel-let-7-5p  Mirna_Gene   ZK112.2     Mirna          None      Gene
# 241    cel-let-7-5p  Mirna_Gene   ZK112.2     Mirna          None      Gene
# 242    cel-miR-1-3p  Mirna_Gene   W10D5.1     Mirna          None      Gene
# 243  cel-miR-243-3p  Mirna_Gene   R13H8.1     Mirna          None      Gene
#
#       kg_source      kg_type     head_id_is tail_id_is head_detail_name  \
# 0    miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-lsy-6-3p
# 1    miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-let-7-5p
# 2    miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-let-7-5p
# 3    miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-lin-4-5p
# 4    miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-lsy-6-3p
# ..          ...          ...            ...        ...              ...
# 239  miRTarBase  Generalised  miRTarBase_ID    NCBI_ID    cel-miR-35-3p
# 240  miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-let-7-5p
# 241  miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-let-7-5p
# 242  miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-miR-1-3p
# 243  miRTarBase  Generalised  miRTarBase_ID    NCBI_ID   cel-miR-243-3p
#
#                                       tail_detail_name    species
# 0                   Homeobox domain-containing protein  C.elegans
# 1                                       Protein lin-41  C.elegans
# 2                                       Protein lin-14  C.elegans
# 3                                       Protein lin-28  C.elegans
# 4                   Homeobox domain-containing protein  C.elegans
# ..                                                 ...        ...
# 239    Female germline-specific tumor suppressor gld-1  C.elegans
# 240  B box-type domain-containing protein;B-box typ...  C.elegans
# 241  B box-type domain-containing protein;B-box typ...  C.elegans
# 242                  MEF2 transcription factor homolog  C.elegans
# 243                             Forkhead box protein O  C.elegans
#
# [244 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Mirna_Gene'}
# head_type           : {'Mirna'}
# tail_type           : {'Gene'}
# relation_type       : {None}
# kg_source           : {'miRTarBase'}
# head_id_is          : {'miRTarBase_ID'}
# tail_id_is          : {'NCBI_ID'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 244 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           244                   0             244
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 244  |  After dedup: 169
#            head    relation     tail head_type relation_type tail_type  \
# 0  cel-let-7-5p  Mirna_Gene  C01G8.9     Mirna          None      Gene
# 1  cel-let-7-5p  Mirna_Gene  C12C8.3     Mirna          None      Gene
# 2  cel-let-7-5p  Mirna_Gene  C18D1.1     Mirna          None      Gene
#
#     kg_source      kg_type     head_id_is tail_id_is head_detail_name  \
# 0  miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-let-7-5p
# 1  miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-let-7-5p
# 2  miRTarBase  Generalised  miRTarBase_ID    NCBI_ID     cel-let-7-5p
#
#                       tail_detail_name    species
# 0       ARID domain-containing protein  C.elegans
# 1                       Protein lin-41  C.elegans
# 2  C2H2-type domain-containing protein  C.elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           169                   0             169
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'miRTarBase'} kg_source
# miRTarBase    169
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    169
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 169 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_mirna_gene/Celegans_mirna_gene.csv

# %%
#
