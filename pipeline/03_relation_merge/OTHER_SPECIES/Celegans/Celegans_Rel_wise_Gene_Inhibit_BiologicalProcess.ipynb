# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_gene_inhibits_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_inhibits_biologicalprocess/Celegans_gene_inhibits_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_gene_inhibits_biologicalprocess’: File exists

# %%
#

# %% [markdown]
# # Genage

# %%
Genage = pd.read_csv(PROC_DIR + 'genage/Cele/Cele_Gene_Inhibits_BiologicalProcess.csv')
Genage.columns = Genage.columns.str.lower()
Genage = Genage[~Genage['head_detail_name'].isna()]

Genage['kg_type'] = 'Aging'

print(f"Genage: {len(Genage):,} rows")
Genage['head_id_is'] = 'NCBI_ID'
Genage['tail_id_is'] = 'Quick_GO'
Genage['species'] = 'Caenorhabditis elegans'
Genage['kg_source'] = 'Genage'

Genage
# Out:
# Genage: 278 rows
#         head                         relation        tail head_type  \
# 0      aak-2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1     abu-11  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2      ain-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3      alg-2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 4      arl-8  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# ..       ...                              ...         ...       ...
# 273    mml-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 274  mir-124  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 275   mir-71  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 276  mir-246  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 277  mir-238  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#              tail_type                                   head_detail_name  \
# 0    BiologicalProcess  5'-AMP-activated protein kinase catalytic subu...
# 1    BiologicalProcess     Activated in Blocked Unfolded protein response
# 2    BiologicalProcess                          ALG-1 INteracting protein
# 3    BiologicalProcess                                Protein argonaute-2
# 4    BiologicalProcess            ADP-ribosylation factor-like protein 8B
# ..                 ...                                                ...
# 273  BiologicalProcess  BHLH domain-containing protein;Protein WBSCR14...
# 274  BiologicalProcess                                              ncRNA
# 275  BiologicalProcess                                            miscRNA
# 276  BiologicalProcess                                              ncRNA
# 277  BiologicalProcess                                              ncRNA
#
#     tail_detail_name relation_source                 species  data_type  \
# 0     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 1     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 2     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 3     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 4     obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# ..               ...             ...                     ...        ...
# 273   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 274   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 275   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 276   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
# 277   obsolete aging         GeneAge  Caenorhabditis elegans  Causative
#
#     head_alt_name kg_type head_id_is tail_id_is kg_source
# 0           aak-2   Aging    NCBI_ID   Quick_GO    Genage
# 1          abu-11   Aging    NCBI_ID   Quick_GO    Genage
# 2           ain-1   Aging    NCBI_ID   Quick_GO    Genage
# 3           alg-2   Aging    NCBI_ID   Quick_GO    Genage
# 4           arl-8   Aging    NCBI_ID   Quick_GO    Genage
# ..            ...     ...        ...        ...       ...
# 273         mml-1   Aging    NCBI_ID   Quick_GO    Genage
# 274       mir-124   Aging    NCBI_ID   Quick_GO    Genage
# 275        mir-71   Aging    NCBI_ID   Quick_GO    Genage
# 276       mir-246   Aging    NCBI_ID   Quick_GO    Genage
# 277       mir-238   Aging    NCBI_ID   Quick_GO    Genage
#
# [278 rows x 15 columns]

# %% [markdown]
# # AgingBank

# %%
AgingBank = pd.read_csv(PROC_DIR + 'agingbank/Celegans_AgingbankGene_inhibits_BioPro.csv')
AgingBank.columns = AgingBank.columns.str.lower()
AgingBank = AgingBank[~AgingBank['head_detail_name'].isna()]


AgingBank['tail_type'] = 'BiologicalProcess'
AgingBank['relation'] = 'Gene_Inhibits_BiologicalProcess'

print(f"AgingBank: {len(AgingBank):,} rows")
AgingBank['head_id_is'] = 'NCBI_ID'
AgingBank['tail_id_is'] = 'Quick_GO'
AgingBank['species'] = 'Caenorhabditis elegans'
AgingBank['kg_source'] = 'AgingBank'
AgingBank
# Out:
# AgingBank: 64 rows
#        head                         relation        tail head_type  \
# 0     cbp-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1    DAF-16  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2    DAF-16  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3    DAF-16  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 4    DAF-16  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# ..      ...                              ...         ...       ...
# 59   SACY-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 60    SKN-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 61    SKN-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 62    SPT-4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 63  UNC-104  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#             tail_type  kg_source kg_type  \
# 0   BiologicalProcess  AgingBank   Aging
# 1   BiologicalProcess  AgingBank   Aging
# 2   BiologicalProcess  AgingBank   Aging
# 3   BiologicalProcess  AgingBank   Aging
# 4   BiologicalProcess  AgingBank   Aging
# ..                ...        ...     ...
# 59  BiologicalProcess  AgingBank   Aging
# 60  BiologicalProcess  AgingBank   Aging
# 61  BiologicalProcess  AgingBank   Aging
# 62  BiologicalProcess  AgingBank   Aging
# 63  BiologicalProcess  AgingBank   Aging
#
#                                      head_detail_name tail_detail_name  \
# 0                                       Protein cbp-1            aging
# 1                              Forkhead box protein O            aging
# 2                              Forkhead box protein O            aging
# 3                              Forkhead box protein O            aging
# 4                              Forkhead box protein O            aging
# ..                                                ...              ...
# 59                                       RNA helicase            aging
# 60  BZIP domain-containing protein;Protein skinhead-1            aging
# 61  BZIP domain-containing protein;Protein skinhead-1            aging
# 62               Transcription elongation factor SPT4            aging
# 63                       Kinesin-like protein unc-104            aging
#
#    head_id_is tail_id_is kg_type.1                 species
# 0     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 1     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 2     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 3     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 4     NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# ..        ...        ...       ...                     ...
# 59    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 60    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 61    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 62    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
# 63    NCBI_ID   Quick_GO     Aging  Caenorhabditis elegans
#
# [64 rows x 13 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Genage, AgingBank
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 342
#         head                         relation        tail head_type  \
# 0      aak-2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1     abu-11  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2      ain-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 3      alg-2  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 4      arl-8  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# ..       ...                              ...         ...       ...
# 337   SACY-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 338    SKN-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 339    SKN-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 340    SPT-4  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 341  UNC-104  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#     relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 1            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 2            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 3            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 4            None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# ..            ...                ...        ...     ...        ...        ...
# 337          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 338          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 339          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 340          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 341          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
#
#                                       head_detail_name tail_detail_name  \
# 0    5'-AMP-activated protein kinase catalytic subu...   obsolete aging
# 1       Activated in Blocked Unfolded protein response   obsolete aging
# 2                            ALG-1 INteracting protein   obsolete aging
# 3                                  Protein argonaute-2   obsolete aging
# 4              ADP-ribosylation factor-like protein 8B   obsolete aging
# ..                                                 ...              ...
# 337                                       RNA helicase            aging
# 338  BZIP domain-containing protein;Protein skinhead-1            aging
# 339  BZIP domain-containing protein;Protein skinhead-1            aging
# 340               Transcription elongation factor SPT4            aging
# 341                       Kinesin-like protein unc-104            aging
#
#                     species
# 0    Caenorhabditis elegans
# 1    Caenorhabditis elegans
# 2    Caenorhabditis elegans
# 3    Caenorhabditis elegans
# 4    Caenorhabditis elegans
# ..                      ...
# 337  Caenorhabditis elegans
# 338  Caenorhabditis elegans
# 339  Caenorhabditis elegans
# 340  Caenorhabditis elegans
# 341  Caenorhabditis elegans
#
# [342 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Inhibits_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'Genage', 'AgingBank'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 342 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           342                   0             342
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 342  |  After dedup: 305
#       head                         relation        tail head_type  \
# 0    AGE-1  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 1  C14A4.9  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
# 2  C26B9.3  Gene_Inhibits_BiologicalProcess  GO:0007568      Gene
#
#   relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 1          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 2          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
#
#                       head_detail_name tail_detail_name  \
# 0  Phosphatidylinositol 3-kinase age-1            aging
# 1         C6 domain-containing protein   obsolete aging
# 2              Uncharacterized protein   obsolete aging
#
#                   species
# 0  Caenorhabditis elegans
# 1  Caenorhabditis elegans
# 2  Caenorhabditis elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           305                   0             305
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Genage', 'AgingBank', 'AgingBank::Genage'} kg_source
# Genage               272
# AgingBank             27
# AgingBank::Genage      6
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    305
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 305 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_inhibits_biologicalprocess/Celegans_gene_inhibits_biologicalprocess.csv

# %%
# OUT_PATH

# %%
# !mkdir Celegans_gene_inhibits_biologicalprocess
