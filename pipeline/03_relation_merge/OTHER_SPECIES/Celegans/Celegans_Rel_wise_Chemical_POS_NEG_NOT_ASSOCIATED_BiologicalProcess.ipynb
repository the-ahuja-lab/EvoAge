# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'


# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %% [markdown]
# # POSITIVE ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_chemical_positiveassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_positiveassociated_biologicalprocess/Celegans_chemical_positiveassociated_biologicalprocess.csv'
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_positiveassociated_biologicalprocess’: File exists

# %% [markdown]
# ### Drugage

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Cele_CE_Pos_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_PositivelyAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 360 rows
#         head                                           relation        tail  \
# 0      14985  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1       3973  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2    9929901  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 3     171249  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 4    9823233  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# ..       ...                                                ...         ...
# 357  5281855  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 358     3830  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 359  9964771  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 360       51  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 361    55245  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#           head_type          tail_type  \
# 0    ChemicalEntity  BiologicalProcess
# 1    ChemicalEntity  BiologicalProcess
# 2    ChemicalEntity  BiologicalProcess
# 3    ChemicalEntity  BiologicalProcess
# 4    ChemicalEntity  BiologicalProcess
# ..              ...                ...
# 357  ChemicalEntity  BiologicalProcess
# 358  ChemicalEntity  BiologicalProcess
# 359  ChemicalEntity  BiologicalProcess
# 360  ChemicalEntity  BiologicalProcess
# 361  ChemicalEntity  BiologicalProcess
#
#                                       head_detail_name  \
# 0    (2R)-2,5,7,8-tetramethyl-2-[(4R,8R)-4,8,12-tri...
# 1               2-morpholin-4-yl-8-phenylchromen-4-one
# 2    2-methyl-2-[(3E,7E)-4,8,12-trimethyltrideca-3,...
# 3    manganese(3+);2-[2-[(2-oxidophenyl)methylidene...
# 4    manganese(3+);2-methoxy-6-[2-[(3-methoxy-2-oxi...
# ..                                                 ...
# 357  6,7,13,14-tetrahydroxy-2,9-dioxatetracyclo[6.6...
# 358              N-(furan-2-ylmethyl)-7H-purin-6-amine
# 359               4-[(7H-purin-6-ylamino)methyl]phenol
# 360                             2-oxopentanedioic acid
# 361  (8S,11R,13S,14S,17S)-11-[4-(dimethylamino)phen...
#
#                                        head_smile_name relation_source  \
# 0    CC1=C(C2=C(CC[C@@](O2)(C)CCC[C@H](C)CCC[C@H](C...         DrugAge
# 1        C1COCCN1C2=CC(=O)C3=C(O2)C(=CC=C3)C4=CC=CC=C4         DrugAge
# 2    CC(=CCC/C(=C/CC/C(=C/CCC1(CCC2=C(O1)C=CC(=C2)O...         DrugAge
# 3    C1=CC=C(C(=C1)C=NCCN=CC2=CC=CC=C2[O-])[O-].[Cl...         DrugAge
# 4    COC1=CC=CC(=C1[O-])C=NCCN=CC2=C(C(=CC=C2)OC)[O...         DrugAge
# ..                                                 ...             ...
# 357  C1=C2C3=C(C(=C1O)O)OC(=O)C4=CC(=C(C(=C43)OC2=O...         DrugAge
# 358                     C1=COC(=C1)CNC2=NC=NC3=C2NC=N3         DrugAge
# 359                  C1=CC(=CC=C1CNC2=NC=NC3=C2NC=N3)O         DrugAge
# 360                              C(CC(=O)O)C(=O)C(=O)O         DrugAge
# 361  CC#C[C@@]1(CC[C@@H]2[C@@]1(C[C@@H](C3=C4CCC(=O...         DrugAge
#
#                     species            head_alt_name  ... age_at_initiation  \
# 0    Caenorhabditis elegans                Vitamin E  ...               NaN
# 1    Caenorhabditis elegans                LY-294002  ...               NaN
# 2    Caenorhabditis elegans              Tocotrienol  ...               NaN
# 3    Caenorhabditis elegans                    EUK-8  ...               NaN
# 4    Caenorhabditis elegans                  EUK-134  ...               NaN
# ..                      ...                      ...  ...               ...
# 357  Caenorhabditis elegans             Ellagic acid  ...               NaN
# 358  Caenorhabditis elegans                  Kinetin  ...               NaN
# 359  Caenorhabditis elegans             para-topolin  ...               NaN
# 360  Caenorhabditis elegans  alpha-ketoglutaric acid  ...               NaN
# 361  Caenorhabditis elegans             Mifepristone  ...               NaN
#
#     treatment_duration  avg_lifespan_change_percent     dosage   pubmed_id  \
# 0                  NaN                        23.00        NaN         NaN
# 1                  NaN                        25.00        NaN         NaN
# 2                  NaN                        19.80        NaN         NaN
# 3                  NaN                        33.00        NaN         NaN
# 4                  NaN                        54.00        NaN         NaN
# ..                 ...                          ...        ...         ...
# 357                NaN                         8.99      50 µM  21805983.0
# 358                NaN                        21.00     200 µM  29255944.0
# 359                NaN                         8.00     100 µM  29255944.0
# 360                NaN                        56.25       8 mM  31820364.0
# 361                NaN                        15.00  400 μg/mL  32648907.0
#
#     kg_type  head_id_is tail_id_is kg_source tail_detail_name
# 0     Aging     Pubchem   Quick_GO   Drugage            aging
# 1     Aging     Pubchem   Quick_GO   Drugage            aging
# 2     Aging     Pubchem   Quick_GO   Drugage            aging
# 3     Aging     Pubchem   Quick_GO   Drugage            aging
# 4     Aging     Pubchem   Quick_GO   Drugage            aging
# ..      ...         ...        ...       ...              ...
# 357   Aging     Pubchem   Quick_GO   Drugage            aging
# 358   Aging     Pubchem   Quick_GO   Drugage            aging
# 359   Aging     Pubchem   Quick_GO   Drugage            aging
# 360   Aging     Pubchem   Quick_GO   Drugage            aging
# 361   Aging     Pubchem   Quick_GO   Drugage            aging
#
# [360 rows x 22 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 360
#         head                                           relation        tail  \
# 0      14985  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1       3973  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2    9929901  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 3     171249  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 4    9823233  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# ..       ...                                                ...         ...
# 355  5281855  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 356     3830  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 357  9964771  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 358       51  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 359    55245  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#           head_type relation_type          tail_type kg_source kg_type  \
# 0    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 3    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 4    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# ..              ...           ...                ...       ...     ...
# 355  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 356  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 357  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 358  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 359  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#     head_id_is tail_id_is                                   head_detail_name  \
# 0      Pubchem   Quick_GO  (2R)-2,5,7,8-tetramethyl-2-[(4R,8R)-4,8,12-tri...
# 1      Pubchem   Quick_GO             2-morpholin-4-yl-8-phenylchromen-4-one
# 2      Pubchem   Quick_GO  2-methyl-2-[(3E,7E)-4,8,12-trimethyltrideca-3,...
# 3      Pubchem   Quick_GO  manganese(3+);2-[2-[(2-oxidophenyl)methylidene...
# 4      Pubchem   Quick_GO  manganese(3+);2-methoxy-6-[2-[(3-methoxy-2-oxi...
# ..         ...        ...                                                ...
# 355    Pubchem   Quick_GO  6,7,13,14-tetrahydroxy-2,9-dioxatetracyclo[6.6...
# 356    Pubchem   Quick_GO              N-(furan-2-ylmethyl)-7H-purin-6-amine
# 357    Pubchem   Quick_GO               4-[(7H-purin-6-ylamino)methyl]phenol
# 358    Pubchem   Quick_GO                             2-oxopentanedioic acid
# 359    Pubchem   Quick_GO  (8S,11R,13S,14S,17S)-11-[4-(dimethylamino)phen...
#
#     tail_detail_name                 species
# 0              aging  Caenorhabditis elegans
# 1              aging  Caenorhabditis elegans
# 2              aging  Caenorhabditis elegans
# 3              aging  Caenorhabditis elegans
# 4              aging  Caenorhabditis elegans
# ..               ...                     ...
# 355            aging  Caenorhabditis elegans
# 356            aging  Caenorhabditis elegans
# 357            aging  Caenorhabditis elegans
# 358            aging  Caenorhabditis elegans
# 359            aging  Caenorhabditis elegans
#
# [360 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'ChemicalEntity_PositivelyAssociatedWith_BiologicalProcess'}
# head_type           : {'ChemicalEntity'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'Drugage'}
# head_id_is          : {'Pubchem'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 360 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           360                   0             360
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 360  |  After dedup: 360
#    head                                           relation        tail  \
# 0    51  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 1    72  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
# 2   176  ChemicalEntity_PositivelyAssociatedWith_Biolog...  GO:0007568
#
#         head_type relation_type          tail_type kg_source kg_type  \
# 0  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#   head_id_is tail_id_is           head_detail_name tail_detail_name  \
# 0    Pubchem   Quick_GO     2-oxopentanedioic acid            aging
# 1    Pubchem   Quick_GO  3,4-dihydroxybenzoic acid            aging
# 2    Pubchem   Quick_GO                acetic acid            aging
#
#                   species
# 0  Caenorhabditis elegans
# 1  Caenorhabditis elegans
# 2  Caenorhabditis elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           360                   0             360
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Drugage'} kg_source
# Drugage    360
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    360
# Name: count, dtype: int64

# %%
! mkdir Celegans_chemical_positiveassociated_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_positiveassociated_biologicalprocess’: File exists

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 360 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_positiveassociated_biologicalprocess/Celegans_chemical_positiveassociated_biologicalprocess.csv

# %%
# OUT_PATH

# %% [markdown]
# # NEGATIVE ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_chemical_negativeassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_negativeassociated_biologicalprocess/Celegans_chemical_negativeassociated_biologicalprocess.csv'
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_negativeassociated_biologicalprocess’: File exists

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Cele_CE_Neg_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_NegativelyAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 97 rows
#        head                                           relation        tail  \
# 0      5790  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 1      5793  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 2       753  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 3    162243  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 4    446284  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# ..      ...                                                ...         ...
# 92   123596  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 93     2230  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 95    12035  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 96   124886  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 97  5353800  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
#
#          head_type          tail_type  \
# 0   ChemicalEntity  BiologicalProcess
# 1   ChemicalEntity  BiologicalProcess
# 2   ChemicalEntity  BiologicalProcess
# 3   ChemicalEntity  BiologicalProcess
# 4   ChemicalEntity  BiologicalProcess
# ..             ...                ...
# 92  ChemicalEntity  BiologicalProcess
# 93  ChemicalEntity  BiologicalProcess
# 95  ChemicalEntity  BiologicalProcess
# 96  ChemicalEntity  BiologicalProcess
# 97  ChemicalEntity  BiologicalProcess
#
#                                      head_detail_name  \
# 0   5-fluoro-1-[(2R,4S,5R)-4-hydroxy-5-(hydroxymet...
# 1   (3R,4S,5S,6R)-6-(hydroxymethyl)oxane-2,3,4,5-t...
# 2                                 propane-1,2,3-triol
# 3   (4R)-4-[(5S,8R,9S,10S,13R,14S,17R)-10,13-dimet...
# 4   (5Z,8Z,11Z,14Z,17Z)-icosa-5,8,11,14,17-pentaen...
# ..                                                ...
# 92  methanesulfonic acid;4-[(4-methylpiperazin-1-y...
# 93  methyl 1-methyl-3,6-dihydro-2H-pyridine-5-carb...
# 95          (2R)-2-acetamido-3-sulfanylpropanoic acid
# 96  (2S)-2-amino-5-[[(2R)-1-(carboxymethylamino)-1...
# 97   (3E)-3-(dimethylcarbamoylimino)-1,1-dimethylurea
#
#                                       head_smile_name relation_source  \
# 0       C1[C@@H]([C@H](O[C@H]1N2C=C(C(=O)NC2=O)F)CO)O         DrugAge
# 1          C([C@@H]1[C@H]([C@@H]([C@H](C(O1)O)O)O)O)O         DrugAge
# 2                                          C(C(CO)O)O         DrugAge
# 3   C[C@H](CCCN(C)C)[C@H]1CC[C@@H]2[C@@]1(CC[C@H]3...         DrugAge
# 4            CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCC(=O)O         DrugAge
# ..                                                ...             ...
# 92  CC1=C(C=C(C=C1)NC(=O)C2=CC=C(C=C2)CN3CCN(CC3)C...         DrugAge
# 93                                CN1CCC=C(C1)C(=O)OC         DrugAge
# 95                            CC(=O)N[C@@H](CS)C(=O)O         DrugAge
# 96   C(CC(=O)N[C@@H](CS)C(=O)NCC(=O)O)[C@@H](C(=O)O)N         DrugAge
# 97                          CN(C)C(=O)/N=N/C(=O)N(C)C         DrugAge
#
#                    species          head_alt_name  ... age_at_initiation  \
# 0   Caenorhabditis elegans            Floxuridine  ...               NaN
# 1   Caenorhabditis elegans                Glucose  ...               NaN
# 2   Caenorhabditis elegans               Glycerol  ...               NaN
# 3   Caenorhabditis elegans       25-Azacoprostane  ...               NaN
# 4   Caenorhabditis elegans  Eicosapentaenoic acid  ...               NaN
# ..                     ...                    ...  ...               ...
# 92  Caenorhabditis elegans      Imatinib mesylate  ...               NaN
# 93  Caenorhabditis elegans              Arecoline  ...               NaN
# 95  Caenorhabditis elegans      N-Acetyl Cysteine  ...               NaN
# 96  Caenorhabditis elegans            Glutathione  ...               NaN
# 97  Caenorhabditis elegans                Diamide  ...               NaN
#
#    treatment_duration  avg_lifespan_change_percent   dosage   pubmed_id  \
# 0                 NaN                       -18.66      NaN         NaN
# 1                 NaN                        -7.75      NaN         NaN
# 2                 NaN                       -24.00      NaN         NaN
# 3                 NaN                       -34.80      NaN         NaN
# 4                 NaN                       -20.37      NaN         NaN
# ..                ...                          ...      ...         ...
# 92                NaN                       -58.91  1000 µM  32010883.0
# 93                NaN                       -63.50   0.2 mM  32854519.0
# 95                NaN                       -10.70     5 mM  34267196.0
# 96                NaN                       -13.90     5 mM  34267196.0
# 97                NaN                       -24.88     5 mM  34267196.0
#
#    kg_type  head_id_is tail_id_is kg_source tail_detail_name
# 0    Aging     Pubchem   Quick_GO   Drugage            aging
# 1    Aging     Pubchem   Quick_GO   Drugage            aging
# 2    Aging     Pubchem   Quick_GO   Drugage            aging
# 3    Aging     Pubchem   Quick_GO   Drugage            aging
# 4    Aging     Pubchem   Quick_GO   Drugage            aging
# ..     ...         ...        ...       ...              ...
# 92   Aging     Pubchem   Quick_GO   Drugage            aging
# 93   Aging     Pubchem   Quick_GO   Drugage            aging
# 95   Aging     Pubchem   Quick_GO   Drugage            aging
# 96   Aging     Pubchem   Quick_GO   Drugage            aging
# 97   Aging     Pubchem   Quick_GO   Drugage            aging
#
# [97 rows x 22 columns]

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
    
]
aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 97
#        head                                           relation        tail  \
# 0      5790  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 1      5793  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 2       753  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 3    162243  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 4    446284  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# ..      ...                                                ...         ...
# 92   123596  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 93     2230  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 94    12035  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 95   124886  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
# 96  5353800  ChemicalEntity_NegativelyAssociatedWith_Biolog...  GO:0007568
#
#          head_type relation_type          tail_type kg_source kg_type  \
# 0   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 3   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 4   ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# ..             ...           ...                ...       ...     ...
# 92  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 93  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 94  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 95  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 96  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#    head_id_is tail_id_is                                   head_detail_name  \
# 0     Pubchem   Quick_GO  5-fluoro-1-[(2R,4S,5R)-4-hydroxy-5-(hydroxymet...
# 1     Pubchem   Quick_GO  (3R,4S,5S,6R)-6-(hydroxymethyl)oxane-2,3,4,5-t...
# 2     Pubchem   Quick_GO                                propane-1,2,3-triol
# 3     Pubchem   Quick_GO  (4R)-4-[(5S,8R,9S,10S,13R,14S,17R)-10,13-dimet...
# 4     Pubchem   Quick_GO  (5Z,8Z,11Z,14Z,17Z)-icosa-5,8,11,14,17-pentaen...
# ..        ...        ...                                                ...
# 92    Pubchem   Quick_GO  methanesulfonic acid;4-[(4-methylpiperazin-1-y...
# 93    Pubchem   Quick_GO  methyl 1-methyl-3,6-dihydro-2H-pyridine-5-carb...
# 94    Pubchem   Quick_GO          (2R)-2-acetamido-3-sulfanylpropanoic acid
# 95    Pubchem   Quick_GO  (2S)-2-amino-5-[[(2R)-1-(carboxymethylamino)-1...
# 96    Pubchem   Quick_GO   (3E)-3-(dimethylcarbamoylimino)-1,1-dimethylurea
#
#    tail_detail_name                 species
# 0             aging  Caenorhabditis elegans
# 1             aging  Caenorhabditis elegans
# 2             aging  Caenorhabditis elegans
# 3             aging  Caenorhabditis elegans
# 4             aging  Caenorhabditis elegans
# ..              ...                     ...
# 92            aging  Caenorhabditis elegans
# 93            aging  Caenorhabditis elegans
# 94            aging  Caenorhabditis elegans
# 95            aging  Caenorhabditis elegans
# 96            aging  Caenorhabditis elegans
#
# [97 rows x 13 columns]

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            97                   0              97
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
! mkdir Celegans_chemical_negativeassociated_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_negativeassociated_biologicalprocess’: File exists

# %%
final_df.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df):,} rows → {OUT_PATH}")
# Out:
# Saved 97 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_negativeassociated_biologicalprocess/Celegans_chemical_negativeassociated_biologicalprocess.csv

# %% [markdown]
# # NOT ASSOCIATION

# %%
# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_chemical_notassociated_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_notassociated_biologicalprocess/Celegans_chemical_notassociated_biologicalprocess.csv'
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_notassociated_biologicalprocess’: File exists

# %%
Drugage = pd.read_csv(PROC_DIR + 'drugage/drugage_final/Cele_CE_Not_BioPro_merged.csv')
Drugage.columns = Drugage.columns.str.lower()
Drugage = Drugage[~Drugage['head_detail_name'].isna()]

Drugage['kg_type'] = 'Aging'

print(f"Drugage: {len(Drugage):,} rows")
Drugage['head_id_is'] = 'Pubchem'
Drugage['tail_id_is'] = 'Quick_GO'
Drugage['relation'] = 'ChemicalEntity_NotAssociatedWith_BiologicalProcess'
Drugage['kg_source'] = 'Drugage'
Drugage['tail_detail_name'] = 'aging'
Drugage
# Out:
# Drugage: 198 rows
#          head                                           relation        tail  \
# 0       65064  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 1        6223  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 2      124886  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 3        5780  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 4        5988  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# ..        ...                                                ...         ...
# 194      2230  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 195      2973  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 196   5353800  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 197  13975035  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 198     55245  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
#
#           head_type          tail_type  \
# 0    ChemicalEntity  BiologicalProcess
# 1    ChemicalEntity  BiologicalProcess
# 2    ChemicalEntity  BiologicalProcess
# 3    ChemicalEntity  BiologicalProcess
# 4    ChemicalEntity  BiologicalProcess
# ..              ...                ...
# 194  ChemicalEntity  BiologicalProcess
# 195  ChemicalEntity  BiologicalProcess
# 196  ChemicalEntity  BiologicalProcess
# 197  ChemicalEntity  BiologicalProcess
# 198  ChemicalEntity  BiologicalProcess
#
#                                       head_detail_name  \
# 0    [(2R,3R)-5,7-dihydroxy-2-(3,4,5-trihydroxyphen...
# 1    (1R,7S,8S,11R)-7-hydroxy-11-(hydroxymethyl)-15...
# 2    (2S)-2-amino-5-[[(2R)-1-(carboxymethylamino)-1...
# 3               (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 4    (2R,3R,4S,5S,6R)-2-[(2S,3S,4S,5R)-3,4-dihydrox...
# ..                                                 ...
# 194  methyl 1-methyl-3,6-dihydro-2H-pyridine-5-carb...
# 195  N-[5-[[4-[5-[acetyl(hydroxy)amino]pentylamino]...
# 196   (3E)-3-(dimethylcarbamoylimino)-1,1-dimethylurea
# 197  2-phenyl-2-sulfanylidene-3H-1,3,2lambda5-benzo...
# 198  (8S,11R,13S,14S,17S)-11-[4-(dimethylamino)phen...
#
#                                        head_smile_name relation_source  \
# 0    C1[C@H]([C@H](OC2=CC(=CC(=C21)O)O)C3=CC(=C(C(=...         DrugAge
# 1    CN1C(=O)[C@]23CC4=CC=C[C@@H]([C@H]4N2C(=O)[C@]...         DrugAge
# 2     C(CC(=O)N[C@@H](CS)C(=O)NCC(=O)O)[C@@H](C(=O)O)N         DrugAge
# 3              C([C@H]([C@H]([C@@H]([C@H](CO)O)O)O)O)O         DrugAge
# 4    C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C...         DrugAge
# ..                                                 ...             ...
# 194                                CN1CCC=C(C1)C(=O)OC         DrugAge
# 195  CC(=O)N(CCCCCNC(=O)CCC(=O)N(CCCCCNC(=O)CCC(=O)...         DrugAge
# 196                          CN(C)C(=O)/N=N/C(=O)N(C)C         DrugAge
# 197                  C1=CC=C(C=C1)P2(=S)NC3=CC=CC=C3O2         DrugAge
# 198  CC#C[C@@]1(CC[C@@H]2[C@@]1(C[C@@H](C3=C4CCC(=O...         DrugAge
#
#                     species               head_alt_name  ...  \
# 0    Caenorhabditis elegans  Epigallocatechin-3-gallate  ...
# 1    Caenorhabditis elegans                   Gliotoxin  ...
# 2    Caenorhabditis elegans                 Glutathione  ...
# 3    Caenorhabditis elegans                    Sorbitol  ...
# 4    Caenorhabditis elegans                     Sucrose  ...
# ..                      ...                         ...  ...
# 194  Caenorhabditis elegans                   Arecoline  ...
# 195  Caenorhabditis elegans                Deferoxamine  ...
# 196  Caenorhabditis elegans                     Diamide  ...
# 197  Caenorhabditis elegans                      FW1256  ...
# 198  Caenorhabditis elegans                Mifepristone  ...
#
#     age_at_initiation treatment_duration  avg_lifespan_change_percent  \
# 0                 NaN                NaN                         4.80
# 1                 NaN                NaN                         0.90
# 2                 NaN                NaN                          NaN
# 3                 NaN                NaN                        -2.00
# 4                 NaN                NaN                        -4.00
# ..                ...                ...                          ...
# 194               NaN                NaN                       -15.95
# 195               NaN                NaN                        -4.45
# 196               NaN                NaN                         1.74
# 197               NaN                NaN                         0.55
# 198               NaN                NaN                        -9.00
#
#         dosage   pubmed_id kg_type  head_id_is tail_id_is kg_source  \
# 0          NaN         NaN   Aging     Pubchem   Quick_GO   Drugage
# 1          NaN         NaN   Aging     Pubchem   Quick_GO   Drugage
# 2          NaN         NaN   Aging     Pubchem   Quick_GO   Drugage
# 3          NaN         NaN   Aging     Pubchem   Quick_GO   Drugage
# 4          NaN         NaN   Aging     Pubchem   Quick_GO   Drugage
# ..         ...         ...     ...         ...        ...       ...
# 194     0.2 mM  32854519.0   Aging     Pubchem   Quick_GO   Drugage
# 195     100 µM  22445852.0   Aging     Pubchem   Quick_GO   Drugage
# 196     2.5 mM  34267196.0   Aging     Pubchem   Quick_GO   Drugage
# 197      10 µM  32566245.0   Aging     Pubchem   Quick_GO   Drugage
# 198  400 μg/mL  32648907.0   Aging     Pubchem   Quick_GO   Drugage
#
#     tail_detail_name
# 0              aging
# 1              aging
# 2              aging
# 3              aging
# 4              aging
# ..               ...
# 194            aging
# 195            aging
# 196            aging
# 197            aging
# 198            aging
#
# [198 rows x 22 columns]

# %%
# List all source DataFrames to include
source_dfs = [
    Drugage
    
]
aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 198
#          head                                           relation        tail  \
# 0       65064  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 1        6223  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 2      124886  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 3        5780  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 4        5988  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# ..        ...                                                ...         ...
# 193      2230  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 194      2973  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 195   5353800  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 196  13975035  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
# 197     55245  ChemicalEntity_NotAssociatedWith_BiologicalPro...  GO:0007568
#
#           head_type relation_type          tail_type kg_source kg_type  \
# 0    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 1    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 2    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 3    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 4    ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# ..              ...           ...                ...       ...     ...
# 193  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 194  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 195  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 196  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
# 197  ChemicalEntity          None  BiologicalProcess   Drugage   Aging
#
#     head_id_is tail_id_is                                   head_detail_name  \
# 0      Pubchem   Quick_GO  [(2R,3R)-5,7-dihydroxy-2-(3,4,5-trihydroxyphen...
# 1      Pubchem   Quick_GO  (1R,7S,8S,11R)-7-hydroxy-11-(hydroxymethyl)-15...
# 2      Pubchem   Quick_GO  (2S)-2-amino-5-[[(2R)-1-(carboxymethylamino)-1...
# 3      Pubchem   Quick_GO             (2R,3R,4R,5S)-hexane-1,2,3,4,5,6-hexol
# 4      Pubchem   Quick_GO  (2R,3R,4S,5S,6R)-2-[(2S,3S,4S,5R)-3,4-dihydrox...
# ..         ...        ...                                                ...
# 193    Pubchem   Quick_GO  methyl 1-methyl-3,6-dihydro-2H-pyridine-5-carb...
# 194    Pubchem   Quick_GO  N-[5-[[4-[5-[acetyl(hydroxy)amino]pentylamino]...
# 195    Pubchem   Quick_GO   (3E)-3-(dimethylcarbamoylimino)-1,1-dimethylurea
# 196    Pubchem   Quick_GO  2-phenyl-2-sulfanylidene-3H-1,3,2lambda5-benzo...
# 197    Pubchem   Quick_GO  (8S,11R,13S,14S,17S)-11-[4-(dimethylamino)phen...
#
#     tail_detail_name                 species
# 0              aging  Caenorhabditis elegans
# 1              aging  Caenorhabditis elegans
# 2              aging  Caenorhabditis elegans
# 3              aging  Caenorhabditis elegans
# 4              aging  Caenorhabditis elegans
# ..               ...                     ...
# 193            aging  Caenorhabditis elegans
# 194            aging  Caenorhabditis elegans
# 195            aging  Caenorhabditis elegans
# 196            aging  Caenorhabditis elegans
# 197            aging  Caenorhabditis elegans
#
# [198 rows x 13 columns]

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           198                   0             198
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
! mkdir Celegans_chemical_notassociated_biologicalprocess
# Out:
# mkdir: cannot create directory ‘Celegans_chemical_notassociated_biologicalprocess’: File exists

# %%
OUT_PATH
# Out:
# '/storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_notassociated_biologicalprocess/Celegans_chemical_notassociated_biologicalprocess.csv'

# %%
final_df.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df):,} rows → {OUT_PATH}")
# Out:
# Saved 198 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_chemical_notassociated_biologicalprocess/Celegans_chemical_notassociated_biologicalprocess.csv
