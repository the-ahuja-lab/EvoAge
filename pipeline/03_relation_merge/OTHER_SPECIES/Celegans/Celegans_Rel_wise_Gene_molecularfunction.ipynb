# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %%
# Gene → CellularComponent
# Monarch/Monarch_final/Celegans/Gene_Cele_CellularComponent.csv

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_gene_MolecularFunction
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_MolecularFunction/Celegans_gene_MolecularFunction.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_gene_MolecularFunction’: File exists

# %%
# cele = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Caenorhabditis_elegans.gene_info',
#     sep='\t',
    
# )
# cele["LocusTag"] = cele["LocusTag"].str.replace("CELE_", "", regex=False)

# cele_symbol2Locus_dict = dict(zip(cele['Symbol'], cele['LocusTag']))
# cele
# # cele_symbol2Locus_dict

# %%
PROC_DIR#+Monarch/Monarch_final/Celegans
# !ls /storage/Arushi/090526_EvoAge/kg_formation/processed_data/Monarch/Monarch_final/Celegans
# Out:
# Cele_AnatomicalEntity_AnatomicalEntity.csv    Gene_Cele_Anatomy.csv
# Cele_Gene_Pathway.csv			      Gene_Cele_BiologicalProcess.csv
# Cele_Phenotype_CellularComponent.csv	      Gene_Cele_CellularComponent.csv
# Cele_Phenotype_ChemicalEntity.csv	      Gene_Cele_MolecularFunction.csv
# Cele_PhenotypicFeature_BiologicalProcess.csv  Gene_Cele_Phenotype.csv
# Cele_PhenotypicFeature_MolecularFunction.csv  GENE_GENE_Cele_Cele.csv

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Celegans/Gene_Cele_MolecularFunction.csv')
monarch.columns = monarch.columns.str.lower()
monarch['kg_type'] = 'Generalised'
monarch['species'] = 'C.elegans'

monarch['kg_source'] = 'Monarch_KG'


print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 39,781 rows
#             head                relation        tail head_type relation_type  \
# 0      Y75B8A.14  Gene_MolecularFunction  GO:0005515      Gene       enables
# 1      Y75B8A.14  Gene_MolecularFunction  GO:0005515      Gene       enables
# 2      Y75B8A.14  Gene_MolecularFunction  GO:0005525      Gene       enables
# 3      Y75B8A.14  Gene_MolecularFunction  GO:0016787      Gene       enables
# 4      Y75B8A.17  Gene_MolecularFunction  GO:0005515      Gene       enables
# ...          ...                     ...         ...       ...           ...
# 39776   Y75B8A.6  Gene_MolecularFunction  GO:0008270      Gene       enables
# 39777   Y75B8A.6  Gene_MolecularFunction  GO:0017056      Gene       enables
# 39778   Y75B8A.6  Gene_MolecularFunction  GO:0046872      Gene       enables
# 39779  Y75B8A.10  Gene_MolecularFunction  GO:0046872      Gene       enables
# 39780  Y75B8A.11  Gene_MolecularFunction  GO:0071855      Gene       enables
#
#                tail_type   relation_source  \
# 0      MolecularFunction    infores:intact
# 1      MolecularFunction    infores:intact
# 2      MolecularFunction   infores:uniprot
# 3      MolecularFunction   infores:uniprot
# 4      MolecularFunction   infores:uniprot
# ...                  ...               ...
# 39776  MolecularFunction  infores:interpro
# 39777  MolecularFunction  infores:interpro
# 39778  MolecularFunction   infores:uniprot
# 39779  MolecularFunction   infores:uniprot
# 39780  MolecularFunction   infores:uniprot
#
#                           head_detail_name  \
# 0                        GPN-loop GTPase 3
# 1                        GPN-loop GTPase 3
# 2                        GPN-loop GTPase 3
# 3                        GPN-loop GTPase 3
# 4                          Geminin homolog
# ...                                    ...
# 39776  CXXC-type domain-containing protein
# 39777  CXXC-type domain-containing protein
# 39778  CXXC-type domain-containing protein
# 39779  RING-type domain-containing protein
# 39780                             LURY-1-2
#
#                              tail_detail_name         head_taxon_name  \
# 0                             protein binding  Caenorhabditis elegans
# 1                             protein binding  Caenorhabditis elegans
# 2                                 GTP binding  Caenorhabditis elegans
# 3                          hydrolase activity  Caenorhabditis elegans
# 4                             protein binding  Caenorhabditis elegans
# ...                                       ...                     ...
# 39776                        zinc ion binding  Caenorhabditis elegans
# 39777  structural constituent of nuclear pore  Caenorhabditis elegans
# 39778                       metal ion binding  Caenorhabditis elegans
# 39779                       metal ion binding  Caenorhabditis elegans
# 39780           neuropeptide receptor binding  Caenorhabditis elegans
#
#        tail_taxon_name head_id_is tail_id_is  head_name    species  \
# 0                  NaN   WormBase   Quick_GO      gex-4  C.elegans
# 1                  NaN   WormBase   Quick_GO      gex-4  C.elegans
# 2                  NaN   WormBase   Quick_GO      gex-4  C.elegans
# 3                  NaN   WormBase   Quick_GO      gex-4  C.elegans
# 4                  NaN   WormBase   Quick_GO      gmn-1  C.elegans
# ...                ...        ...        ...        ...        ...
# 39776              NaN   WormBase   Quick_GO   Y75B8A.6  C.elegans
# 39777              NaN   WormBase   Quick_GO   Y75B8A.6  C.elegans
# 39778              NaN   WormBase   Quick_GO   Y75B8A.6  C.elegans
# 39779              NaN   WormBase   Quick_GO  Y75B8A.10  C.elegans
# 39780              NaN   WormBase   Quick_GO     lury-1  C.elegans
#
#            kg_type   kg_source
# 0      Generalised  Monarch_KG
# 1      Generalised  Monarch_KG
# 2      Generalised  Monarch_KG
# 3      Generalised  Monarch_KG
# 4      Generalised  Monarch_KG
# ...            ...         ...
# 39776  Generalised  Monarch_KG
# 39777  Generalised  Monarch_KG
# 39778  Generalised  Monarch_KG
# 39779  Generalised  Monarch_KG
# 39780  Generalised  Monarch_KG
#
# [39781 rows x 17 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
     monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 39,781
#             head                relation        tail head_type relation_type  \
# 0      Y75B8A.14  Gene_MolecularFunction  GO:0005515      Gene       enables
# 1      Y75B8A.14  Gene_MolecularFunction  GO:0005515      Gene       enables
# 2      Y75B8A.14  Gene_MolecularFunction  GO:0005525      Gene       enables
# 3      Y75B8A.14  Gene_MolecularFunction  GO:0016787      Gene       enables
# 4      Y75B8A.17  Gene_MolecularFunction  GO:0005515      Gene       enables
# ...          ...                     ...         ...       ...           ...
# 39776   Y75B8A.6  Gene_MolecularFunction  GO:0008270      Gene       enables
# 39777   Y75B8A.6  Gene_MolecularFunction  GO:0017056      Gene       enables
# 39778   Y75B8A.6  Gene_MolecularFunction  GO:0046872      Gene       enables
# 39779  Y75B8A.10  Gene_MolecularFunction  GO:0046872      Gene       enables
# 39780  Y75B8A.11  Gene_MolecularFunction  GO:0071855      Gene       enables
#
#                tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0      MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 1      MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 2      MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 3      MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 4      MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# ...                  ...         ...          ...        ...        ...
# 39776  MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 39777  MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 39778  MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 39779  MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 39780  MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
#
#                           head_detail_name  \
# 0                        GPN-loop GTPase 3
# 1                        GPN-loop GTPase 3
# 2                        GPN-loop GTPase 3
# 3                        GPN-loop GTPase 3
# 4                          Geminin homolog
# ...                                    ...
# 39776  CXXC-type domain-containing protein
# 39777  CXXC-type domain-containing protein
# 39778  CXXC-type domain-containing protein
# 39779  RING-type domain-containing protein
# 39780                             LURY-1-2
#
#                              tail_detail_name    species
# 0                             protein binding  C.elegans
# 1                             protein binding  C.elegans
# 2                                 GTP binding  C.elegans
# 3                          hydrolase activity  C.elegans
# 4                             protein binding  C.elegans
# ...                                       ...        ...
# 39776                        zinc ion binding  C.elegans
# 39777  structural constituent of nuclear pore  C.elegans
# 39778                       metal ion binding  C.elegans
# 39779                       metal ion binding  C.elegans
# 39780           neuropeptide receptor binding  C.elegans
#
# [39781 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_MolecularFunction'}
# head_type           : {'Gene'}
# tail_type           : {'MolecularFunction'}
# relation_type       : {'contributes_to', 'enables'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'WormBase'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 39,781 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                     63                  63             126
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name         63                  63             126
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 39,781  |  After dedup: 27,235
#       head                relation        tail head_type relation_type  \
# 0  2RSSE.1  Gene_MolecularFunction  GO:0005096      Gene       enables
# 1    3R5.1  Gene_MolecularFunction  GO:0003677      Gene       enables
# 2    3R5.1  Gene_MolecularFunction  GO:0043047      Gene       enables
#
#            tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0  MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 1  MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
# 2  MolecularFunction  Monarch_KG  Generalised   WormBase   Quick_GO
#
#                                     head_detail_name  \
# 0                  Rho-GAP domain-containing protein
# 1  Protection of telomeres protein 1 ssDNA-bindin...
# 2  Protection of telomeres protein 1 ssDNA-bindin...
#
#                         tail_detail_name    species
# 0              GTPase activator activity  C.elegans
# 1                            DNA binding  C.elegans
# 2  single-stranded telomeric DNA binding  C.elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    27235
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    27235
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 27,235 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_MolecularFunction/Celegans_gene_MolecularFunction.csv

# %%
#
