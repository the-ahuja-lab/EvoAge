# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans

# %% [markdown]
# # Databases Having Gene biologicalprocess relation of celegans

# %%
# gendr/Cele/Cele_GenDR_Gene_BioProcess.csv
# Monarch/Monarch_final/Celegans/Gene_Cele_BiologicalProcess.csv

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Celegans_gene_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_biologicalprocess/Celegans_gene_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Celegans_gene_biologicalprocess’: File exists

# %%
cele = pd.read_csv(
    f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Caenorhabditis_elegans.gene_info',
    sep='\t',
    
)
cele["LocusTag"] = cele["LocusTag"].str.replace("CELE_", "", regex=False)

cele_symbol2Locus_dict = dict(zip(cele['Symbol'], cele['LocusTag']))
cele
# cele_symbol2Locus_dict
# Out:
#        #tax_id    GeneID     Symbol    LocusTag Synonyms  \
# 0         6239    171590     homt-1    Y74C9A.3        -
# 1         6239    171591     nlp-40    Y74C9A.2        -
# 2         6239    171592     rcor-1    Y74C9A.4        -
# 3         6239    171593     sesn-1    Y74C9A.5        -
# 4         6239    171594      pgs-1    Y48G1C.4        -
# ...        ...       ...        ...         ...      ...
# 46922     6239  80510347     azyx-1    F42G4.11        -
# 46923     6239  80510348  F54D10.10   F54D10.10        -
# 46924     6239  80510349   F58B6.11    F58B6.11        -
# 46925     6239  80510350  Y34B4A.20   Y34B4A.20        -
# 46926     6239  80510351     ceh-44  Y54F10AM.4        -
#
#                                                  dbXrefs chromosome  \
# 0      WormBase:WBGene00022277|AllianceGenome:WB:WBGe...          I
# 1      WormBase:WBGene00022276|AllianceGenome:WB:WBGe...          I
# 2      WormBase:WBGene00022278|AllianceGenome:WB:WBGe...          I
# 3      WormBase:WBGene00022279|AllianceGenome:WB:WBGe...          I
# 4      WormBase:WBGene00021677|AllianceGenome:WB:WBGe...          I
# ...                                                  ...        ...
# 46922  WormBase:WBGene00306133|AllianceGenome:WB:WBGe...         II
# 46923  WormBase:WBGene00306132|AllianceGenome:WB:WBGe...         II
# 46924  WormBase:WBGene00306125|AllianceGenome:WB:WBGe...        III
# 46925  WormBase:WBGene00306131|AllianceGenome:WB:WBGe...          X
# 46926  WormBase:WBGene00000464|AllianceGenome:WB:WBGe...        III
#
#       map_location                                        description  \
# 0                -       Alpha N-terminal protein methyltransferase 1
# 1                -                                         Peptide P4
# 2                -                            REST corepressor rcor-1
# 3                -                                    Sestrin homolog
# 4                -  CDP-diacylglycerol--glycerol-3-phosphate 3-pho...
# ...            ...                                                ...
# 46922            -  Alternative N-terminal open reading frame of Z...
# 46923            -                            Uncharacterized protein
# 46924            -                            Uncharacterized protein
# 46925            -                            Uncharacterized protein
# 46926            -                   Homeobox protein cut-like ceh-44
#
#          type_of_gene Symbol_from_nomenclature_authority  \
# 0      protein-coding                             homt-1
# 1      protein-coding                             nlp-40
# 2      protein-coding                             rcor-1
# 3      protein-coding                             sesn-1
# 4      protein-coding                              pgs-1
# ...               ...                                ...
# 46922  protein-coding                             azyx-1
# 46923  protein-coding                          F54D10.10
# 46924  protein-coding                           F58B6.11
# 46925  protein-coding                          Y34B4A.20
# 46926  protein-coding                             ceh-44
#
#                    Full_name_from_nomenclature_authority Nomenclature_status  \
# 0           Alpha N-terminal protein methyltransferase 1                   O
# 1                                             Peptide P4                   O
# 2                                REST corepressor rcor-1                   O
# 3                                        Sestrin homolog                   O
# 4      CDP-diacylglycerol--glycerol-3-phosphate 3-pho...                   O
# ...                                                  ...                 ...
# 46922  Alternative N-terminal open reading frame of Z...                   O
# 46923                            Uncharacterized protein                   O
# 46924                            Uncharacterized protein                   O
# 46925                            Uncharacterized protein                   O
# 46926                   Homeobox protein cut-like ceh-44                   O
#
#                                       Other_designations  Modification_date  \
# 0           Alpha N-terminal protein methyltransferase 1           20250308
# 1                                             Peptide P4           20250308
# 2                                REST corepressor rcor-1           20250308
# 3                                        Sestrin homolog           20250308
# 4      CDP-diacylglycerol--glycerol-3-phosphate 3-pho...           20250308
# ...                                                  ...                ...
# 46922  Alternative N-terminal open reading frame of Z...           20250308
# 46923                            Uncharacterized protein           20241028
# 46924                            Uncharacterized protein           20241028
# 46925                            Uncharacterized protein           20241028
# 46926                   Homeobox protein cut-like ceh-44           20250308
#
#       Feature_type
# 0                -
# 1                -
# 2                -
# 3                -
# 4                -
# ...            ...
# 46922            -
# 46923            -
# 46924            -
# 46925            -
# 46926            -
#
# [46927 rows x 16 columns]

# %% [markdown]
# # genDR

# %%
genDR = pd.read_csv(PROC_DIR + 'gendr/Cele/Cele_GenDR_Gene_BioProcess.csv')
genDR.columns = genDR.columns.str.lower()
genDR['head'] = genDR['head'].map(cele_symbol2Locus_dict).fillna(genDR['head'])
genDR['kg_type'] = 'Aging'
genDR['species'] = 'C.elegans'
genDR['head_id_is'] = 'NCBI_ID'
genDR['tail_id_is'] = 'Quick_GO'
genDR['kg_source'] = 'GenDR'
genDR['relation'] = 'Gene_BiologicalProcess'
genDR['tail_type'] = 'BiologicalProcess'

print(f"genDR: {len(genDR):,} rows")
genDR
# Out:
# genDR: 60 rows
#           head                relation        tail head_type  \
# 0      R13H8.1  Gene_BiologicalProcess  GO:0061771      Gene
# 1     Y55D5A.5  Gene_BiologicalProcess  GO:0061771      Gene
# 2      ZC395.2  Gene_BiologicalProcess  GO:0061771      Gene
# 3      C49F5.1  Gene_BiologicalProcess  GO:0061771      Gene
# 4      T23H2.5  Gene_BiologicalProcess  GO:0061771      Gene
# 5     F45H10.4  Gene_BiologicalProcess  GO:0061771      Gene
# 6      T12D8.2  Gene_BiologicalProcess  GO:0061771      Gene
# 7      R11A8.4  Gene_BiologicalProcess  GO:0061771      Gene
# 8      B0261.2  Gene_BiologicalProcess  GO:0061771      Gene
# 9      B0334.8  Gene_BiologicalProcess  GO:0061771      Gene
# 10     F38A6.1  Gene_BiologicalProcess  GO:0061771      Gene
# 11     F41E6.4  Gene_BiologicalProcess  GO:0061771      Gene
# 12     T19E7.2  Gene_BiologicalProcess  GO:0061771      Gene
# 13     T01C8.1  Gene_BiologicalProcess  GO:0061771      Gene
# 14     T19E7.3  Gene_BiologicalProcess  GO:0061771      Gene
# 15        M7.5  Gene_BiologicalProcess  GO:0061771      Gene
# 16     B0025.1  Gene_BiologicalProcess  GO:0061771      Gene
# 17  Y53C10A.12  Gene_BiologicalProcess  GO:0061771      Gene
# 18     F54C8.5  Gene_BiologicalProcess  GO:0061771      Gene
# 19    F38E11.2  Gene_BiologicalProcess  GO:0061771      Gene
# 20     F38A6.3  Gene_BiologicalProcess  GO:0061771      Gene
# 21     C41C4.4  Gene_BiologicalProcess  GO:0061771      Gene
# 22    F22E12.4  Gene_BiologicalProcess  GO:0061771      Gene
# 23   Y65B4BR.4  Gene_BiologicalProcess  GO:0061771      Gene
# 24     R01H2.6  Gene_BiologicalProcess  GO:0061771      Gene
# 25     F18E9.2  Gene_BiologicalProcess  GO:0061771      Gene
# 26     C02C2.3  Gene_BiologicalProcess  GO:0061771      Gene
# 27    Y58G8A.1  Gene_BiologicalProcess  GO:0061771      Gene
# 28     R13A5.1  Gene_BiologicalProcess  GO:0061771      Gene
# 29     T23B3.4  Gene_BiologicalProcess  GO:0061771      Gene
# 30    Y39A3B.5  Gene_BiologicalProcess  GO:0061771      Gene
# 31    R10E11.1  Gene_BiologicalProcess  GO:0061771      Gene
# 32    ZK1193.5  Gene_BiologicalProcess  GO:0061771      Gene
# 33    Y48B6A.4  Gene_BiologicalProcess  GO:0061771      Gene
# 34     K02B9.4  Gene_BiologicalProcess  GO:0061771      Gene
# 35     B0218.1  Gene_BiologicalProcess  GO:0061771      Gene
# 36     B0228.5  Gene_BiologicalProcess  GO:0061771      Gene
# 37     F59F5.1  Gene_BiologicalProcess  GO:0061771      Gene
# 38    Y60A3A.1  Gene_BiologicalProcess  GO:0061771      Gene
# 39    ZK1321.2  Gene_BiologicalProcess  GO:0061771      Gene
# 40     F57A8.4  Gene_BiologicalProcess  GO:0061771      Gene
# 41       CHA-1  Gene_BiologicalProcess  GO:0061771      Gene
# 42    Y67A6A.2  Gene_BiologicalProcess  GO:0061771      Gene
# 43    Y81G3A.3  Gene_BiologicalProcess  GO:0061771      Gene
# 44     F40F8.7  Gene_BiologicalProcess  GO:0061771      Gene
# 45    F55G11.5  Gene_BiologicalProcess  GO:0061771      Gene
# 46    C04F12.3  Gene_BiologicalProcess  GO:0061771      Gene
# 47    ZC455.10  Gene_BiologicalProcess  GO:0061771      Gene
# 48    F18F11.5  Gene_BiologicalProcess  GO:0061771      Gene
# 49   Y38C1AA.3  Gene_BiologicalProcess  GO:0061771      Gene
# 50    F56F11.3  Gene_BiologicalProcess  GO:0061771      Gene
# 51     ZC373.1  Gene_BiologicalProcess  GO:0061771      Gene
# 52    F56D12.1  Gene_BiologicalProcess  GO:0061771      Gene
# 53     F29G9.4  Gene_BiologicalProcess  GO:0061771      Gene
# 54     T07A9.3  Gene_BiologicalProcess  GO:0061771      Gene
# 55     K08A8.1  Gene_BiologicalProcess  GO:0061771      Gene
# 56   K11D12.10  Gene_BiologicalProcess  GO:0061771      Gene
# 57     F59A6.1  Gene_BiologicalProcess  GO:0061771      Gene
# 58     K09A9.5  Gene_BiologicalProcess  GO:0061771      Gene
# 59     K08C7.5  Gene_BiologicalProcess  GO:0061771      Gene
#
#             tail_type                                   head_detail_name  \
# 0   BiologicalProcess                             Forkhead box protein O
# 1   BiologicalProcess  Insulin-like receptor subunit beta;Protein kin...
# 2   BiologicalProcess   5-demethoxyubiquinone hydroxylase, mitochondrial
# 3   BiologicalProcess           putative S-adenosylmethionine synthase 1
# 4   BiologicalProcess                         Ras-related protein Rab-10
# 5   BiologicalProcess                   MARVEL domain-containing protein
# 6   BiologicalProcess             Serine/arginine-rich splicing factor 2
# 7   BiologicalProcess  Deacetylase sirtuin-type domain-containing pro...
# 8   BiologicalProcess                        Target of rapamycin homolog
# 9   BiologicalProcess                Phosphatidylinositol 3-kinase age-1
# 10  BiologicalProcess         Defective pharyngeal development protein 4
# 11  BiologicalProcess  Serine/threonine-protein phosphatase 4 regulat...
# 12  BiologicalProcess  BZIP domain-containing protein;Protein skinhead-1
# 13  BiologicalProcess  5'-AMP-activated protein kinase catalytic subu...
# 14  BiologicalProcess                                     Beclin homolog
# 15  BiologicalProcess     Ubiquitin-like modifier-activating enzyme ATG7
# 16  BiologicalProcess  Phosphatidylinositol 3-kinase catalytic subuni...
# 17  BiologicalProcess              Heat shock transcription factor hsf-1
# 18  BiologicalProcess                 GTP-binding protein Rheb homolog 1
# 19  BiologicalProcess                     SHSP domain-containing protein
# 20  BiologicalProcess  Hypoxia-inducible factor 1;PAS domain-containi...
# 21  BiologicalProcess   Endoribonuclease;Serine/threonine-protein kinase
# 22  BiologicalProcess        Hypoxia-inducible factor prolyl hydroxylase
# 23  BiologicalProcess                  E3 ubiquitin-protein ligase wwp-1
# 24  BiologicalProcess             Ubiquitin-conjugating enzyme E2 ubc-18
# 25  BiologicalProcess                        Neuropeptide-like protein 7
# 26  BiologicalProcess          Acetylcholine receptor-like protein cup-4
# 27  BiologicalProcess  Neurotransmitter-gated ion-channel ligand-bind...
# 28  BiologicalProcess  Polycystin cation channel PKD1/PKD2 domain-con...
# 29  BiologicalProcess  G-protein coupled receptors family 1 profile d...
# 30  BiologicalProcess  G-protein coupled receptors family 1 profile d...
# 31  BiologicalProcess                                      Protein cbp-1
# 32  BiologicalProcess                             Homeobox protein dve-1
# 33  BiologicalProcess      Neuronal acetylcholine receptor subunit eat-2
# 34  BiologicalProcess                         Transcription factor elt-3
# 35  BiologicalProcess                       Fatty acid amide hydrolase 1
# 36  BiologicalProcess                                      Thioredoxin-1
# 37  BiologicalProcess                      MFS domain-containing protein
# 38  BiologicalProcess             Serine/threonine-protein kinase unc-51
# 39  BiologicalProcess      Potassium voltage-gated channel protein shk-1
# 40  BiologicalProcess  G-protein coupled receptors family 1 profile d...
# 41  BiologicalProcess                        Choline O-acetyltransferase
# 42  BiologicalProcess  NR LBD domain-containing protein;Nuclear hormo...
# 43  BiologicalProcess  Eukaryotic translation initiation factor 2-alp...
# 44  BiologicalProcess             Zinc finger transcription factor pqm-1
# 45  BiologicalProcess                 CUB-like domain-containing protein
# 46  BiologicalProcess                    Death domain-containing protein
# 47  BiologicalProcess                           peptidylprolyl isomerase
# 48  BiologicalProcess                                      Protein drl-1
# 49  BiologicalProcess                                     nicotinamidase
# 50  BiologicalProcess                              Kruppel-like factor 1
# 51  BiologicalProcess                  Cystathionine beta-synthase cbs-1
# 52  BiologicalProcess  Aldehyde dehydrogenase domain-containing prote...
# 53  BiologicalProcess                         Transcription factor fos-1
# 54  BiologicalProcess                               GLH-binding kinase 1
# 55  BiologicalProcess  Dual specificity mitogen-activated protein kin...
# 56  BiologicalProcess  Mitogen-activated protein kinase kinase kinase...
# 57  BiologicalProcess  Mitogen-activated protein kinase kinase kinase...
# 58  BiologicalProcess  putative NADH dehydrogenase [ubiquinone] iron-...
# 59  BiologicalProcess                    Flavin-containing monooxygenase
#
#                    tail_detail_name relation_source    species kg_type  \
# 0   response to caloric restriction           GenDR  C.elegans   Aging
# 1   response to caloric restriction           GenDR  C.elegans   Aging
# 2   response to caloric restriction           GenDR  C.elegans   Aging
# 3   response to caloric restriction           GenDR  C.elegans   Aging
# 4   response to caloric restriction           GenDR  C.elegans   Aging
# 5   response to caloric restriction           GenDR  C.elegans   Aging
# 6   response to caloric restriction           GenDR  C.elegans   Aging
# 7   response to caloric restriction           GenDR  C.elegans   Aging
# 8   response to caloric restriction           GenDR  C.elegans   Aging
# 9   response to caloric restriction           GenDR  C.elegans   Aging
# 10  response to caloric restriction           GenDR  C.elegans   Aging
# 11  response to caloric restriction           GenDR  C.elegans   Aging
# 12  response to caloric restriction           GenDR  C.elegans   Aging
# 13  response to caloric restriction           GenDR  C.elegans   Aging
# 14  response to caloric restriction           GenDR  C.elegans   Aging
# 15  response to caloric restriction           GenDR  C.elegans   Aging
# 16  response to caloric restriction           GenDR  C.elegans   Aging
# 17  response to caloric restriction           GenDR  C.elegans   Aging
# 18  response to caloric restriction           GenDR  C.elegans   Aging
# 19  response to caloric restriction           GenDR  C.elegans   Aging
# 20  response to caloric restriction           GenDR  C.elegans   Aging
# 21  response to caloric restriction           GenDR  C.elegans   Aging
# 22  response to caloric restriction           GenDR  C.elegans   Aging
# 23  response to caloric restriction           GenDR  C.elegans   Aging
# 24  response to caloric restriction           GenDR  C.elegans   Aging
# 25  response to caloric restriction           GenDR  C.elegans   Aging
# 26  response to caloric restriction           GenDR  C.elegans   Aging
# 27  response to caloric restriction           GenDR  C.elegans   Aging
# 28  response to caloric restriction           GenDR  C.elegans   Aging
# 29  response to caloric restriction           GenDR  C.elegans   Aging
# 30  response to caloric restriction           GenDR  C.elegans   Aging
# 31  response to caloric restriction           GenDR  C.elegans   Aging
# 32  response to caloric restriction           GenDR  C.elegans   Aging
# 33  response to caloric restriction           GenDR  C.elegans   Aging
# 34  response to caloric restriction           GenDR  C.elegans   Aging
# 35  response to caloric restriction           GenDR  C.elegans   Aging
# 36  response to caloric restriction           GenDR  C.elegans   Aging
# 37  response to caloric restriction           GenDR  C.elegans   Aging
# 38  response to caloric restriction           GenDR  C.elegans   Aging
# 39  response to caloric restriction           GenDR  C.elegans   Aging
# 40  response to caloric restriction           GenDR  C.elegans   Aging
# 41  response to caloric restriction           GenDR  C.elegans   Aging
# 42  response to caloric restriction           GenDR  C.elegans   Aging
# 43  response to caloric restriction           GenDR  C.elegans   Aging
# 44  response to caloric restriction           GenDR  C.elegans   Aging
# 45  response to caloric restriction           GenDR  C.elegans   Aging
# 46  response to caloric restriction           GenDR  C.elegans   Aging
# 47  response to caloric restriction           GenDR  C.elegans   Aging
# 48  response to caloric restriction           GenDR  C.elegans   Aging
# 49  response to caloric restriction           GenDR  C.elegans   Aging
# 50  response to caloric restriction           GenDR  C.elegans   Aging
# 51  response to caloric restriction           GenDR  C.elegans   Aging
# 52  response to caloric restriction           GenDR  C.elegans   Aging
# 53  response to caloric restriction           GenDR  C.elegans   Aging
# 54  response to caloric restriction           GenDR  C.elegans   Aging
# 55  response to caloric restriction           GenDR  C.elegans   Aging
# 56  response to caloric restriction           GenDR  C.elegans   Aging
# 57  response to caloric restriction           GenDR  C.elegans   Aging
# 58  response to caloric restriction           GenDR  C.elegans   Aging
# 59  response to caloric restriction           GenDR  C.elegans   Aging
#
#    head_id_is tail_id_is kg_source
# 0     NCBI_ID   Quick_GO     GenDR
# 1     NCBI_ID   Quick_GO     GenDR
# 2     NCBI_ID   Quick_GO     GenDR
# 3     NCBI_ID   Quick_GO     GenDR
# 4     NCBI_ID   Quick_GO     GenDR
# 5     NCBI_ID   Quick_GO     GenDR
# 6     NCBI_ID   Quick_GO     GenDR
# 7     NCBI_ID   Quick_GO     GenDR
# 8     NCBI_ID   Quick_GO     GenDR
# 9     NCBI_ID   Quick_GO     GenDR
# 10    NCBI_ID   Quick_GO     GenDR
# 11    NCBI_ID   Quick_GO     GenDR
# 12    NCBI_ID   Quick_GO     GenDR
# 13    NCBI_ID   Quick_GO     GenDR
# 14    NCBI_ID   Quick_GO     GenDR
# 15    NCBI_ID   Quick_GO     GenDR
# 16    NCBI_ID   Quick_GO     GenDR
# 17    NCBI_ID   Quick_GO     GenDR
# 18    NCBI_ID   Quick_GO     GenDR
# 19    NCBI_ID   Quick_GO     GenDR
# 20    NCBI_ID   Quick_GO     GenDR
# 21    NCBI_ID   Quick_GO     GenDR
# 22    NCBI_ID   Quick_GO     GenDR
# 23    NCBI_ID   Quick_GO     GenDR
# 24    NCBI_ID   Quick_GO     GenDR
# 25    NCBI_ID   Quick_GO     GenDR
# 26    NCBI_ID   Quick_GO     GenDR
# 27    NCBI_ID   Quick_GO     GenDR
# 28    NCBI_ID   Quick_GO     GenDR
# 29    NCBI_ID   Quick_GO     GenDR
# 30    NCBI_ID   Quick_GO     GenDR
# 31    NCBI_ID   Quick_GO     GenDR
# 32    NCBI_ID   Quick_GO     GenDR
# 33    NCBI_ID   Quick_GO     GenDR
# 34    NCBI_ID   Quick_GO     GenDR
# 35    NCBI_ID   Quick_GO     GenDR
# 36    NCBI_ID   Quick_GO     GenDR
# 37    NCBI_ID   Quick_GO     GenDR
# 38    NCBI_ID   Quick_GO     GenDR
# 39    NCBI_ID   Quick_GO     GenDR
# 40    NCBI_ID   Quick_GO     GenDR
# 41    NCBI_ID   Quick_GO     GenDR
# 42    NCBI_ID   Quick_GO     GenDR
# 43    NCBI_ID   Quick_GO     GenDR
# 44    NCBI_ID   Quick_GO     GenDR
# 45    NCBI_ID   Quick_GO     GenDR
# 46    NCBI_ID   Quick_GO     GenDR
# 47    NCBI_ID   Quick_GO     GenDR
# 48    NCBI_ID   Quick_GO     GenDR
# 49    NCBI_ID   Quick_GO     GenDR
# 50    NCBI_ID   Quick_GO     GenDR
# 51    NCBI_ID   Quick_GO     GenDR
# 52    NCBI_ID   Quick_GO     GenDR
# 53    NCBI_ID   Quick_GO     GenDR
# 54    NCBI_ID   Quick_GO     GenDR
# 55    NCBI_ID   Quick_GO     GenDR
# 56    NCBI_ID   Quick_GO     GenDR
# 57    NCBI_ID   Quick_GO     GenDR
# 58    NCBI_ID   Quick_GO     GenDR
# 59    NCBI_ID   Quick_GO     GenDR

# %% [markdown]
# # Monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Celegans/Gene_Cele_BiologicalProcess.csv')
monarch.columns = monarch.columns.str.lower()
monarch['kg_type'] = 'Generalised'
monarch['species'] = 'C.elegans'
monarch['head_id_is'] = 'NCBI_ID'
monarch['tail_id_is'] = 'Quick_GO'
monarch['kg_source'] = 'Monarch_KG'


print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 41,253 rows
#             head                relation        tail head_type  \
# 0      Y75B8A.11  Gene_BiologicalProcess  GO:1901046      Gene
# 1      Y75B8A.11  Gene_BiologicalProcess  GO:2000252      Gene
# 2      Y75B8A.16  Gene_BiologicalProcess  GO:0098656      Gene
# 3      Y75B8A.17  Gene_BiologicalProcess  GO:0008156      Gene
# 4      Y75B8A.17  Gene_BiologicalProcess  GO:0008156      Gene
# ...          ...                     ...         ...       ...
# 41248   Y75B8A.7  Gene_BiologicalProcess  GO:0006364      Gene
# 41249   Y75B8A.7  Gene_BiologicalProcess  GO:0042254      Gene
# 41250  Y75B8A.11  Gene_BiologicalProcess  GO:0007218      Gene
# 41251  Y75B8A.11  Gene_BiologicalProcess  GO:0008340      Gene
# 41252  Y75B8A.11  Gene_BiologicalProcess  GO:0040013      Gene
#
#               relation_type          tail_type  relation_source  \
# 0      actively_involved_in  BiologicalProcess  infores:uniprot
# 1      actively_involved_in  BiologicalProcess  infores:uniprot
# 2      actively_involved_in  BiologicalProcess      infores:goc
# 3      actively_involved_in  BiologicalProcess  infores:uniprot
# 4      actively_involved_in  BiologicalProcess  infores:uniprot
# ...                     ...                ...              ...
# 41248  actively_involved_in  BiologicalProcess  infores:uniprot
# 41249  actively_involved_in  BiologicalProcess  infores:uniprot
# 41250  actively_involved_in  BiologicalProcess  infores:uniprot
# 41251  actively_involved_in  BiologicalProcess  infores:uniprot
# 41252  actively_involved_in  BiologicalProcess  infores:uniprot
#
#                                  head_detail_name  \
# 0                                        LURY-1-2
# 1                                        LURY-1-2
# 2                              Golgi pH regulator
# 3                                 Geminin homolog
# 4                                 Geminin homolog
# ...                                           ...
# 41248  U3 small nucleolar ribonucleoprotein MPP10
# 41249  U3 small nucleolar ribonucleoprotein MPP10
# 41250                                    LURY-1-2
# 41251                                    LURY-1-2
# 41252                                    LURY-1-2
#
#                                  tail_detail_name         head_taxon_name  \
# 0      positive regulation of egg-laying behavior  Caenorhabditis elegans
# 1         negative regulation of feeding behavior  Caenorhabditis elegans
# 2        monoatomic anion transmembrane transport  Caenorhabditis elegans
# 3          negative regulation of DNA replication  Caenorhabditis elegans
# 4          negative regulation of DNA replication  Caenorhabditis elegans
# ...                                           ...                     ...
# 41248                             rRNA processing  Caenorhabditis elegans
# 41249                         ribosome biogenesis  Caenorhabditis elegans
# 41250              neuropeptide signaling pathway  Caenorhabditis elegans
# 41251             determination of adult lifespan  Caenorhabditis elegans
# 41252           negative regulation of locomotion  Caenorhabditis elegans
#
#        tail_taxon_name head_id_is tail_id_is head_name    species  \
# 0                  NaN    NCBI_ID   Quick_GO    lury-1  C.elegans
# 1                  NaN    NCBI_ID   Quick_GO    lury-1  C.elegans
# 2                  NaN    NCBI_ID   Quick_GO    gphr-1  C.elegans
# 3                  NaN    NCBI_ID   Quick_GO     gmn-1  C.elegans
# 4                  NaN    NCBI_ID   Quick_GO     gmn-1  C.elegans
# ...                ...        ...        ...       ...        ...
# 41248              NaN    NCBI_ID   Quick_GO  Y75B8A.7  C.elegans
# 41249              NaN    NCBI_ID   Quick_GO  Y75B8A.7  C.elegans
# 41250              NaN    NCBI_ID   Quick_GO    lury-1  C.elegans
# 41251              NaN    NCBI_ID   Quick_GO    lury-1  C.elegans
# 41252              NaN    NCBI_ID   Quick_GO    lury-1  C.elegans
#
#            kg_type   kg_source
# 0      Generalised  Monarch_KG
# 1      Generalised  Monarch_KG
# 2      Generalised  Monarch_KG
# 3      Generalised  Monarch_KG
# 4      Generalised  Monarch_KG
# ...            ...         ...
# 41248  Generalised  Monarch_KG
# 41249  Generalised  Monarch_KG
# 41250  Generalised  Monarch_KG
# 41251  Generalised  Monarch_KG
# 41252  Generalised  Monarch_KG
#
# [41253 rows x 17 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    genDR, monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 41,313
#             head                relation        tail head_type  \
# 0        R13H8.1  Gene_BiologicalProcess  GO:0061771      Gene
# 1       Y55D5A.5  Gene_BiologicalProcess  GO:0061771      Gene
# 2        ZC395.2  Gene_BiologicalProcess  GO:0061771      Gene
# 3        C49F5.1  Gene_BiologicalProcess  GO:0061771      Gene
# 4        T23H2.5  Gene_BiologicalProcess  GO:0061771      Gene
# ...          ...                     ...         ...       ...
# 41308   Y75B8A.7  Gene_BiologicalProcess  GO:0006364      Gene
# 41309   Y75B8A.7  Gene_BiologicalProcess  GO:0042254      Gene
# 41310  Y75B8A.11  Gene_BiologicalProcess  GO:0007218      Gene
# 41311  Y75B8A.11  Gene_BiologicalProcess  GO:0008340      Gene
# 41312  Y75B8A.11  Gene_BiologicalProcess  GO:0040013      Gene
#
#               relation_type          tail_type   kg_source      kg_type  \
# 0                      None  BiologicalProcess       GenDR        Aging
# 1                      None  BiologicalProcess       GenDR        Aging
# 2                      None  BiologicalProcess       GenDR        Aging
# 3                      None  BiologicalProcess       GenDR        Aging
# 4                      None  BiologicalProcess       GenDR        Aging
# ...                     ...                ...         ...          ...
# 41308  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 41309  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 41310  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 41311  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 41312  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
#
#       head_id_is tail_id_is  \
# 0        NCBI_ID   Quick_GO
# 1        NCBI_ID   Quick_GO
# 2        NCBI_ID   Quick_GO
# 3        NCBI_ID   Quick_GO
# 4        NCBI_ID   Quick_GO
# ...          ...        ...
# 41308    NCBI_ID   Quick_GO
# 41309    NCBI_ID   Quick_GO
# 41310    NCBI_ID   Quick_GO
# 41311    NCBI_ID   Quick_GO
# 41312    NCBI_ID   Quick_GO
#
#                                         head_detail_name  \
# 0                                 Forkhead box protein O
# 1      Insulin-like receptor subunit beta;Protein kin...
# 2       5-demethoxyubiquinone hydroxylase, mitochondrial
# 3               putative S-adenosylmethionine synthase 1
# 4                             Ras-related protein Rab-10
# ...                                                  ...
# 41308         U3 small nucleolar ribonucleoprotein MPP10
# 41309         U3 small nucleolar ribonucleoprotein MPP10
# 41310                                           LURY-1-2
# 41311                                           LURY-1-2
# 41312                                           LURY-1-2
#
#                         tail_detail_name    species
# 0        response to caloric restriction  C.elegans
# 1        response to caloric restriction  C.elegans
# 2        response to caloric restriction  C.elegans
# 3        response to caloric restriction  C.elegans
# 4        response to caloric restriction  C.elegans
# ...                                  ...        ...
# 41308                    rRNA processing  C.elegans
# 41309                ribosome biogenesis  C.elegans
# 41310     neuropeptide signaling pathway  C.elegans
# 41311    determination of adult lifespan  C.elegans
# 41312  negative regulation of locomotion  C.elegans
#
# [41313 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {'acts_upstream_of_or_within_negative_effect', 'acts_upstream_of_negative_effect', 'acts_upstream_of_or_within', None, 'acts_upstream_of_or_within_positive_effect', 'acts_upstream_of', 'acts_upstream_of_positive_effect', 'actively_involved_in'}
# kg_source           : {'Monarch_KG', 'GenDR'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 41,313 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                    252                 252             504
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            60                   0              60
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name        252                 252             504
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 41,313  |  After dedup: 32,524
#       head                relation        tail head_type  \
# 0  2RSSE.1  Gene_BiologicalProcess  GO:0007165      Gene
# 1   4R79.1  Gene_BiologicalProcess  GO:0006508      Gene
# 2   4R79.1  Gene_BiologicalProcess  GO:0043050      Gene
#
#           relation_type          tail_type   kg_source      kg_type  \
# 0  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 1  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 2  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
#
#   head_id_is tail_id_is                                   head_detail_name  \
# 0    NCBI_ID   Quick_GO                  Rho-GAP domain-containing protein
# 1    NCBI_ID   Quick_GO  Metalloendopeptidase;Zinc metalloproteinase nas-6
# 2    NCBI_ID   Quick_GO  Metalloendopeptidase;Zinc metalloproteinase nas-6
#
#               tail_detail_name    species
# 0          signal transduction  C.elegans
# 1                  proteolysis  C.elegans
# 2  nematode pharyngeal pumping  C.elegans

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            57                   0              57
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'GenDR::Monarch_KG', 'Monarch_KG', 'GenDR'} kg_source
# Monarch_KG           32464
# GenDR                   57
# GenDR::Monarch_KG        3
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging::Generalised', 'Aging', 'Generalised'} kg_type
# Generalised           32464
# Aging                    57
# Aging::Generalised        3
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 32,524 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Celegans/Celegans_gene_biologicalprocess/Celegans_gene_biologicalprocess.csv

# %%
#

# %%
final_df_dedup
# Out:
#           head                relation        tail head_type  \
# 0      2RSSE.1  Gene_BiologicalProcess  GO:0007165      Gene
# 1       4R79.1  Gene_BiologicalProcess  GO:0006508      Gene
# 2       4R79.1  Gene_BiologicalProcess  GO:0043050      Gene
# 3       4R79.1  Gene_BiologicalProcess  GO:0060465      Gene
# 4       4R79.2  Gene_BiologicalProcess  GO:0016192      Gene
# ...        ...                     ...         ...       ...
# 32519  ZK994.3  Gene_BiologicalProcess  GO:0006979      Gene
# 32520  ZK994.3  Gene_BiologicalProcess  GO:0016203      Gene
# 32521  ZK994.3  Gene_BiologicalProcess  GO:0042744      Gene
# 32522  ZK994.3  Gene_BiologicalProcess  GO:0098869      Gene
# 32523  ZK994.3  Gene_BiologicalProcess  GO:1902669      Gene
#
#               relation_type          tail_type   kg_source      kg_type  \
# 0      actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 1      actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 2      actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 3      actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 4      actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# ...                     ...                ...         ...          ...
# 32519  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 32520  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 32521  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 32522  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
# 32523  actively_involved_in  BiologicalProcess  Monarch_KG  Generalised
#
#       head_id_is tail_id_is  \
# 0        NCBI_ID   Quick_GO
# 1        NCBI_ID   Quick_GO
# 2        NCBI_ID   Quick_GO
# 3        NCBI_ID   Quick_GO
# 4        NCBI_ID   Quick_GO
# ...          ...        ...
# 32519    NCBI_ID   Quick_GO
# 32520    NCBI_ID   Quick_GO
# 32521    NCBI_ID   Quick_GO
# 32522    NCBI_ID   Quick_GO
# 32523    NCBI_ID   Quick_GO
#
#                                         head_detail_name  \
# 0                      Rho-GAP domain-containing protein
# 1      Metalloendopeptidase;Zinc metalloproteinase nas-6
# 2      Metalloendopeptidase;Zinc metalloproteinase nas-6
# 3      Metalloendopeptidase;Zinc metalloproteinase nas-6
# 4                             Ras-related protein Rab-44
# ...                                                  ...
# 32519                          Peroxidasin homolog pxn-1
# 32520                          Peroxidasin homolog pxn-1
# 32521                          Peroxidasin homolog pxn-1
# 32522                          Peroxidasin homolog pxn-1
# 32523                          Peroxidasin homolog pxn-1
#
#                            tail_detail_name    species
# 0                       signal transduction  C.elegans
# 1                               proteolysis  C.elegans
# 2               nematode pharyngeal pumping  C.elegans
# 3                       pharynx development  C.elegans
# 4                vesicle-mediated transport  C.elegans
# ...                                     ...        ...
# 32519          response to oxidative stress  C.elegans
# 32520                     muscle attachment  C.elegans
# 32521   hydrogen peroxide catabolic process  C.elegans
# 32522       cellular oxidant detoxification  C.elegans
# 32523  positive regulation of axon guidance  C.elegans
#
# [32524 rows x 13 columns]

# %%
set(final_df_dedup['tail_id_is']),
# Out:
# {'Quick_GO'}

# %%
set(final_df_dedup['head_id_is'])
# Out:
# {'NCBI_ID'}
