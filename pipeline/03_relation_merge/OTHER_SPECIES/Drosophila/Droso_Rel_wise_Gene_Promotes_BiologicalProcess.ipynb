# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila

# %%
! pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Droso_gene_promotes_biologicalprocess
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Droso_gene_promotes_biologicalprocess/Droso_gene_promotes_biologicalprocess.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %%
# Mouse = pd.read_csv(
#     f'{BASE_DIR}data_collection/databases_for_mapping/ncbi/Mus_musculus.gene_info',
#     sep='\t',
    
# )
# # Mouse["LocusTag"] = Mouse["LocusTag"].str.replace("Dmel_", "", regex=False)

# # Mouse_symbol2Locus_dict = dict(zip(Mouse['Symbol'], Mouse['LocusTag']))
# # Mouse
# # Mouse_symbol2Locus_dict
# Mouse

# %% [markdown]
# # Genage

# %%
Genage = pd.read_csv(PROC_DIR + 'genage/Droso/Droso_Gene_Promotes_BiologicalProcess.csv')
Genage.columns = Genage.columns.str.lower()
Genage = Genage[~Genage['head_detail_name'].isna()]

Genage['kg_type'] = 'Aging'
Genage['relation'] = 'Gene_Promotes_BiologicalProcess'
print(f"Genage: {len(Genage):,} rows")
Genage['head_id_is'] = 'NCBI_ID'
Genage['tail_id_is'] = 'Quick_GO'
Genage['species']    = 'Drosophila melanogaster'
Genage['kg_source'] = 'Genage'

Genage
# Out:
# Genage: 61 rows
#        head                         relation        tail head_type  \
# 0      Bmcp  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1     chico  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2       dnc  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3       EcR  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 4       Egm  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# ..      ...                              ...         ...       ...
# 56      chm  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 57    Hex-A  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 58    Hex-C  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 59  mir-277  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 60  mir-184  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#             tail_type   head_detail_name tail_detail_name relation_source  \
# 0   BiologicalProcess               bmcp   obsolete aging         GeneAge
# 1   BiologicalProcess              chico   obsolete aging         GeneAge
# 2   BiologicalProcess              dunce   obsolete aging         GeneAge
# 3   BiologicalProcess  Ecdysone receptor   obsolete aging         GeneAge
# 4   BiologicalProcess             Enigma   obsolete aging         GeneAge
# ..                ...                ...              ...             ...
# 56  BiologicalProcess            chameau   obsolete aging         GeneAge
# 57  BiologicalProcess       Hexokinase A   obsolete aging         GeneAge
# 58  BiologicalProcess       Hexokinase C   obsolete aging         GeneAge
# 59  BiologicalProcess  mir-277 stem loop   obsolete aging         GeneAge
# 60  BiologicalProcess  mir-184 stem loop   obsolete aging         GeneAge
#
#                     species  data_type head_alt_name kg_type head_id_is  \
# 0   Drosophila melanogaster  Causative          Bmcp   Aging    NCBI_ID
# 1   Drosophila melanogaster  Causative         chico   Aging    NCBI_ID
# 2   Drosophila melanogaster  Causative           dnc   Aging    NCBI_ID
# 3   Drosophila melanogaster  Causative           EcR   Aging    NCBI_ID
# 4   Drosophila melanogaster  Causative           Egm   Aging    NCBI_ID
# ..                      ...        ...           ...     ...        ...
# 56  Drosophila melanogaster  Causative           chm   Aging    NCBI_ID
# 57  Drosophila melanogaster  Causative         Hex-A   Aging    NCBI_ID
# 58  Drosophila melanogaster  Causative         Hex-C   Aging    NCBI_ID
# 59  Drosophila melanogaster  Causative       mir-277   Aging    NCBI_ID
# 60  Drosophila melanogaster  Causative       mir-184   Aging    NCBI_ID
#
#    tail_id_is kg_source
# 0    Quick_GO    Genage
# 1    Quick_GO    Genage
# 2    Quick_GO    Genage
# 3    Quick_GO    Genage
# 4    Quick_GO    Genage
# ..        ...       ...
# 56   Quick_GO    Genage
# 57   Quick_GO    Genage
# 58   Quick_GO    Genage
# 59   Quick_GO    Genage
# 60   Quick_GO    Genage
#
# [61 rows x 15 columns]

# %% [markdown]
# # AgingBank

# %%
AgingBank = pd.read_csv(PROC_DIR + 'agingbank/Droso_AgingbankGene_promotes_BioPro.csv')
AgingBank.columns = AgingBank.columns.str.lower()
AgingBank = AgingBank[~AgingBank['head_detail_name'].isna()]

AgingBank['kg_type'] = 'Aging'
AgingBank['relation'] = 'Gene_Promotes_BiologicalProcess'
AgingBank['tail_type'] = 'BiologicalProcess'
print(f"AgingBank: {len(AgingBank):,} rows")
AgingBank['head_id_is'] = 'NCBI_ID'
AgingBank['tail_id_is'] = 'Quick_GO'
AgingBank['species'] = 'Drosophila melanogaster'
AgingBank['kg_source'] = 'AgingBank'
AgingBank
# Out:
# AgingBank: 4 rows
#    head                         relation        tail head_type  \
# 0   CAT  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1  EXD2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2  SOD2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3  LMNA  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#            tail_type  kg_source kg_type  \
# 0  BiologicalProcess  AgingBank   Aging
# 1  BiologicalProcess  AgingBank   Aging
# 2  BiologicalProcess  AgingBank   Aging
# 3  BiologicalProcess  AgingBank   Aging
#
#                         head_detail_name tail_detail_name head_id_is  \
# 0                               catalase            aging    NCBI_ID
# 1  exonuclease 3'-5' domain containing 2            aging    NCBI_ID
# 2  superoxide dismutase 2, mitochondrial            aging    NCBI_ID
# 3                                lamin A            aging    NCBI_ID
#
#   tail_id_is kg_type.1                  species
# 0   Quick_GO     Aging  Drosophila melanogaster
# 1   Quick_GO     Aging  Drosophila melanogaster
# 2   Quick_GO     Aging  Drosophila melanogaster
# 3   Quick_GO     Aging  Drosophila melanogaster

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    Genage, AgingBank
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 65
#        head                         relation        tail head_type  \
# 0      Bmcp  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1     chico  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2       dnc  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 3       EcR  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 4       Egm  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# ..      ...                              ...         ...       ...
# 60  mir-184  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 61      CAT  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 62     EXD2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 63     SOD2  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 64     LMNA  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#    relation_type          tail_type  kg_source kg_type head_id_is tail_id_is  \
# 0           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 1           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 2           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 3           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 4           None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# ..           ...                ...        ...     ...        ...        ...
# 60          None  BiologicalProcess     Genage   Aging    NCBI_ID   Quick_GO
# 61          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 62          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 63          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
# 64          None  BiologicalProcess  AgingBank   Aging    NCBI_ID   Quick_GO
#
#                          head_detail_name tail_detail_name  \
# 0                                    bmcp   obsolete aging
# 1                                   chico   obsolete aging
# 2                                   dunce   obsolete aging
# 3                       Ecdysone receptor   obsolete aging
# 4                                  Enigma   obsolete aging
# ..                                    ...              ...
# 60                      mir-184 stem loop   obsolete aging
# 61                               catalase            aging
# 62  exonuclease 3'-5' domain containing 2            aging
# 63  superoxide dismutase 2, mitochondrial            aging
# 64                                lamin A            aging
#
#                     species
# 0   Drosophila melanogaster
# 1   Drosophila melanogaster
# 2   Drosophila melanogaster
# 3   Drosophila melanogaster
# 4   Drosophila melanogaster
# ..                      ...
# 60  Drosophila melanogaster
# 61  Drosophila melanogaster
# 62  Drosophila melanogaster
# 63  Drosophila melanogaster
# 64  Drosophila melanogaster
#
# [65 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Promotes_BiologicalProcess'}
# head_type           : {'Gene'}
# tail_type           : {'BiologicalProcess'}
# relation_type       : {None}
# kg_source           : {'Genage', 'AgingBank'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 65 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            65                   0              65
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 65  |  After dedup: 65
#             head                         relation        tail head_type  \
# 0  14-3-3epsilon  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 1         5-HT2A  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
# 2          ATPCL  Gene_Promotes_BiologicalProcess  GO:0007568      Gene
#
#   relation_type          tail_type kg_source kg_type head_id_is tail_id_is  \
# 0          None  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
# 1          None  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
# 2          None  BiologicalProcess    Genage   Aging    NCBI_ID   Quick_GO
#
#                               head_detail_name tail_detail_name  \
# 0                                14-3-3epsilon   obsolete aging
# 1  5-hydroxytryptamine (serotonin) receptor 2A   obsolete aging
# 2                            ATP citrate lyase   obsolete aging
#
#                    species
# 0  Drosophila melanogaster
# 1  Drosophila melanogaster
# 2  Drosophila melanogaster

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type            65                   0              65
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Genage', 'AgingBank'} kg_source
# Genage       61
# AgingBank     4
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    65
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 65 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Droso_gene_promotes_biologicalprocess/Droso_gene_promotes_biologicalprocess.csv

# %%
# OUT_PATH

# %%
# ! mkdir Droso_gene_promotes_biologicalprocess
