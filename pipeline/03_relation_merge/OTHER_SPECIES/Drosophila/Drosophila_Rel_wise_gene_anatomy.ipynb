# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila

# %%
# flybase/Flybase_Droso_Gene_Phenotype.csv
# Monarch/Drosophila/Gene_Droso_Phenotype_MONARCH.csv

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Drosophila_gene_anatomy
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_gene_anatomy/Drosophila_gene_anatomy.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Drosophila_gene_anatomy’: File exists

# %%
#

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Drosophila/Gene_Droso_Anatomy.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['relation'] = 'Gene_AnatomicalEntity'
monarch['tail_type'] = 'AnatomicalEntity'

monarch['species'] = 'D.melanogaster'
monarch['head_id_is'] = 'NCBI_ID'
monarch['tail_id_is'] = 'Quick_GO'
print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 396,331 rows
#            head      relation           tail head_type relation_type  \
# 0        CG8340  Gene_Anatomy  FBbt:00003007      Gene  expressed_in
# 1       CG31196  Gene_Anatomy  FBbt:00001056      Gene  expressed_in
# 2       CG31196  Gene_Anatomy  FBbt:00001134      Gene  expressed_in
# 3       CG31196  Gene_Anatomy  FBbt:00000092      Gene  expressed_in
# 4       CG31196  Gene_Anatomy  FBbt:00005409      Gene  expressed_in
# ...         ...           ...            ...       ...           ...
# 397416  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
# 397417  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
# 397418  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
# 397419  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
# 397420  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
#
#                tail_type  relation_source      head_detail_name  \
# 0       AnatomicalEntity  infores:flybase  upstream of RpIII128
# 1       AnatomicalEntity  infores:flybase         14-3-3epsilon
# 2       AnatomicalEntity  infores:flybase         14-3-3epsilon
# 3       AnatomicalEntity  infores:flybase         14-3-3epsilon
# 4       AnatomicalEntity  infores:flybase         14-3-3epsilon
# ...                  ...              ...                   ...
# 397416  AnatomicalEntity  infores:flybase               Neb-cGP
# 397417  AnatomicalEntity  infores:flybase               Neb-cGP
# 397418  AnatomicalEntity  infores:flybase               Neb-cGP
# 397419  AnatomicalEntity  infores:flybase               Neb-cGP
# 397420  AnatomicalEntity  infores:flybase               Neb-cGP
#
#                                          tail_detail_name  \
# 0                                              adult head
# 1       presumptive embryonic/larval central nervous s...
# 2       presumptive embryonic/larval peripheral nervou...
# 3                                    primordial germ cell
# 4                                              ring canal
# ...                                                   ...
# 397416                                        adult heart
# 397417                                        adult heart
# 397418                                        adult heart
# 397419                                        adult heart
# 397420                                        adult heart
#
#                 head_taxon_name  tail_taxon_name head_id_is tail_id_is  \
# 0       Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 1       Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 2       Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 3       Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 4       Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# ...                         ...              ...        ...        ...
# 397416  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 397417  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 397418  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 397419  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 397420  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
#
#        head_name         species      kg_type   kg_source
# 0          128up  D.melanogaster  Generalised  Monarch_KG
# 1        14-3-3ε  D.melanogaster  Generalised  Monarch_KG
# 2        14-3-3ε  D.melanogaster  Generalised  Monarch_KG
# 3        14-3-3ε  D.melanogaster  Generalised  Monarch_KG
# 4        14-3-3ε  D.melanogaster  Generalised  Monarch_KG
# ...          ...             ...          ...         ...
# 397416   Neb-cGP  D.melanogaster  Generalised  Monarch_KG
# 397417   Neb-cGP  D.melanogaster  Generalised  Monarch_KG
# 397418   Neb-cGP  D.melanogaster  Generalised  Monarch_KG
# 397419   Neb-cGP  D.melanogaster  Generalised  Monarch_KG
# 397420   Neb-cGP  D.melanogaster  Generalised  Monarch_KG
#
# [396331 rows x 17 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 396,331
#            head      relation           tail head_type relation_type  \
# 0        CG8340  Gene_Anatomy  FBbt:00003007      Gene  expressed_in
# 1       CG31196  Gene_Anatomy  FBbt:00001056      Gene  expressed_in
# 2       CG31196  Gene_Anatomy  FBbt:00001134      Gene  expressed_in
# 3       CG31196  Gene_Anatomy  FBbt:00000092      Gene  expressed_in
# 4       CG31196  Gene_Anatomy  FBbt:00005409      Gene  expressed_in
# ...         ...           ...            ...       ...           ...
# 396326  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
# 396327  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
# 396328  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
# 396329  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
# 396330  CG15304  Gene_Anatomy  FBbt:00003154      Gene  expressed_in
#
#                tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0       AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 1       AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 2       AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 3       AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 4       AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# ...                  ...         ...          ...        ...        ...
# 396326  AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 396327  AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 396328  AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 396329  AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 396330  AnatomicalEntity  Monarch_KG  Generalised    NCBI_ID   Quick_GO
#
#             head_detail_name  \
# 0       upstream of RpIII128
# 1              14-3-3epsilon
# 2              14-3-3epsilon
# 3              14-3-3epsilon
# 4              14-3-3epsilon
# ...                      ...
# 396326               Neb-cGP
# 396327               Neb-cGP
# 396328               Neb-cGP
# 396329               Neb-cGP
# 396330               Neb-cGP
#
#                                          tail_detail_name         species
# 0                                              adult head  D.melanogaster
# 1       presumptive embryonic/larval central nervous s...  D.melanogaster
# 2       presumptive embryonic/larval peripheral nervou...  D.melanogaster
# 3                                    primordial germ cell  D.melanogaster
# 4                                              ring canal  D.melanogaster
# ...                                                   ...             ...
# 396326                                        adult heart  D.melanogaster
# 396327                                        adult heart  D.melanogaster
# 396328                                        adult heart  D.melanogaster
# 396329                                        adult heart  D.melanogaster
# 396330                                        adult heart  D.melanogaster
#
# [396331 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Anatomy'}
# head_type           : {'Gene'}
# tail_type           : {'AnatomicalEntity'}
# relation_type       : {'expressed_in'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 396,331 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
genDR_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_genDR_count": genDR_nan,
    'Total_NaN_like':     true_nan + genDR_nan
})
# Out:
#                   NaN_count  'NAN'_genDR_count  Total_NaN_like
# head                      0                  0               0
# relation                  0                  0               0
# tail                      0                  0               0
# head_type                 0                  0               0
# relation_type             0                  0               0
# tail_type                 0                  0               0
# kg_source                 0                  0               0
# kg_type                   0                  0               0
# head_id_is                0                  0               0
# tail_id_is                0                  0               0
# head_detail_name          0                  0               0
# tail_detail_name          0                  0               0
# species                   0                  0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 396,331  |  After dedup: 88,664
#   head      relation           tail head_type relation_type         tail_type  \
# 0    -  Gene_Anatomy  FBbt:00000001      Gene  expressed_in  AnatomicalEntity
# 1    -  Gene_Anatomy  FBbt:00000004      Gene  expressed_in  AnatomicalEntity
# 2    -  Gene_Anatomy  FBbt:00000007      Gene  expressed_in  AnatomicalEntity
#
#     kg_source      kg_type head_id_is tail_id_is head_detail_name  \
# 0  Monarch_KG  Generalised    NCBI_ID   Quick_GO  lethal (1) XG10
# 1  Monarch_KG  Generalised    NCBI_ID   Quick_GO  lethal (1) XG10
# 2  Monarch_KG  Generalised    NCBI_ID   Quick_GO  lethal (1) XG10
#
#       tail_detail_name
# 0             organism
# 1                 head
# 2  procephalic segment

# %%
true_nan   = final_df_dedup.isna().sum()
genDR_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_genDR_count": genDR_nan,
    'Total_NaN_like':     true_nan + genDR_nan
})
# Out:
#                   NaN_count  'NAN'_genDR_count  Total_NaN_like
# head                      0                  0               0
# relation                  0                  0               0
# tail                      0                  0               0
# head_type                 0                  0               0
# relation_type             0                  0               0
# tail_type                 0                  0               0
# kg_source                 0                  0               0
# kg_type                   0                  0               0
# head_id_is                0                  0               0
# tail_id_is                0                  0               0
# head_detail_name          0                  0               0
# tail_detail_name          0                  0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    88664
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    88664
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 88,664 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_gene_anatomy/Drosophila_gene_anatomy.csv

# %%
#
