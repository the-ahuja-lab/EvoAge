# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Drosophila_gene_pathway
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_gene_pathway/Drosophila_gene_pathway.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Drosophila/Droso_Gene_Pathway.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'

monarch['species'] = 'D.melanogaster'
monarch['head_id_is'] = 'NCBI_ID'
monarch['tail_id_is'] = 'Quick_GO'
print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 18,454 rows
#           head      relation           tail head_type    relation_type  \
# 0       CG2316  Gene_Pathway   R-HSA-390247      Gene  participates_in
# 1       CG2316  Gene_Pathway  R-HSA-9603798      Gene  participates_in
# 2       CG1587  Gene_Pathway   R-HSA-186763      Gene  participates_in
# 3       CG1587  Gene_Pathway  R-HSA-4420097      Gene  participates_in
# 4       CG1587  Gene_Pathway  R-HSA-8849471      Gene  participates_in
# ...        ...           ...            ...       ...              ...
# 18464  CG34403  Gene_Pathway  R-HSA-9825892      Gene  participates_in
# 18465   CG1651  Gene_Pathway  R-HSA-6807878      Gene  participates_in
# 18466   CG2316  Gene_Pathway  R-HSA-1369062      Gene  participates_in
# 18467   CG2316  Gene_Pathway  R-HSA-2046105      Gene  participates_in
# 18468   CG2316  Gene_Pathway  R-HSA-2046106      Gene  participates_in
#
#       tail_type   relation_source                           head_detail_name  \
# 0       Pathway  infores:reactome  ATP binding cassette subfamily D member 1
# 1       Pathway  infores:reactome  ATP binding cassette subfamily D member 1
# 2       Pathway  infores:reactome                               Crk oncogene
# 3       Pathway  infores:reactome                               Crk oncogene
# 4       Pathway  infores:reactome                               Crk oncogene
# ...         ...               ...                                        ...
# 18464   Pathway  infores:reactome                                   pangolin
# 18465   Pathway  infores:reactome                                    Ankyrin
# 18466   Pathway  infores:reactome  ATP binding cassette subfamily D member 1
# 18467   Pathway  infores:reactome  ATP binding cassette subfamily D member 1
# 18468   Pathway  infores:reactome  ATP binding cassette subfamily D member 1
#
#                                         tail_detail_name  \
# 0          Beta-oxidation of very long chain fatty acids
# 1            Class I peroxisomal membrane protein import
# 2                         Downstream signal transduction
# 3                                   VEGFA-VEGFR2 Pathway
# 4      PTK6 Regulates RHO GTPases, RAS GTPase and MAP...
# ...                                                  ...
# 18464  Regulation of MITF-M-dependent genes involved ...
# 18465                COPI-mediated anterograde transport
# 18466              ABC transporters in lipid homeostasis
# 18467                      Linoleic acid (LA) metabolism
# 18468              alpha-linolenic acid (ALA) metabolism
#
#                head_taxon_name tail_taxon_name head_id_is tail_id_is  \
# 0      Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# 1      Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# 2      Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# 3      Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# 4      Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# ...                        ...             ...        ...        ...
# 18464  Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# 18465  Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# 18466  Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# 18467  Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
# 18468  Drosophila melanogaster    Homo sapiens    NCBI_ID   Quick_GO
#
#       head_name         species      kg_type   kg_source
# 0         Abcd1  D.melanogaster  Generalised  Monarch_KG
# 1         Abcd1  D.melanogaster  Generalised  Monarch_KG
# 2           Crk  D.melanogaster  Generalised  Monarch_KG
# 3           Crk  D.melanogaster  Generalised  Monarch_KG
# 4           Crk  D.melanogaster  Generalised  Monarch_KG
# ...         ...             ...          ...         ...
# 18464       pan  D.melanogaster  Generalised  Monarch_KG
# 18465       Ank  D.melanogaster  Generalised  Monarch_KG
# 18466     Abcd1  D.melanogaster  Generalised  Monarch_KG
# 18467     Abcd1  D.melanogaster  Generalised  Monarch_KG
# 18468     Abcd1  D.melanogaster  Generalised  Monarch_KG
#
# [18454 rows x 17 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 18,454
#           head      relation           tail head_type    relation_type  \
# 0       CG2316  Gene_Pathway   R-HSA-390247      Gene  participates_in
# 1       CG2316  Gene_Pathway  R-HSA-9603798      Gene  participates_in
# 2       CG1587  Gene_Pathway   R-HSA-186763      Gene  participates_in
# 3       CG1587  Gene_Pathway  R-HSA-4420097      Gene  participates_in
# 4       CG1587  Gene_Pathway  R-HSA-8849471      Gene  participates_in
# ...        ...           ...            ...       ...              ...
# 18449  CG34403  Gene_Pathway  R-HSA-9825892      Gene  participates_in
# 18450   CG1651  Gene_Pathway  R-HSA-6807878      Gene  participates_in
# 18451   CG2316  Gene_Pathway  R-HSA-1369062      Gene  participates_in
# 18452   CG2316  Gene_Pathway  R-HSA-2046105      Gene  participates_in
# 18453   CG2316  Gene_Pathway  R-HSA-2046106      Gene  participates_in
#
#       tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0       Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 1       Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 2       Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 3       Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 4       Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# ...         ...         ...          ...        ...        ...
# 18449   Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 18450   Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 18451   Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 18452   Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 18453   Pathway  Monarch_KG  Generalised    NCBI_ID   Quick_GO
#
#                                 head_detail_name  \
# 0      ATP binding cassette subfamily D member 1
# 1      ATP binding cassette subfamily D member 1
# 2                                   Crk oncogene
# 3                                   Crk oncogene
# 4                                   Crk oncogene
# ...                                          ...
# 18449                                   pangolin
# 18450                                    Ankyrin
# 18451  ATP binding cassette subfamily D member 1
# 18452  ATP binding cassette subfamily D member 1
# 18453  ATP binding cassette subfamily D member 1
#
#                                         tail_detail_name         species
# 0          Beta-oxidation of very long chain fatty acids  D.melanogaster
# 1            Class I peroxisomal membrane protein import  D.melanogaster
# 2                         Downstream signal transduction  D.melanogaster
# 3                                   VEGFA-VEGFR2 Pathway  D.melanogaster
# 4      PTK6 Regulates RHO GTPases, RAS GTPase and MAP...  D.melanogaster
# ...                                                  ...             ...
# 18449  Regulation of MITF-M-dependent genes involved ...  D.melanogaster
# 18450                COPI-mediated anterograde transport  D.melanogaster
# 18451              ABC transporters in lipid homeostasis  D.melanogaster
# 18452                      Linoleic acid (LA) metabolism  D.melanogaster
# 18453              alpha-linolenic acid (ALA) metabolism  D.melanogaster
#
# [18454 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_Pathway'}
# head_type           : {'Gene'}
# tail_type           : {'Pathway'}
# relation_type       : {'participates_in'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 18,454 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
genDR_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_genDR_count": genDR_nan,
    'Total_NaN_like':     true_nan + genDR_nan
})
# Out:
#                   NaN_count  'NAN'_genDR_count  Total_NaN_like
# head                      0                  0               0
# relation                  0                  0               0
# tail                      0                  0               0
# head_type                 0                  0               0
# relation_type             0                  0               0
# tail_type                 0                  0               0
# kg_source                 0                  0               0
# kg_type                   0                  0               0
# head_id_is                0                  0               0
# tail_id_is                0                  0               0
# head_detail_name          0                  0               0
# tail_detail_name          0                  0               0
# species                   0                  0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 18,454  |  After dedup: 18,454
#       head      relation          tail head_type    relation_type tail_type  \
# 0  CG10000  Gene_Pathway  R-HSA-913709      Gene  participates_in   Pathway
# 1  CG10001  Gene_Pathway  R-HSA-391906      Gene  participates_in   Pathway
# 2  CG10001  Gene_Pathway  R-HSA-416476      Gene  participates_in   Pathway
#
#     kg_source      kg_type head_id_is tail_id_is           head_detail_name  \
# 0  Monarch_KG  Generalised    NCBI_ID   Quick_GO    uncharacterized protein
# 1  Monarch_KG  Generalised    NCBI_ID   Quick_GO  Allatostatin A receptor 2
# 2  Monarch_KG  Generalised    NCBI_ID   Quick_GO  Allatostatin A receptor 2
#
#                    tail_detail_name
# 0  O-linked glycosylation of mucins
# 1             Leukotriene receptors
# 2     G alpha (q) signalling events

# %%
true_nan   = final_df_dedup.isna().sum()
genDR_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_genDR_count": genDR_nan,
    'Total_NaN_like':     true_nan + genDR_nan
})
# Out:
#                   NaN_count  'NAN'_genDR_count  Total_NaN_like
# head                      0                  0               0
# relation                  0                  0               0
# tail                      0                  0               0
# head_type                 0                  0               0
# relation_type             0                  0               0
# tail_type                 0                  0               0
# kg_source                 0                  0               0
# kg_type                   0                  0               0
# head_id_is                0                  0               0
# tail_id_is                0                  0               0
# head_detail_name          0                  0               0
# tail_detail_name          0                  0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    18454
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    18454
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 18,454 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_gene_pathway/Drosophila_gene_pathway.csv

# %%
#
