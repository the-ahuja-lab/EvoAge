# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila

# %% [markdown]
# # Databases Having Gene Phenotype relation of Drosophila

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Drosophila_protein_tissue
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_protein_tissue/Drosophila_protein_tissue.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Drosophila_protein_tissue’: File exists

# %% [markdown]
# # AgeAnnOMO

# %%
ageanno = pd.read_csv(PROC_DIR + 'ageanno_processed_mo/AgeAnnoMO_Droso_Protein_Tissue.csv')
ageanno.columns = ageanno.columns.str.lower()
ageanno['relation'] = 'Protein_Tissue'
ageanno['kg_type'] = 'Aging'
ageanno['species'] = 'Drosophila melanogaster'

print(f"ageanno: {len(ageanno):,} rows")
ageanno
# Out:
# ageanno: 170 rows
#        head        relation         tail head_type tail_type head_id_is  \
# 0    P41572  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# 1    Q9VSA3  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# 2    Q9VLJ6  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# 3    Q7KML2  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# 4    P02574  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# ..      ...             ...          ...       ...       ...        ...
# 165  Q9VTF9  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# 166  Q9W4P5  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# 167  Q9V7D2  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# 168  P54611  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
# 169  O46037  Protein_Tissue  BTO:0000142   Protein    Tissue    Uniprot
#
#     tail_id_is relation_source                  species tail_detail_name  \
# 0       BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# 1       BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# 2       BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# 3       BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# 4       BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# ..         ...             ...                      ...              ...
# 165     BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# 166     BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# 167     BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# 168     BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
# 169     BTO_ID       AgeAnnoMO  Drosophila melanogaster            brain
#
#                                       head_detail_name kg_type
# 0    6-phosphogluconate dehydrogenase, decarboxylating   Aging
# 1    Medium-chain specific acyl-CoA dehydrogenase, ...   Aging
# 2        Angiotensin-converting enzyme-related protein   Aging
# 3              Acyl-coenzyme A oxidase 1 {ECO:0000305}   Aging
# 4                                 Actin, larval muscle   Aging
# ..                                                 ...     ...
# 165  Ubiquitin fusion degradation protein 1 homolog...   Aging
# 166                   V-type proton ATPase subunit d 1   Aging
# 167                   V-type proton ATPase subunit D 1   Aging
# 168                     V-type proton ATPase subunit E   Aging
# 169                                           Vinculin   Aging
#
# [170 rows x 12 columns]

# %%
#

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    ageanno
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 170
#        head        relation         tail head_type relation_type tail_type  \
# 0    P41572  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 1    Q9VSA3  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 2    Q9VLJ6  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 3    Q7KML2  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 4    P02574  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# ..      ...             ...          ...       ...           ...       ...
# 165  Q9VTF9  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 166  Q9W4P5  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 167  Q9V7D2  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 168  P54611  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 169  O46037  Protein_Tissue  BTO:0000142   Protein          None    Tissue
#
#     kg_source kg_type head_id_is tail_id_is  \
# 0        None   Aging    Uniprot     BTO_ID
# 1        None   Aging    Uniprot     BTO_ID
# 2        None   Aging    Uniprot     BTO_ID
# 3        None   Aging    Uniprot     BTO_ID
# 4        None   Aging    Uniprot     BTO_ID
# ..        ...     ...        ...        ...
# 165      None   Aging    Uniprot     BTO_ID
# 166      None   Aging    Uniprot     BTO_ID
# 167      None   Aging    Uniprot     BTO_ID
# 168      None   Aging    Uniprot     BTO_ID
# 169      None   Aging    Uniprot     BTO_ID
#
#                                       head_detail_name tail_detail_name  \
# 0    6-phosphogluconate dehydrogenase, decarboxylating            brain
# 1    Medium-chain specific acyl-CoA dehydrogenase, ...            brain
# 2        Angiotensin-converting enzyme-related protein            brain
# 3              Acyl-coenzyme A oxidase 1 {ECO:0000305}            brain
# 4                                 Actin, larval muscle            brain
# ..                                                 ...              ...
# 165  Ubiquitin fusion degradation protein 1 homolog...            brain
# 166                   V-type proton ATPase subunit d 1            brain
# 167                   V-type proton ATPase subunit D 1            brain
# 168                     V-type proton ATPase subunit E            brain
# 169                                           Vinculin            brain
#
#                      species
# 0    Drosophila melanogaster
# 1    Drosophila melanogaster
# 2    Drosophila melanogaster
# 3    Drosophila melanogaster
# 4    Drosophila melanogaster
# ..                       ...
# 165  Drosophila melanogaster
# 166  Drosophila melanogaster
# 167  Drosophila melanogaster
# 168  Drosophila melanogaster
# 169  Drosophila melanogaster
#
# [170 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Protein_Tissue'}
# head_type           : {'Protein'}
# tail_type           : {'Tissue'}
# relation_type       : {None}
# kg_source           : {None}
# head_id_is          : {'Uniprot'}
# tail_id_is          : {'BTO_ID'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 170 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           170                   0             170
# tail_type                 0                   0               0
# kg_source               170                   0             170
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    
    'species': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 170  |  After dedup: 170
#      head        relation         tail head_type relation_type tail_type  \
# 0  A0A1F4  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 1  H1UUD2  Protein_Tissue  BTO:0000142   Protein          None    Tissue
# 2  H8F4T6  Protein_Tissue  BTO:0000142   Protein          None    Tissue
#
#   kg_source kg_type head_id_is tail_id_is  \
# 0             Aging    Uniprot     BTO_ID
# 1             Aging    Uniprot     BTO_ID
# 2             Aging    Uniprot     BTO_ID
#
#                                     head_detail_name tail_detail_name  \
# 0                                  Protein eyes shut            brain
# 1  Ferritin heavy chain {ECO:0000303|PubMed:9266686}            brain
# 2  Enoyl-[acyl-carrier-protein] reductase, mitoch...            brain
#
#                    species
# 0  Drosophila melanogaster
# 1  Drosophila melanogaster
# 2  Drosophila melanogaster

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type           170                   0             170
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# kg_type                   0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# species                   0                   0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {''} kg_source
#     170
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Aging'} kg_type
# Aging    170
# Name: count, dtype: int64

# %%
# ! mkdir Drosophila_protein_tissue

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 170 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_protein_tissue/Drosophila_protein_tissue.csv

# %%
#
