# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Drosophila_gene_molecularfunction
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_gene_molecularfunction/Drosophila_gene_molecularfunction.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]

# %%
#

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Drosophila/Gene_Droso_MolecularFunction.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'

monarch['species'] = 'D.melanogaster'
monarch['head_id_is'] = 'NCBI_ID'
monarch['tail_id_is'] = 'Quick_GO'
print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 38,402 rows
#           head                relation        tail head_type relation_type  \
# 0      CG12725  Gene_MolecularFunction  GO:0003735      Gene       enables
# 1      CG13623  Gene_MolecularFunction  GO:0051539      Gene       enables
# 2      CG14250  Gene_MolecularFunction  GO:0008010      Gene       enables
# 3      CG15864  Gene_MolecularFunction  GO:0004656      Gene       enables
# 4       CG4661  Gene_MolecularFunction  GO:0097602      Gene       enables
# ...        ...                     ...         ...       ...           ...
# 38730  CG13225  Gene_MolecularFunction  GO:0004984      Gene       enables
# 38731   CG6057  Gene_MolecularFunction  GO:0003677      Gene       enables
# 38732  CG42258  Gene_MolecularFunction  GO:0004402      Gene       enables
# 38733   CG5682  Gene_MolecularFunction  GO:0004571      Gene       enables
# 38734   CG2331  Gene_MolecularFunction  GO:0031593      Gene       enables
#
#                tail_type     relation_source  \
# 0      MolecularFunction  infores:go-central
# 1      MolecularFunction  infores:go-central
# 2      MolecularFunction  infores:go-central
# 3      MolecularFunction  infores:go-central
# 4      MolecularFunction  infores:go-central
# ...                  ...                 ...
# 38730  MolecularFunction  infores:go-central
# 38731  MolecularFunction  infores:go-central
# 38732  MolecularFunction  infores:go-central
# 38733  MolecularFunction  infores:go-central
# 38734  MolecularFunction  infores:go-central
#
#                                         head_detail_name  \
# 0                                uncharacterized protein
# 1                                uncharacterized protein
# 2                                               TweedleQ
# 3                                uncharacterized protein
# 4                                uncharacterized protein
# ...                                                  ...
# 38730                               Odorant receptor 47a
# 38731            Structural maintenance of chromosomes 1
# 38732                            uncharacterized protein
# 38733  ER degradation enhancer, mannosidase alpha-like 2
# 38734              Transitional endoplasmic reticulum 94
#
#                                         tail_detail_name  \
# 0                     structural constituent of ribosome
# 1                       4 iron, 4 sulfur cluster binding
# 2      structural constituent of chitin-based larval ...
# 3             procollagen-proline 4-dioxygenase activity
# 4                          cullin family protein binding
# ...                                                  ...
# 38730                        olfactory receptor activity
# 38731                                        DNA binding
# 38732                 histone acetyltransferase activity
# 38733  mannosyl-oligosaccharide 1,2-alpha-mannosidase...
# 38734  polyubiquitin modification-dependent protein b...
#
#                head_taxon_name  tail_taxon_name head_id_is tail_id_is  \
# 0      Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 1      Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 2      Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 3      Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 4      Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# ...                        ...              ...        ...        ...
# 38730  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 38731  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 38732  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 38733  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
# 38734  Drosophila melanogaster              NaN    NCBI_ID   Quick_GO
#
#       head_name         species      kg_type   kg_source
# 0       CG12725  D.melanogaster  Generalised  Monarch_KG
# 1       CG13623  D.melanogaster  Generalised  Monarch_KG
# 2         TwdlQ  D.melanogaster  Generalised  Monarch_KG
# 3       CG15864  D.melanogaster  Generalised  Monarch_KG
# 4        CG4661  D.melanogaster  Generalised  Monarch_KG
# ...         ...             ...          ...         ...
# 38730     Or47a  D.melanogaster  Generalised  Monarch_KG
# 38731      SMC1  D.melanogaster  Generalised  Monarch_KG
# 38732   CG42258  D.melanogaster  Generalised  Monarch_KG
# 38733     Edem2  D.melanogaster  Generalised  Monarch_KG
# 38734     TER94  D.melanogaster  Generalised  Monarch_KG
#
# [38402 rows x 17 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 38,402
#           head                relation        tail head_type relation_type  \
# 0      CG12725  Gene_MolecularFunction  GO:0003735      Gene       enables
# 1      CG13623  Gene_MolecularFunction  GO:0051539      Gene       enables
# 2      CG14250  Gene_MolecularFunction  GO:0008010      Gene       enables
# 3      CG15864  Gene_MolecularFunction  GO:0004656      Gene       enables
# 4       CG4661  Gene_MolecularFunction  GO:0097602      Gene       enables
# ...        ...                     ...         ...       ...           ...
# 38397  CG13225  Gene_MolecularFunction  GO:0004984      Gene       enables
# 38398   CG6057  Gene_MolecularFunction  GO:0003677      Gene       enables
# 38399  CG42258  Gene_MolecularFunction  GO:0004402      Gene       enables
# 38400   CG5682  Gene_MolecularFunction  GO:0004571      Gene       enables
# 38401   CG2331  Gene_MolecularFunction  GO:0031593      Gene       enables
#
#                tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0      MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 1      MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 2      MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 3      MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 4      MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# ...                  ...         ...          ...        ...        ...
# 38397  MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 38398  MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 38399  MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 38400  MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 38401  MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
#
#                                         head_detail_name  \
# 0                                uncharacterized protein
# 1                                uncharacterized protein
# 2                                               TweedleQ
# 3                                uncharacterized protein
# 4                                uncharacterized protein
# ...                                                  ...
# 38397                               Odorant receptor 47a
# 38398            Structural maintenance of chromosomes 1
# 38399                            uncharacterized protein
# 38400  ER degradation enhancer, mannosidase alpha-like 2
# 38401              Transitional endoplasmic reticulum 94
#
#                                         tail_detail_name         species
# 0                     structural constituent of ribosome  D.melanogaster
# 1                       4 iron, 4 sulfur cluster binding  D.melanogaster
# 2      structural constituent of chitin-based larval ...  D.melanogaster
# 3             procollagen-proline 4-dioxygenase activity  D.melanogaster
# 4                          cullin family protein binding  D.melanogaster
# ...                                                  ...             ...
# 38397                        olfactory receptor activity  D.melanogaster
# 38398                                        DNA binding  D.melanogaster
# 38399                 histone acetyltransferase activity  D.melanogaster
# 38400  mannosyl-oligosaccharide 1,2-alpha-mannosidase...  D.melanogaster
# 38401  polyubiquitin modification-dependent protein b...  D.melanogaster
#
# [38402 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'Gene_MolecularFunction'}
# head_type           : {'Gene'}
# tail_type           : {'MolecularFunction'}
# relation_type       : {'contributes_to', 'enables'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'NCBI_ID'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 38,402 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
genDR_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_genDR_count": genDR_nan,
    'Total_NaN_like':     true_nan + genDR_nan
})
# Out:
#                   NaN_count  'NAN'_genDR_count  Total_NaN_like
# head                      0                  0               0
# relation                  0                  0               0
# tail                      0                  0               0
# head_type                 0                  0               0
# relation_type             0                  0               0
# tail_type                 0                  0               0
# kg_source                 0                  0               0
# kg_type                   0                  0               0
# head_id_is                0                  0               0
# tail_id_is                0                  0               0
# head_detail_name          0                  0               0
# tail_detail_name          0                  0               0
# species                   0                  0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 38,402  |  After dedup: 25,935
#   head                relation        tail head_type relation_type  \
# 0    -  Gene_MolecularFunction  GO:0000981      Gene       enables
# 1    -  Gene_MolecularFunction  GO:0003674      Gene       enables
# 2    -  Gene_MolecularFunction  GO:0003725      Gene       enables
#
#            tail_type   kg_source      kg_type head_id_is tail_id_is  \
# 0  MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 1  MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
# 2  MolecularFunction  Monarch_KG  Generalised    NCBI_ID   Quick_GO
#
#   head_detail_name                                   tail_detail_name
# 0  lethal (1) XG10  DNA-binding transcription factor activity, RNA...
# 1  lethal (1) XG10                                 molecular_function
# 2  lethal (1) XG10                        double-stranded RNA binding

# %%
true_nan   = final_df_dedup.isna().sum()
genDR_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_genDR_count": genDR_nan,
    'Total_NaN_like':     true_nan + genDR_nan
})
# Out:
#                   NaN_count  'NAN'_genDR_count  Total_NaN_like
# head                      0                  0               0
# relation                  0                  0               0
# tail                      0                  0               0
# head_type                 0                  0               0
# relation_type             0                  0               0
# tail_type                 0                  0               0
# kg_source                 0                  0               0
# kg_type                   0                  0               0
# head_id_is                0                  0               0
# tail_id_is                0                  0               0
# head_detail_name          0                  0               0
# tail_detail_name          0                  0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    25935
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    25935
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 25,935 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_gene_molecularfunction/Drosophila_gene_molecularfunction.csv

# %%
#
