# %%
import pandas as pd
import numpy as np
import glob
import os
from tqdm import tqdm

# %%
# !pwd
# Out:
# /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila

# %%
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
MAPPING_DIR  = BASE_DIR + 'data_collection/databases_for_mapping/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
# !mkdir Drosophila_anatomy_cellcomponent
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_anatomy_cellcomponent/Drosophila_anatomy_cellcomp.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'kg_type',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'species'
]
# Out:
# mkdir: cannot create directory ‘Drosophila_anatomy_cellcomponent’: File exists

# %%
#

# %% [markdown]
# # monarch

# %%
monarch = pd.read_csv(PROC_DIR + 'Monarch/Monarch_final/Drosophila/Droso_AnatomicalEntity_CellularComponent.csv')

monarch.columns = monarch.columns.str.lower()
monarch = monarch[~monarch['head'].isna()]
monarch['kg_type'] = 'Generalised'
monarch['kg_source'] = 'Monarch_KG'
monarch['relation'] = 'AnatomicalEntity_CellularComponent'
monarch['head_type'] = 'AnatomicalEntity'

monarch['species'] = 'D.melanogaster'
monarch['head_id_is'] = 'FlyBase'
monarch['tail_id_is'] = 'Quick_GO'
print(f"monarch: {len(monarch):,} rows")
monarch
# Out:
# monarch: 2,766 rows
#               head                            relation        tail  \
# 0     WBbt:0001001  AnatomicalEntity_CellularComponent  GO:0005634
# 1     WBbt:0001002  AnatomicalEntity_CellularComponent  GO:0005634
# 2     WBbt:0001003  AnatomicalEntity_CellularComponent  GO:0005634
# 3     WBbt:0001004  AnatomicalEntity_CellularComponent  GO:0005634
# 4     WBbt:0001005  AnatomicalEntity_CellularComponent  GO:0005634
# ...            ...                                 ...         ...
# 2761  WBbt:0008067  AnatomicalEntity_CellularComponent  GO:0005634
# 2762  WBbt:0008615  AnatomicalEntity_CellularComponent  GO:0005634
# 2763  WBbt:0008616  AnatomicalEntity_CellularComponent  GO:0005634
# 2764  WBbt:0008617  AnatomicalEntity_CellularComponent  GO:0005634
# 2765  WBbt:0008618  AnatomicalEntity_CellularComponent  GO:0005634
#
#              head_type relation_type          tail_type relation_source  \
# 0     AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# 1     AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# 2     AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# 3     AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# 4     AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# ...                ...           ...                ...             ...
# 2761  AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# 2762  AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# 2763  AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# 2764  AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
# 2765  AnatomicalEntity   subclass_of  CellularComponent    infores:wbbt
#
#           head_detail_name tail_detail_name          head_taxon_name  \
# 0               AB nucleus          nucleus  Drosophila melanogaster
# 1              ABa nucleus          nucleus  Drosophila melanogaster
# 2             ABal nucleus          nucleus  Drosophila melanogaster
# 3            ABala nucleus          nucleus  Drosophila melanogaster
# 4           ABalaa nucleus          nucleus  Drosophila melanogaster
# ...                    ...              ...                      ...
# 2761          Z1.a nucleus          nucleus  Drosophila melanogaster
# 2762  ABplpaapapaa nucleus          nucleus  Drosophila melanogaster
# 2763  ABplpaapapap nucleus          nucleus  Drosophila melanogaster
# 2764  ABprpaapapap nucleus          nucleus  Drosophila melanogaster
# 2765  ABprpaapapaa nucleus          nucleus  Drosophila melanogaster
#
#       tail_taxon_name head_id_is tail_id_is         species      kg_type  \
# 0                 NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# 1                 NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# 2                 NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# 3                 NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# 4                 NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# ...               ...        ...        ...             ...          ...
# 2761              NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# 2762              NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# 2763              NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# 2764              NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
# 2765              NaN    FlyBase   Quick_GO  D.melanogaster  Generalised
#
#        kg_source
# 0     Monarch_KG
# 1     Monarch_KG
# 2     Monarch_KG
# 3     Monarch_KG
# 4     Monarch_KG
# ...          ...
# 2761  Monarch_KG
# 2762  Monarch_KG
# 2763  Monarch_KG
# 2764  Monarch_KG
# 2765  Monarch_KG
#
# [2766 rows x 16 columns]

# %% [markdown]
# # Consolidate into Unified Schem

# %%
# List all source DataFrames to include
source_dfs = [
    monarch
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 2,766
#               head                            relation        tail  \
# 0     WBbt:0001001  AnatomicalEntity_CellularComponent  GO:0005634
# 1     WBbt:0001002  AnatomicalEntity_CellularComponent  GO:0005634
# 2     WBbt:0001003  AnatomicalEntity_CellularComponent  GO:0005634
# 3     WBbt:0001004  AnatomicalEntity_CellularComponent  GO:0005634
# 4     WBbt:0001005  AnatomicalEntity_CellularComponent  GO:0005634
# ...            ...                                 ...         ...
# 2761  WBbt:0008067  AnatomicalEntity_CellularComponent  GO:0005634
# 2762  WBbt:0008615  AnatomicalEntity_CellularComponent  GO:0005634
# 2763  WBbt:0008616  AnatomicalEntity_CellularComponent  GO:0005634
# 2764  WBbt:0008617  AnatomicalEntity_CellularComponent  GO:0005634
# 2765  WBbt:0008618  AnatomicalEntity_CellularComponent  GO:0005634
#
#              head_type relation_type          tail_type   kg_source  \
# 0     AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# 1     AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# 2     AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# 3     AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# 4     AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# ...                ...           ...                ...         ...
# 2761  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# 2762  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# 2763  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# 2764  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
# 2765  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG
#
#           kg_type head_id_is tail_id_is      head_detail_name  \
# 0     Generalised    FlyBase   Quick_GO            AB nucleus
# 1     Generalised    FlyBase   Quick_GO           ABa nucleus
# 2     Generalised    FlyBase   Quick_GO          ABal nucleus
# 3     Generalised    FlyBase   Quick_GO         ABala nucleus
# 4     Generalised    FlyBase   Quick_GO        ABalaa nucleus
# ...           ...        ...        ...                   ...
# 2761  Generalised    FlyBase   Quick_GO          Z1.a nucleus
# 2762  Generalised    FlyBase   Quick_GO  ABplpaapapaa nucleus
# 2763  Generalised    FlyBase   Quick_GO  ABplpaapapap nucleus
# 2764  Generalised    FlyBase   Quick_GO  ABprpaapapap nucleus
# 2765  Generalised    FlyBase   Quick_GO  ABprpaapapaa nucleus
#
#      tail_detail_name         species
# 0             nucleus  D.melanogaster
# 1             nucleus  D.melanogaster
# 2             nucleus  D.melanogaster
# 3             nucleus  D.melanogaster
# 4             nucleus  D.melanogaster
# ...               ...             ...
# 2761          nucleus  D.melanogaster
# 2762          nucleus  D.melanogaster
# 2763          nucleus  D.melanogaster
# 2764          nucleus  D.melanogaster
# 2765          nucleus  D.melanogaster
#
# [2766 rows x 13 columns]

# %% [markdown]
# # Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'AnatomicalEntity_CellularComponent'}
# head_type           : {'AnatomicalEntity'}
# tail_type           : {'CellularComponent'}
# relation_type       : {'subclass_of'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'FlyBase'}
# tail_id_is          : {'Quick_GO'}

# %%
# Step 4: drop unresolvable rows
before = len(final_df)
final_df = final_df[~final_df['tail_detail_name'].isna()].reset_index(drop=True)
print(f"Dropped {before - len(final_df):,} unresolvable rows → {len(final_df):,} remaining")
# Out:
# Dropped 0 unresolvable rows → 2,766 remaining

# %% [markdown]
# # NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
genDR_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_genDR_count": genDR_nan,
    'Total_NaN_like':     true_nan + genDR_nan
})
# Out:
#                   NaN_count  'NAN'_genDR_count  Total_NaN_like
# head                      0                  0               0
# relation                  0                  0               0
# tail                      0                  0               0
# head_type                 0                  0               0
# relation_type             0                  0               0
# tail_type                 0                  0               0
# kg_source                 0                  0               0
# kg_type                   0                  0               0
# head_id_is                0                  0               0
# tail_id_is                0                  0               0
# head_detail_name          0                  0               0
# tail_detail_name          0                  0               0
# species                   0                  0               0

# %% [markdown]
# # Deduplication

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'kg_type':          merge_sources,   # ← changed from 'first'
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first'
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 2,766  |  After dedup: 2,766
#            head                            relation        tail  \
# 0  WBbt:0001001  AnatomicalEntity_CellularComponent  GO:0005634
# 1  WBbt:0001002  AnatomicalEntity_CellularComponent  GO:0005634
# 2  WBbt:0001003  AnatomicalEntity_CellularComponent  GO:0005634
#
#           head_type relation_type          tail_type   kg_source      kg_type  \
# 0  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG  Generalised
# 1  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG  Generalised
# 2  AnatomicalEntity   subclass_of  CellularComponent  Monarch_KG  Generalised
#
#   head_id_is tail_id_is head_detail_name tail_detail_name
# 0    FlyBase   Quick_GO       AB nucleus          nucleus
# 1    FlyBase   Quick_GO      ABa nucleus          nucleus
# 2    FlyBase   Quick_GO     ABal nucleus          nucleus

# %%
true_nan   = final_df_dedup.isna().sum()
genDR_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_genDR_count": genDR_nan,
    'Total_NaN_like':     true_nan + genDR_nan
})
# Out:
#                   NaN_count  'NAN'_genDR_count  Total_NaN_like
# head                      0                  0               0
# relation                  0                  0               0
# tail                      0                  0               0
# head_type                 0                  0               0
# relation_type             0                  0               0
# tail_type                 0                  0               0
# kg_source                 0                  0               0
# kg_type                   0                  0               0
# head_id_is                0                  0               0
# tail_id_is                0                  0               0
# head_detail_name          0                  0               0
# tail_detail_name          0                  0               0

# %%
print("kg_source values present:", set(final_df_dedup['kg_source']), final_df_dedup['kg_source'].value_counts())
# Out:
# kg_source values present: {'Monarch_KG'} kg_source
# Monarch_KG    2766
# Name: count, dtype: int64

# %%
print("kg_source values present:", set(final_df_dedup['kg_type']), final_df_dedup['kg_type'].value_counts())
# Out:
# kg_source values present: {'Generalised'} kg_type
# Generalised    2766
# Name: count, dtype: int64

# %%
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 2,766 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/OTHER_SPECIES/Drosophila/Drosophila_anatomy_cellcomponent/Drosophila_anatomy_cellcomp.csv

# %%
#
