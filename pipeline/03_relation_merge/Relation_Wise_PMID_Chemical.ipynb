# %%
import os
import pandas as pd
import numpy as np

BASE_DIR   = '/storage/Arushi/090526_EvoAge/kg_formation/'
PROC_DIR   = BASE_DIR + 'processed_data/'
DB_DIR     = BASE_DIR + 'data_collection/databases_for_mapping/'

OUT_PATH   = BASE_DIR + 'processed_data_relation_wise_merge/generalised/PMID_CHEMICAL/ALL_PMID_CHEMICAL.parquet'

REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

# %% [markdown]
# ## 2. Load KG Sources

# %% [markdown]
# #### CKG

# %%
CKG = pd.read_csv(PROC_DIR + 'CKG/File_43_PMID_CHEMICAL_CKG.csv')
CKG
# Out:
#                    Head                  Relation      Tail Head_type  \
# 0         PMID:20398344  MENTIONED_IN_PUBLICATION   7045767      PMID
# 1         PMID:19399243  MENTIONED_IN_PUBLICATION   7045767      PMID
# 2         PMID:19783937  MENTIONED_IN_PUBLICATION   7045767      PMID
# 3         PMID:18555826  MENTIONED_IN_PUBLICATION   7045767      PMID
# 4         PMID:19300586  MENTIONED_IN_PUBLICATION   7045767      PMID
# ...                 ...                       ...       ...       ...
# 42809921  PMID:37652915  MENTIONED_IN_PUBLICATION  17754356      PMID
# 42809922  PMID:41260918  MENTIONED_IN_PUBLICATION  17754356      PMID
# 42809923  PMID:21980712  MENTIONED_IN_PUBLICATION  17754356      PMID
# 42809924  PMID:21701441  MENTIONED_IN_PUBLICATION  17754356      PMID
# 42809925   PMID:2055987  MENTIONED_IN_PUBLICATION  17754356      PMID
#
#          Tail_type KG_Source Tail_ID_IS  \
# 0             Drug       CKG    Pubchem
# 1             Drug       CKG    Pubchem
# 2             Drug       CKG    Pubchem
# 3             Drug       CKG    Pubchem
# 4             Drug       CKG    Pubchem
# ...            ...       ...        ...
# 42809921      Drug       CKG    Pubchem
# 42809922      Drug       CKG    Pubchem
# 42809923      Drug       CKG    Pubchem
# 42809924      Drug       CKG    Pubchem
# 42809925      Drug       CKG    Pubchem
#
#                                            Tail_detail_name Head_ID_IS
# 0          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# 1          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# 2          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# 3          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# 4          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# ...                                                     ...        ...
# 42809921  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
# 42809922  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
# 42809923  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
# 42809924  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
# 42809925  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
#
# [42809926 rows x 9 columns]

# %%
CKG.columns = CKG.columns.str.lower()
CKG['head_detail_name'] = ''
CKG['relation'] = 'PMID_ChemicalEntity'
CKG['tail_type'] = 'ChemicalEntity'
CKG['kg_type'] = 'Generalised'
CKG['kg_source'] = 'CKG'
CKG['species'] = 'Homo species'
CKG
# Out:
#                    head             relation      tail head_type  \
# 0         PMID:20398344  PMID_ChemicalEntity   7045767      PMID
# 1         PMID:19399243  PMID_ChemicalEntity   7045767      PMID
# 2         PMID:19783937  PMID_ChemicalEntity   7045767      PMID
# 3         PMID:18555826  PMID_ChemicalEntity   7045767      PMID
# 4         PMID:19300586  PMID_ChemicalEntity   7045767      PMID
# ...                 ...                  ...       ...       ...
# 42809921  PMID:37652915  PMID_ChemicalEntity  17754356      PMID
# 42809922  PMID:41260918  PMID_ChemicalEntity  17754356      PMID
# 42809923  PMID:21980712  PMID_ChemicalEntity  17754356      PMID
# 42809924  PMID:21701441  PMID_ChemicalEntity  17754356      PMID
# 42809925   PMID:2055987  PMID_ChemicalEntity  17754356      PMID
#
#                tail_type kg_source tail_id_is  \
# 0         ChemicalEntity       CKG    Pubchem
# 1         ChemicalEntity       CKG    Pubchem
# 2         ChemicalEntity       CKG    Pubchem
# 3         ChemicalEntity       CKG    Pubchem
# 4         ChemicalEntity       CKG    Pubchem
# ...                  ...       ...        ...
# 42809921  ChemicalEntity       CKG    Pubchem
# 42809922  ChemicalEntity       CKG    Pubchem
# 42809923  ChemicalEntity       CKG    Pubchem
# 42809924  ChemicalEntity       CKG    Pubchem
# 42809925  ChemicalEntity       CKG    Pubchem
#
#                                            tail_detail_name head_id_is  \
# 0          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# 1          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# 2          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# 3          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# 4          (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate   PubmedID
# ...                                                     ...        ...
# 42809921  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
# 42809922  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
# 42809923  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
# 42809924  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
# 42809925  (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...   PubmedID
#
#          head_detail_name      kg_type       species
# 0                          Generalised  Homo species
# 1                          Generalised  Homo species
# 2                          Generalised  Homo species
# 3                          Generalised  Homo species
# 4                          Generalised  Homo species
# ...                   ...          ...           ...
# 42809921                   Generalised  Homo species
# 42809922                   Generalised  Homo species
# 42809923                   Generalised  Homo species
# 42809924                   Generalised  Homo species
# 42809925                   Generalised  Homo species
#
# [42809926 rows x 12 columns]

# %%
SOURCE_DFS = [
              ('CKG', CKG)
             ]
for name, df in SOURCE_DFS:
    dupes = df.columns[df.columns.duplicated(keep=False)].unique().tolist()
    print(f"[{name}] {'duplicate columns: ' + str(dupes) if dupes else '✓ no duplicates'}")
# Out:
# [CKG] ✓ no duplicates

# %%
CONCAT_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name','kg_type', 'species'
]

df_list = []
for name, df in SOURCE_DFS:
    tmp = df.loc[:, ~df.columns.duplicated()].copy()
    for col in CONCAT_COLS:
        if col not in tmp.columns:
            tmp[col] = pd.NA
    df_list.append(tmp[CONCAT_COLS])

final_df = pd.concat(df_list, ignore_index=True)
print(f"Combined: {len(final_df):,} rows")
final_df
# Out:
# Combined: 42,809,926 rows
#                    head             relation      tail head_type  \
# 0         PMID:20398344  PMID_ChemicalEntity   7045767      PMID
# 1         PMID:19399243  PMID_ChemicalEntity   7045767      PMID
# 2         PMID:19783937  PMID_ChemicalEntity   7045767      PMID
# 3         PMID:18555826  PMID_ChemicalEntity   7045767      PMID
# 4         PMID:19300586  PMID_ChemicalEntity   7045767      PMID
# ...                 ...                  ...       ...       ...
# 42809921  PMID:37652915  PMID_ChemicalEntity  17754356      PMID
# 42809922  PMID:41260918  PMID_ChemicalEntity  17754356      PMID
# 42809923  PMID:21980712  PMID_ChemicalEntity  17754356      PMID
# 42809924  PMID:21701441  PMID_ChemicalEntity  17754356      PMID
# 42809925   PMID:2055987  PMID_ChemicalEntity  17754356      PMID
#
#          relation_type       tail_type kg_source head_id_is tail_id_is  \
# 0                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 1                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 2                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 3                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 4                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# ...                ...             ...       ...        ...        ...
# 42809921          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42809922          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42809923          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42809924          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42809925          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
#
#          head_detail_name                                   tail_detail_name  \
# 0                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 1                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 2                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 3                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 4                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# ...                   ...                                                ...
# 42809921                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42809922                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42809923                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42809924                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42809925                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
#
#               kg_type       species
# 0         Generalised  Homo species
# 1         Generalised  Homo species
# 2         Generalised  Homo species
# 3         Generalised  Homo species
# 4         Generalised  Homo species
# ...               ...           ...
# 42809921  Generalised  Homo species
# 42809922  Generalised  Homo species
# 42809923  Generalised  Homo species
# 42809924  Generalised  Homo species
# 42809925  Generalised  Homo species
#
# [42809926 rows x 13 columns]

# %%
final_df = final_df[~final_df['tail_detail_name'].isna()]
final_df
# Out:
#                    head             relation      tail head_type  \
# 0         PMID:20398344  PMID_ChemicalEntity   7045767      PMID
# 1         PMID:19399243  PMID_ChemicalEntity   7045767      PMID
# 2         PMID:19783937  PMID_ChemicalEntity   7045767      PMID
# 3         PMID:18555826  PMID_ChemicalEntity   7045767      PMID
# 4         PMID:19300586  PMID_ChemicalEntity   7045767      PMID
# ...                 ...                  ...       ...       ...
# 42809921  PMID:37652915  PMID_ChemicalEntity  17754356      PMID
# 42809922  PMID:41260918  PMID_ChemicalEntity  17754356      PMID
# 42809923  PMID:21980712  PMID_ChemicalEntity  17754356      PMID
# 42809924  PMID:21701441  PMID_ChemicalEntity  17754356      PMID
# 42809925   PMID:2055987  PMID_ChemicalEntity  17754356      PMID
#
#          relation_type       tail_type kg_source head_id_is tail_id_is  \
# 0                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 1                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 2                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 3                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 4                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# ...                ...             ...       ...        ...        ...
# 42809921          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42809922          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42809923          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42809924          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42809925          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
#
#          head_detail_name                                   tail_detail_name  \
# 0                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 1                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 2                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 3                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 4                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# ...                   ...                                                ...
# 42809921                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42809922                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42809923                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42809924                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42809925                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
#
#               kg_type       species
# 0         Generalised  Homo species
# 1         Generalised  Homo species
# 2         Generalised  Homo species
# 3         Generalised  Homo species
# 4         Generalised  Homo species
# ...               ...           ...
# 42809921  Generalised  Homo species
# 42809922  Generalised  Homo species
# 42809923  Generalised  Homo species
# 42809924  Generalised  Homo species
# 42809925  Generalised  Homo species
#
# [42795681 rows x 13 columns]

# %%
import pandas as pd
import numpy as np

# Vectorized hash using numpy — avoids Python string ops entirely
keys = (
    pd.util.hash_array(final_df['head'].to_numpy()) ^
    pd.util.hash_array(final_df['relation'].to_numpy()) * 2654435761 ^
    pd.util.hash_array(final_df['tail'].to_numpy()) * 40503
)

# Keep first occurrence of each hash
mask = ~pd.Series(keys).duplicated(keep='first').to_numpy()
final_df = final_df.iloc[mask].reset_index(drop=True)

print(f"After dedup: {len(final_df):,} rows")
final_df
# Out:
# After dedup: 42,795,681 rows
#                    head             relation      tail head_type  \
# 0         PMID:20398344  PMID_ChemicalEntity   7045767      PMID
# 1         PMID:19399243  PMID_ChemicalEntity   7045767      PMID
# 2         PMID:19783937  PMID_ChemicalEntity   7045767      PMID
# 3         PMID:18555826  PMID_ChemicalEntity   7045767      PMID
# 4         PMID:19300586  PMID_ChemicalEntity   7045767      PMID
# ...                 ...                  ...       ...       ...
# 42795676  PMID:37652915  PMID_ChemicalEntity  17754356      PMID
# 42795677  PMID:41260918  PMID_ChemicalEntity  17754356      PMID
# 42795678  PMID:21980712  PMID_ChemicalEntity  17754356      PMID
# 42795679  PMID:21701441  PMID_ChemicalEntity  17754356      PMID
# 42795680   PMID:2055987  PMID_ChemicalEntity  17754356      PMID
#
#          relation_type       tail_type kg_source head_id_is tail_id_is  \
# 0                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 1                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 2                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 3                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 4                 <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# ...                ...             ...       ...        ...        ...
# 42795676          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42795677          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42795678          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42795679          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
# 42795680          <NA>  ChemicalEntity       CKG   PubmedID    Pubchem
#
#          head_detail_name                                   tail_detail_name  \
# 0                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 1                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 2                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 3                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# 4                           (3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate
# ...                   ...                                                ...
# 42795676                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42795677                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42795678                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42795679                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
# 42795680                   (1S,2S,5R,7S,9S,10S,14R,15S,19S)-15-[(2R,5S,6R...
#
#               kg_type       species
# 0         Generalised  Homo species
# 1         Generalised  Homo species
# 2         Generalised  Homo species
# 3         Generalised  Homo species
# 4         Generalised  Homo species
# ...               ...           ...
# 42795676  Generalised  Homo species
# 42795677  Generalised  Homo species
# 42795678  Generalised  Homo species
# 42795679  Generalised  Homo species
# 42795680  Generalised  Homo species
#
# [42795681 rows x 13 columns]

# %%
os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)
final_df.to_parquet(OUT_PATH, index=False)
print(f"Saved {len(final_df):,} rows → {OUT_PATH}")
# Out:
# Saved 42,795,681 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/PMID_CHEMICAL/ALL_PMID_CHEMICAL.parquet

# %%
#
