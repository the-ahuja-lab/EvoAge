# %%
import os
import pandas as pd
import numpy as np

# %%
# ── Base directories ──────────────────────────────────────────────────────────
BASE_DIR   = '/storage/Arushi/090526_EvoAge/kg_formation/'
PROC_DIR   = BASE_DIR + 'processed_data/'
DB_DIR     = BASE_DIR + 'data_collection/databases_for_mapping/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH   = BASE_DIR + 'processed_data_relation_wise_merge/generalised/CHEMICAL_NOEFFECT_BIOLOGICALPROCESS/ALL_CHEMICAL_NOEFFECT_BIOLOGICALPROCESS_Human.parquet'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

# %%
# AgeXtend
AgeXtend_Human_Chem_noeffect_BioPro_1 = pd.read_csv(PROC_DIR + 'agextend_processed/CHEM_BioP_Hallmarks/All_Chemical_Noeffect_BioPro(Hallmarks).csv')
AgeXtend_Human_Chem_noeffect_BioPro_1.columns = AgeXtend_Human_Chem_noeffect_BioPro_1.columns.str.lower()
AgeXtend_Human_Chem_noeffect_BioPro_1.rename(columns={'relation_source': 'kg_source'}, inplace=True)
AgeXtend_Human_Chem_noeffect_BioPro_1['kg_type'] = 'Aging'
AgeXtend_Human_Chem_noeffect_BioPro_1['kg_source'] = 'AgeXtend'
AgeXtend_Human_Chem_noeffect_BioPro_1['species'] = 'Homo sapiens'
AgeXtend_Human_Chem_noeffect_BioPro_1
# Out:
#             head                                   relation        tail  \
# 0       49778107  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 1        2530863  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 2        4203055  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 3       49778108  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 4       49778109  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# ...          ...                                        ...         ...
# 642373  71717698  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
# 642374  71719512  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
# 642375  71720111  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
# 642376  71720112  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
# 642377  71720769  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
#
#              head_type          tail_type  \
# 0       ChemicalEntity  BiologicalProcess
# 1       ChemicalEntity  BiologicalProcess
# 2       ChemicalEntity  BiologicalProcess
# 3       ChemicalEntity  BiologicalProcess
# 4       ChemicalEntity  BiologicalProcess
# ...                ...                ...
# 642373  ChemicalEntity  BiologicalProcess
# 642374  ChemicalEntity  BiologicalProcess
# 642375  ChemicalEntity  BiologicalProcess
# 642376  ChemicalEntity  BiologicalProcess
# 642377  ChemicalEntity  BiologicalProcess
#
#                                          head_detail_name  \
# 0       3-[(4-acetamidophenyl)methyl-methylamino]-N-(3...
# 1       2-(4-cyanophenoxy)-N-[3-(2-oxopyrrolidin-1-yl)...
# 2       N-cyclohexyl-2-[[4-methyl-5-(trifluoromethyl)-...
# 3       5-[1-(4-phenylbutanoyl)piperidin-2-yl]-N-(pyri...
# 4       [(2S,6R)-4-benzyl-6-(6-pyrrolidin-1-ylpurin-9-...
# ...                                                   ...
# 642373  methyl (4R,5R)-5-[(1S,9R,10R)-3-hydroxy-4,12-d...
# 642374  methyl (4R,5R)-3-(4-bromophenyl)-5-[(1S,9R,10R...
# 642375  methyl (4R,5R)-3-(3-chlorophenyl)-5-[(1S,9R,10...
# 642376  methyl (4R,5R)-5-[(1S,9R,10R)-3-hydroxy-4,12-d...
# 642377  methyl (4R,5R)-3-(4-chlorophenyl)-5-[(1S,9R,10...
#
#                                           head_smile_name  \
# 0       CC1=C(N2C=C(C=CC2=N1)C(=O)NCCCN3C=CN=C3)N(C)CC...
# 1                C1CC(=O)N(C1)CCCNC(=O)COC2=CC=C(C=C2)C#N
# 2                    CN1C(=NN=C1SCC(=O)NC2CCCCC2)C(F)(F)F
# 3       C1CCN(C(C1)C2=CC(=NO2)C(=O)NCC3=CN=CC=C3)C(=O)...
# 4       CC(=O)OC[C@@H]1CN(C[C@@H](O1)N2C=NC3=C2N=CN=C3...
# ...                                                   ...
# 642373  CN1CC[C@]23CC(=O)C(=C[C@H]2[C@H]1CC4=C3C(=C(C=...
# 642374  CN1CC[C@]23CC(=O)C(=C[C@H]2[C@H]1CC4=C3C(=C(C=...
# 642375  CN1CC[C@]23CC(=O)C(=C[C@H]2[C@H]1CC4=C3C(=C(C=...
# 642376  CN1CC[C@]23CC(=O)C(=C[C@H]2[C@H]1CC4=C3C(=C(C=...
# 642377  CN1CC[C@]23CC(=O)C(=C[C@H]2[C@H]1CC4=C3C(=C(C=...
#
#                            tail_detail_name kg_source       species  \
# 0                 mitochondrial dysfunction  AgeXtend  Homo sapiens
# 1                 mitochondrial dysfunction  AgeXtend  Homo sapiens
# 2                 mitochondrial dysfunction  AgeXtend  Homo sapiens
# 3                 mitochondrial dysfunction  AgeXtend  Homo sapiens
# 4                 mitochondrial dysfunction  AgeXtend  Homo sapiens
# ...                                     ...       ...           ...
# 642373  altered intercellular communication  AgeXtend  Homo sapiens
# 642374  altered intercellular communication  AgeXtend  Homo sapiens
# 642375  altered intercellular communication  AgeXtend  Homo sapiens
# 642376  altered intercellular communication  AgeXtend  Homo sapiens
# 642377  altered intercellular communication  AgeXtend  Homo sapiens
#
#        head_id_is tail_id_is                         source kg_type
# 0         Pubchem   Quick_GO  AID_624263_datatable_inactive   Aging
# 1         Pubchem   Quick_GO  AID_624263_datatable_inactive   Aging
# 2         Pubchem   Quick_GO  AID_624263_datatable_inactive   Aging
# 3         Pubchem   Quick_GO  AID_624263_datatable_inactive   Aging
# 4         Pubchem   Quick_GO  AID_624263_datatable_inactive   Aging
# ...           ...        ...                            ...     ...
# 642373    Pubchem   Quick_GO  AID_736485_datatable_inactive   Aging
# 642374    Pubchem   Quick_GO  AID_736485_datatable_inactive   Aging
# 642375    Pubchem   Quick_GO  AID_736485_datatable_inactive   Aging
# 642376    Pubchem   Quick_GO  AID_736485_datatable_inactive   Aging
# 642377    Pubchem   Quick_GO  AID_736485_datatable_inactive   Aging
#
# [642378 rows x 14 columns]

# %%
SOURCE_DFS = [
    ('AgeXtend_Human_Chem_noeffect_BioPro_1', AgeXtend_Human_Chem_noeffect_BioPro_1),
]

for name, df in SOURCE_DFS:
    dupes = df.columns[df.columns.duplicated(keep=False)].unique().tolist()
    if dupes:
        print(f'\n[{name}] duplicate columns: {dupes}')
        for col in dupes:
            for i, (_, s) in enumerate(df.loc[:, df.columns == col].items()):
                print(f"  '{col}' occurrence {i} → sample: {s.dropna().head(3).tolist()}")
    else:
        print(f'[{name}] ✓ no duplicates')
# Out:
# [AgeXtend_Human_Chem_noeffect_BioPro_1] ✓ no duplicates

# %%
CONCAT_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source', 'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

df_list = []
for name, df in SOURCE_DFS:
    tmp = df.loc[:, ~df.columns.duplicated()].copy()
    for col in CONCAT_COLS:
        if col not in tmp.columns:
            tmp[col] = pd.NA
    df_list.append(tmp[CONCAT_COLS])

final_df = pd.concat(df_list, ignore_index=True)
print(f'Combined: {len(final_df):,} rows')
final_df
# Out:
# Combined: 642,378 rows
#             head                                   relation        tail  \
# 0       49778107  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 1        2530863  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 2        4203055  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 3       49778108  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 4       49778109  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# ...          ...                                        ...         ...
# 642373  71717698  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
# 642374  71719512  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
# 642375  71720111  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
# 642376  71720112  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
# 642377  71720769  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111118
#
#              head_type relation_type          tail_type kg_source head_id_is  \
# 0       ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 1       ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 2       ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 3       ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 4       ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# ...                ...           ...                ...       ...        ...
# 642373  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 642374  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 642375  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 642376  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
# 642377  ChemicalEntity          <NA>  BiologicalProcess  AgeXtend    Pubchem
#
#        tail_id_is                                   head_detail_name  \
# 0        Quick_GO  3-[(4-acetamidophenyl)methyl-methylamino]-N-(3...
# 1        Quick_GO  2-(4-cyanophenoxy)-N-[3-(2-oxopyrrolidin-1-yl)...
# 2        Quick_GO  N-cyclohexyl-2-[[4-methyl-5-(trifluoromethyl)-...
# 3        Quick_GO  5-[1-(4-phenylbutanoyl)piperidin-2-yl]-N-(pyri...
# 4        Quick_GO  [(2S,6R)-4-benzyl-6-(6-pyrrolidin-1-ylpurin-9-...
# ...           ...                                                ...
# 642373   Quick_GO  methyl (4R,5R)-5-[(1S,9R,10R)-3-hydroxy-4,12-d...
# 642374   Quick_GO  methyl (4R,5R)-3-(4-bromophenyl)-5-[(1S,9R,10R...
# 642375   Quick_GO  methyl (4R,5R)-3-(3-chlorophenyl)-5-[(1S,9R,10...
# 642376   Quick_GO  methyl (4R,5R)-5-[(1S,9R,10R)-3-hydroxy-4,12-d...
# 642377   Quick_GO  methyl (4R,5R)-3-(4-chlorophenyl)-5-[(1S,9R,10...
#
#                            tail_detail_name kg_type       species
# 0                 mitochondrial dysfunction   Aging  Homo sapiens
# 1                 mitochondrial dysfunction   Aging  Homo sapiens
# 2                 mitochondrial dysfunction   Aging  Homo sapiens
# 3                 mitochondrial dysfunction   Aging  Homo sapiens
# 4                 mitochondrial dysfunction   Aging  Homo sapiens
# ...                                     ...     ...           ...
# 642373  altered intercellular communication   Aging  Homo sapiens
# 642374  altered intercellular communication   Aging  Homo sapiens
# 642375  altered intercellular communication   Aging  Homo sapiens
# 642376  altered intercellular communication   Aging  Homo sapiens
# 642377  altered intercellular communication   Aging  Homo sapiens
#
# [642378 rows x 13 columns]

# %%
GROUP_COLS = ['head', 'relation', 'tail']

def merge_sources(x):
    return '::'.join(sorted(set(x.dropna())))

final_df_dedup = final_df.groupby(GROUP_COLS, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':         merge_sources,
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'kg_type': merge_sources,
    'species': 'first',
})
print(f'After deduplication: {len(final_df_dedup):,} rows')
final_df_dedup = final_df_dedup[REQUIRED_COLS]
final_df_dedup.head()
# Out:
# After deduplication: 642,378 rows
#    head                                   relation        tail  \
# 0     4  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111114
# 1     6  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 2    11  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111114
# 3    13  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111111
# 4    13  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111114
#
#         head_type relation_type          tail_type kg_source head_id_is  \
# 0  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 1  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 2  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 3  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 4  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
#
#   tail_id_is             head_detail_name           tail_detail_name kg_type  \
# 0   Quick_GO           1-aminopropan-2-ol       loss of proteostasis   Aging
# 1   Quick_GO  1-chloro-2,4-dinitrobenzene  mitochondrial dysfunction   Aging
# 2   Quick_GO           1,2-dichloroethane       loss of proteostasis   Aging
# 3   Quick_GO       1,2,4-trichlorobenzene        genomic instability   Aging
# 4   Quick_GO       1,2,4-trichlorobenzene       loss of proteostasis   Aging
#
#         species
# 0  Homo sapiens
# 1  Homo sapiens
# 2  Homo sapiens
# 3  Homo sapiens
# 4  Homo sapiens

# %%
def nan_summary(df):
    true_nan   = df.isna().sum()
    string_nan = df.apply(lambda c: c.astype(str).str.upper().eq('NAN').sum())
    return pd.DataFrame({
        'NaN_count':          true_nan,
        "'NAN'_string_count": string_nan,
        'Total_NaN_like':     true_nan + string_nan
    })

nan_summary(final_df_dedup)
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type        642378                   0          642378
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name        132                   0             132
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %%
final_df_dedup['head_species'] = 'Homo sapiens'
final_df_dedup['head_species'] = 'Homo sapiens'
final_df_dedup
# Out:
#              head                                   relation        tail  \
# 0               4  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111114
# 1               6  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 2              11  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111114
# 3              13  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111111
# 4              13  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111114
# ...           ...                                        ...         ...
# 642373  136153828  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 642374  136181841  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111116
# 642375  136185788  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111112
# 642376  136187687  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111112
# 642377  139971569  ChemicalEntity_NoEffect_BiologicalProcess  GO:1111111
#
#              head_type relation_type          tail_type kg_source head_id_is  \
# 0       ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 1       ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 2       ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 3       ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 4       ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# ...                ...           ...                ...       ...        ...
# 642373  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 642374  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 642375  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 642376  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
# 642377  ChemicalEntity          None  BiologicalProcess  AgeXtend    Pubchem
#
#        tail_id_is                                   head_detail_name  \
# 0        Quick_GO                                 1-aminopropan-2-ol
# 1        Quick_GO                        1-chloro-2,4-dinitrobenzene
# 2        Quick_GO                                 1,2-dichloroethane
# 3        Quick_GO                             1,2,4-trichlorobenzene
# 4        Quick_GO                             1,2,4-trichlorobenzene
# ...           ...                                                ...
# 642373   Quick_GO  3-[1-(2,6-dimethylphenyl)tetrazol-5-yl]-1H-ben...
# 642374   Quick_GO  6,6-dimethyl-3-[4-(trifluoromethyl)phenyl]-4H-...
# 642375   Quick_GO  N-(1,3-benzodioxol-5-yl)-2-[4-hydroxy-5-[(E)-i...
# 642376   Quick_GO  2-[4-hydroxy-5-[(Z)-(2-oxoquinolin-3-ylidene)m...
# 642377   Quick_GO       1-hydroxy-2-methyl-N,2-diphenylindol-3-imine
#
#                  tail_detail_name kg_type       species  head_species
# 0            loss of proteostasis   Aging  Homo sapiens  Homo sapiens
# 1       mitochondrial dysfunction   Aging  Homo sapiens  Homo sapiens
# 2            loss of proteostasis   Aging  Homo sapiens  Homo sapiens
# 3             genomic instability   Aging  Homo sapiens  Homo sapiens
# 4            loss of proteostasis   Aging  Homo sapiens  Homo sapiens
# ...                           ...     ...           ...           ...
# 642373  mitochondrial dysfunction   Aging  Homo sapiens  Homo sapiens
# 642374  mitochondrial dysfunction   Aging  Homo sapiens  Homo sapiens
# 642375         telomere attrition   Aging  Homo sapiens  Homo sapiens
# 642376         telomere attrition   Aging  Homo sapiens  Homo sapiens
# 642377        genomic instability   Aging  Homo sapiens  Homo sapiens
#
# [642378 rows x 14 columns]

# %%
os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)
final_df_dedup.to_parquet(OUT_PATH, index=False)
print(f'Saved {len(final_df_dedup):,} rows → {OUT_PATH}')
# Out:
# Saved 642,378 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/CHEMICAL_NOEFFECT_BIOLOGICALPROCESS/ALL_CHEMICAL_NOEFFECT_BIOLOGICALPROCESS_Human.parquet
