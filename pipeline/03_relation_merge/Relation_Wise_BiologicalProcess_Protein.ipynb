# %% [markdown]
# #

# %% [markdown]
# ## 0 · Imports & Base Paths

# %%
import pandas as pd
import os

# ── Base directories ──────────────────────────────────────────────────────────
BASE_DIR     = '/storage/Arushi/090526_EvoAge/kg_formation/'
PROC_DIR     = BASE_DIR + 'processed_data/'

# ── Output path ───────────────────────────────────────────────────────────────
OUT_PATH = BASE_DIR + 'processed_data_relation_wise_merge/generalised/BIOLOGICALPROCESS_Protein/ALL_BIOLOGICALPROCESS_Protein.csv'

# ── Required output schema ────────────────────────────────────────────────────
REQUIRED_COLS = [
    'head', 'relation', 'tail',
    'head_type', 'relation_type', 'tail_type',
    'kg_source',
    'head_id_is', 'tail_id_is',
    'head_detail_name', 'tail_detail_name', 'kg_type', 'species'
]

# %% [markdown]
# ## 1 · Load Source Files
#
# Each source DataFrame is loaded, columns lowercased, and `tail_id_is` / `head_id_is`
# set to the appropriate ID namespace (Quick_GO).

# %% [markdown]
# ### 1.1 Monarch

# %%
Monarch_BP_P = pd.read_csv(PROC_DIR + 'Monarch/Human/BiologicalProcess_Protein_Monarch.csv')
Monarch_BP_P.columns = Monarch_BP_P.columns.str.lower()
Monarch_BP_P.rename(columns={'head_name':'head_detail_name','tail_name':'tail_detail_name'}, inplace=True, errors='ignore')
Monarch_BP_P['tail_id_is'] = 'Quick_GO'
Monarch_BP_P['head_id_is'] = 'Quick_GO'
Monarch_BP_P['relation'] = 'BiologicalProcess_Protein'
Monarch_BP_P['head_type'] = 'BiologicalProcess'
Monarch_BP_P['tail_type'] = 'Protein'

Monarch_BP_P['kg_source'] = 'Monarch_KG'
Monarch_BP_P['kg_type'] = 'Generalised'
Monarch_BP_P['species'] = 'Homo sapiens'
print(f"Monarch BP→P: {len(Monarch_BP_P):,} rows")
Monarch_BP_P.head(3)
# Out:
# Monarch BP→P: 28 rows
#          head          tail relation_type relation_source   kgsource  \
# 0  GO:0061847  PR:000005110    related_to      infores:go  MonarchKG
# 1  GO:0070162  PR:000003777    related_to      infores:go  MonarchKG
# 2  GO:0070459  PR:000013246    related_to      infores:go  MonarchKG
#
#               head_detail_name          head_type head_id_is  head_taxon  \
# 0  response to cholecystokinin  BiologicalProcess   Quick_GO         NaN
# 1        adiponectin secretion  BiologicalProcess   Quick_GO         NaN
# 2          prolactin secretion  BiologicalProcess   Quick_GO         NaN
#
#    head_taxon_label  ... tail_taxon_label head_taxon_name tail_taxon_name  \
# 0               NaN  ...              NaN             NaN             NaN
# 1               NaN  ...              NaN             NaN             NaN
# 2               NaN  ...              NaN             NaN             NaN
#
#      head_type_clean  tail_type_clean                   relation  \
# 0  BiologicalProcess          Protein  BiologicalProcess_Protein
# 1  BiologicalProcess          Protein  BiologicalProcess_Protein
# 2  BiologicalProcess          Protein  BiologicalProcess_Protein
#
#    species_species   kg_source      kg_type       species
# 0              NaN  Monarch_KG  Generalised  Homo sapiens
# 1              NaN  Monarch_KG  Generalised  Homo sapiens
# 2              NaN  Monarch_KG  Generalised  Homo sapiens
#
# [3 rows x 24 columns]

# %% [markdown]
# ## 2 · Consolidate into Unified Schema
#
# All source DataFrames are aligned to `REQUIRED_COLS` (missing columns filled with `pd.NA`),
# then concatenated into `final_df`.

# %%
source_dfs = [
    Monarch_BP_P,
    
]

aligned = []
for df in source_dfs:
    df = df.copy()
    # Drop any duplicated columns that might have resulted from original CSVs
    df = df.loc[:, ~df.columns.duplicated()]
    for col in REQUIRED_COLS:
        if col not in df.columns:
            df[col] = None       
    aligned.append(df[REQUIRED_COLS])

final_df = pd.concat(aligned, ignore_index=True)
# final_df = final_df.dropna(subset=['head_detail_name', 'tail_detail_name']).reset_index(drop=True)
print(f"Consolidated rows: {len(final_df):,}")
final_df
# Out:
# Consolidated rows: 28
#           head                   relation          tail          head_type  \
# 0   GO:0061847  BiologicalProcess_Protein  PR:000005110  BiologicalProcess
# 1   GO:0070162  BiologicalProcess_Protein  PR:000003777  BiologicalProcess
# 2   GO:0070459  BiologicalProcess_Protein  PR:000013246  BiologicalProcess
# 3   GO:0099191  BiologicalProcess_Protein  PR:000004716  BiologicalProcess
# 4   GO:1901142  BiologicalProcess_Protein  PR:000009054  BiologicalProcess
# 5   GO:1901143  BiologicalProcess_Protein  PR:000009054  BiologicalProcess
# 6   GO:1904391  BiologicalProcess_Protein  PR:000005663  BiologicalProcess
# 7   GO:0002001  BiologicalProcess_Protein  PR:000013883  BiologicalProcess
# 8   GO:0002415  BiologicalProcess_Protein  PR:000012705  BiologicalProcess
# 9   GO:0003050  BiologicalProcess_Protein  PR:000011374  BiologicalProcess
# 10  GO:0007264  BiologicalProcess_Protein  PR:000000028  BiologicalProcess
# 11  GO:0008104  BiologicalProcess_Protein  PR:000000001  BiologicalProcess
# 12  GO:0010992  BiologicalProcess_Protein  PR:000035728  BiologicalProcess
# 13  GO:0016056  BiologicalProcess_Protein  PR:000001245  BiologicalProcess
# 14  GO:0016063  BiologicalProcess_Protein  PR:000001245  BiologicalProcess
# 15  GO:0016567  BiologicalProcess_Protein  PR:000035728  BiologicalProcess
# 16  GO:0019538  BiologicalProcess_Protein  PR:000000001  BiologicalProcess
# 17  GO:0030073  BiologicalProcess_Protein  PR:000009054  BiologicalProcess
# 18  GO:0030163  BiologicalProcess_Protein  PR:000000001  BiologicalProcess
# 19  GO:0032604  BiologicalProcess_Protein  PR:000005931  BiologicalProcess
# 20  GO:0032605  BiologicalProcess_Protein  PR:000008534  BiologicalProcess
# 21  GO:0032641  BiologicalProcess_Protein  PR:000002204  BiologicalProcess
# 22  GO:0032868  BiologicalProcess_Protein  PR:000009054  BiologicalProcess
# 23  GO:0033571  BiologicalProcess_Protein  PR:000009978  BiologicalProcess
# 24  GO:0033572  BiologicalProcess_Protein  PR:000001887  BiologicalProcess
# 25  GO:0034231  BiologicalProcess_Protein  PR:000008875  BiologicalProcess
# 26  GO:0042983  BiologicalProcess_Protein  PR:000004168  BiologicalProcess
# 27  GO:0045222  BiologicalProcess_Protein  PR:000001004  BiologicalProcess
#
#    relation_type tail_type   kg_source head_id_is tail_id_is  \
# 0     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 1     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 2     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 3     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 4     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 5     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 6     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 7     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 8     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 9     related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 10    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 11    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 12    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 13    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 14    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 15    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 16    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 17    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 18    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 19    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 20    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 21    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 22    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 23    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 24    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 25    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 26    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 27    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
#
#                                      head_detail_name  \
# 0                         response to cholecystokinin
# 1                               adiponectin secretion
# 2                                 prolactin secretion
# 3                    trans-synaptic signaling by BDNF
# 4                           insulin metabolic process
# 5                           insulin catabolic process
# 6             response to ciliary neurotrophic factor
# 7                   renin secretion into blood stream
# 8   immunoglobulin transcytosis in epithelial cell...
# 9   regulation of systemic arterial blood pressure...
# 10          small GTPase-mediated signal transduction
# 11                               protein localization
# 12                                ubiquitin recycling
# 13          G protein-coupled opsin signaling pathway
# 14                     rhodopsin biosynthetic process
# 15                             protein ubiquitination
# 16                          protein metabolic process
# 17                                  insulin secretion
# 18                          protein catabolic process
# 19  granulocyte macrophage colony-stimulating fact...
# 20                hepatocyte growth factor production
# 21                           lymphotoxin A production
# 22                                response to insulin
# 23                              lactoferrin transport
# 24                              transferrin transport
# 25               islet amyloid polypeptide processing
# 26     amyloid precursor protein biosynthetic process
# 27                           CD4 biosynthetic process
#
#                                     tail_detail_name      kg_type  \
# 0                                    cholecystokinin  Generalised
# 1                                        adiponectin  Generalised
# 2                                          prolactin  Generalised
# 3                  brain-derived neurotrophic factor  Generalised
# 4                   insulin gene translation product  Generalised
# 5                   insulin gene translation product  Generalised
# 6                        ciliary neurotrophic factor  Generalised
# 7                                              renin  Generalised
# 8                  polymeric immunoglobulin receptor  Generalised
# 9                          atrial natriuretic factor  Generalised
# 10                                      small GTPase  Generalised
# 11                                           protein  Generalised
# 12                                         ubiquitin  Generalised
# 13                                         rhodopsin  Generalised
# 14                                         rhodopsin  Generalised
# 15                                         ubiquitin  Generalised
# 16                                           protein  Generalised
# 17                  insulin gene translation product  Generalised
# 18                                           protein  Generalised
# 19  granulocyte-macrophage colony-stimulating factor  Generalised
# 20                          hepatocyte growth factor  Generalised
# 21                                 lymphotoxin-alpha  Generalised
# 22                  insulin gene translation product  Generalised
# 23                                  lactotransferrin  Generalised
# 24                                 melanotransferrin  Generalised
# 25                         islet amyloid polypeptide  Generalised
# 26                    amyloid-beta precursor protein  Generalised
# 27                                      CD4 molecule  Generalised
#
#          species
# 0   Homo sapiens
# 1   Homo sapiens
# 2   Homo sapiens
# 3   Homo sapiens
# 4   Homo sapiens
# 5   Homo sapiens
# 6   Homo sapiens
# 7   Homo sapiens
# 8   Homo sapiens
# 9   Homo sapiens
# 10  Homo sapiens
# 11  Homo sapiens
# 12  Homo sapiens
# 13  Homo sapiens
# 14  Homo sapiens
# 15  Homo sapiens
# 16  Homo sapiens
# 17  Homo sapiens
# 18  Homo sapiens
# 19  Homo sapiens
# 20  Homo sapiens
# 21  Homo sapiens
# 22  Homo sapiens
# 23  Homo sapiens
# 24  Homo sapiens
# 25  Homo sapiens
# 26  Homo sapiens
# 27  Homo sapiens

# %% [markdown]
# ## 3 · Sanity Check — Distinct Values

# %%
for col in ['relation', 'head_type', 'tail_type', 'relation_type', 'kg_source', 'head_id_is', 'tail_id_is']:
    print(f"{col:20s}: {set(final_df[col])}")
# Out:
# relation            : {'BiologicalProcess_Protein'}
# head_type           : {'BiologicalProcess'}
# tail_type           : {'Protein'}
# relation_type       : {'related_to'}
# kg_source           : {'Monarch_KG'}
# head_id_is          : {'Quick_GO'}
# tail_id_is          : {'Quick_GO'}

# %% [markdown]
# ## 4 · NaN Audit (pre-dedup)

# %%
true_nan   = final_df.isna().sum()
string_nan = final_df.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
})
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0

# %% [markdown]
# ## 5 · Deduplication
#
# Group on `(head, relation, tail)`. For `kg_source`, merge all unique sources with `::` delimiter.
# All other metadata columns take the first non-null value.

# %%
def merge_sources(x):
    """Combine unique, non-null source labels with '::' delimiter."""
    return '::'.join(sorted(set(x.dropna())))

group_cols = ['head', 'relation', 'tail']

final_df_dedup = final_df.groupby(group_cols, as_index=False).agg({
    'head_type':        'first',
    'relation_type':    'first',
    'tail_type':        'first',
    'kg_source':        merge_sources,
    'head_id_is':       'first',
    'tail_id_is':       'first',
    'head_detail_name': 'first',
    'tail_detail_name': 'first',
    'kg_type': 'first',
    'species': 'first'
    
})

print(f"Before dedup: {len(final_df):,}  |  After dedup: {len(final_df_dedup):,}")
final_df_dedup.head(3)
# Out:
# Before dedup: 28  |  After dedup: 28
#          head                   relation          tail          head_type  \
# 0  GO:0002001  BiologicalProcess_Protein  PR:000013883  BiologicalProcess
# 1  GO:0002415  BiologicalProcess_Protein  PR:000012705  BiologicalProcess
# 2  GO:0003050  BiologicalProcess_Protein  PR:000011374  BiologicalProcess
#
#   relation_type tail_type   kg_source head_id_is tail_id_is  \
# 0    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 1    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
# 2    related_to   Protein  Monarch_KG   Quick_GO   Quick_GO
#
#                                     head_detail_name  \
# 0                  renin secretion into blood stream
# 1  immunoglobulin transcytosis in epithelial cell...
# 2  regulation of systemic arterial blood pressure...
#
#                     tail_detail_name      kg_type       species
# 0                              renin  Generalised  Homo sapiens
# 1  polymeric immunoglobulin receptor  Generalised  Homo sapiens
# 2          atrial natriuretic factor  Generalised  Homo sapiens

# %% [markdown]
# ## 6 · Post-dedup NaN Audit & Source Distribution

# %%
true_nan   = final_df_dedup.isna().sum()
string_nan = final_df_dedup.apply(lambda col: col.astype(str).str.upper().eq('NAN').sum())

display(pd.DataFrame({
    'NaN_count':          true_nan,
    "'NAN'_string_count": string_nan,
    'Total_NaN_like':     true_nan + string_nan
}))

print("\nkg_source values present:", set(final_df_dedup['kg_source']), set(final_df_dedup['kg_type']))
# Out:
#                   NaN_count  'NAN'_string_count  Total_NaN_like
# head                      0                   0               0
# relation                  0                   0               0
# tail                      0                   0               0
# head_type                 0                   0               0
# relation_type             0                   0               0
# tail_type                 0                   0               0
# kg_source                 0                   0               0
# head_id_is                0                   0               0
# tail_id_is                0                   0               0
# head_detail_name          0                   0               0
# tail_detail_name          0                   0               0
# kg_type                   0                   0               0
# species                   0                   0               0
# kg_source values present: {'Monarch_KG'} {'Generalised'}

# %% [markdown]
# ## 7 · Save Output

# %%
import os
os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)
final_df_dedup.to_csv(OUT_PATH, index=False)
print(f"Saved {len(final_df_dedup):,} rows → {OUT_PATH}")
# Out:
# Saved 28 rows → /storage/Arushi/090526_EvoAge/kg_formation/processed_data_relation_wise_merge/generalised/BIOLOGICALPROCESS_Protein/ALL_BIOLOGICALPROCESS_Protein.csv
