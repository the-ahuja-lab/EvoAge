# %%
# AgeAnno

# !cd data_collection
# !mkdir ageanno
# !wget https://github.com/vikkihuangkexin/AgeAnno/archive/refs/heads/main.zip
# !unizp main.zip

# %%
# AgeAnnoMO

# !cd data_collection
# ! mkdir ageannomo
# !wget https://github.com/vikkihuangkexin/AgeAnnoMO/archive/refs/heads/main.zip
# !unzip main.zip

# %%
# Aging Bank
# https://bio-bigdata.hrbmu.edu.cn/AgingBank/download.html

# %%
# Aging Atlas

# manully exported from here https://ngdc.cncb.ac.cn/aging/index
# https://ngdc.cncb.ac.cn/aging/metabolomics
# https://ngdc.cncb.ac.cn/aging/aging-drugs
# https://ngdc.cncb.ac.cn/aging/age_related_genes

# %%
# CellAge

# https://genomics.senescence.info/cells/cellAge.zip
# unzip cellAge.zip

# %%
# Digital Aging Atlas

# https://ageing-map.org/static/downloads/digital_ageing_atlas_data.zip
# unzip digital_ageing_atlas_data.zip

# %%
# DrugAge

# ! wget https://genomics.senescence.info/drugs/dataset.zip 
# https://genomics.senescence.info/drugs/browse.php

# %%
# GenDR

# https://genomics.senescence.info/drugs/dataset.zip
# unzip dataset.zip

# %%
# GenAge
# ! wget https://genomics.senescence.info/genes/human_genes.zip
# ! wget https://genomics.senescence.info/genes/models_genes.zip

# %%
# Agingbank 

# https://bio-bigdata.hrbmu.edu.cn/AgingBank/download.html
# https://bio-bigdata.hrbmu.edu.cn/AgingBank/Download/all_experimentally%20supported%20associations.zip
# https://bio-bigdata.hrbmu.edu.cn/AgingBank/Download/human_experimentally%20supported%20associations.zip

# %%
# HALD
# https://figshare.com/articles/dataset/HALD_a_human_aging_and_longevity_knowledge_graph_for_precision_gerontology_and_geroscience_analyses/22828196/4

# %%
## hetionet
# !wget https://github.com/hetio/hetionet/archive/refs/heads/main.zip
# unzip main.zip
# cd /storage/Arushi/090526_EvoAge/kg_formation/data_collection/hetionet/hetionet-main/hetnet/tsv
# rm hetionet-v1.0-edges.sif.gz hetionet-v1.0-edges.sif
# wget --content-disposition \
#  "https://media.githubusercontent.com/media/hetio/hetionet/main/hetnet/tsv/hetionet-v1.0-edges.sif.gz"
# gunzip hetionet-v1.0-edges.sif.gz

# %%
## Monarch kg

# wget https://data.monarchinitiative.org/monarch-kg/latest/monarch-kg.tar.gz
# tar -xvzf monarch-kg.tar.gz

# %%
## PharmKG
# wget https://zenodo.org/records/4077338/files/raw_PharmKG-180k.zip?download=1
# unzip raw_PharmKG-180k.zip

# %%
## Primekg 

# wget -O kg.csv https://dataverse.harvard.edu/api/access/datafile/6180620

# %%
## DRKG

# wget https://dgl-data.s3-us-west-2.amazonaws.com/dataset/DRKG/drkg.tar.gz
# tar -xvzf drkg.tar.gz

# %%
## Biograkn

# wget https://github.com/typedb/biograkn/archive/refs/heads/master.zip
# Directly download https://github.com/typedb/biograkn/blob/master/diseasenetwork/dataset/dgidb/interactions.tsv

# %%
## CROssBAR

# wget https://github.com/cansyl/CROssBAR/archive/refs/heads/master.zip
# unzip master.zip

# %%
## GO to WID

# go to link provided download 
# Integrated Network file/data

# %%
## FIC
# wget http://worm.biomedtzc.cn/downloads/networks2.zip

# %%
## Flybase

# wget https://flybase.org/releases/FB2024_02/precomputed_files/alleles/genotype_phenotype_data_fb_2024_02.tsv.gz

# %%
# iBKH

# go to and dowlaod each file https://wcm.app.box.com/s/dcq6lj4vxzs4rnxu6xx60ziwl62qrzyp

# %%
# wget https://www.informatics.jax.org/downloads/reports/HMD_HumanPhenotype.rpt
# wget https://www.informatics.jax.org/downloads/reports/MGI_PhenoGenoMP.rpt

# %%
# MGI DO
https://www.informatics.jax.org/downloads/reports/index.html#pheno

# %%
# TarKG

# go to https://tarkg.ddtmlab.org/download and downlaod these files
# Gene_nodes.csv   TarKG_edges_mapping.csv  TarKG_nodes_mapping.csv
# TarKG_edges.csv  TarKG_nodes.csv

# %%
# Phytohub
# https://phytohub.eu/entries

# TTD
# https://ttd.idrblab.cn/files/download/P1-05-Drug_disease.txt

# IMMPAT
# https://cb.imsc.res.in/imppat/phytochemical/Abelmoschus%20esculentus

# Other Sources
# https://github.com/akshachrya/AyurvedicPlantClassifier/blob/main/data/english.xlsx
# https://github.com/alrichardbollans/PhytoChemicalDiversity/blob/master/collect_and_compile_data/collect_compound_data/outputs/all_species_compound_data.csv
# https://github.com/asgarhussain/phytochemicals/blob/main/phyto_chemicals.db
# https://github.com/kuralamuthan300/ayurvedic-medicine-catalogue/blob/master/Database.json
# https://github.com/petermr/CEVOpen/blob/master/Data%20Analysis/Plant_compound.csv
